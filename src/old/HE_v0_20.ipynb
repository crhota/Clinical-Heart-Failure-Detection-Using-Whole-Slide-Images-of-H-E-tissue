# %% [markdown]
# # Clinical Heart Failure Detection Using Whole-Slide Images of H&E tissue

# %% [markdown]
# ## Version

# %% [markdown]
# ### Version 0.20: Trying MobileNetV2
# - Commented MobileNet and called MobileNetV2 in model definition for Regular Run XFR/FT, CV Run  for XFR and CV Run for FT sections
# - Epochs = 1, CV = False, Dropout = 0.4
#   - XFR: Train / Val / Test Acc % = 59 / 75 / 67
#   - FT @ 80th Layer : Train / Val / Test Acc % = 69 / 69 / 65
# - Epochs = 100, CV = False, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 76.0 / 80.5 / 72.9
#   - FT @ 80th Layer
#     - Total/Trainable Params = ~4M / ~3.8M
#     - Train / Val / Test Acc % = 76.6 / 80.2 / 72.8
# - Epochs = 100, CV = False, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 72.4 / 80.0 / 71.6
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Train / Val / Test Acc % =  73.9 / 80.8 / 73.2
# - Epochs = 100, CV = False, Dropout = 0.6
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 76.3 / 80.5 / 70.3
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Train / Val / Test Acc % = 76.4 / 81.0 / 72.6
# - Epochs = 100, CV = True, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Validation Accuracy Mean (+/- Std Deviation): 77.03% (+/- 0.79%)
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Validation Accuracy Mean (+/- Std Deviation): 78.99% (+/- 1.06%)

# %% [markdown]
# ### Version 0.18-0.19:

# %% [markdown]
# - **0.18-0.19**:
#   - Implemented time function to calculate the desired time more precisely as the time from colab and verbose are not matching.
#   - XFR = Transfer Learning, FT = Fine tuning
#   - For Regular Run: Train & Test Acc is w.r.t. Best Val Accuracy.
#   - Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / 25M / 1M / 0.0021G
#       - Total params: 24,637,826, Trainable params: 1,050,114, Non-trainable params: 23,587,712
#     - Regular Run:
#       - Train Time (time / verbose) = 446.35871052742004s / 411s
#       - Test Time (time / verbose) = 4.191006660461426s / 4s
#       - Test Time / sample (time / verbose) = 0.0036285771952046975s / 0.00346s
#       - Train / Val / Test Acc % = 92.2 / 90.4 / 82.6
#     - CV:
#       - Validation Time (time) = 2644.3752892017365s
#       - Validation Accuracy Mean (+/- Std Deviation): 88.30% (+/- 0.80%)
#   - **MobileNet**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = 4.8M / 0.5M
#         - Total params: 4,767,402 , Trainable params: 513,538 , Non-trainable params: 4,253,864
#       - Regular Run:
#         - Train Time (time / verbose) = 162.90089511871338s / 202s
#         - Test Time (time / verbose) = 1.819808006286621s / 2s
#         - Test Time / sample (time / verbose) = 0.001575591347434304s / 0.00173s
#         - Train / Val / Test Acc % = 83.2 / 85.0 / 78.4
#       - CV:
#         - Validation Time (time) = 988.1067225933075s
#         - Validation Accuracy Mean (+/- Std Deviation): 78.03% (+/- 0.78%)
#     - **FT**
#       - Total Params / Trainable Params = 4.8M / 2.6M
#         - Total params: 4,767,402 , Trainable params: 2,600,426 , Non-trainable params: 2,166,976
#       - Regular Run:
#         - Train Time (time / verbose) = 160.71819162368774s / 200s
#         - Test Time (time / verbose) = 1.453615665435791s / 1s
#         - Test Time / sample (time / verbose) = 0.0012585417016760096s / 0.00087s
#         - Train / Val / Test Acc % = 84.8 / 89.6 / 83.6
#       - CV:
#         - Validation Time (time) = 992.2293410301208s
#         - Validation Accuracy Mean (+/- Std Deviation): 78.29% (+/- 1.35%)

# %% [markdown]
# ### Version 0.17:
# - **0.17**: run for Epoch = 100
#   - XFR = Transfer Learning, FT = Fine tuning
#   - For Regular Run: Train & Test Acc is w.r.t. Best Val Accuracy.
#   - Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / 25M / 1M / 0.0021G
#     - Regular Run:
#       - Train Time Verbose / Colab = 404s / 474.015s
#       - Test Time Verbose / Colab (1155 samples) = 4s / 490.921s ?
#       - Test Time per sample = 3.5ms / 425ms ?
#       - Train / Val / Test Acc % = 86.7 / 90.1 / 81.8
#     - CV:
#       - Validation Time (Colab) = 3030.406s
#       - Val Acc Mean (+/- Std Deviation): 87.86% (+/- 1.24%)
#   - **MobileNet**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = 5M / 0.5M
#       - Regular Run:
#         - Train Time Verbose / Colab =  202s / 3192.38s ?
#         - Test Time Verbose / Colab (1155 samples) = 1s / 3198.253s ?
#         - Test Time per sample = 0.87ms / 2.77s ?
#         - Train / Val / Test Acc % = 82.1 / 84.2 / 77.8
#       - CV:
#         - Validation Time (Colab) = 4169.914s
#         - Val Acc Mean (+/- Std Deviation): 78.34% (+/- 1.30%)
#     - **FT**
#       - Total Params / Trainable Params = 5M / 2.6M
#       - Regular Run:
#         - Train Time Verbose / Colab = 200s / 4328.194s ?
#         - Test Time Verbose / Colab (1155 samples) = 1s / 4333.798s ?
#         - Test Time per sample = 0.87ms / 3.75s ?
#         - Train / Val / Test Acc % = 82.6 / 89.3 / 84.9
#       - CV:
#         - Validation Time (Colab) = 5311.684s
#         - Val Acc Mean (+/- Std Deviation): 79.16% (+/- 1.23%)

# %% [markdown]
# ### Version 0.16
# - **0.16**
#   - Changed 'tf.keras.applications.mobilenet.MobileNet()' to 'mobilenet = tf.keras.applications.MobileNet()' to reconfirm using MobilenetV1
#   - mobilenet = tf.keras.applications.mobilenet.MobileNet()
#     - Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
#   - mobilenet = tf.keras.applications.MobileNet()
#     - Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
#   - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 61.2 / 74.3 / 73.3
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 77.90% (+/- 1.05%)
#   - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc = 70.1 / 76.5 / 74.0
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 76.69% (+/- 1.32%)
#   - MobileNet FineTune
#       - Regular Run: Train/Val/Test Acc = 76.4 / 80.5 / 76.5
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 77.77% (+/- 2.34%)

# %% [markdown]
# ### Version 0.15

# %% [markdown]
# - **0.15**: implemented flops
#     - ResNet50 Transfer - 0.0021G
#       - Regular Run: Train/Val/Test Acc = 59.5 / 73.5 / 71.0
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 79.34% (+/- 1.76%)
#     - MobileNet Transfer - 1.15G
#       - Regular Run: Train/Val/Test Acc =  71.0 / 82.4 / 75.6
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.03% (+/- 1.57%)
#     - MobileNet FineTune - 1.15G
#       - Regular Run: Train/Val/Test Acc =  76.9 / 83.2 / 77.1
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.16% (+/- 0.93%)
#
# - Note: XFR = Transfer Learning, FT = Fine tuning, Train & Test Acc is w.r.t. Best Val Accuracy. Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - Without cross-validation, with same hyper parameters, Test Accuracy/Total Params/Trainable Params/No. of Convolution Layers/FLOPS/Train Time/Test Time/Test Time per Sample
#     - Below is for Epoch = 100
#     - Resnet50 XFR (~81%/~25M/~1M/5 Conv/0.0021G/~300s/3s/~2.6ms)
#     - MobileNet XFR (~78%/~5M/~0.5M/13 Conv/1.15G/~200s/1s/~0.87ms)
#     - MobileNet FT (~79%/~5M/~2.6M/13 Conv/1.15G/~200s/1s/~0.87ms)
#   - With cross-validation, with same hyper parameters, Test Accuracy Mean +/- Std Dev/Total Params/Trainable Params/No. of Convolution Layers/FLOPS
#     - Below is for Epoch = 1, Cross Validation Folds = 4
#     - Resnet50 XFR (79.34% (+/- 1.76%)/~25M/~1M/5 Conv/0.0021G)
#     - MobileNet XFR (76.03% (+/- 1.57%)/~5M/~0.5M/13 Conv/1.15G)
#     - MobileNet FT (75.16% (+/- 0.93%)/~5M/~2.6M/13 Conv/1.15G)

# %% [markdown]
# ### Version 0.12-0.14 (Implemented Cross Validation for 1 Epoch, 4 Folds: Other hyperparameters same as in v0.11)

# %% [markdown]
# - **0.12**: rerun to baseline
# - **0.13**
#   - **epoch = 1, fold = 2**
#   - saved labels before conversion to categorical
#   - added code macros for cross validation = true, fold = 2
#   - added code for cross-validation for resnet50 transfer learning
#   - added code for cross-validation for mobilenet transfer learning
#   - ResNet50 Transfer
#     - Regular Run: Train/Val/Test Acc = 57.0 / 73.5 / 70.7
#     - CV Run: Validation Accuracy Mean (+/- Std Deviation): 74.64% (+/- 1.51%)
#   - MobileNet Transfer
#     - Regular Run: Train/Val/Test Acc = 69.1 / 77.3 / 74.5
#     - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.82% (+/- 0.27%)
# - **0.14**
#   - **epoch = 100, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 88.1 / 88.8 / 79
#       - CV Run: only for 1 fold ... 88.4 .. later I interrupted
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc .. later I interrupted
#       - CV Run: .. later I interrupted
#   - **epoch = 1, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc =  60.0 / 72.7 / 69.7
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 79.16% (+/- 2.54%)
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc =  71.6 / 80.5 / 74.8
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.64% (+/- 1.61%)
#     - MobileNet FineTune
#       - CV done before the regular run of train/val/test to ensure we use the weights from transfer and not from regular run of finetune.
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 77.82% (+/- 2.03%)
#       - Regular Run: Train/Val/Test Acc =  75.3 / 81.8 / 76.6
#   - Updated code to have separate checkpoint files for each model. Cross-validation of MobileNet FineTune Model uses MobileNet Transfer file for initialization.
#     - **epoch = 1, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 61.5 / 71.9 / 72.1
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 78.78% (+/- 3.65%)
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc = 68.0 / 81.3 / 75.6
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.64% (+/- 0.98%)
#     - MobileNet FineTune
#       - Regular Run: Train/Val/Test Acc = 74.6 / 81.8 / 76.9
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.03% (+/- 1.67%)

# %% [markdown]
# ### Version 0.11

# %% [markdown]
# - **0.11**
#   - As is Rerun
#     - Epoch = 100, Batchsize = 10, Learning Rate = 0.01, Neurons = 512, Dropout = 0.4. Train & Test Acc is w.r.t. Best Val Accuracy.
#     - ResNet50 (Transfer Learning) - 5 Convolution Layers
#       - Total/Trainable Params: 24.64M/1.05M
#       - Train + Validation Time: (8s x 1) + (3s x 99) = 305s
#       - Test Time: 3s, Test/sample = (3/1155)s = 0.0026s = 2.6ms
#       - Train/Val/Test Acc: 93.7 / 89.0 / 80.7
#     - MobileNet - 13 Convolution Layers
#       - Transfer Learning
#         - Total/Trainable Params: 4.77M/0.51M
#         - Train + Validation Time: (4s x 1) + (max 2s x 99) = 202s
#         - Test Time: 1s, Test/sample = (1/1155)s = 0.87ms
#         - Train/Val/Test Acc: 79.5 / 84.2 / 78.0
#       - Finetuning
#         - Total/Trainable Params: 4.77M/2.60M
#         - Train + Validation Time: (max 2s x 100) = 200s
#         - Test Time: 1s, Test/sample = (1/1155)s = 0.87ms
#         - Train/Val/Test Acc: 88.2 / 84.2 / 78.8

# %% [markdown]
# ### Version 0.10

# %% [markdown]
# - **0.10**
#   - Cleaned up indenting
#   - Added hyperparameter macros that can be used for all models
#     - ResNet50 was with 1024 neurons, 40% dropout
#     - MobileNet was with 512 neurons, 60% dropout.
#     - Made EPOCHS = 100, BATCH_SIZE = 10, LEARNING_RATE = 0.01, DENSE_LAYER_NEURONS = 512, DENSE_LAYER_DROPOUT = 0.4
#   - Implemented 'checkpoint' as a function to be used a callback by any model. Enabled callback for ResNet50
#   - Accuracy
#     - ResNet50 (XFR Learning): Best_Train/Best_Val/Test = 89.4 / 88.8 / 80.7
#     - MobileNet (XFR Learning): Best_Train/Best_Val/Test = 83.6 / 85.0 / 77.6
#     - MobileNet (Fine Tuning): Best_Train/Best_Val/Test = 86.9 / 84.0 / 77.7

# %% [markdown]
# ### Version 0.09

# %% [markdown]
# - **0.09** **MobileNet**
#   - **Epoch=100**: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 87.4/80.8/78.0
#   - Epoch=100: **Best Model**: Train/Val/Test Acc = 82.1/84.0/77.8
#   - **Epoch=200**: Best Model: Train/Val/Test Acc = 79.0/84.0/78.9
#   - **Epoch=100**: Best Model: **Regularizer: Kernel/Bias L2(0.01) for Dense(1024)**: Train/Val/Test Acc = 70.6/80.0/72.5
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias L2(0.01) for Dense(1024), **Dense(2)**: Train/Val/Test Acc = 69.0/78.3/72.6
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias **L1**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/**Activity L2**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = 68.1/79.1/72.4
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(0.2)** for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(1e-4/1e-4/1e-5)** for Dense(1024), Dense(2): Train/Val/Test Acc = 77.6/84.0/77.5 ... regularizer is not helping much ... revert to No Regularizer
#   - **Best Model**: **Epoch=100**: Train/Val/Test Acc = 81.5/84.5/77.8
#   - Best Model: **Epoch=1**: **Nottrainable/trainabele layers = 0-79/80-94**:  Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: **Epoch=100**: NonTrainable(MobileNet)+ Trainable(Dense(1024), Dropout, Dense(2)): Train/Val/Test Acc = 82.3/85/79
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.8/78.7
#   - Best Model: Epoch=100: **MobileNet NT till Conv13 (0-85), T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: MobileNet NT **till Conv12 (0-79)**, T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 88.5/85.0/77.7
#   - Best Model: Epoch=100: **NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet till <86) Trainable (86 and later = GAP...)+ Trainable(Dense(**512**), Dropout, Dense(2))**: Train/Val/Test Acc = 78.7/84.8/76.8 -> ../84.8/76.8
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.2/78.2 -> ../84.2/78.2
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 80.1/84.2/78.4 -> ../84.2/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> **Trainable(MobileNet till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 81.8/84.2/78.3 -> 86.2/84.5/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Params (Total/Trainable/Non-trainable)= 4,767,402 / 2,600,426 / 2,166,976: Train/Val/Test Acc = 79.8/84.8/78.4 -> ../84.8/78.4

# %% [markdown]
# ### Version 0.08

# %% [markdown]
# - **0.08** **MobileNet**
#   - Changed model to Pre-trained MobileNet
#   - Epoch=1: **img resize**: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 68.2/76.5/73.8
#   - Epoch=10: img resize: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 80.5/82.4/78.9
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = N:Train/Val/Test Acc = 83.7/79.2/76.5 ... revert to Epoch=10
#   - **Epoch=10**: img resize: **lr=0.0001**: BN = N: Dropout = N:Train/Val/Test Acc = 71.9/78.6/73.6 ... revert to lr=0.01
#   - Epoch=10: img resize: **lr=0.01**: **BN = Y**: Dropout = N: Train/Val/Test Acc = 83.0/77.8/71.0 revert to BN = N
#   - Epoch=10: img resize: lr=0.01: **BN = N**: **Dropout = 0.2**: Train/Val/Test Acc = 77.1/80.8/76.9
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Train/Val/Test Acc = 78.8/82.6/78.0
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = 0.4: Train/Val/Test Acc = 81.6/76.6/75.4 ... revert to Epoch = 10
#   - **Epoch=10**: img resize: lr=0.01: BN = N: **Dropout = 0.5**: Train/Val/Test Acc = 78.3/84.2/77.8 ... revert to Dropout = 0.4
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 78.3/79.1/76.5

# %% [markdown]
# ### Version 0.07

# %% [markdown]
# - **0.07** **ResNet50**
#   - As is rerun: Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: batch size = 10: Train/Val/Test Acc = 86.7/86.6/81.4
#   - Change **batch size** from 10 to 20: Train/Val/Test Acc = 91.2/83.7/78.9 ... reduces accuracy, so reverted to batch size of 10
#   - Implemented **Data Augmentation** with batch size of 10: Train/Val/Test Acc = 78.1/79.7/69.0 ...reduces accuracy, should we increase batch size?
#   - Implemented **Data Augmentation** with batch size of 100: Train/Val/Test Acc = 89.3/72.2/67.9 ...reduces accuracy, should we decrease batch size?
#   - Implemented **Data Augmentation** with batch size of 5: Train/Val/Test Acc = 58.3/48.4/48.1  ... reduces accuracy, reverted to batch size of 10, and no Data Augmentation
#   - Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: **batch size = 10**: **No DataAug**: Params (Total/Trainable/Non-trainable)= 25,687,938 / 2,100,226 / 23,587,712: Train/Val/Test Acc = 91.8/90.6/81.1

# %% [markdown]
# ### Version 0.06

# %% [markdown]
# - **0.06** **ResNet50**
#   - Before any modification: full rerun took ~15mins (most of it for loading train/val/test images/labels... and very less for model training/test)
#   - Before any modification: Train/Val/Test Acc = 53/51.1/51.3
#   - Changed model = Pre-trained ResNet50 + Modified FCN Layer
#     - SGD (LR=0.0001, M=0.9), Categorical Crossentropy
#     - 1st run: Train/Val/Test Acc = 57.5/72.7/67.1
#     - Converted ones/zeroes count to function
#     - Converted images/label prep to function
#     - Epoch=1: Train/Val/Test Acc = 61/67.9/67
#     - Epoch=5: Train/Val/Test Acc = 85.6/80.8/75.9
#     - Epoch=10: Train/Val/Test Acc = 93.0/85.6/77.7
#     - Epoch=20: Train/Val/Test Acc = 94.1/89.0/80.4
#     - Epoch=20: Changed loss function to 'binary crossentropy', reduced the accuracy: Train/Val/Test Acc = 90.2/84.0/77.7 Hence, reverted to categorical crossentropy as the loss function
#     - Epoch=20: Changed optimizer to Adam(lr=0.01), increased accuracy: Train/Val/Test Acc = 99.3/86.9/83.2
#     - In above training accuracy is high, validation and test accuracy is low ... it is overfitting ... let us implement Dropout
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): Train/Val/Test Acc = 93.0/88.8/82.1
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 90.8/89.8/83.4
#     - Epoch=20: Adam(lr=0.01): Dropout(0.5): Train/Val/Test Acc = 92.2/90.6/82.3 .. reverted to Dropout(0.4)
#     - Let us try Batch Normalization. ResNet50 -> Dense (1024) -> Batch Norm -> relu -> Dropout -> Dense(2,softmax)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): BN: Train/Val/Test Acc = 90.6/81.6/79.0 ... reduced accuracy
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): BN: Train/Val/Test Acc = 95.2/86.9/81.9 ... reduced accuracy will revert to no BN, Dropout(0.4)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 88.2/89.3/81.7

# %% [markdown]
# ### Version 0.01 - 0.05

# %% [markdown]
# - **0.05**: Migrate to Google Colab/Drive, changed loss function to 'binary_crossentropy', epochs to 1 : Train/Val/Test Acc = 55.7/55.9/55.2
# - **0.04**: Class Label Info in List was not accurate - fixed it. Now, Train/Validate/Test Accuracy is more realistic = ~55%
# - **0.03**: Tweak CNN model done for MNIST to work for this dataset to have a working end to end CNN model. Train/Validate/Test Accuracy = ~100%
# - **0.02**: Prepare Train/Validate/Test Labels and Images
# - **0.01**: Prepare Train/Validate/Test Images

# %% [markdown]
# ## Improvement Opportunity

# %% [markdown]
# - **TRIED**: As this is a 2 class classification - loss function can be changed to binary_crossentropy instead of categorical_crossentropy
# - **DONE**: Change model to ResNet50
# - **DONE**: Convert code sections in data preparation for train/validation/test to functions
# - **TRIED**: Reduce parameters, epochs.
# - **TRIED**: Try changing batch size
# - **TRIED**: Use Data Augmentation
# - **DONE**: Try to train last few layers of ResNet50 with the data
# - **TRIED**: Accuracy is fluctuating... optimize hyper parameters to have a smooth increase
# - **TRIED** Try Regularization
# - Our image size is 250x250. ResNet50 expects 224x224. Do we need to do anything or ResNet50 will understand ?
# - **DONE**: Change Model to MobileNet
# - **DONE**: Is image resize done correctly for MobileNet ?
# - **DONE**: Implement K Cross Validation for Epoch = 1, Fold = 4
# - **DONE**: Implement FLOPS
# - Check version of MobileNet ... try using tf.keras.applications.MobileNet() instead of tf.keras.applications.mobilenet.MobileNet()
# - Query: Should the batch_size be 1 or 10 for FLOPS calculation
# - Query: There should not be any difference in FLOPS for Transfer/FineTune Model, correct ?
# - Run K Cross Validation for Epoch = 100, Fold = 4
# - IO: Convert K-cross validation sections into functions
# - IO: Save best k fold of MobileNet Transfer and use for FineTune

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# ### Download Train, Validate and Test Images

# %% [markdown]
# - Source Link to the Dataset / Annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Follow the instructions at following link, install IBM Aspera Desktop Client to download the dataset.
# - Copy downloaded folders to '**data/images**' folder in your working directory where you have this Jupyter Notebook:
#   - 'held-out_validation'
#   - 'training'

# %% [markdown]
# ### Download Label Information for Train, Validate and Test Images

# %% [markdown]
# - Following link will point to below Github link which has the annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Source Link for the Annotation File: https://github.com/IDR/idr0042-nirschl-wsideeplearning/tree/master/experimentA
# - Download and copy file '**idr0042-experimentA-annotation.csv**' to '**data/labels/**' folder in your working directory where you have this Jupyter Notebook

# %% [markdown]
# ## References

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# - Access Google Drive files from Google Colab
#   - https://www.youtube.com/watch?reload=9&v=lHRC5gFvQnA
# - Reading an image
#   - mathplotlib: https://stackoverflow.com/questions/9298665/cannot-import-scipy-misc-imread
#   - pathlib: https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f#:~:text=To%20use%20it%2C%20you%20just,for%20the%20current%20operating%20system.
#   - OpenCV: https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/
# - Load multiple images into a numpy array
#   - glob / os.listdir: https://stackoverflow.com/questions/39195113/how-to-load-multiple-images-in-a-numpy-array
#   - glob / cv2: https://medium.com/@muskulpesent/create-numpy-array-of-images-fecb4e514c4b
# - Load a CSV file
#   - Datacamp: https://www.datacamp.com/community/tutorials/pandas-read-csv?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377095&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=9061994&gclid=EAIaIQobChMIz5TKz-v17QIV1AorCh0bfw96EAAYASAAEgKiGPD_BwE
# - Split a String
#   - Python Central: https://www.pythoncentral.io/cutting-and-slicing-strings-in-python/
# - Image Resize
#   - https://stackoverflow.com/questions/44650888/resize-an-image-without-distortion-opencv
#   - https://stackoverflow.com/questions/55571664/mobilenets-for-a-custom-image-size
# - Merge Train/Val/Test data
#   - Merge Dataframes
#     - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#   - Merge and Split Dataframes
#     - https://datascience.stackexchange.com/questions/81617/how-to-combine-and-separate-test-and-train-data-for-data-cleaning
#   -

# %% [markdown]
# ### Model Definition

# %% [markdown]
# - ResNet50
#   - https://cv-tricks.com/keras/understand-implement-resnets/
#   - Finetuning ResNet50
#     - https://www.pyimagesearch.com/2020/04/27/fine-tuning-resnet-with-keras-tensorflow-and-deep-learning/
# - MobileNet
#   - https://deeplizard.com/learn/video/Zrt76AIbeh4
#   - https://towardsdatascience.com/exploring-mobilenets-from-paper-to-keras-f01308ada818
#   - Fine Tuning MobileNet - Last few layers trainable
#     - https://towardsdatascience.com/transfer-learning-using-mobilenet-and-keras-c75daf7ff299
#   - MobileNet Version:
#     - https://keras.io/api/applications/mobilenet/
# - SqueezeNet
#   - https://codelabs.developers.google.com/codelabs/keras-flowers-squeezenet#6

# %% [markdown]
# ### Model Validation

# %% [markdown]
# - Keras Optimizer / Adam
#   - https://keras.io/api/optimizers/
# - Regularizer
#   - https://keras.io/api/layers/regularizers/
# - Save Weights for Best Model
#   - https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
#   - Monitoring Validaiton Accuracy - Skipping Error Solution
#     - https://github.com/tensorflow/tensorflow/issues/33163
#   - Predict using saved model
#     - https://stackoverflow.com/questions/44259651/how-to-use-predefined-trained-hdf5-file-with-wights-to-predict-a-class-of-new
# - K-cross validation: https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538
#   - use non-categorical labels for k-cross validation splits: https://stackoverflow.com/questions/48508036/sklearn-stratifiedkfold-valueerror-supported-target-types-are-binary-mul
#   - https://machinelearningmastery.com/ : Deep Learning with Python Book
# - FLOPS calculation
#   - https://pypi.org/project/keras-flops/
#   - https://www.manongdao.com/article-1967231.html
# - Time calculation
#   - https://www.tutorialspoint.com/How-to-get-current-time-in-milliseconds-in-Python#:~:text=You%20can%20get%20the%20current,1000%20and%20round%20it%20off.

# %% [markdown]
# ## Understand Dataset

# %% [markdown]
# ### Understand Images Folder Structure and Number of Images Available

# %% [markdown]
# Training/Validation
# - \..\training\fold_1: has images for training = 770#
# - \..\training\test_fold_1: has images for validation = 374#
# - Total = 770 + 374 = 1144 images
#
# Test
# - \..\held-out_validation: has images for testing = 1155#

# %% [markdown]
# ### Understand Annotation File and Label Information Available

# %% [markdown]
# Relevant columns of interest:
# - Column A: Dataset Name: Classifies each row/instance as 'training' or 'test'
# - Column B: Image Name: Specifies filename of the image for the row/instance
# - Column Z: Experimental Condition [Diagnosis]: has 3 classes:
#   - 'chronic heart failure'
#   - 'heart tissue pathology' - We will treat this as 'not chronic heart failure'
#   - 'not chronic heart failure'
# - Column AA: Channels: mentions RGB => images are color images and will have 3 channels Red/Green/Blue (for CNN).
#
# Breakup of training/test instances:
# - training
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 627
# - test
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 638
#
# Total 'training' = 517 + 627 = 1144  (Note: 'validate' is a portion of this 'training' set.)
#
# Total 'test' = 517 + 638 = 1155

# %% [markdown]
# ## Access Dataset

# %% [markdown]
# ### Load Libraries

# %% [markdown]
# We need to read 'train, validate and test images' to arrays so that we can then use them to feed to our CNN model. We need to import the annotation file into a dataframe so that we can then access the labels information.

# %%
# install OpenCV package - this is required only once
# pip install opencv-python

# %%
# aids in reading image files
import cv2
import glob

# %%
# aids in working with arrays
import numpy as np

# %%
# aids in working with dataframes
import pandas as pd

# %% [markdown]
# ### Mount Google Drive

# %% [markdown]
# We need to mount the google drive so that we can then access the files from google drive.

# %%
# run this. click on the link it will ask for. get the authentication code. Copy/Paste in the cell. Hit Enter.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Libraries for Calculating Time Duration

# %%
import time

# %% [markdown]
# ### Get labels info into a dataframe

# %%
# Google Drive / Colab
filepath_annotation_file = r'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/labels/idr0042-experimentA-annotation.csv'
labels = pd.read_csv(filepath_annotation_file)

# Local Drive / Jupyter
# labels = pd.read_csv('data/labels/idr0042-experimentA-annotation.csv')

# %% [markdown]
# ### Explore and Understand

# %%
# uncomment & check the contents of labels is as expected
labels
# Out:
#      Dataset Name  ... Channels
# 0        training  ...      RGB
# 1        training  ...      RGB
# 2        training  ...      RGB
# 3        training  ...      RGB
# 4        training  ...      RGB
# ...           ...  ...      ...
# 2294         test  ...      RGB
# 2295         test  ...      RGB
# 2296         test  ...      RGB
# 2297         test  ...      RGB
# 2298         test  ...      RGB
#
# [2299 rows x 27 columns]

# %%
print(labels['Dataset Name'])
# Out:
# 0       training
# 1       training
# 2       training
# 3       training
# 4       training
#           ...
# 2294        test
# 2295        test
# 2296        test
# 2297        test
# 2298        test
# Name: Dataset Name, Length: 2299, dtype: object

# %%
print(labels['Dataset Name'][0])
# Out:
# training

# %%
type(labels['Dataset Name'][0])
# Out:
# str

# %%
print(labels['Image Name'])
# Out:
# 0       33381_0_fal_10_0.png
# 1       33381_0_fal_14_0.png
# 2       33381_0_fal_16_0.png
# 3       33381_0_fal_18_0.png
# 4       33381_0_fal_25_0.png
#                 ...
# 2294    36175_1_nrm_18_0.png
# 2295     36175_1_nrm_1_0.png
# 2296    36175_1_nrm_20_0.png
# 2297    36175_1_nrm_21_0.png
# 2298     36175_1_nrm_2_0.png
# Name: Image Name, Length: 2299, dtype: object

# %%
print(labels['Image Name'][0])
# Out:
# 33381_0_fal_10_0.png

# %%
type(labels['Image Name'][0])
# Out:
# str

# %%
print(labels['Experimental Condition [Diagnosis]'])
# Out:
# 0           chronic heart failure
# 1           chronic heart failure
# 2           chronic heart failure
# 3           chronic heart failure
# 4           chronic heart failure
#                   ...
# 2294    not chronic heart failure
# 2295    not chronic heart failure
# 2296    not chronic heart failure
# 2297    not chronic heart failure
# 2298    not chronic heart failure
# Name: Experimental Condition [Diagnosis], Length: 2299, dtype: object

# %%
print(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# chronic heart failure

# %%
type(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# str

# %%
# confirm 'no info' cells have been encoded as 'nan'... check one entry
print(labels['Characteristics [Disease Subtype]'][463])
# Out:
# nan

# %% [markdown]
# ### Prepare Train Images and Train Labels

# %% [markdown]
# #### Explore and Understand

# %%
# Google Drive / Colab
filepathlist_train = glob.glob('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png')

# %%
# confirm you have got the total number of desired items in the list
len(filepathlist_train)
# Out:
# 770

# %%
# check what an element in the filelist contain.
# it has both directory information and the filename, we need to extract filename 
# the filename can then be used to check for the label info in the labels dataframe
filepathlist_train[0]
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/33392_0_fal_4_0.png'

# %% [markdown]
# #### Extract Filename and Label Info

# %% [markdown]
# All the images are of type '*.png'. We will read filepath for all "filenames with extension as 'png'" into a list. Here, filepath means 'relative directory + filename'. We will extract filename of the image from the file path. This filename can then be used to get the label information from the annotation file.

# %% [markdown]
# ##### Local Drive / Jupyter

# %%
# this scenario has '\\' between the directory and filename
# split the string
# directory, filename = filepathlist_train[0].split('\\')
# gives the directory info
# directory
# gives the filname we need
# filename

# %% [markdown]
# ##### Google Drive / Colab

# %% [markdown]
# ###### Explore and Understand

# %%
len(filepathlist_train[0])
# Out:
# 128

# %%
filepathlist_train[0][-19:]
# Out:
# '33392_0_fal_4_0.png'

# %%
filepathlist_train[0][len(filepathlist_train[0]) - 1]
# Out:
# 'g'

# %%
filepathlist_train[0][-1]
# Out:
# 'g'

# %%
# POC
idx = -1
while (filepathlist_train[0][idx] != '/'):
  idx = idx - 1 
# index currently points to '/' location, we need to start reading from next location to get file name
print(idx)
filename = filepathlist_train[0][idx + 1:]
print(filename)
# Out:
# -20
# 33392_0_fal_4_0.png

# %%
# POC
index_filepathlist = 0
for filepath in filepathlist_train:
    #print(index_filepathlist, filepath)
    index_filepathlist += 1

# %%
# read a file using the list containing the file path
img = cv2.imread(filepathlist_train[0])

# %% [markdown]
# ##### Define a Call Function to prepare images and labels

# %%
# function to prepare images & labels for the model
def prepare_images_labels (path_to_img_files, labels_dataframe, resize = 0):
  filepathlist = glob.glob(path_to_img_files)
  # define the empty list that need to populated with info
  images = []
  labels = []
  index_filepathlist = 0
  # iterate for all items in the file path list
  for filepath in filepathlist:
      # prepare image list
      img = cv2.imread(filepath)
      if (resize == 1):
        dim = (224,224)
        img = cv2.resize(img, dim)#, interpolation = inter)
      images.append(img)
      # prepare labels list
      # extract filename from the file path
      # Local Drive / Jupyter
      # directory, filename = filepath.split('\\')
      # Google Drive / Colab
      index_character = -1
      while (filepathlist[index_filepathlist][index_character] != '/'):
        index_character = index_character - 1 
      # character index currently points to '/' location, we need to start reading from next location to get file name
      filename = filepathlist[index_filepathlist][index_character + 1:]
      index_filepathlist += 1
      # iterate for all items in our labels dataframe to search for the label
      for index in range(len(labels_dataframe)):
          # we will compare the filename with all the filenames in the 'Image Name' column of the labels dataframe
          # when there is a match, we will copy the label from the 'Experimental Condition [Diagnosis]' column
          if (filename == labels_dataframe['Image Name'][index]):
              label = labels_dataframe['Experimental Condition [Diagnosis]'][index]
              # encode Class1 and Class0 as applicable
              if (label == 'chronic heart failure'):
                  label = 1
              elif (label == 'not chronic heart failure'):
                  label = 0
              elif (label == 'heart tissue pathology'):
                  label = 0
              # append the label to the list
              labels.append(label)
  return images, labels

# %% [markdown]
# ##### Prepare Train Images and Train Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png'
# for resnet50
# train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
start_time = time.time()
duration = time.time() - start_time
train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 1)
print(f'Train Image/Labels Prep Core Time = {duration}s')

# Local Drive / Jupyter
# filepathlist_train = glob.glob('data/images/training/fold_1/*.png')
# Out:
# Train Image/Labels Prep Core Time = 1.621246337890625e-05s

# %%
# train_labels

# %% [markdown]
# Convert images to numpy arrays and confirm shape is as required for CNN.

# %%
# confirm you have got the total number desired images in the list
len(train_images)
# Out:
# 770

# %%
# train is a list
type(train_images)
# Out:
# list

# %%
# convert list to a numpy array and the values to float
train_images = np.array(train_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
# number of instances, width, height, number of channels
# number of instances = number of image
# number of channels = 3 ... as these are color images
train_images.shape
# Out:
# (770, 224, 224, 3)

# %% [markdown]
# Convert labels to numpy arrays and confirm shape is as required for CNN.

# %%
len(train_labels)
# Out:
# 770

# %%
type(train_labels)
# Out:
# list

# %%
train_labels[0]
# Out:
# 1

# %%
train_labels[432]
# Out:
# 0

# %%
# convert list to a numpy array and the values to int64
train_labels = np.array(train_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
train_labels.shape
# Out:
# (770,)

# %%
len(train_labels)
# Out:
# 770

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
# function to count ones and zeroes in the label array
def print_ones_zeroes (labels):
  count_ones = 0
  count_zeroes = 0
  for i in range(len(labels)):
    if (labels[i] == 1):
      count_ones += 1
    elif (labels[i] == 0):
      count_zeroes += 1
  print('Total Labels:',(count_ones + count_zeroes))
  print('# of Class 1:',count_ones)   
  print('# of Class 0:',count_zeroes)

# %%
print_ones_zeroes(train_labels)
# Out:
# Total Labels: 770
# # of Class 1: 352
# # of Class 0: 418

# %%
# save the train labels before converting to categorical to use for cross validation splits
train_labels_before_categorical = train_labels
print(type(train_labels_before_categorical), len(train_labels_before_categorical), train_labels_before_categorical.shape)
# Out:
# <class 'numpy.ndarray'> 770 (770,)

# %% [markdown]
# We will convert the labels to 2bit values: 01 and 10 to correspond to the 2 classes. This is required to match to the model's output layer expectation so that we can effectively train and test.

# %%
from keras.utils import to_categorical

# %%
# convert labels to categorical
train_labels = to_categorical(train_labels)

# %% [markdown]
# ### Prepare Validation Images and Validation Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/test_fold_1/*.png'
# for resnet50
# validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
start_time = time.time()
validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 1)
duration = time.time() - start_time
print(f'Validation Image/Labels Prep Core Time = {duration}s')

# Local Drive / Jupyter
# filepathlist_validation = glob.glob('data/images/training/test_fold_1/*.png')
# Out:
# Validation Image/Labels Prep Core Time = 6.092658758163452s

# %%
# convert list to a numpy array and the values to float
validation_images = np.array(validation_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
validation_images.shape
# Out:
# (374, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
validation_labels = np.array(validation_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
validation_labels.shape
# Out:
# (374,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(validation_labels)
# Out:
# Total Labels: 374
# # of Class 1: 165
# # of Class 0: 209

# %%
# save the train labels before converting to categorical to use for cross validation splits
validation_labels_before_categorical = validation_labels
print(type(validation_labels_before_categorical), len(validation_labels_before_categorical), validation_labels_before_categorical.shape)
# Out:
# <class 'numpy.ndarray'> 374 (374,)

# %%
# convert labels to categorical
validation_labels = to_categorical(validation_labels)

# %% [markdown]
# ### Prepare Test Images and Test Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/held-out_validation/*.png'
# for resnet50
# test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
start_time = time.time()
test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 1)
duration = time.time() - start_time
print(f'Test Image/Labels Prep Core Time = {duration}s')

# Local Drive / Jupyter
# filepathlist_test = glob.glob('data/images/held-out_validation/*.png')
# Out:
# Test Image/Labels Prep Core Time = 17.9451105594635s

# %%
# convert list to a numpy array and the values to float
test_images = np.array(test_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
test_images.shape
# Out:
# (1155, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
test_labels = np.array(test_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
test_labels.shape
# Out:
# (1155,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(test_labels)
# Out:
# Total Labels: 1155
# # of Class 1: 517
# # of Class 0: 638

# %%
# save the train labels before converting to categorical to use for cross validation splits
test_labels_before_categorical = test_labels
print(type(test_labels_before_categorical), len(test_labels_before_categorical), test_labels_before_categorical.shape)
# Out:
# <class 'numpy.ndarray'> 1155 (1155,)

# %%
# convert labels to categorical
test_labels = to_categorical(test_labels)

# %% [markdown]
# ### Prepare All Images and Labels for Cross Validation

# %%
# confirm all are numpy arrays, length and shape
print(type(train_images), len(train_images), train_images.shape)
print(type(validation_images), len(validation_images), validation_images.shape)
print(type(test_images), len(test_images), test_images.shape)
print(len(train_images) + len(validation_images) + len(test_images))
print(type(train_labels), len(train_labels), train_labels.shape)
print(type(validation_labels), len(validation_labels), validation_labels.shape)
print(type(test_labels), len(test_labels), test_labels.shape)
print(len(train_labels) + len(validation_labels) + len(test_labels))
# Out:
# <class 'numpy.ndarray'> 770 (770, 224, 224, 3)
# <class 'numpy.ndarray'> 374 (374, 224, 224, 3)
# <class 'numpy.ndarray'> 1155 (1155, 224, 224, 3)
# 2299
# <class 'numpy.ndarray'> 770 (770, 2)
# <class 'numpy.ndarray'> 374 (374, 2)
# <class 'numpy.ndarray'> 1155 (1155, 2)
# 2299

# %%
# join train / validation / test arrays for images
all_images = np.concatenate((train_images, validation_images, test_images))
print(type(all_images), len(all_images), all_images.shape)
# Out:
# <class 'numpy.ndarray'> 2299 (2299, 224, 224, 3)

# %%
# join train / validation / test arrays for labels
all_labels = np.concatenate((train_labels, validation_labels, test_labels))
print(type(all_labels), len(all_labels), all_labels.shape)
# Out:
# <class 'numpy.ndarray'> 2299 (2299, 2)

# %%
# prepare the labels to enable split during k-cross validation
all_labels_before_categorical = np.concatenate((train_labels_before_categorical, validation_labels_before_categorical, test_labels_before_categorical))
print(type(all_labels_before_categorical), len(all_labels_before_categorical), all_labels_before_categorical.shape)
# Out:
# <class 'numpy.ndarray'> 2299 (2299,)

# %% [markdown]
# ## Model Definition / Train / Validate / Test

# %% [markdown]
# ### MNIST CNN modified for HE

# %%
# import libraries (general)
# from keras import models
# from keras import layers
# model_cnn = models.Sequential()

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 32
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# - Input Shape = 250x250 matrix with 3 channel (as we have a color image)
# model_cnn.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(250,250,3)))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation = 'relu'))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation='relu'))

# Data at this stage is in matrix form. We will convert it to vector form to feed to a fully connected network (FCN).
# model_cnn.add(layers.Flatten())

# We will design for 64 outputs with activation function as relu (to learn non-linearity).
# model_cnn.add(layers.Dense(64, activation = 'relu'))

# This is the final layer. Hence, the outputs will be 2 corresponding to the 2 classes:
# - clinical heart failure = yes: 1
# - clinical heart failure = no: 0
# Activation Function chosen here is softmax to have a probabilistic output. 
# model_cnn.add(layers.Dense(2, activation = 'softmax'))

# model_cnn.summary()

# Define Optimizer, Loss Function and Metrics to be used for the Model
# - Going ahead with the well known functions at this point in time
# - Selected accuracy as the metrics to understand validation / test accuracy of the model
# model_cnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Train and Validate the Model
# We will now train the model using train images and train labels. 
# - We will use a batch size = 10.
# - 1 epoch = 770 / 10 = 77 batches
# - 1 epoch = 1 complete run of all train samples for training the model
# - We will go for a total of 5 epochs = 5 complete run of the all train samples
# We will validate the model using validation images and validation labels.
# model_cnn.fit(train_images, train_labels, epochs = 1, batch_size = 10, validation_data = (validation_images, validation_labels))

# Test the Model
# We will now test model's performance with the test data.
# - We predict the class for each of the 1155 test using the model.
# - We will check the test accuracy.
# test_loss, test_acc = model_cnn.evaluate(test_images, test_labels)
# print('test accuracy:', (test_acc*100))

# %% [markdown]
# ### Define Common Hyperparameters

# %%
BATCH_SIZE = 10
EPOCHS = 100
LEARNING_RATE = 0.01
DENSE_LAYER_NEURONS = 512
DENSE_LAYER_DROPOUT = 0.4
CROSS_VALIDATE = True
CROSS_VALIDATION_FOLDS = 4

# %% [markdown]
# ### Define a checkpoint function

# %%
from keras.callbacks import ModelCheckpoint
def checkpoint(path_to_model_parameters_file):
  # 1st argument: file to which the weights need to be saved
  # 2nd argument: defines the quantity to monitor ... we will monitor validation accuracy
  # 3rd argument: verbose yes/no
  # 4th argument: true then save weghts else save entire model
  # 5th argument: max if val_acc, min if val_loss, auto decides based on the quantity getting monitored
  # 6th argument: period:  check after every epoch therefore 1
  # 6th arguemnt: save_freq:  specify the frequency in number of batches seen
  #checkpoint = ModelCheckpoint("/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  checkpoint_value = ModelCheckpoint(path_to_model_parameters_file, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  return checkpoint_value

# %% [markdown]
# ### Libraries for FLOPS

# %%
pip install keras-flops
# Out:
# Requirement already satisfied: keras-flops in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.6/dist-packages (from keras-flops) (2.4.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.36.2)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.3.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.4.0)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.12.4)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.7.4.3)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.32.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.19.5)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.2)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.15.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12.1)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.10.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow<3.0,>=2.2->keras-flops) (51.3.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.17.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.4.2)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2.23.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.0.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.1.0)

# %%
from keras_flops import get_flops

# %% [markdown]
# ### ResNet50 - Transfer Learning

# %%
# import libraries (resnet50)
from keras.applications.resnet50 import ResNet50
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
from keras.preprocessing.image import ImageDataGenerator

# %%
# load ResNet50 with pre-trained parameters for 'imagenet' challenge
# disable the last layer ... so that we can have our own FCN layer for our desired classes
resnet50 = ResNet50(include_top=False, weights='imagenet')

# define the last layers
# get the output of the last layer of the ResNet50
prediction = resnet50.output
# add a Global Average Pooling layer (GAP) - this helps reduce number of parameters as compared to a flatten/dense layer
prediction = GlobalAveragePooling2D()(prediction)
# add a FCN with 1024 output neurons
#prediction = Dense(1024, activation = 'relu')(prediction)
# we will split the actions to have the Batch Normalization done befor relu
prediction = Dense(DENSE_LAYER_NEURONS)(prediction)
#prediction = BatchNormalization()(prediction)
prediction = Activation('relu')(prediction)
# add a dropout of 40% to avoid overfitting
prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)
# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction = Dense(2, activation = 'softmax')(prediction)

# connect the last layer with ResNet50 layer to define the model
model = Model(inputs = resnet50.input, outputs = prediction)

# we wish use the pretrained resnet50 model as is i.e. do not want it's parameters to get updated during training
for layer in resnet50.layers:
  layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
model.summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_9[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, None, None, 2 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, None, None, 2 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, None, None, 2 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, None, None, 2 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, None, None, 2 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, None, None, 5 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, None, None, 5 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, None, None, 5 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, None, None, 5 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, None, None, 5 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, None, None, 5 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, None, None, 1 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, None, None, 1 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, None, None, 1 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, None, None, 1 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, None, None, 1 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, None, None, 1 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, None, None, 1 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, None, None, 1 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, None, None, 2 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, None, None, 2 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, None, None, 2 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, None, None, 2 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_8 (Glo (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 512)          1049088     global_average_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 512)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 512)          0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 2)            1026        dropout_8[0][0]
# ==================================================================================================
# Total params: 24,637,826
# Trainable params: 1,050,114
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# len(resnet50.layers)
# resnet50.layers
# resnet50.summary()

# %%
# calculate FLOPS for the model
flops_resnet50_xfr = get_flops(model, batch_size = 1)
print(f"ResNet50 Transfer FLOPS: {flops_resnet50_xfr / 10 ** 9:.03} G")
# Out:
# ResNet50 Transfer FLOPS: 0.0021 G

# %%
# data augmentation helps change the data slightly so that the model does not overfit
# train_generator = ImageDataGenerator(rotation_range = 8, width_shift_range = 0.08, shear_range = 0.3, height_shift_range = 0.08, zoom_range = 0.08)
# validation_generator = ImageDataGenerator()
# below ensures the augmented data is provided in batches to the model
# train_augmented = train_generator.flow(train_images, train_labels, batch_size = 10)
# validation_augmented = validation_generator.flow(validation_images, validation_labels, batch_size = 10)

# %%
# train and validate model
path_to_resnet50_xfr_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5'
start_time = time.time()
model.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_resnet50_xfr_parameters_file)])
duration = time.time() - start_time
print(f'ResNet50 XFR Train Time = {duration}s')

# train and validate model with augmented data
# model.fit(train_augmented, epochs = 20, batch_size = 10, validation_data = validation_augmented)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 7s 63ms/step - loss: 4.9464 - accuracy: 0.6296 - val_loss: 0.6980 - val_accuracy: 0.6551
#
# Epoch 00001: val_accuracy improved from -inf to 0.65508, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 2/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3871 - accuracy: 0.8172 - val_loss: 0.5618 - val_accuracy: 0.7647
#
# Epoch 00002: val_accuracy improved from 0.65508 to 0.76471, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 3/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3902 - accuracy: 0.8330 - val_loss: 0.4293 - val_accuracy: 0.8262
#
# Epoch 00003: val_accuracy improved from 0.76471 to 0.82620, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 4/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3807 - accuracy: 0.8421 - val_loss: 0.5186 - val_accuracy: 0.7754
#
# Epoch 00004: val_accuracy did not improve from 0.82620
# Epoch 5/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3879 - accuracy: 0.8294 - val_loss: 0.4285 - val_accuracy: 0.8422
#
# Epoch 00005: val_accuracy improved from 0.82620 to 0.84225, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 6/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3689 - accuracy: 0.8287 - val_loss: 0.5340 - val_accuracy: 0.7888
#
# Epoch 00006: val_accuracy did not improve from 0.84225
# Epoch 7/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2824 - accuracy: 0.8808 - val_loss: 0.5256 - val_accuracy: 0.8048
#
# Epoch 00007: val_accuracy did not improve from 0.84225
# Epoch 8/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3086 - accuracy: 0.8536 - val_loss: 0.4947 - val_accuracy: 0.8102
#
# Epoch 00008: val_accuracy did not improve from 0.84225
# Epoch 9/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.4141 - accuracy: 0.8278 - val_loss: 0.3633 - val_accuracy: 0.8556
#
# Epoch 00009: val_accuracy improved from 0.84225 to 0.85561, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 10/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.4179 - accuracy: 0.8408 - val_loss: 0.3304 - val_accuracy: 0.8556
#
# Epoch 00010: val_accuracy did not improve from 0.85561
# Epoch 11/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3460 - accuracy: 0.8585 - val_loss: 1.2588 - val_accuracy: 0.7005
#
# Epoch 00011: val_accuracy did not improve from 0.85561
# Epoch 12/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.4566 - accuracy: 0.8156 - val_loss: 0.4250 - val_accuracy: 0.8235
#
# Epoch 00012: val_accuracy did not improve from 0.85561
# Epoch 13/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3103 - accuracy: 0.8620 - val_loss: 0.4061 - val_accuracy: 0.8342
#
# Epoch 00013: val_accuracy did not improve from 0.85561
# Epoch 14/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3075 - accuracy: 0.8535 - val_loss: 0.3620 - val_accuracy: 0.8289
#
# Epoch 00014: val_accuracy did not improve from 0.85561
# Epoch 15/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2947 - accuracy: 0.8909 - val_loss: 0.4380 - val_accuracy: 0.8075
#
# Epoch 00015: val_accuracy did not improve from 0.85561
# Epoch 16/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2903 - accuracy: 0.8804 - val_loss: 0.3719 - val_accuracy: 0.8316
#
# Epoch 00016: val_accuracy did not improve from 0.85561
# Epoch 17/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2500 - accuracy: 0.8979 - val_loss: 0.4663 - val_accuracy: 0.8209
#
# Epoch 00017: val_accuracy did not improve from 0.85561
# Epoch 18/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2293 - accuracy: 0.9107 - val_loss: 0.4353 - val_accuracy: 0.8610
#
# Epoch 00018: val_accuracy improved from 0.85561 to 0.86096, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 19/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2666 - accuracy: 0.8822 - val_loss: 0.4204 - val_accuracy: 0.8503
#
# Epoch 00019: val_accuracy did not improve from 0.86096
# Epoch 20/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2090 - accuracy: 0.9179 - val_loss: 0.3924 - val_accuracy: 0.8529
#
# Epoch 00020: val_accuracy did not improve from 0.86096
# Epoch 21/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2603 - accuracy: 0.8760 - val_loss: 0.4947 - val_accuracy: 0.8690
#
# Epoch 00021: val_accuracy improved from 0.86096 to 0.86898, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 22/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3236 - accuracy: 0.8556 - val_loss: 0.4908 - val_accuracy: 0.8476
#
# Epoch 00022: val_accuracy did not improve from 0.86898
# Epoch 23/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2494 - accuracy: 0.8741 - val_loss: 0.4443 - val_accuracy: 0.8556
#
# Epoch 00023: val_accuracy did not improve from 0.86898
# Epoch 24/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2497 - accuracy: 0.8832 - val_loss: 0.5987 - val_accuracy: 0.7513
#
# Epoch 00024: val_accuracy did not improve from 0.86898
# Epoch 25/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3661 - accuracy: 0.8702 - val_loss: 0.3314 - val_accuracy: 0.8743
#
# Epoch 00025: val_accuracy improved from 0.86898 to 0.87433, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 26/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2395 - accuracy: 0.9015 - val_loss: 0.4763 - val_accuracy: 0.8396
#
# Epoch 00026: val_accuracy did not improve from 0.87433
# Epoch 27/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3204 - accuracy: 0.8768 - val_loss: 0.4063 - val_accuracy: 0.8610
#
# Epoch 00027: val_accuracy did not improve from 0.87433
# Epoch 28/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2442 - accuracy: 0.8976 - val_loss: 0.5185 - val_accuracy: 0.8529
#
# Epoch 00028: val_accuracy did not improve from 0.87433
# Epoch 29/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1742 - accuracy: 0.9317 - val_loss: 0.4007 - val_accuracy: 0.8449
#
# Epoch 00029: val_accuracy did not improve from 0.87433
# Epoch 30/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3279 - accuracy: 0.8398 - val_loss: 0.5181 - val_accuracy: 0.7888
#
# Epoch 00030: val_accuracy did not improve from 0.87433
# Epoch 31/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2988 - accuracy: 0.8520 - val_loss: 0.3933 - val_accuracy: 0.8503
#
# Epoch 00031: val_accuracy did not improve from 0.87433
# Epoch 32/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2426 - accuracy: 0.8664 - val_loss: 0.3783 - val_accuracy: 0.8316
#
# Epoch 00032: val_accuracy did not improve from 0.87433
# Epoch 33/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3675 - accuracy: 0.8394 - val_loss: 0.4550 - val_accuracy: 0.8235
#
# Epoch 00033: val_accuracy did not improve from 0.87433
# Epoch 34/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3076 - accuracy: 0.8717 - val_loss: 0.3545 - val_accuracy: 0.8316
#
# Epoch 00034: val_accuracy did not improve from 0.87433
# Epoch 35/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.3187 - accuracy: 0.8533 - val_loss: 0.4196 - val_accuracy: 0.8476
#
# Epoch 00035: val_accuracy did not improve from 0.87433
# Epoch 36/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2794 - accuracy: 0.8718 - val_loss: 0.4273 - val_accuracy: 0.8396
#
# Epoch 00036: val_accuracy did not improve from 0.87433
# Epoch 37/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2493 - accuracy: 0.8777 - val_loss: 0.4605 - val_accuracy: 0.8476
#
# Epoch 00037: val_accuracy did not improve from 0.87433
# Epoch 38/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2038 - accuracy: 0.9149 - val_loss: 0.5908 - val_accuracy: 0.8476
#
# Epoch 00038: val_accuracy did not improve from 0.87433
# Epoch 39/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2081 - accuracy: 0.9131 - val_loss: 0.5649 - val_accuracy: 0.8636
#
# Epoch 00039: val_accuracy did not improve from 0.87433
# Epoch 40/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1250 - accuracy: 0.9508 - val_loss: 0.5810 - val_accuracy: 0.8235
#
# Epoch 00040: val_accuracy did not improve from 0.87433
# Epoch 41/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1627 - accuracy: 0.9401 - val_loss: 0.5409 - val_accuracy: 0.8529
#
# Epoch 00041: val_accuracy did not improve from 0.87433
# Epoch 42/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1716 - accuracy: 0.9377 - val_loss: 0.4452 - val_accuracy: 0.8610
#
# Epoch 00042: val_accuracy did not improve from 0.87433
# Epoch 43/100
# 77/77 [==============================] - 4s 56ms/step - loss: 0.1888 - accuracy: 0.9251 - val_loss: 0.5275 - val_accuracy: 0.8422
#
# Epoch 00043: val_accuracy did not improve from 0.87433
# Epoch 44/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1381 - accuracy: 0.9406 - val_loss: 1.0622 - val_accuracy: 0.8583
#
# Epoch 00044: val_accuracy did not improve from 0.87433
# Epoch 45/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1992 - accuracy: 0.9137 - val_loss: 0.5159 - val_accuracy: 0.8209
#
# Epoch 00045: val_accuracy did not improve from 0.87433
# Epoch 46/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2637 - accuracy: 0.8780 - val_loss: 0.6363 - val_accuracy: 0.8529
#
# Epoch 00046: val_accuracy did not improve from 0.87433
# Epoch 47/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2953 - accuracy: 0.8446 - val_loss: 0.6886 - val_accuracy: 0.8663
#
# Epoch 00047: val_accuracy did not improve from 0.87433
# Epoch 48/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2396 - accuracy: 0.8985 - val_loss: 0.7153 - val_accuracy: 0.8503
#
# Epoch 00048: val_accuracy did not improve from 0.87433
# Epoch 49/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1634 - accuracy: 0.9090 - val_loss: 0.4239 - val_accuracy: 0.8717
#
# Epoch 00049: val_accuracy did not improve from 0.87433
# Epoch 50/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1470 - accuracy: 0.9232 - val_loss: 0.5014 - val_accuracy: 0.8663
#
# Epoch 00050: val_accuracy did not improve from 0.87433
# Epoch 51/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1585 - accuracy: 0.9192 - val_loss: 0.4304 - val_accuracy: 0.8743
#
# Epoch 00051: val_accuracy did not improve from 0.87433
# Epoch 52/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1748 - accuracy: 0.9322 - val_loss: 0.6424 - val_accuracy: 0.8449
#
# Epoch 00052: val_accuracy did not improve from 0.87433
# Epoch 53/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2133 - accuracy: 0.8971 - val_loss: 0.7596 - val_accuracy: 0.8289
#
# Epoch 00053: val_accuracy did not improve from 0.87433
# Epoch 54/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1644 - accuracy: 0.9377 - val_loss: 0.5429 - val_accuracy: 0.8503
#
# Epoch 00054: val_accuracy did not improve from 0.87433
# Epoch 55/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1371 - accuracy: 0.9338 - val_loss: 0.4612 - val_accuracy: 0.8396
#
# Epoch 00055: val_accuracy did not improve from 0.87433
# Epoch 56/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2460 - accuracy: 0.9054 - val_loss: 0.5258 - val_accuracy: 0.8503
#
# Epoch 00056: val_accuracy did not improve from 0.87433
# Epoch 57/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1516 - accuracy: 0.9381 - val_loss: 0.4160 - val_accuracy: 0.8610
#
# Epoch 00057: val_accuracy did not improve from 0.87433
# Epoch 58/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1967 - accuracy: 0.9098 - val_loss: 0.6917 - val_accuracy: 0.8289
#
# Epoch 00058: val_accuracy did not improve from 0.87433
# Epoch 59/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2087 - accuracy: 0.8964 - val_loss: 0.4707 - val_accuracy: 0.8075
#
# Epoch 00059: val_accuracy did not improve from 0.87433
# Epoch 60/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2506 - accuracy: 0.8681 - val_loss: 0.6068 - val_accuracy: 0.8449
#
# Epoch 00060: val_accuracy did not improve from 0.87433
# Epoch 61/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2393 - accuracy: 0.8859 - val_loss: 0.7096 - val_accuracy: 0.8476
#
# Epoch 00061: val_accuracy did not improve from 0.87433
# Epoch 62/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1619 - accuracy: 0.9375 - val_loss: 0.6182 - val_accuracy: 0.8503
#
# Epoch 00062: val_accuracy did not improve from 0.87433
# Epoch 63/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1850 - accuracy: 0.9130 - val_loss: 0.8880 - val_accuracy: 0.8209
#
# Epoch 00063: val_accuracy did not improve from 0.87433
# Epoch 64/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1696 - accuracy: 0.9280 - val_loss: 0.8377 - val_accuracy: 0.8503
#
# Epoch 00064: val_accuracy did not improve from 0.87433
# Epoch 65/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2152 - accuracy: 0.9151 - val_loss: 0.5803 - val_accuracy: 0.8556
#
# Epoch 00065: val_accuracy did not improve from 0.87433
# Epoch 66/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1615 - accuracy: 0.9352 - val_loss: 0.8863 - val_accuracy: 0.8690
#
# Epoch 00066: val_accuracy did not improve from 0.87433
# Epoch 67/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1104 - accuracy: 0.9541 - val_loss: 0.7221 - val_accuracy: 0.8503
#
# Epoch 00067: val_accuracy did not improve from 0.87433
# Epoch 68/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1799 - accuracy: 0.9121 - val_loss: 0.9077 - val_accuracy: 0.8449
#
# Epoch 00068: val_accuracy did not improve from 0.87433
# Epoch 69/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1355 - accuracy: 0.9453 - val_loss: 0.5661 - val_accuracy: 0.8717
#
# Epoch 00069: val_accuracy did not improve from 0.87433
# Epoch 70/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2326 - accuracy: 0.9434 - val_loss: 0.5892 - val_accuracy: 0.8369
#
# Epoch 00070: val_accuracy did not improve from 0.87433
# Epoch 71/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1789 - accuracy: 0.9273 - val_loss: 1.0233 - val_accuracy: 0.8529
#
# Epoch 00071: val_accuracy did not improve from 0.87433
# Epoch 72/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2077 - accuracy: 0.9001 - val_loss: 1.1503 - val_accuracy: 0.8021
#
# Epoch 00072: val_accuracy did not improve from 0.87433
# Epoch 73/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.3042 - accuracy: 0.8658 - val_loss: 0.7325 - val_accuracy: 0.8342
#
# Epoch 00073: val_accuracy did not improve from 0.87433
# Epoch 74/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2227 - accuracy: 0.9086 - val_loss: 0.6669 - val_accuracy: 0.8743
#
# Epoch 00074: val_accuracy did not improve from 0.87433
# Epoch 75/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1838 - accuracy: 0.9130 - val_loss: 0.9817 - val_accuracy: 0.8556
#
# Epoch 00075: val_accuracy did not improve from 0.87433
# Epoch 76/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1346 - accuracy: 0.9534 - val_loss: 0.7606 - val_accuracy: 0.8556
#
# Epoch 00076: val_accuracy did not improve from 0.87433
# Epoch 77/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1660 - accuracy: 0.9283 - val_loss: 0.6471 - val_accuracy: 0.8690
#
# Epoch 00077: val_accuracy did not improve from 0.87433
# Epoch 78/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1136 - accuracy: 0.9545 - val_loss: 0.6302 - val_accuracy: 0.8503
#
# Epoch 00078: val_accuracy did not improve from 0.87433
# Epoch 79/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1669 - accuracy: 0.9164 - val_loss: 0.7154 - val_accuracy: 0.8556
#
# Epoch 00079: val_accuracy did not improve from 0.87433
# Epoch 80/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1726 - accuracy: 0.9439 - val_loss: 0.6367 - val_accuracy: 0.8396
#
# Epoch 00080: val_accuracy did not improve from 0.87433
# Epoch 81/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1541 - accuracy: 0.9336 - val_loss: 1.4177 - val_accuracy: 0.8369
#
# Epoch 00081: val_accuracy did not improve from 0.87433
# Epoch 82/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1864 - accuracy: 0.9145 - val_loss: 1.0148 - val_accuracy: 0.8663
#
# Epoch 00082: val_accuracy did not improve from 0.87433
# Epoch 83/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1244 - accuracy: 0.9461 - val_loss: 0.7326 - val_accuracy: 0.8503
#
# Epoch 00083: val_accuracy did not improve from 0.87433
# Epoch 84/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1581 - accuracy: 0.9127 - val_loss: 0.8362 - val_accuracy: 0.8529
#
# Epoch 00084: val_accuracy did not improve from 0.87433
# Epoch 85/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1831 - accuracy: 0.9222 - val_loss: 0.6932 - val_accuracy: 0.8583
#
# Epoch 00085: val_accuracy did not improve from 0.87433
# Epoch 86/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1972 - accuracy: 0.8971 - val_loss: 0.3936 - val_accuracy: 0.8583
#
# Epoch 00086: val_accuracy did not improve from 0.87433
# Epoch 87/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2691 - accuracy: 0.8799 - val_loss: 0.6011 - val_accuracy: 0.8476
#
# Epoch 00087: val_accuracy did not improve from 0.87433
# Epoch 88/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1660 - accuracy: 0.9398 - val_loss: 1.0482 - val_accuracy: 0.8449
#
# Epoch 00088: val_accuracy did not improve from 0.87433
# Epoch 89/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.2019 - accuracy: 0.9246 - val_loss: 0.5035 - val_accuracy: 0.8556
#
# Epoch 00089: val_accuracy did not improve from 0.87433
# Epoch 90/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1531 - accuracy: 0.9497 - val_loss: 0.7593 - val_accuracy: 0.8529
#
# Epoch 00090: val_accuracy did not improve from 0.87433
# Epoch 91/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1518 - accuracy: 0.9505 - val_loss: 0.6338 - val_accuracy: 0.8690
#
# Epoch 00091: val_accuracy did not improve from 0.87433
# Epoch 92/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1752 - accuracy: 0.9232 - val_loss: 0.9288 - val_accuracy: 0.8556
#
# Epoch 00092: val_accuracy did not improve from 0.87433
# Epoch 93/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1361 - accuracy: 0.9502 - val_loss: 0.9115 - val_accuracy: 0.8610
#
# Epoch 00093: val_accuracy did not improve from 0.87433
# Epoch 94/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1019 - accuracy: 0.9630 - val_loss: 0.7599 - val_accuracy: 0.8556
#
# Epoch 00094: val_accuracy did not improve from 0.87433
# Epoch 95/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1331 - accuracy: 0.9496 - val_loss: 0.8830 - val_accuracy: 0.8663
#
# Epoch 00095: val_accuracy did not improve from 0.87433
# Epoch 96/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1195 - accuracy: 0.9553 - val_loss: 0.6467 - val_accuracy: 0.8476
#
# Epoch 00096: val_accuracy did not improve from 0.87433
# Epoch 97/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1577 - accuracy: 0.9518 - val_loss: 0.5633 - val_accuracy: 0.8717
#
# Epoch 00097: val_accuracy did not improve from 0.87433
# Epoch 98/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1582 - accuracy: 0.9402 - val_loss: 0.6350 - val_accuracy: 0.8476
#
# Epoch 00098: val_accuracy did not improve from 0.87433
# Epoch 99/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1744 - accuracy: 0.9302 - val_loss: 1.0314 - val_accuracy: 0.8583
#
# Epoch 00099: val_accuracy did not improve from 0.87433
# Epoch 100/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.1014 - accuracy: 0.9679 - val_loss: 0.6284 - val_accuracy: 0.8636
#
# Epoch 00100: val_accuracy did not improve from 0.87433
# ResNet50 XFR Train Time = 420.9718437194824s

# %%
# test model
#test_loss, test_acc = model.evaluate(test_images, test_labels)

# %%
# test with best model
model.load_weights(path_to_resnet50_xfr_parameters_file)
start_time = time.time()
test_loss, test_acc = model.evaluate(test_images, test_labels)
duration = time.time() - start_time
print(f'ResNet50 XFR Test Time = {duration}s')
print(f'ResNet50 XFR Test Time / sample = {duration/1155}s')
# Out:
# 37/37 [==============================] - 4s 96ms/step - loss: 0.5388 - accuracy: 0.7896
# ResNet50 XFR Test Time = 3.6487972736358643s
# ResNet50 XFR Test Time / sample = 0.00315913183864577s

# %%
# perform cross validation
start_time = time.time()
if (CROSS_VALIDATE == True):
  # import libraries
  from sklearn.model_selection import StratifiedKFold
  # using stratifiedkfold so that we have balanced classes in each split
  cvfold = StratifiedKFold(n_splits = CROSS_VALIDATION_FOLDS, shuffle = True)
  # we will use below to store all individual validation scores
  cvscores = []
  # based on the class value, get the split done and respective train and test index
  for train_index, val_index in cvfold.split(all_images, all_labels_before_categorical):
    # model definition as is from top - starts
    resnet50 = ResNet50(include_top=False, weights='imagenet')
    prediction = resnet50.output
    prediction = GlobalAveragePooling2D()(prediction)
    prediction = Dense(DENSE_LAYER_NEURONS)(prediction)
    prediction = Activation('relu')(prediction)
    prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)
    prediction = Dense(2, activation = 'softmax')(prediction)
    model = Model(inputs = resnet50.input, outputs = prediction)
    for layer in resnet50.layers:
      layer.trainable = False
    model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    # model definition as is from top - ends
    # train based on train index elements
    model.fit(all_images[train_index], all_labels[train_index], epochs = EPOCHS, batch_size = BATCH_SIZE) 
    # validate based on validation index elements
    cv_score = model.evaluate(all_images[val_index], all_labels[val_index])
    print("Validation Accuracy: %0.2f%%" % (cv_score[1]*100))
    # append each iteration validation accuracy score
    cvscores.append(cv_score[1]*100)
  # print mean and std deviation of the validation accuracy for the complete cross validation i.e. for all iterations
  print("Validation Accuracy Mean (+/- Std Deviation): %0.2f%% (+/- %0.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
duration = time.time() - start_time
print(f'ResNet50 XFR Cross Validation Time = {duration}s')
# Out:
# Epoch 1/100
# 173/173 [==============================] - 9s 37ms/step - loss: 3.4865 - accuracy: 0.6566
# Epoch 2/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4771 - accuracy: 0.7787
# Epoch 3/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4761 - accuracy: 0.7719
# Epoch 4/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4388 - accuracy: 0.8020
# Epoch 5/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4393 - accuracy: 0.8061
# Epoch 6/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4356 - accuracy: 0.8025
# Epoch 7/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4245 - accuracy: 0.7846
# Epoch 8/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3697 - accuracy: 0.8414
# Epoch 9/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3951 - accuracy: 0.8262
# Epoch 10/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3888 - accuracy: 0.8073
# Epoch 11/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3595 - accuracy: 0.8434
# Epoch 12/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2910 - accuracy: 0.8821
# Epoch 13/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3922 - accuracy: 0.8539
# Epoch 14/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3711 - accuracy: 0.8329
# Epoch 15/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3066 - accuracy: 0.8654
# Epoch 16/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2908 - accuracy: 0.8772
# Epoch 17/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3041 - accuracy: 0.8727
# Epoch 18/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3158 - accuracy: 0.8626
# Epoch 19/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3581 - accuracy: 0.8177
# Epoch 20/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3310 - accuracy: 0.8504
# Epoch 21/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2968 - accuracy: 0.8594
# Epoch 22/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2741 - accuracy: 0.8739
# Epoch 23/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2175 - accuracy: 0.9064
# Epoch 24/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3012 - accuracy: 0.8740
# Epoch 25/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2951 - accuracy: 0.8694
# Epoch 26/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2405 - accuracy: 0.8949
# Epoch 27/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2438 - accuracy: 0.8920
# Epoch 28/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2471 - accuracy: 0.8933
# Epoch 29/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2650 - accuracy: 0.8876
# Epoch 30/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2143 - accuracy: 0.9132
# Epoch 31/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2216 - accuracy: 0.9089
# Epoch 32/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2771 - accuracy: 0.8826
# Epoch 33/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3011 - accuracy: 0.8526
# Epoch 34/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2917 - accuracy: 0.8473
# Epoch 35/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2425 - accuracy: 0.8833
# Epoch 36/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2105 - accuracy: 0.9133
# Epoch 37/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2408 - accuracy: 0.9122
# Epoch 38/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2149 - accuracy: 0.9144
# Epoch 39/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1956 - accuracy: 0.9166
# Epoch 40/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2389 - accuracy: 0.9030
# Epoch 41/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2104 - accuracy: 0.9040
# Epoch 42/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2130 - accuracy: 0.9119
# Epoch 43/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1940 - accuracy: 0.9213
# Epoch 44/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2125 - accuracy: 0.9126
# Epoch 45/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2476 - accuracy: 0.8974
# Epoch 46/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1856 - accuracy: 0.9203
# Epoch 47/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2289 - accuracy: 0.9044
# Epoch 48/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2164 - accuracy: 0.8946
# Epoch 49/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2815 - accuracy: 0.8683
# Epoch 50/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2098 - accuracy: 0.9118
# Epoch 51/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2771 - accuracy: 0.8775
# Epoch 52/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2631 - accuracy: 0.8712
# Epoch 53/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2519 - accuracy: 0.8933
# Epoch 54/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2317 - accuracy: 0.9028
# Epoch 55/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1831 - accuracy: 0.9219
# Epoch 56/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1873 - accuracy: 0.9393
# Epoch 57/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1832 - accuracy: 0.9285
# Epoch 58/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1848 - accuracy: 0.9377
# Epoch 59/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2096 - accuracy: 0.9050
# Epoch 60/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1965 - accuracy: 0.9271
# Epoch 61/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1899 - accuracy: 0.9286
# Epoch 62/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2060 - accuracy: 0.9138
# Epoch 63/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2037 - accuracy: 0.9188
# Epoch 64/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1996 - accuracy: 0.9301
# Epoch 65/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2426 - accuracy: 0.8977
# Epoch 66/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1745 - accuracy: 0.9292
# Epoch 67/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1942 - accuracy: 0.9146
# Epoch 68/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1536 - accuracy: 0.9438
# Epoch 69/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1667 - accuracy: 0.9290
# Epoch 70/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1881 - accuracy: 0.9289
# Epoch 71/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1785 - accuracy: 0.9299
# Epoch 72/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2075 - accuracy: 0.9146
# Epoch 73/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1543 - accuracy: 0.9396
# Epoch 74/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1783 - accuracy: 0.9298
# Epoch 75/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2190 - accuracy: 0.9001
# Epoch 76/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1661 - accuracy: 0.9314
# Epoch 77/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1601 - accuracy: 0.9389
# Epoch 78/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1538 - accuracy: 0.9433
# Epoch 79/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1784 - accuracy: 0.9290
# Epoch 80/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1662 - accuracy: 0.9359
# Epoch 81/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1845 - accuracy: 0.9328
# Epoch 82/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2268 - accuracy: 0.9156
# Epoch 83/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2480 - accuracy: 0.8863
# Epoch 84/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2528 - accuracy: 0.8860
# Epoch 85/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2065 - accuracy: 0.9039
# Epoch 86/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2434 - accuracy: 0.8849
# Epoch 87/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2172 - accuracy: 0.9148
# Epoch 88/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1725 - accuracy: 0.9305
# Epoch 89/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2072 - accuracy: 0.9168
# Epoch 90/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2224 - accuracy: 0.9004
# Epoch 91/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1544 - accuracy: 0.9369
# Epoch 92/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1890 - accuracy: 0.9154
# Epoch 93/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1319 - accuracy: 0.9507
# Epoch 94/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2268 - accuracy: 0.9038
# Epoch 95/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1606 - accuracy: 0.9354
# Epoch 96/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1408 - accuracy: 0.9412
# Epoch 97/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1362 - accuracy: 0.9498
# Epoch 98/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1554 - accuracy: 0.9361
# Epoch 99/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1821 - accuracy: 0.9372
# Epoch 100/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1673 - accuracy: 0.9319
# 18/18 [==============================] - 3s 121ms/step - loss: 0.6532 - accuracy: 0.8696
# Validation Accuracy: 86.96%
# Epoch 1/100
# 173/173 [==============================] - 9s 37ms/step - loss: 4.2635 - accuracy: 0.6131
# Epoch 2/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4949 - accuracy: 0.7734
# Epoch 3/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4726 - accuracy: 0.7757
# Epoch 4/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4887 - accuracy: 0.7591
# Epoch 5/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4155 - accuracy: 0.7893
# Epoch 6/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4575 - accuracy: 0.7802
# Epoch 7/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3895 - accuracy: 0.8051
# Epoch 8/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4838 - accuracy: 0.7697
# Epoch 9/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3826 - accuracy: 0.8324
# Epoch 10/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4180 - accuracy: 0.8156
# Epoch 11/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3790 - accuracy: 0.8296
# Epoch 12/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3920 - accuracy: 0.8266
# Epoch 13/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3385 - accuracy: 0.8565
# Epoch 14/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3971 - accuracy: 0.8288
# Epoch 15/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3261 - accuracy: 0.8626
# Epoch 16/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3239 - accuracy: 0.8660
# Epoch 17/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3944 - accuracy: 0.8246
# Epoch 18/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3431 - accuracy: 0.8558
# Epoch 19/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4237 - accuracy: 0.7891
# Epoch 20/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3872 - accuracy: 0.8240
# Epoch 21/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3165 - accuracy: 0.8733
# Epoch 22/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2931 - accuracy: 0.8842
# Epoch 23/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2741 - accuracy: 0.8986
# Epoch 24/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2884 - accuracy: 0.8952
# Epoch 25/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2787 - accuracy: 0.8951
# Epoch 26/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2867 - accuracy: 0.8889
# Epoch 27/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2733 - accuracy: 0.9010
# Epoch 28/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2752 - accuracy: 0.8906
# Epoch 29/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3091 - accuracy: 0.8877
# Epoch 30/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2581 - accuracy: 0.9044
# Epoch 31/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3655 - accuracy: 0.8445
# Epoch 32/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3156 - accuracy: 0.8656
# Epoch 33/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2693 - accuracy: 0.8968
# Epoch 34/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2468 - accuracy: 0.9121
# Epoch 35/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2158 - accuracy: 0.9262
# Epoch 36/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2689 - accuracy: 0.8982
# Epoch 37/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2482 - accuracy: 0.9092
# Epoch 38/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2528 - accuracy: 0.9039
# Epoch 39/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2251 - accuracy: 0.9199
# Epoch 40/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2337 - accuracy: 0.9160
# Epoch 41/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2611 - accuracy: 0.9093
# Epoch 42/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2554 - accuracy: 0.9094
# Epoch 43/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2329 - accuracy: 0.9154
# Epoch 44/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2440 - accuracy: 0.9110
# Epoch 45/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2225 - accuracy: 0.9259
# Epoch 46/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2683 - accuracy: 0.8973
# Epoch 47/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2624 - accuracy: 0.8982
# Epoch 48/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2810 - accuracy: 0.8888
# Epoch 49/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1952 - accuracy: 0.9356
# Epoch 50/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2167 - accuracy: 0.9249
# Epoch 51/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2193 - accuracy: 0.9282
# Epoch 52/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2144 - accuracy: 0.9231
# Epoch 53/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2060 - accuracy: 0.9321
# Epoch 54/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2296 - accuracy: 0.9177
# Epoch 55/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2963 - accuracy: 0.8836
# Epoch 56/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2489 - accuracy: 0.9082
# Epoch 57/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1962 - accuracy: 0.9321
# Epoch 58/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2084 - accuracy: 0.9290
# Epoch 59/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2103 - accuracy: 0.9303
# Epoch 60/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2465 - accuracy: 0.9086
# Epoch 61/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2234 - accuracy: 0.9242
# Epoch 62/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2235 - accuracy: 0.9237
# Epoch 63/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2957 - accuracy: 0.8740
# Epoch 64/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1941 - accuracy: 0.9354
# Epoch 65/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2202 - accuracy: 0.9215
# Epoch 66/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2174 - accuracy: 0.9246
# Epoch 67/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2459 - accuracy: 0.9100
# Epoch 68/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3168 - accuracy: 0.8708
# Epoch 69/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2137 - accuracy: 0.9286
# Epoch 70/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2404 - accuracy: 0.9109
# Epoch 71/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2059 - accuracy: 0.9300
# Epoch 72/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2165 - accuracy: 0.9269
# Epoch 73/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2191 - accuracy: 0.9224
# Epoch 74/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2147 - accuracy: 0.9260
# Epoch 75/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2303 - accuracy: 0.9172
# Epoch 76/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2081 - accuracy: 0.9283
# Epoch 77/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1869 - accuracy: 0.9391
# Epoch 78/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1583 - accuracy: 0.9520
# Epoch 79/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2230 - accuracy: 0.9237
# Epoch 80/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1854 - accuracy: 0.9409
# Epoch 81/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2863 - accuracy: 0.8954
# Epoch 82/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2457 - accuracy: 0.9113
# Epoch 83/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2339 - accuracy: 0.9118
# Epoch 84/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2470 - accuracy: 0.9073
# Epoch 85/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2078 - accuracy: 0.9285
# Epoch 86/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2617 - accuracy: 0.9084
# Epoch 87/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2160 - accuracy: 0.9241
# Epoch 88/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2468 - accuracy: 0.9140
# Epoch 89/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1845 - accuracy: 0.9429
# Epoch 90/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2040 - accuracy: 0.9274
# Epoch 91/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2332 - accuracy: 0.9149
# Epoch 92/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2072 - accuracy: 0.9354
# Epoch 93/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2084 - accuracy: 0.9264
# Epoch 94/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1757 - accuracy: 0.9451
# Epoch 95/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2241 - accuracy: 0.9189
# Epoch 96/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2211 - accuracy: 0.9180
# Epoch 97/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2931 - accuracy: 0.8917
# Epoch 98/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2076 - accuracy: 0.9303
# Epoch 99/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2042 - accuracy: 0.9286
# Epoch 100/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1664 - accuracy: 0.9495
# 18/18 [==============================] - 3s 100ms/step - loss: 0.8618 - accuracy: 0.8765
# Validation Accuracy: 87.65%
# Epoch 1/100
# 173/173 [==============================] - 9s 37ms/step - loss: 4.7922 - accuracy: 0.6067
# Epoch 2/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4340 - accuracy: 0.7978
# Epoch 3/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4272 - accuracy: 0.7996
# Epoch 4/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4294 - accuracy: 0.8055
# Epoch 5/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3986 - accuracy: 0.8116
# Epoch 6/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3777 - accuracy: 0.8312
# Epoch 7/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3720 - accuracy: 0.8283
# Epoch 8/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3220 - accuracy: 0.8462
# Epoch 9/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3906 - accuracy: 0.8193
# Epoch 10/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4109 - accuracy: 0.8015
# Epoch 11/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.3587 - accuracy: 0.8274
# Epoch 12/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.4121 - accuracy: 0.7983
# Epoch 13/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4266 - accuracy: 0.7885
# Epoch 14/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3351 - accuracy: 0.8357
# Epoch 15/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3791 - accuracy: 0.8077
# Epoch 16/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3716 - accuracy: 0.7967
# Epoch 17/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3074 - accuracy: 0.8607
# Epoch 18/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3161 - accuracy: 0.8542
# Epoch 19/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3514 - accuracy: 0.8370
# Epoch 20/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3317 - accuracy: 0.8219
# Epoch 21/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2732 - accuracy: 0.8718
# Epoch 22/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3033 - accuracy: 0.8471
# Epoch 23/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2854 - accuracy: 0.8724
# Epoch 24/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2225 - accuracy: 0.8954
# Epoch 25/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2460 - accuracy: 0.8666
# Epoch 26/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2749 - accuracy: 0.8579
# Epoch 27/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3249 - accuracy: 0.8048
# Epoch 28/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3009 - accuracy: 0.8148
# Epoch 29/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2397 - accuracy: 0.8796
# Epoch 30/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2234 - accuracy: 0.8928
# Epoch 31/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1993 - accuracy: 0.8964
# Epoch 32/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2143 - accuracy: 0.8841
# Epoch 33/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2335 - accuracy: 0.8876
# Epoch 34/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3499 - accuracy: 0.8492
# Epoch 35/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2777 - accuracy: 0.8469
# Epoch 36/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2281 - accuracy: 0.8756
# Epoch 37/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2278 - accuracy: 0.8657
# Epoch 38/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2629 - accuracy: 0.8534
# Epoch 39/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2607 - accuracy: 0.8416
# Epoch 40/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2533 - accuracy: 0.8486
# Epoch 41/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2592 - accuracy: 0.8605
# Epoch 42/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2487 - accuracy: 0.8715
# Epoch 43/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2999 - accuracy: 0.8521
# Epoch 44/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2959 - accuracy: 0.8139
# Epoch 45/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2307 - accuracy: 0.8511
# Epoch 46/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.2625 - accuracy: 0.8729
# Epoch 47/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2190 - accuracy: 0.8751
# Epoch 48/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2174 - accuracy: 0.8432
# Epoch 49/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2012 - accuracy: 0.8903
# Epoch 50/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2489 - accuracy: 0.8588
# Epoch 51/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2903 - accuracy: 0.8130
# Epoch 52/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1932 - accuracy: 0.8903
# Epoch 53/100
# 173/173 [==============================] - 6s 36ms/step - loss: 0.1966 - accuracy: 0.8839
# Epoch 54/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2592 - accuracy: 0.8323
# Epoch 55/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3446 - accuracy: 0.8217
# Epoch 56/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2551 - accuracy: 0.8551
# Epoch 57/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1924 - accuracy: 0.8751
# Epoch 58/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2006 - accuracy: 0.8665
# Epoch 59/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2330 - accuracy: 0.8648
# Epoch 60/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2088 - accuracy: 0.8695
# Epoch 61/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1649 - accuracy: 0.8947
# Epoch 62/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1897 - accuracy: 0.8816
# Epoch 63/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2440 - accuracy: 0.8947
# Epoch 64/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1981 - accuracy: 0.8718
# Epoch 65/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1876 - accuracy: 0.8997
# Epoch 66/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2133 - accuracy: 0.8599
# Epoch 67/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2256 - accuracy: 0.8512
# Epoch 68/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2179 - accuracy: 0.8703
# Epoch 69/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2321 - accuracy: 0.8743
# Epoch 70/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2017 - accuracy: 0.8749
# Epoch 71/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2103 - accuracy: 0.8549
# Epoch 72/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2272 - accuracy: 0.8645
# Epoch 73/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2202 - accuracy: 0.8525
# Epoch 74/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2118 - accuracy: 0.8743
# Epoch 75/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1489 - accuracy: 0.9080
# Epoch 76/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1724 - accuracy: 0.8991
# Epoch 77/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2004 - accuracy: 0.8621
# Epoch 78/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1668 - accuracy: 0.8917
# Epoch 79/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2207 - accuracy: 0.8665
# Epoch 80/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2598 - accuracy: 0.8582
# Epoch 81/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2435 - accuracy: 0.8568
# Epoch 82/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2026 - accuracy: 0.8699
# Epoch 83/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1664 - accuracy: 0.9030
# Epoch 84/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1721 - accuracy: 0.8973
# Epoch 85/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2240 - accuracy: 0.8728
# Epoch 86/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1852 - accuracy: 0.9108
# Epoch 87/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2549 - accuracy: 0.8697
# Epoch 88/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1759 - accuracy: 0.8908
# Epoch 89/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2381 - accuracy: 0.8746
# Epoch 90/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1981 - accuracy: 0.8936
# Epoch 91/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1845 - accuracy: 0.8913
# Epoch 92/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2555 - accuracy: 0.8473
# Epoch 93/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2359 - accuracy: 0.8512
# Epoch 94/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2156 - accuracy: 0.8899
# Epoch 95/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1931 - accuracy: 0.8895
# Epoch 96/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1722 - accuracy: 0.8892
# Epoch 97/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1802 - accuracy: 0.8736
# Epoch 98/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1851 - accuracy: 0.8891
# Epoch 99/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1894 - accuracy: 0.8907
# Epoch 100/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.1780 - accuracy: 0.8886
# 18/18 [==============================] - 3s 99ms/step - loss: 0.5456 - accuracy: 0.8922
# Validation Accuracy: 89.22%
# Epoch 1/100
# 173/173 [==============================] - 9s 38ms/step - loss: 3.2439 - accuracy: 0.6468
# Epoch 2/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4603 - accuracy: 0.7940
# Epoch 3/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4883 - accuracy: 0.7838
# Epoch 4/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4085 - accuracy: 0.8193
# Epoch 5/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3704 - accuracy: 0.8250
# Epoch 6/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4270 - accuracy: 0.7957
# Epoch 7/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3849 - accuracy: 0.8219
# Epoch 8/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4042 - accuracy: 0.8195
# Epoch 9/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3678 - accuracy: 0.8248
# Epoch 10/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4119 - accuracy: 0.8112
# Epoch 11/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3550 - accuracy: 0.8343
# Epoch 12/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4007 - accuracy: 0.7719
# Epoch 13/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3874 - accuracy: 0.7845
# Epoch 14/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4123 - accuracy: 0.7719
# Epoch 15/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3855 - accuracy: 0.8259
# Epoch 16/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3315 - accuracy: 0.8247
# Epoch 17/100
# 173/173 [==============================] - 7s 38ms/step - loss: 0.3502 - accuracy: 0.8179
# Epoch 18/100
# 173/173 [==============================] - 7s 38ms/step - loss: 0.3332 - accuracy: 0.8267
# Epoch 19/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2778 - accuracy: 0.8563
# Epoch 20/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3061 - accuracy: 0.8478
# Epoch 21/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.4745 - accuracy: 0.8121
# Epoch 22/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3745 - accuracy: 0.8281
# Epoch 23/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3245 - accuracy: 0.8293
# Epoch 24/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2994 - accuracy: 0.8510
# Epoch 25/100
# 173/173 [==============================] - 7s 38ms/step - loss: 0.2746 - accuracy: 0.8355
# Epoch 26/100
# 173/173 [==============================] - 6s 38ms/step - loss: 0.2740 - accuracy: 0.8493
# Epoch 27/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2711 - accuracy: 0.8519
# Epoch 28/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2599 - accuracy: 0.8581
# Epoch 29/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2711 - accuracy: 0.8528
# Epoch 30/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3124 - accuracy: 0.8370
# Epoch 31/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3120 - accuracy: 0.8527
# Epoch 32/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2864 - accuracy: 0.8603
# Epoch 33/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2669 - accuracy: 0.8426
# Epoch 34/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2388 - accuracy: 0.8820
# Epoch 35/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2202 - accuracy: 0.8780
# Epoch 36/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2656 - accuracy: 0.8631
# Epoch 37/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3199 - accuracy: 0.8310
# Epoch 38/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2655 - accuracy: 0.8788
# Epoch 39/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2544 - accuracy: 0.8753
# Epoch 40/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2215 - accuracy: 0.8676
# Epoch 41/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2525 - accuracy: 0.8388
# Epoch 42/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2169 - accuracy: 0.8767
# Epoch 43/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2211 - accuracy: 0.8811
# Epoch 44/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2029 - accuracy: 0.8880
# Epoch 45/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2114 - accuracy: 0.8833
# Epoch 46/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2181 - accuracy: 0.8857
# Epoch 47/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2172 - accuracy: 0.8748
# Epoch 48/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2594 - accuracy: 0.8559
# Epoch 49/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2275 - accuracy: 0.8701
# Epoch 50/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2102 - accuracy: 0.8859
# Epoch 51/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2122 - accuracy: 0.8874
# Epoch 52/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2071 - accuracy: 0.8748
# Epoch 53/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2522 - accuracy: 0.8799
# Epoch 54/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3409 - accuracy: 0.7888
# Epoch 55/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2905 - accuracy: 0.8122
# Epoch 56/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3091 - accuracy: 0.8141
# Epoch 57/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2822 - accuracy: 0.8558
# Epoch 58/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2516 - accuracy: 0.8646
# Epoch 59/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2586 - accuracy: 0.8581
# Epoch 60/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2759 - accuracy: 0.8346
# Epoch 61/100
# 173/173 [==============================] - 6s 38ms/step - loss: 0.2627 - accuracy: 0.8655
# Epoch 62/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2494 - accuracy: 0.8559
# Epoch 63/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2871 - accuracy: 0.8318
# Epoch 64/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2215 - accuracy: 0.8809
# Epoch 65/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2764 - accuracy: 0.8577
# Epoch 66/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2570 - accuracy: 0.8621
# Epoch 67/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2803 - accuracy: 0.8625
# Epoch 68/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2888 - accuracy: 0.8427
# Epoch 69/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2826 - accuracy: 0.8291
# Epoch 70/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.3007 - accuracy: 0.8780
# Epoch 71/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2482 - accuracy: 0.8660
# Epoch 72/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2357 - accuracy: 0.8751
# Epoch 73/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2508 - accuracy: 0.8650
# Epoch 74/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2848 - accuracy: 0.8636
# Epoch 75/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2533 - accuracy: 0.8641
# Epoch 76/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2299 - accuracy: 0.8827
# Epoch 77/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2408 - accuracy: 0.8719
# Epoch 78/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2647 - accuracy: 0.8588
# Epoch 79/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2419 - accuracy: 0.8603
# Epoch 80/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2457 - accuracy: 0.8792
# Epoch 81/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2197 - accuracy: 0.8897
# Epoch 82/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2753 - accuracy: 0.8695
# Epoch 83/100
# 173/173 [==============================] - 6s 38ms/step - loss: 0.2751 - accuracy: 0.8670
# Epoch 84/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2518 - accuracy: 0.8640
# Epoch 85/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2367 - accuracy: 0.8652
# Epoch 86/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2236 - accuracy: 0.8823
# Epoch 87/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2234 - accuracy: 0.8763
# Epoch 88/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2441 - accuracy: 0.8818
# Epoch 89/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2838 - accuracy: 0.8416
# Epoch 90/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2201 - accuracy: 0.8963
# Epoch 91/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2285 - accuracy: 0.8731
# Epoch 92/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2956 - accuracy: 0.8617
# Epoch 93/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2693 - accuracy: 0.8526
# Epoch 94/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2689 - accuracy: 0.8684
# Epoch 95/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2502 - accuracy: 0.8677
# Epoch 96/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2284 - accuracy: 0.8687
# Epoch 97/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2333 - accuracy: 0.8688
# Epoch 98/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2328 - accuracy: 0.8793
# Epoch 99/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2029 - accuracy: 0.8928
# Epoch 100/100
# 173/173 [==============================] - 6s 37ms/step - loss: 0.2278 - accuracy: 0.8862
# 18/18 [==============================] - 3s 121ms/step - loss: 0.4508 - accuracy: 0.9042
# Validation Accuracy: 90.42%
# Validation Accuracy Mean (+/- Std Deviation): 88.56% (+/- 1.35%)
# ResNet50 XFR Cross Validation Time = 2571.192714691162s

# %% [markdown]
# ### MobileNet

# %% [markdown]
# We will first perform transfer learning. This will help get the parameter values initialized for the last layers before we engage few convolution layers of MobileNet in learning (Fine Tuning).

# %% [markdown]
# #### Transfer Learning

# %%
# import libraries
import tensorflow as tf
from keras.models import Model
#from keras.optimizers import SGD
from keras.optimizers import Adam
#from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
#from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers

# %%
# load MobileNet with pre-trained parameters for 'imagenet' challenge
# mobilenet = tf.keras.applications.mobilenet.MobileNet()
# mobilenet = tf.keras.applications.MobileNet()
mobilenet = tf.keras.applications.MobileNetV2()
# mobilenet.summary()

# define the last layers
# get the output of the last layer of the MobileNet
prediction_mn = mobilenet.output

# mobilenet already has a GAP layer, hence we need to only add a Dense layer

# add a FCN with 512 output neurons
prediction_mn = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction_mn)
# with regularizer
# prediction_mn = Dense(1024, activation = 'relu', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# we will split the actions to have the Batch Normalization done befor relu
# prediction_mn = Dense(1024)(prediction_mn)
# prediction_mn = BatchNormalization()(prediction_mn)
# prediction_mn = Activation('relu')(prediction_mn)

# add a dropout to avoid overfitting
prediction_mn = Dropout(DENSE_LAYER_DROPOUT)(prediction_mn)

# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction_mn = Dense(2, activation = 'softmax')(prediction_mn)
# with regularizer
# prediction_mn = Dense(2, activation = 'softmax', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# connect the last layer with MobileNet layer to define the model
model_mn = Model(inputs = mobilenet.input, outputs = prediction_mn)

# we wish use the pretrained MobileNet model as is i.e. do not want it's parameters to get updated during training
for layer in mobilenet.layers:
   layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model_mn.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
#model_mn.compile(optimizer = Adam(lr=0.01), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# we want to monitor validation accuracy and save the best validation accuracy, hence changing the metrics to 'val_accuracy'
model_mn.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
model_mn.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_14[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_13 (Gl (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         1281000     global_average_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 512)          512512      predictions[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 512)          0           dense_26[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 2)            1026        dropout_13[0][0]
# ==================================================================================================
# Total params: 4,052,522
# Trainable params: 513,538
# Non-trainable params: 3,538,984
# __________________________________________________________________________________________________

# %%
# calculate FLOPS for the model
flops_mobilenet_xfr = get_flops(model_mn, batch_size = 1)
print(f"MobileNet Transfer FLOPS: {flops_mobilenet_xfr / 10 ** 9:.03} G")
# Out:
# MobileNet Transfer FLOPS: 0.616 G

# %%
# let us check the layers in the model 
for i,layer in enumerate(model_mn.layers):
  print(i,layer.name)
# Out:
# 0 input_14
# 1 Conv1
# 2 bn_Conv1
# 3 Conv1_relu
# 4 expanded_conv_depthwise
# 5 expanded_conv_depthwise_BN
# 6 expanded_conv_depthwise_relu
# 7 expanded_conv_project
# 8 expanded_conv_project_BN
# 9 block_1_expand
# 10 block_1_expand_BN
# 11 block_1_expand_relu
# 12 block_1_pad
# 13 block_1_depthwise
# 14 block_1_depthwise_BN
# 15 block_1_depthwise_relu
# 16 block_1_project
# 17 block_1_project_BN
# 18 block_2_expand
# 19 block_2_expand_BN
# 20 block_2_expand_relu
# 21 block_2_depthwise
# 22 block_2_depthwise_BN
# 23 block_2_depthwise_relu
# 24 block_2_project
# 25 block_2_project_BN
# 26 block_2_add
# 27 block_3_expand
# 28 block_3_expand_BN
# 29 block_3_expand_relu
# 30 block_3_pad
# 31 block_3_depthwise
# 32 block_3_depthwise_BN
# 33 block_3_depthwise_relu
# 34 block_3_project
# 35 block_3_project_BN
# 36 block_4_expand
# 37 block_4_expand_BN
# 38 block_4_expand_relu
# 39 block_4_depthwise
# 40 block_4_depthwise_BN
# 41 block_4_depthwise_relu
# 42 block_4_project
# 43 block_4_project_BN
# 44 block_4_add
# 45 block_5_expand
# 46 block_5_expand_BN
# 47 block_5_expand_relu
# 48 block_5_depthwise
# 49 block_5_depthwise_BN
# 50 block_5_depthwise_relu
# 51 block_5_project
# 52 block_5_project_BN
# 53 block_5_add
# 54 block_6_expand
# 55 block_6_expand_BN
# 56 block_6_expand_relu
# 57 block_6_pad
# 58 block_6_depthwise
# 59 block_6_depthwise_BN
# 60 block_6_depthwise_relu
# 61 block_6_project
# 62 block_6_project_BN
# 63 block_7_expand
# 64 block_7_expand_BN
# 65 block_7_expand_relu
# 66 block_7_depthwise
# 67 block_7_depthwise_BN
# 68 block_7_depthwise_relu
# 69 block_7_project
# 70 block_7_project_BN
# 71 block_7_add
# 72 block_8_expand
# 73 block_8_expand_BN
# 74 block_8_expand_relu
# 75 block_8_depthwise
# 76 block_8_depthwise_BN
# 77 block_8_depthwise_relu
# 78 block_8_project
# 79 block_8_project_BN
# 80 block_8_add
# 81 block_9_expand
# 82 block_9_expand_BN
# 83 block_9_expand_relu
# 84 block_9_depthwise
# 85 block_9_depthwise_BN
# 86 block_9_depthwise_relu
# 87 block_9_project
# 88 block_9_project_BN
# 89 block_9_add
# 90 block_10_expand
# 91 block_10_expand_BN
# 92 block_10_expand_relu
# 93 block_10_depthwise
# 94 block_10_depthwise_BN
# 95 block_10_depthwise_relu
# 96 block_10_project
# 97 block_10_project_BN
# 98 block_11_expand
# 99 block_11_expand_BN
# 100 block_11_expand_relu
# 101 block_11_depthwise
# 102 block_11_depthwise_BN
# 103 block_11_depthwise_relu
# 104 block_11_project
# 105 block_11_project_BN
# 106 block_11_add
# 107 block_12_expand
# 108 block_12_expand_BN
# 109 block_12_expand_relu
# 110 block_12_depthwise
# 111 block_12_depthwise_BN
# 112 block_12_depthwise_relu
# 113 block_12_project
# 114 block_12_project_BN
# 115 block_12_add
# 116 block_13_expand
# 117 block_13_expand_BN
# 118 block_13_expand_relu
# 119 block_13_pad
# 120 block_13_depthwise
# 121 block_13_depthwise_BN
# 122 block_13_depthwise_relu
# 123 block_13_project
# 124 block_13_project_BN
# 125 block_14_expand
# 126 block_14_expand_BN
# 127 block_14_expand_relu
# 128 block_14_depthwise
# 129 block_14_depthwise_BN
# 130 block_14_depthwise_relu
# 131 block_14_project
# 132 block_14_project_BN
# 133 block_14_add
# 134 block_15_expand
# 135 block_15_expand_BN
# 136 block_15_expand_relu
# 137 block_15_depthwise
# 138 block_15_depthwise_BN
# 139 block_15_depthwise_relu
# 140 block_15_project
# 141 block_15_project_BN
# 142 block_15_add
# 143 block_16_expand
# 144 block_16_expand_BN
# 145 block_16_expand_relu
# 146 block_16_depthwise
# 147 block_16_depthwise_BN
# 148 block_16_depthwise_relu
# 149 block_16_project
# 150 block_16_project_BN
# 151 Conv_1
# 152 Conv_1_bn
# 153 out_relu
# 154 global_average_pooling2d_13
# 155 predictions
# 156 dense_26
# 157 dropout_13
# 158 dense_27

# %%
# train and validate model
path_to_mobilenet_xfr_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5'
start_time = time.time()
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_xfr_parameters_file)])
duration = time.time() - start_time
print(f'MobileNet XFR Train Time = {duration}s')
# Out:
# Epoch 1/100
# 77/77 [==============================] - 5s 35ms/step - loss: 0.6266 - accuracy: 0.6476 - val_loss: 0.5410 - val_accuracy: 0.7540
#
# Epoch 00001: val_accuracy improved from -inf to 0.75401, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 2/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5817 - accuracy: 0.6999 - val_loss: 0.5087 - val_accuracy: 0.7620
#
# Epoch 00002: val_accuracy improved from 0.75401 to 0.76203, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 3/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5903 - accuracy: 0.6967 - val_loss: 0.4978 - val_accuracy: 0.7701
#
# Epoch 00003: val_accuracy improved from 0.76203 to 0.77005, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 4/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5880 - accuracy: 0.7018 - val_loss: 0.5175 - val_accuracy: 0.7914
#
# Epoch 00004: val_accuracy improved from 0.77005 to 0.79144, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 5/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5832 - accuracy: 0.7084 - val_loss: 0.4959 - val_accuracy: 0.7781
#
# Epoch 00005: val_accuracy did not improve from 0.79144
# Epoch 6/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5669 - accuracy: 0.7091 - val_loss: 0.4864 - val_accuracy: 0.7701
#
# Epoch 00006: val_accuracy did not improve from 0.79144
# Epoch 7/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5633 - accuracy: 0.7099 - val_loss: 0.4885 - val_accuracy: 0.7888
#
# Epoch 00007: val_accuracy did not improve from 0.79144
# Epoch 8/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5547 - accuracy: 0.7173 - val_loss: 0.4991 - val_accuracy: 0.7781
#
# Epoch 00008: val_accuracy did not improve from 0.79144
# Epoch 9/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5732 - accuracy: 0.7126 - val_loss: 0.4674 - val_accuracy: 0.7941
#
# Epoch 00009: val_accuracy improved from 0.79144 to 0.79412, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 10/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5870 - accuracy: 0.7114 - val_loss: 0.4863 - val_accuracy: 0.7567
#
# Epoch 00010: val_accuracy did not improve from 0.79412
# Epoch 11/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5518 - accuracy: 0.6977 - val_loss: 0.4943 - val_accuracy: 0.7995
#
# Epoch 00011: val_accuracy improved from 0.79412 to 0.79947, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 12/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5752 - accuracy: 0.6764 - val_loss: 0.4844 - val_accuracy: 0.7861
#
# Epoch 00012: val_accuracy did not improve from 0.79947
# Epoch 13/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5311 - accuracy: 0.7352 - val_loss: 0.5019 - val_accuracy: 0.7567
#
# Epoch 00013: val_accuracy did not improve from 0.79947
# Epoch 14/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5178 - accuracy: 0.7353 - val_loss: 0.4902 - val_accuracy: 0.7968
#
# Epoch 00014: val_accuracy did not improve from 0.79947
# Epoch 15/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5321 - accuracy: 0.7299 - val_loss: 0.4903 - val_accuracy: 0.7701
#
# Epoch 00015: val_accuracy did not improve from 0.79947
# Epoch 16/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5692 - accuracy: 0.6927 - val_loss: 0.4806 - val_accuracy: 0.7540
#
# Epoch 00016: val_accuracy did not improve from 0.79947
# Epoch 17/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5161 - accuracy: 0.7381 - val_loss: 0.4732 - val_accuracy: 0.7781
#
# Epoch 00017: val_accuracy did not improve from 0.79947
# Epoch 18/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5685 - accuracy: 0.6973 - val_loss: 0.4871 - val_accuracy: 0.7540
#
# Epoch 00018: val_accuracy did not improve from 0.79947
# Epoch 19/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5282 - accuracy: 0.7323 - val_loss: 0.4582 - val_accuracy: 0.8021
#
# Epoch 00019: val_accuracy improved from 0.79947 to 0.80214, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 20/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5128 - accuracy: 0.7456 - val_loss: 0.4819 - val_accuracy: 0.7888
#
# Epoch 00020: val_accuracy did not improve from 0.80214
# Epoch 21/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5142 - accuracy: 0.7485 - val_loss: 0.4940 - val_accuracy: 0.7701
#
# Epoch 00021: val_accuracy did not improve from 0.80214
# Epoch 22/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5314 - accuracy: 0.7425 - val_loss: 0.4925 - val_accuracy: 0.7674
#
# Epoch 00022: val_accuracy did not improve from 0.80214
# Epoch 23/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5034 - accuracy: 0.7521 - val_loss: 0.4847 - val_accuracy: 0.7674
#
# Epoch 00023: val_accuracy did not improve from 0.80214
# Epoch 24/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5051 - accuracy: 0.7303 - val_loss: 0.5060 - val_accuracy: 0.7594
#
# Epoch 00024: val_accuracy did not improve from 0.80214
# Epoch 25/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5354 - accuracy: 0.7137 - val_loss: 0.4660 - val_accuracy: 0.7914
#
# Epoch 00025: val_accuracy did not improve from 0.80214
# Epoch 26/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5383 - accuracy: 0.7064 - val_loss: 0.4852 - val_accuracy: 0.7647
#
# Epoch 00026: val_accuracy did not improve from 0.80214
# Epoch 27/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5171 - accuracy: 0.7300 - val_loss: 0.4578 - val_accuracy: 0.7834
#
# Epoch 00027: val_accuracy did not improve from 0.80214
# Epoch 28/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5116 - accuracy: 0.7399 - val_loss: 0.4826 - val_accuracy: 0.7807
#
# Epoch 00028: val_accuracy did not improve from 0.80214
# Epoch 29/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4756 - accuracy: 0.7707 - val_loss: 0.4878 - val_accuracy: 0.7914
#
# Epoch 00029: val_accuracy did not improve from 0.80214
# Epoch 30/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4982 - accuracy: 0.7490 - val_loss: 0.4478 - val_accuracy: 0.7781
#
# Epoch 00030: val_accuracy did not improve from 0.80214
# Epoch 31/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5163 - accuracy: 0.7309 - val_loss: 0.4841 - val_accuracy: 0.7594
#
# Epoch 00031: val_accuracy did not improve from 0.80214
# Epoch 32/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4981 - accuracy: 0.7554 - val_loss: 0.5033 - val_accuracy: 0.7460
#
# Epoch 00032: val_accuracy did not improve from 0.80214
# Epoch 33/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4985 - accuracy: 0.7670 - val_loss: 0.4638 - val_accuracy: 0.7807
#
# Epoch 00033: val_accuracy did not improve from 0.80214
# Epoch 34/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5335 - accuracy: 0.7023 - val_loss: 0.4791 - val_accuracy: 0.7594
#
# Epoch 00034: val_accuracy did not improve from 0.80214
# Epoch 35/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5096 - accuracy: 0.7398 - val_loss: 0.4878 - val_accuracy: 0.7701
#
# Epoch 00035: val_accuracy did not improve from 0.80214
# Epoch 36/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4682 - accuracy: 0.7549 - val_loss: 0.4925 - val_accuracy: 0.7701
#
# Epoch 00036: val_accuracy did not improve from 0.80214
# Epoch 37/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5191 - accuracy: 0.7191 - val_loss: 0.4560 - val_accuracy: 0.7674
#
# Epoch 00037: val_accuracy did not improve from 0.80214
# Epoch 38/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4828 - accuracy: 0.7732 - val_loss: 0.5122 - val_accuracy: 0.7754
#
# Epoch 00038: val_accuracy did not improve from 0.80214
# Epoch 39/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4950 - accuracy: 0.7598 - val_loss: 0.4831 - val_accuracy: 0.7861
#
# Epoch 00039: val_accuracy did not improve from 0.80214
# Epoch 40/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4747 - accuracy: 0.7440 - val_loss: 0.4810 - val_accuracy: 0.7647
#
# Epoch 00040: val_accuracy did not improve from 0.80214
# Epoch 41/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4885 - accuracy: 0.7479 - val_loss: 0.4765 - val_accuracy: 0.7914
#
# Epoch 00041: val_accuracy did not improve from 0.80214
# Epoch 42/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.5033 - accuracy: 0.7349 - val_loss: 0.4847 - val_accuracy: 0.7647
#
# Epoch 00042: val_accuracy did not improve from 0.80214
# Epoch 43/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.5000 - accuracy: 0.7436 - val_loss: 0.4893 - val_accuracy: 0.7727
#
# Epoch 00043: val_accuracy did not improve from 0.80214
# Epoch 44/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4837 - accuracy: 0.7560 - val_loss: 0.4884 - val_accuracy: 0.7968
#
# Epoch 00044: val_accuracy did not improve from 0.80214
# Epoch 45/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4572 - accuracy: 0.7738 - val_loss: 0.4610 - val_accuracy: 0.7781
#
# Epoch 00045: val_accuracy did not improve from 0.80214
# Epoch 46/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4849 - accuracy: 0.7385 - val_loss: 0.4849 - val_accuracy: 0.7594
#
# Epoch 00046: val_accuracy did not improve from 0.80214
# Epoch 47/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4378 - accuracy: 0.7833 - val_loss: 0.5263 - val_accuracy: 0.7326
#
# Epoch 00047: val_accuracy did not improve from 0.80214
# Epoch 48/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4847 - accuracy: 0.7549 - val_loss: 0.4748 - val_accuracy: 0.7834
#
# Epoch 00048: val_accuracy did not improve from 0.80214
# Epoch 49/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4499 - accuracy: 0.7656 - val_loss: 0.5284 - val_accuracy: 0.7273
#
# Epoch 00049: val_accuracy did not improve from 0.80214
# Epoch 50/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4867 - accuracy: 0.7518 - val_loss: 0.4809 - val_accuracy: 0.7995
#
# Epoch 00050: val_accuracy did not improve from 0.80214
# Epoch 51/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4898 - accuracy: 0.7708 - val_loss: 0.4816 - val_accuracy: 0.7888
#
# Epoch 00051: val_accuracy did not improve from 0.80214
# Epoch 52/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4722 - accuracy: 0.7774 - val_loss: 0.4742 - val_accuracy: 0.7647
#
# Epoch 00052: val_accuracy did not improve from 0.80214
# Epoch 53/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4553 - accuracy: 0.7814 - val_loss: 0.4832 - val_accuracy: 0.7647
#
# Epoch 00053: val_accuracy did not improve from 0.80214
# Epoch 54/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4681 - accuracy: 0.7670 - val_loss: 0.5322 - val_accuracy: 0.7246
#
# Epoch 00054: val_accuracy did not improve from 0.80214
# Epoch 55/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4765 - accuracy: 0.7541 - val_loss: 0.5061 - val_accuracy: 0.7807
#
# Epoch 00055: val_accuracy did not improve from 0.80214
# Epoch 56/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4619 - accuracy: 0.7762 - val_loss: 0.4995 - val_accuracy: 0.7674
#
# Epoch 00056: val_accuracy did not improve from 0.80214
# Epoch 57/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4458 - accuracy: 0.7735 - val_loss: 0.4835 - val_accuracy: 0.7594
#
# Epoch 00057: val_accuracy did not improve from 0.80214
# Epoch 58/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4739 - accuracy: 0.7658 - val_loss: 0.4768 - val_accuracy: 0.7861
#
# Epoch 00058: val_accuracy did not improve from 0.80214
# Epoch 59/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4530 - accuracy: 0.7700 - val_loss: 0.5020 - val_accuracy: 0.7620
#
# Epoch 00059: val_accuracy did not improve from 0.80214
# Epoch 60/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4659 - accuracy: 0.7565 - val_loss: 0.4875 - val_accuracy: 0.7754
#
# Epoch 00060: val_accuracy did not improve from 0.80214
# Epoch 61/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4736 - accuracy: 0.7449 - val_loss: 0.4910 - val_accuracy: 0.7754
#
# Epoch 00061: val_accuracy did not improve from 0.80214
# Epoch 62/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4322 - accuracy: 0.7874 - val_loss: 0.5017 - val_accuracy: 0.7941
#
# Epoch 00062: val_accuracy did not improve from 0.80214
# Epoch 63/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4866 - accuracy: 0.7396 - val_loss: 0.5265 - val_accuracy: 0.7727
#
# Epoch 00063: val_accuracy did not improve from 0.80214
# Epoch 64/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4542 - accuracy: 0.7901 - val_loss: 0.4911 - val_accuracy: 0.7727
#
# Epoch 00064: val_accuracy did not improve from 0.80214
# Epoch 65/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4761 - accuracy: 0.7498 - val_loss: 0.5102 - val_accuracy: 0.7861
#
# Epoch 00065: val_accuracy did not improve from 0.80214
# Epoch 66/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4763 - accuracy: 0.7565 - val_loss: 0.5108 - val_accuracy: 0.7620
#
# Epoch 00066: val_accuracy did not improve from 0.80214
# Epoch 67/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4828 - accuracy: 0.7429 - val_loss: 0.4829 - val_accuracy: 0.7861
#
# Epoch 00067: val_accuracy did not improve from 0.80214
# Epoch 68/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4462 - accuracy: 0.7741 - val_loss: 0.5549 - val_accuracy: 0.7139
#
# Epoch 00068: val_accuracy did not improve from 0.80214
# Epoch 69/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4782 - accuracy: 0.7636 - val_loss: 0.5236 - val_accuracy: 0.7353
#
# Epoch 00069: val_accuracy did not improve from 0.80214
# Epoch 70/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4753 - accuracy: 0.7606 - val_loss: 0.4797 - val_accuracy: 0.7888
#
# Epoch 00070: val_accuracy did not improve from 0.80214
# Epoch 71/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.4669 - accuracy: 0.7723 - val_loss: 0.5380 - val_accuracy: 0.7246
#
# Epoch 00071: val_accuracy did not improve from 0.80214
# Epoch 72/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4598 - accuracy: 0.7663 - val_loss: 0.4876 - val_accuracy: 0.7941
#
# Epoch 00072: val_accuracy did not improve from 0.80214
# Epoch 73/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4668 - accuracy: 0.7614 - val_loss: 0.4990 - val_accuracy: 0.7834
#
# Epoch 00073: val_accuracy did not improve from 0.80214
# Epoch 74/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4723 - accuracy: 0.7717 - val_loss: 0.4944 - val_accuracy: 0.7888
#
# Epoch 00074: val_accuracy did not improve from 0.80214
# Epoch 75/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4288 - accuracy: 0.7689 - val_loss: 0.5210 - val_accuracy: 0.7754
#
# Epoch 00075: val_accuracy did not improve from 0.80214
# Epoch 76/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4515 - accuracy: 0.7922 - val_loss: 0.5252 - val_accuracy: 0.7594
#
# Epoch 00076: val_accuracy did not improve from 0.80214
# Epoch 77/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4728 - accuracy: 0.7276 - val_loss: 0.5171 - val_accuracy: 0.7995
#
# Epoch 00077: val_accuracy did not improve from 0.80214
# Epoch 78/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4596 - accuracy: 0.7586 - val_loss: 0.5358 - val_accuracy: 0.7834
#
# Epoch 00078: val_accuracy did not improve from 0.80214
# Epoch 79/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4535 - accuracy: 0.7493 - val_loss: 0.5122 - val_accuracy: 0.7834
#
# Epoch 00079: val_accuracy did not improve from 0.80214
# Epoch 80/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4284 - accuracy: 0.7857 - val_loss: 0.5086 - val_accuracy: 0.7727
#
# Epoch 00080: val_accuracy did not improve from 0.80214
# Epoch 81/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4345 - accuracy: 0.7779 - val_loss: 0.4863 - val_accuracy: 0.7861
#
# Epoch 00081: val_accuracy did not improve from 0.80214
# Epoch 82/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4458 - accuracy: 0.7609 - val_loss: 0.4803 - val_accuracy: 0.7781
#
# Epoch 00082: val_accuracy did not improve from 0.80214
# Epoch 83/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4360 - accuracy: 0.7914 - val_loss: 0.5069 - val_accuracy: 0.7807
#
# Epoch 00083: val_accuracy did not improve from 0.80214
# Epoch 84/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4151 - accuracy: 0.7789 - val_loss: 0.5441 - val_accuracy: 0.7567
#
# Epoch 00084: val_accuracy did not improve from 0.80214
# Epoch 85/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4459 - accuracy: 0.7779 - val_loss: 0.5165 - val_accuracy: 0.7754
#
# Epoch 00085: val_accuracy did not improve from 0.80214
# Epoch 86/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4520 - accuracy: 0.7887 - val_loss: 0.5151 - val_accuracy: 0.7888
#
# Epoch 00086: val_accuracy did not improve from 0.80214
# Epoch 87/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4599 - accuracy: 0.7535 - val_loss: 0.5008 - val_accuracy: 0.7834
#
# Epoch 00087: val_accuracy did not improve from 0.80214
# Epoch 88/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4571 - accuracy: 0.7477 - val_loss: 0.5232 - val_accuracy: 0.8048
#
# Epoch 00088: val_accuracy improved from 0.80214 to 0.80481, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 89/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4226 - accuracy: 0.7909 - val_loss: 0.5352 - val_accuracy: 0.7620
#
# Epoch 00089: val_accuracy did not improve from 0.80481
# Epoch 90/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4350 - accuracy: 0.7801 - val_loss: 0.5061 - val_accuracy: 0.8075
#
# Epoch 00090: val_accuracy improved from 0.80481 to 0.80749, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_xfr.hdf5
# Epoch 91/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4595 - accuracy: 0.7632 - val_loss: 0.5231 - val_accuracy: 0.7914
#
# Epoch 00091: val_accuracy did not improve from 0.80749
# Epoch 92/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4012 - accuracy: 0.7924 - val_loss: 0.5302 - val_accuracy: 0.7941
#
# Epoch 00092: val_accuracy did not improve from 0.80749
# Epoch 93/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4142 - accuracy: 0.7833 - val_loss: 0.5169 - val_accuracy: 0.7914
#
# Epoch 00093: val_accuracy did not improve from 0.80749
# Epoch 94/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4233 - accuracy: 0.8014 - val_loss: 0.5162 - val_accuracy: 0.7781
#
# Epoch 00094: val_accuracy did not improve from 0.80749
# Epoch 95/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4741 - accuracy: 0.7349 - val_loss: 0.5274 - val_accuracy: 0.7647
#
# Epoch 00095: val_accuracy did not improve from 0.80749
# Epoch 96/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4315 - accuracy: 0.7555 - val_loss: 0.5292 - val_accuracy: 0.7861
#
# Epoch 00096: val_accuracy did not improve from 0.80749
# Epoch 97/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4062 - accuracy: 0.8031 - val_loss: 0.5494 - val_accuracy: 0.7674
#
# Epoch 00097: val_accuracy did not improve from 0.80749
# Epoch 98/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4190 - accuracy: 0.7971 - val_loss: 0.5192 - val_accuracy: 0.7941
#
# Epoch 00098: val_accuracy did not improve from 0.80749
# Epoch 99/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4617 - accuracy: 0.7603 - val_loss: 0.5453 - val_accuracy: 0.7594
#
# Epoch 00099: val_accuracy did not improve from 0.80749
# Epoch 100/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4167 - accuracy: 0.7974 - val_loss: 0.5422 - val_accuracy: 0.7914
#
# Epoch 00100: val_accuracy did not improve from 0.80749
# MobileNet XFR Train Time = 181.1317481994629s

# %%
# how to get the keys in your model
# for key in hist.history:
#   print(key)

# %%
# test model
#test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)

# %%
#len(test_predict)

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_xfr_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
start_time = time.time()
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
duration = time.time() - start_time
print(f'MobileNet XFR Test Time = {duration}s')
print(f'MobileNet XFR Test Time / sample = {duration/1155}s')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3db4f27053f8> in <module>()
#       1 # test with best model
#       2 #model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
# ----> 3 model_mn.load_weights(path_to_mobilenet_xfr_parameters_file)
#       4 # test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
#       5 start_time = time.time()
#
# NameError: name 'model_mn' is not defined

# %%
start_time = time.time()
# perform cross validation
if (CROSS_VALIDATE == True):
  # import libraries
  from sklearn.model_selection import StratifiedKFold
  # using stratifiedkfold so that we have balanced classes in each split
  cvfold = StratifiedKFold(n_splits = CROSS_VALIDATION_FOLDS, shuffle = True)
  # we will use below to store all individual validation scores
  cvscores = []
  # based on the class value, get the split done and respective train and test index
  for train_index, val_index in cvfold.split(all_images, all_labels_before_categorical):
    # model definition as is from top - starts
    # mobilenet = tf.keras.applications.mobilenet.MobileNet()
    # mobilenet = tf.keras.applications.MobileNet()
    mobilenet = tf.keras.applications.MobileNetV2()
    prediction_mn = mobilenet.output
    prediction_mn = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction_mn)
    prediction_mn = Dropout(DENSE_LAYER_DROPOUT)(prediction_mn)
    prediction_mn = Dense(2, activation = 'softmax')(prediction_mn)
    model_mn = Model(inputs = mobilenet.input, outputs = prediction_mn)
    for layer in mobilenet.layers:
      layer.trainable = False
    model_mn.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    # model definition as is from top - ends
    # train based on train index elements
    model_mn.fit(all_images[train_index], all_labels[train_index], epochs = EPOCHS, batch_size = BATCH_SIZE) 
    # validate based on validation index elements
    cv_score = model_mn.evaluate(all_images[val_index], all_labels[val_index])
    print("Validation Accuracy: %0.2f%%" % (cv_score[1]*100))
    # append each iteration validation accuracy score
    cvscores.append(cv_score[1]*100)
  # print mean and std deviation of the validation accuracy for the complete cross validation i.e. for all iterations
  print("Validation Accuracy Mean (+/- Std Deviation): %0.2f%% (+/- %0.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
duration = time.time() - start_time
print(f'MobileNet XFR Cross Validation Time = {duration}s')
# Out:
# Epoch 1/100
# 173/173 [==============================] - 5s 16ms/step - loss: 0.6292 - accuracy: 0.6664
# Epoch 2/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.5832 - accuracy: 0.7018
# Epoch 3/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5689 - accuracy: 0.7223
# Epoch 4/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5818 - accuracy: 0.7087
# Epoch 5/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5366 - accuracy: 0.7366
# Epoch 6/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5142 - accuracy: 0.7551
# Epoch 7/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5453 - accuracy: 0.7420
# Epoch 8/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5358 - accuracy: 0.7335
# Epoch 9/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5141 - accuracy: 0.7469
# Epoch 10/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.5440 - accuracy: 0.7375
# Epoch 11/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5159 - accuracy: 0.7441
# Epoch 12/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4934 - accuracy: 0.7532
# Epoch 13/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5117 - accuracy: 0.7457
# Epoch 14/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5080 - accuracy: 0.7413
# Epoch 15/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5007 - accuracy: 0.7669
# Epoch 16/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5114 - accuracy: 0.7565
# Epoch 17/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4960 - accuracy: 0.7667
# Epoch 18/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4963 - accuracy: 0.7662
# Epoch 19/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5069 - accuracy: 0.7649
# Epoch 20/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5103 - accuracy: 0.7375
# Epoch 21/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5135 - accuracy: 0.7268
# Epoch 22/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4769 - accuracy: 0.7630
# Epoch 23/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4843 - accuracy: 0.7700
# Epoch 24/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4530 - accuracy: 0.7821
# Epoch 25/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4584 - accuracy: 0.7886
# Epoch 26/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4932 - accuracy: 0.7626
# Epoch 27/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4691 - accuracy: 0.7707
# Epoch 28/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4757 - accuracy: 0.7709
# Epoch 29/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4708 - accuracy: 0.7773
# Epoch 30/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4664 - accuracy: 0.7733
# Epoch 31/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4822 - accuracy: 0.7762
# Epoch 32/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4599 - accuracy: 0.7818
# Epoch 33/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4912 - accuracy: 0.7722
# Epoch 34/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4807 - accuracy: 0.7625
# Epoch 35/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4436 - accuracy: 0.7782
# Epoch 36/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4457 - accuracy: 0.7896
# Epoch 37/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4909 - accuracy: 0.7698
# Epoch 38/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4658 - accuracy: 0.7767
# Epoch 39/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4550 - accuracy: 0.7881
# Epoch 40/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4764 - accuracy: 0.7676
# Epoch 41/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4578 - accuracy: 0.7683
# Epoch 42/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4346 - accuracy: 0.7962
# Epoch 43/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4348 - accuracy: 0.7845
# Epoch 44/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4474 - accuracy: 0.7828
# Epoch 45/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4634 - accuracy: 0.7649
# Epoch 46/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4868 - accuracy: 0.7604
# Epoch 47/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4580 - accuracy: 0.7668
# Epoch 48/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4237 - accuracy: 0.7882
# Epoch 49/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4353 - accuracy: 0.7911
# Epoch 50/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4549 - accuracy: 0.7694
# Epoch 51/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4372 - accuracy: 0.7880
# Epoch 52/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4358 - accuracy: 0.7919
# Epoch 53/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4234 - accuracy: 0.8021
# Epoch 54/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4305 - accuracy: 0.8057
# Epoch 55/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4250 - accuracy: 0.7935
# Epoch 56/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4274 - accuracy: 0.7913
# Epoch 57/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4189 - accuracy: 0.8111
# Epoch 58/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4175 - accuracy: 0.8099
# Epoch 59/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4304 - accuracy: 0.7959
# Epoch 60/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4348 - accuracy: 0.7969
# Epoch 61/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4337 - accuracy: 0.7846
# Epoch 62/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4176 - accuracy: 0.8018
# Epoch 63/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4181 - accuracy: 0.8018
# Epoch 64/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4327 - accuracy: 0.8002
# Epoch 65/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4194 - accuracy: 0.7955
# Epoch 66/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4239 - accuracy: 0.7901
# Epoch 67/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4062 - accuracy: 0.8224
# Epoch 68/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4360 - accuracy: 0.7981
# Epoch 69/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4239 - accuracy: 0.7971
# Epoch 70/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4340 - accuracy: 0.8079
# Epoch 71/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4283 - accuracy: 0.7950
# Epoch 72/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4154 - accuracy: 0.7890
# Epoch 73/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4207 - accuracy: 0.7917
# Epoch 74/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4113 - accuracy: 0.8009
# Epoch 75/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4426 - accuracy: 0.7879
# Epoch 76/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4370 - accuracy: 0.7965
# Epoch 77/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4236 - accuracy: 0.7867
# Epoch 78/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4122 - accuracy: 0.7954
# Epoch 79/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4226 - accuracy: 0.7938
# Epoch 80/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4383 - accuracy: 0.7783
# Epoch 81/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4275 - accuracy: 0.7994
# Epoch 82/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4131 - accuracy: 0.7882
# Epoch 83/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4226 - accuracy: 0.8020
# Epoch 84/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4107 - accuracy: 0.7939
# Epoch 85/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4194 - accuracy: 0.7849
# Epoch 86/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3743 - accuracy: 0.8296
# Epoch 87/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4088 - accuracy: 0.8080
# Epoch 88/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4047 - accuracy: 0.8032
# Epoch 89/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.3953 - accuracy: 0.8150
# Epoch 90/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4047 - accuracy: 0.7995
# Epoch 91/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4037 - accuracy: 0.8106
# Epoch 92/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3662 - accuracy: 0.8157
# Epoch 93/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3994 - accuracy: 0.8152
# Epoch 94/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4281 - accuracy: 0.7911
# Epoch 95/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4026 - accuracy: 0.8157
# Epoch 96/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.3826 - accuracy: 0.8156
# Epoch 97/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3961 - accuracy: 0.8043
# Epoch 98/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.3943 - accuracy: 0.8077
# Epoch 99/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4180 - accuracy: 0.7920
# Epoch 100/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3767 - accuracy: 0.8231
# 18/18 [==============================] - 2s 52ms/step - loss: 0.5211 - accuracy: 0.7600
# Validation Accuracy: 76.00%
# Epoch 1/100
# 173/173 [==============================] - 5s 16ms/step - loss: 0.6198 - accuracy: 0.6748
# Epoch 2/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5881 - accuracy: 0.6931
# Epoch 3/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5737 - accuracy: 0.7129
# Epoch 4/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5836 - accuracy: 0.6991
# Epoch 5/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5621 - accuracy: 0.7246
# Epoch 6/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5341 - accuracy: 0.7359
# Epoch 7/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5521 - accuracy: 0.7086
# Epoch 8/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.5373 - accuracy: 0.7366
# Epoch 9/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5203 - accuracy: 0.7528
# Epoch 10/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5251 - accuracy: 0.7437
# Epoch 11/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5244 - accuracy: 0.7337
# Epoch 12/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5155 - accuracy: 0.7391
# Epoch 13/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5137 - accuracy: 0.7399
# Epoch 14/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4947 - accuracy: 0.7517
# Epoch 15/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4967 - accuracy: 0.7421
# Epoch 16/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4865 - accuracy: 0.7534
# Epoch 17/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5059 - accuracy: 0.7469
# Epoch 18/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5179 - accuracy: 0.7416
# Epoch 19/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5036 - accuracy: 0.7565
# Epoch 20/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5117 - accuracy: 0.7292
# Epoch 21/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5218 - accuracy: 0.7244
# Epoch 22/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.5008 - accuracy: 0.7463
# Epoch 23/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4941 - accuracy: 0.7623
# Epoch 24/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4990 - accuracy: 0.7688
# Epoch 25/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5006 - accuracy: 0.7375
# Epoch 26/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5222 - accuracy: 0.7303
# Epoch 27/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4876 - accuracy: 0.7583
# Epoch 28/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4952 - accuracy: 0.7531
# Epoch 29/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4908 - accuracy: 0.7578
# Epoch 30/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5083 - accuracy: 0.7693
# Epoch 31/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4780 - accuracy: 0.7550
# Epoch 32/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4855 - accuracy: 0.7518
# Epoch 33/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4771 - accuracy: 0.7761
# Epoch 34/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4837 - accuracy: 0.7695
# Epoch 35/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4793 - accuracy: 0.7666
# Epoch 36/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4652 - accuracy: 0.7746
# Epoch 37/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4654 - accuracy: 0.7691
# Epoch 38/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4591 - accuracy: 0.7750
# Epoch 39/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4605 - accuracy: 0.7796
# Epoch 40/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4787 - accuracy: 0.7524
# Epoch 41/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4658 - accuracy: 0.7897
# Epoch 42/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4626 - accuracy: 0.7932
# Epoch 43/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4677 - accuracy: 0.7798
# Epoch 44/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4307 - accuracy: 0.7972
# Epoch 45/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4505 - accuracy: 0.7778
# Epoch 46/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4624 - accuracy: 0.7650
# Epoch 47/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4464 - accuracy: 0.7780
# Epoch 48/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4570 - accuracy: 0.7728
# Epoch 49/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4602 - accuracy: 0.7791
# Epoch 50/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4458 - accuracy: 0.7841
# Epoch 51/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4511 - accuracy: 0.7816
# Epoch 52/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4383 - accuracy: 0.7852
# Epoch 53/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4649 - accuracy: 0.7743
# Epoch 54/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4371 - accuracy: 0.7919
# Epoch 55/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4523 - accuracy: 0.7715
# Epoch 56/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4442 - accuracy: 0.7902
# Epoch 57/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4454 - accuracy: 0.7906
# Epoch 58/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4372 - accuracy: 0.7791
# Epoch 59/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4158 - accuracy: 0.8120
# Epoch 60/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4651 - accuracy: 0.7767
# Epoch 61/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4322 - accuracy: 0.7971
# Epoch 62/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4541 - accuracy: 0.7712
# Epoch 63/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4203 - accuracy: 0.7975
# Epoch 64/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4350 - accuracy: 0.7958
# Epoch 65/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4208 - accuracy: 0.8016
# Epoch 66/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4612 - accuracy: 0.7632
# Epoch 67/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4405 - accuracy: 0.7731
# Epoch 68/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4431 - accuracy: 0.7909
# Epoch 69/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4471 - accuracy: 0.7780
# Epoch 70/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4215 - accuracy: 0.7919
# Epoch 71/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4258 - accuracy: 0.8001
# Epoch 72/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4322 - accuracy: 0.7877
# Epoch 73/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4349 - accuracy: 0.7898
# Epoch 74/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4198 - accuracy: 0.7877
# Epoch 75/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4329 - accuracy: 0.7834
# Epoch 76/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4228 - accuracy: 0.8138
# Epoch 77/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4294 - accuracy: 0.7799
# Epoch 78/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4149 - accuracy: 0.7843
# Epoch 79/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4547 - accuracy: 0.7672
# Epoch 80/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4122 - accuracy: 0.7968
# Epoch 81/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4351 - accuracy: 0.7959
# Epoch 82/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4041 - accuracy: 0.8048
# Epoch 83/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4302 - accuracy: 0.7727
# Epoch 84/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4158 - accuracy: 0.7991
# Epoch 85/100
# 173/173 [==============================] - 3s 15ms/step - loss: 0.4231 - accuracy: 0.7947
# Epoch 86/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4237 - accuracy: 0.7881
# Epoch 87/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4421 - accuracy: 0.7759
# Epoch 88/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4063 - accuracy: 0.7997
# Epoch 89/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4004 - accuracy: 0.8155
# Epoch 90/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3991 - accuracy: 0.8178
# Epoch 91/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4202 - accuracy: 0.7926
# Epoch 92/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3979 - accuracy: 0.7988
# Epoch 93/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3901 - accuracy: 0.8197
# Epoch 94/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4212 - accuracy: 0.7845
# Epoch 95/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4014 - accuracy: 0.8030
# Epoch 96/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4032 - accuracy: 0.8172
# Epoch 97/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3916 - accuracy: 0.8007
# Epoch 98/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4234 - accuracy: 0.7824
# Epoch 99/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4047 - accuracy: 0.8113
# Epoch 100/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4053 - accuracy: 0.8104
# 18/18 [==============================] - 1s 42ms/step - loss: 0.5120 - accuracy: 0.7687
# Validation Accuracy: 76.87%
# Epoch 1/100
# 173/173 [==============================] - 5s 16ms/step - loss: 0.6209 - accuracy: 0.6602
# Epoch 2/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5850 - accuracy: 0.7091
# Epoch 3/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5758 - accuracy: 0.7111
# Epoch 4/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5444 - accuracy: 0.7305
# Epoch 5/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5611 - accuracy: 0.7318
# Epoch 6/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5412 - accuracy: 0.7291
# Epoch 7/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5289 - accuracy: 0.7368
# Epoch 8/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5262 - accuracy: 0.7313
# Epoch 9/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5192 - accuracy: 0.7432
# Epoch 10/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5244 - accuracy: 0.7447
# Epoch 11/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5156 - accuracy: 0.7427
# Epoch 12/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5009 - accuracy: 0.7542
# Epoch 13/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5066 - accuracy: 0.7500
# Epoch 14/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5111 - accuracy: 0.7504
# Epoch 15/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4941 - accuracy: 0.7614
# Epoch 16/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4977 - accuracy: 0.7444
# Epoch 17/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4906 - accuracy: 0.7451
# Epoch 18/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4817 - accuracy: 0.7688
# Epoch 19/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4989 - accuracy: 0.7361
# Epoch 20/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4844 - accuracy: 0.7612
# Epoch 21/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5214 - accuracy: 0.7420
# Epoch 22/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4890 - accuracy: 0.7572
# Epoch 23/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4916 - accuracy: 0.7596
# Epoch 24/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4954 - accuracy: 0.7755
# Epoch 25/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4809 - accuracy: 0.7567
# Epoch 26/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4807 - accuracy: 0.7629
# Epoch 27/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4950 - accuracy: 0.7477
# Epoch 28/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4890 - accuracy: 0.7450
# Epoch 29/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4634 - accuracy: 0.7823
# Epoch 30/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4554 - accuracy: 0.7870
# Epoch 31/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4646 - accuracy: 0.7878
# Epoch 32/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4847 - accuracy: 0.7714
# Epoch 33/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4489 - accuracy: 0.7878
# Epoch 34/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4694 - accuracy: 0.7786
# Epoch 35/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4633 - accuracy: 0.7750
# Epoch 36/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4507 - accuracy: 0.7834
# Epoch 37/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4393 - accuracy: 0.7840
# Epoch 38/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4413 - accuracy: 0.7979
# Epoch 39/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4630 - accuracy: 0.7827
# Epoch 40/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4746 - accuracy: 0.7492
# Epoch 41/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4667 - accuracy: 0.7705
# Epoch 42/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4562 - accuracy: 0.7664
# Epoch 43/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4927 - accuracy: 0.7779
# Epoch 44/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4504 - accuracy: 0.7755
# Epoch 45/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4626 - accuracy: 0.7662
# Epoch 46/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4557 - accuracy: 0.7674
# Epoch 47/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4349 - accuracy: 0.7823
# Epoch 48/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4673 - accuracy: 0.7758
# Epoch 49/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4406 - accuracy: 0.7909
# Epoch 50/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4487 - accuracy: 0.7861
# Epoch 51/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4457 - accuracy: 0.7873
# Epoch 52/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4381 - accuracy: 0.7797
# Epoch 53/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4564 - accuracy: 0.7840
# Epoch 54/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4486 - accuracy: 0.7861
# Epoch 55/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4634 - accuracy: 0.7688
# Epoch 56/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4544 - accuracy: 0.7882
# Epoch 57/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4572 - accuracy: 0.7733
# Epoch 58/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4397 - accuracy: 0.7913
# Epoch 59/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4461 - accuracy: 0.7879
# Epoch 60/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4494 - accuracy: 0.7837
# Epoch 61/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4423 - accuracy: 0.7841
# Epoch 62/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4496 - accuracy: 0.8077
# Epoch 63/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4405 - accuracy: 0.7937
# Epoch 64/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4323 - accuracy: 0.7923
# Epoch 65/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4140 - accuracy: 0.8118
# Epoch 66/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4395 - accuracy: 0.7895
# Epoch 67/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4658 - accuracy: 0.7841
# Epoch 68/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4244 - accuracy: 0.7996
# Epoch 69/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4331 - accuracy: 0.7880
# Epoch 70/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4291 - accuracy: 0.8072
# Epoch 71/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4586 - accuracy: 0.7723
# Epoch 72/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4364 - accuracy: 0.7860
# Epoch 73/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4232 - accuracy: 0.8000
# Epoch 74/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4327 - accuracy: 0.7841
# Epoch 75/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4344 - accuracy: 0.7960
# Epoch 76/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4363 - accuracy: 0.7944
# Epoch 77/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4261 - accuracy: 0.7989
# Epoch 78/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4255 - accuracy: 0.7916
# Epoch 79/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4191 - accuracy: 0.7884
# Epoch 80/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4251 - accuracy: 0.7960
# Epoch 81/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4183 - accuracy: 0.8067
# Epoch 82/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4064 - accuracy: 0.8085
# Epoch 83/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4108 - accuracy: 0.8139
# Epoch 84/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4367 - accuracy: 0.7896
# Epoch 85/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4268 - accuracy: 0.7877
# Epoch 86/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4106 - accuracy: 0.8007
# Epoch 87/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4107 - accuracy: 0.8071
# Epoch 88/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4294 - accuracy: 0.7964
# Epoch 89/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4036 - accuracy: 0.8018
# Epoch 90/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3987 - accuracy: 0.8162
# Epoch 91/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4246 - accuracy: 0.7898
# Epoch 92/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4343 - accuracy: 0.7995
# Epoch 93/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4370 - accuracy: 0.7768
# Epoch 94/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4234 - accuracy: 0.7951
# Epoch 95/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3999 - accuracy: 0.8026
# Epoch 96/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4094 - accuracy: 0.8095
# Epoch 97/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4345 - accuracy: 0.7736
# Epoch 98/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3971 - accuracy: 0.8133
# Epoch 99/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3992 - accuracy: 0.8187
# Epoch 100/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4103 - accuracy: 0.7962
# 18/18 [==============================] - 1s 42ms/step - loss: 0.4812 - accuracy: 0.7704
# Validation Accuracy: 77.04%
# Epoch 1/100
# 173/173 [==============================] - 5s 17ms/step - loss: 0.6030 - accuracy: 0.6780
# Epoch 2/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5636 - accuracy: 0.7154
# Epoch 3/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5617 - accuracy: 0.7111
# Epoch 4/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5205 - accuracy: 0.7457
# Epoch 5/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5401 - accuracy: 0.7206
# Epoch 6/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5235 - accuracy: 0.7380
# Epoch 7/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5394 - accuracy: 0.7285
# Epoch 8/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5445 - accuracy: 0.7181
# Epoch 9/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5257 - accuracy: 0.7424
# Epoch 10/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5236 - accuracy: 0.7387
# Epoch 11/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5105 - accuracy: 0.7309
# Epoch 12/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5087 - accuracy: 0.7466
# Epoch 13/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5317 - accuracy: 0.7225
# Epoch 14/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4833 - accuracy: 0.7626
# Epoch 15/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4929 - accuracy: 0.7533
# Epoch 16/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4905 - accuracy: 0.7503
# Epoch 17/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4861 - accuracy: 0.7559
# Epoch 18/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4835 - accuracy: 0.7630
# Epoch 19/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4938 - accuracy: 0.7567
# Epoch 20/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4711 - accuracy: 0.7760
# Epoch 21/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.5055 - accuracy: 0.7427
# Epoch 22/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4808 - accuracy: 0.7655
# Epoch 23/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4939 - accuracy: 0.7551
# Epoch 24/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4677 - accuracy: 0.7669
# Epoch 25/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4763 - accuracy: 0.7569
# Epoch 26/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4850 - accuracy: 0.7558
# Epoch 27/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4990 - accuracy: 0.7492
# Epoch 28/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4702 - accuracy: 0.7775
# Epoch 29/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4837 - accuracy: 0.7669
# Epoch 30/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4667 - accuracy: 0.7762
# Epoch 31/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4652 - accuracy: 0.7649
# Epoch 32/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4807 - accuracy: 0.7635
# Epoch 33/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4650 - accuracy: 0.7541
# Epoch 34/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4878 - accuracy: 0.7426
# Epoch 35/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4778 - accuracy: 0.7610
# Epoch 36/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4421 - accuracy: 0.7815
# Epoch 37/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4711 - accuracy: 0.7741
# Epoch 38/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4566 - accuracy: 0.7728
# Epoch 39/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4543 - accuracy: 0.7868
# Epoch 40/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4468 - accuracy: 0.7900
# Epoch 41/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4628 - accuracy: 0.7626
# Epoch 42/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4653 - accuracy: 0.7786
# Epoch 43/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4525 - accuracy: 0.7719
# Epoch 44/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4372 - accuracy: 0.7925
# Epoch 45/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4702 - accuracy: 0.7659
# Epoch 46/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4486 - accuracy: 0.7968
# Epoch 47/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4638 - accuracy: 0.7603
# Epoch 48/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4554 - accuracy: 0.7794
# Epoch 49/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4444 - accuracy: 0.7914
# Epoch 50/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4514 - accuracy: 0.7551
# Epoch 51/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4620 - accuracy: 0.7632
# Epoch 52/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4557 - accuracy: 0.7695
# Epoch 53/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4380 - accuracy: 0.7814
# Epoch 54/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4519 - accuracy: 0.7815
# Epoch 55/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4314 - accuracy: 0.7948
# Epoch 56/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4399 - accuracy: 0.7871
# Epoch 57/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4431 - accuracy: 0.7741
# Epoch 58/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4453 - accuracy: 0.7737
# Epoch 59/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4150 - accuracy: 0.7896
# Epoch 60/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4420 - accuracy: 0.7917
# Epoch 61/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4384 - accuracy: 0.7797
# Epoch 62/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4566 - accuracy: 0.7817
# Epoch 63/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4369 - accuracy: 0.7762
# Epoch 64/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4278 - accuracy: 0.7782
# Epoch 65/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4514 - accuracy: 0.7814
# Epoch 66/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4507 - accuracy: 0.7758
# Epoch 67/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4490 - accuracy: 0.7746
# Epoch 68/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4166 - accuracy: 0.8124
# Epoch 69/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4282 - accuracy: 0.7931
# Epoch 70/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4449 - accuracy: 0.7855
# Epoch 71/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4316 - accuracy: 0.7831
# Epoch 72/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4252 - accuracy: 0.8011
# Epoch 73/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4412 - accuracy: 0.7784
# Epoch 74/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4200 - accuracy: 0.7948
# Epoch 75/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4282 - accuracy: 0.7801
# Epoch 76/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4492 - accuracy: 0.7868
# Epoch 77/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4454 - accuracy: 0.7749
# Epoch 78/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4135 - accuracy: 0.8106
# Epoch 79/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4369 - accuracy: 0.7840
# Epoch 80/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4330 - accuracy: 0.7928
# Epoch 81/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4221 - accuracy: 0.7967
# Epoch 82/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3942 - accuracy: 0.8154
# Epoch 83/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4253 - accuracy: 0.7967
# Epoch 84/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4199 - accuracy: 0.7916
# Epoch 85/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4192 - accuracy: 0.7880
# Epoch 86/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4262 - accuracy: 0.7669
# Epoch 87/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4421 - accuracy: 0.7899
# Epoch 88/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4284 - accuracy: 0.8059
# Epoch 89/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4071 - accuracy: 0.7963
# Epoch 90/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4345 - accuracy: 0.8049
# Epoch 91/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4141 - accuracy: 0.8036
# Epoch 92/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3753 - accuracy: 0.8305
# Epoch 93/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4080 - accuracy: 0.8073
# Epoch 94/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3948 - accuracy: 0.8169
# Epoch 95/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4138 - accuracy: 0.7968
# Epoch 96/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4009 - accuracy: 0.8043
# Epoch 97/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4078 - accuracy: 0.7923
# Epoch 98/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.3844 - accuracy: 0.8125
# Epoch 99/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4165 - accuracy: 0.7990
# Epoch 100/100
# 173/173 [==============================] - 3s 16ms/step - loss: 0.4157 - accuracy: 0.7973
# 18/18 [==============================] - 2s 53ms/step - loss: 0.5640 - accuracy: 0.7822
# Validation Accuracy: 78.22%
# Validation Accuracy Mean (+/- Std Deviation): 77.03% (+/- 0.79%)
# MobileNet XFR Cross Validation Time = 1114.5975017547607s

# %% [markdown]
# #### Fine Tuning

# %%
# 0 to 72 = Till Conv11
# 73 to 79 - Conv12
# 80 to 85 = Conv13
# 86 to 91 = Post Conv13 before Custom (GAP...)
# 92 to 94 = Custom (Dense/Dropout/Dense(2)) = Trainable 
for layer in model_mn.layers[:151]: #80 for v1, 151 for v2
    layer.trainable=False
for layer in model_mn.layers[151:]: #80 for v1, 151 for v2
    layer.trainable=True

# %%
# calculate FLOPS for the model
flops_mobilenet_ft = get_flops(model_mn, batch_size = 1)
print(f"MobileNet FineTune FLOPS: {flops_mobilenet_ft / 10 ** 9:.03} G")
# Out:
# MobileNet FineTune FLOPS: 0.616 G

# %%
# train and validate model
path_to_mobilenet_ft_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5'
start_time = time.time()
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_ft_parameters_file)])
duration = time.time() - start_time
print(f'MobileNet FT Train Time = {duration}s')
# Out:
# Epoch 1/100
# 77/77 [==============================] - 3s 24ms/step - loss: 0.5001 - accuracy: 0.7519 - val_loss: 0.3923 - val_accuracy: 0.8342
#
# Epoch 00001: val_accuracy improved from -inf to 0.83422, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5
# Epoch 2/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4658 - accuracy: 0.7740 - val_loss: 0.3757 - val_accuracy: 0.8396
#
# Epoch 00002: val_accuracy improved from 0.83422 to 0.83957, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5
# Epoch 3/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4725 - accuracy: 0.7701 - val_loss: 0.3956 - val_accuracy: 0.8583
#
# Epoch 00003: val_accuracy improved from 0.83957 to 0.85829, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5
# Epoch 4/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4528 - accuracy: 0.7740 - val_loss: 0.3715 - val_accuracy: 0.8636
#
# Epoch 00004: val_accuracy improved from 0.85829 to 0.86364, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5
# Epoch 5/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4523 - accuracy: 0.7792 - val_loss: 0.3776 - val_accuracy: 0.8503
#
# Epoch 00005: val_accuracy did not improve from 0.86364
# Epoch 6/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4603 - accuracy: 0.7623 - val_loss: 0.3836 - val_accuracy: 0.8369
#
# Epoch 00006: val_accuracy did not improve from 0.86364
# Epoch 7/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4410 - accuracy: 0.7753 - val_loss: 0.3874 - val_accuracy: 0.8369
#
# Epoch 00007: val_accuracy did not improve from 0.86364
# Epoch 8/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4635 - accuracy: 0.7649 - val_loss: 0.3919 - val_accuracy: 0.8422
#
# Epoch 00008: val_accuracy did not improve from 0.86364
# Epoch 9/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4541 - accuracy: 0.7701 - val_loss: 0.3962 - val_accuracy: 0.8182
#
# Epoch 00009: val_accuracy did not improve from 0.86364
# Epoch 10/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4442 - accuracy: 0.7727 - val_loss: 0.3832 - val_accuracy: 0.8342
#
# Epoch 00010: val_accuracy did not improve from 0.86364
# Epoch 11/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4502 - accuracy: 0.7805 - val_loss: 0.3743 - val_accuracy: 0.8529
#
# Epoch 00011: val_accuracy did not improve from 0.86364
# Epoch 12/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4467 - accuracy: 0.7844 - val_loss: 0.3838 - val_accuracy: 0.8422
#
# Epoch 00012: val_accuracy did not improve from 0.86364
# Epoch 13/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4473 - accuracy: 0.7844 - val_loss: 0.3958 - val_accuracy: 0.8342
#
# Epoch 00013: val_accuracy did not improve from 0.86364
# Epoch 14/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4358 - accuracy: 0.7792 - val_loss: 0.3880 - val_accuracy: 0.8422
#
# Epoch 00014: val_accuracy did not improve from 0.86364
# Epoch 15/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4389 - accuracy: 0.7792 - val_loss: 0.3804 - val_accuracy: 0.8289
#
# Epoch 00015: val_accuracy did not improve from 0.86364
# Epoch 16/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4346 - accuracy: 0.7779 - val_loss: 0.3967 - val_accuracy: 0.8369
#
# Epoch 00016: val_accuracy did not improve from 0.86364
# Epoch 17/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4500 - accuracy: 0.7688 - val_loss: 0.4022 - val_accuracy: 0.8342
#
# Epoch 00017: val_accuracy did not improve from 0.86364
# Epoch 18/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4380 - accuracy: 0.7870 - val_loss: 0.4007 - val_accuracy: 0.8048
#
# Epoch 00018: val_accuracy did not improve from 0.86364
# Epoch 19/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4212 - accuracy: 0.7883 - val_loss: 0.4198 - val_accuracy: 0.8449
#
# Epoch 00019: val_accuracy did not improve from 0.86364
# Epoch 20/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4489 - accuracy: 0.7610 - val_loss: 0.4441 - val_accuracy: 0.8128
#
# Epoch 00020: val_accuracy did not improve from 0.86364
# Epoch 21/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4403 - accuracy: 0.7766 - val_loss: 0.3877 - val_accuracy: 0.8529
#
# Epoch 00021: val_accuracy did not improve from 0.86364
# Epoch 22/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4419 - accuracy: 0.7766 - val_loss: 0.3987 - val_accuracy: 0.8396
#
# Epoch 00022: val_accuracy did not improve from 0.86364
# Epoch 23/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4290 - accuracy: 0.7818 - val_loss: 0.3910 - val_accuracy: 0.8396
#
# Epoch 00023: val_accuracy did not improve from 0.86364
# Epoch 24/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4345 - accuracy: 0.8013 - val_loss: 0.4062 - val_accuracy: 0.8422
#
# Epoch 00024: val_accuracy did not improve from 0.86364
# Epoch 25/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4419 - accuracy: 0.7688 - val_loss: 0.4073 - val_accuracy: 0.8556
#
# Epoch 00025: val_accuracy did not improve from 0.86364
# Epoch 26/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4269 - accuracy: 0.7857 - val_loss: 0.4088 - val_accuracy: 0.8396
#
# Epoch 00026: val_accuracy did not improve from 0.86364
# Epoch 27/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4258 - accuracy: 0.7948 - val_loss: 0.4251 - val_accuracy: 0.8316
#
# Epoch 00027: val_accuracy did not improve from 0.86364
# Epoch 28/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4365 - accuracy: 0.7649 - val_loss: 0.3918 - val_accuracy: 0.8690
#
# Epoch 00028: val_accuracy improved from 0.86364 to 0.86898, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet_ft.hdf5
# Epoch 29/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4313 - accuracy: 0.7857 - val_loss: 0.3938 - val_accuracy: 0.8396
#
# Epoch 00029: val_accuracy did not improve from 0.86898
# Epoch 30/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4258 - accuracy: 0.7922 - val_loss: 0.4025 - val_accuracy: 0.8422
#
# Epoch 00030: val_accuracy did not improve from 0.86898
# Epoch 31/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4315 - accuracy: 0.8013 - val_loss: 0.4245 - val_accuracy: 0.7834
#
# Epoch 00031: val_accuracy did not improve from 0.86898
# Epoch 32/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4187 - accuracy: 0.7961 - val_loss: 0.4141 - val_accuracy: 0.8449
#
# Epoch 00032: val_accuracy did not improve from 0.86898
# Epoch 33/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4223 - accuracy: 0.7987 - val_loss: 0.4029 - val_accuracy: 0.8503
#
# Epoch 00033: val_accuracy did not improve from 0.86898
# Epoch 34/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4175 - accuracy: 0.7870 - val_loss: 0.4005 - val_accuracy: 0.8503
#
# Epoch 00034: val_accuracy did not improve from 0.86898
# Epoch 35/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4289 - accuracy: 0.7714 - val_loss: 0.3999 - val_accuracy: 0.8369
#
# Epoch 00035: val_accuracy did not improve from 0.86898
# Epoch 36/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4138 - accuracy: 0.7870 - val_loss: 0.4004 - val_accuracy: 0.8369
#
# Epoch 00036: val_accuracy did not improve from 0.86898
# Epoch 37/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4212 - accuracy: 0.7727 - val_loss: 0.4198 - val_accuracy: 0.8262
#
# Epoch 00037: val_accuracy did not improve from 0.86898
# Epoch 38/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4237 - accuracy: 0.7857 - val_loss: 0.4324 - val_accuracy: 0.8342
#
# Epoch 00038: val_accuracy did not improve from 0.86898
# Epoch 39/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4130 - accuracy: 0.7961 - val_loss: 0.4413 - val_accuracy: 0.8021
#
# Epoch 00039: val_accuracy did not improve from 0.86898
# Epoch 40/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4106 - accuracy: 0.7896 - val_loss: 0.4024 - val_accuracy: 0.8209
#
# Epoch 00040: val_accuracy did not improve from 0.86898
# Epoch 41/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4289 - accuracy: 0.7987 - val_loss: 0.3929 - val_accuracy: 0.8369
#
# Epoch 00041: val_accuracy did not improve from 0.86898
# Epoch 42/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3998 - accuracy: 0.8013 - val_loss: 0.3946 - val_accuracy: 0.8476
#
# Epoch 00042: val_accuracy did not improve from 0.86898
# Epoch 43/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4152 - accuracy: 0.7844 - val_loss: 0.3956 - val_accuracy: 0.8262
#
# Epoch 00043: val_accuracy did not improve from 0.86898
# Epoch 44/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4199 - accuracy: 0.7909 - val_loss: 0.4103 - val_accuracy: 0.8369
#
# Epoch 00044: val_accuracy did not improve from 0.86898
# Epoch 45/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4038 - accuracy: 0.7935 - val_loss: 0.4121 - val_accuracy: 0.8422
#
# Epoch 00045: val_accuracy did not improve from 0.86898
# Epoch 46/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4170 - accuracy: 0.7896 - val_loss: 0.3995 - val_accuracy: 0.8449
#
# Epoch 00046: val_accuracy did not improve from 0.86898
# Epoch 47/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4115 - accuracy: 0.7948 - val_loss: 0.4161 - val_accuracy: 0.8262
#
# Epoch 00047: val_accuracy did not improve from 0.86898
# Epoch 48/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4006 - accuracy: 0.8000 - val_loss: 0.3936 - val_accuracy: 0.8289
#
# Epoch 00048: val_accuracy did not improve from 0.86898
# Epoch 49/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4107 - accuracy: 0.7948 - val_loss: 0.4074 - val_accuracy: 0.8449
#
# Epoch 00049: val_accuracy did not improve from 0.86898
# Epoch 50/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.4079 - accuracy: 0.8026 - val_loss: 0.3946 - val_accuracy: 0.8476
#
# Epoch 00050: val_accuracy did not improve from 0.86898
# Epoch 51/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4132 - accuracy: 0.7922 - val_loss: 0.4226 - val_accuracy: 0.8503
#
# Epoch 00051: val_accuracy did not improve from 0.86898
# Epoch 52/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3932 - accuracy: 0.8247 - val_loss: 0.4086 - val_accuracy: 0.8316
#
# Epoch 00052: val_accuracy did not improve from 0.86898
# Epoch 53/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4046 - accuracy: 0.8026 - val_loss: 0.3902 - val_accuracy: 0.8503
#
# Epoch 00053: val_accuracy did not improve from 0.86898
# Epoch 54/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4102 - accuracy: 0.7961 - val_loss: 0.4097 - val_accuracy: 0.8316
#
# Epoch 00054: val_accuracy did not improve from 0.86898
# Epoch 55/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4044 - accuracy: 0.7974 - val_loss: 0.4083 - val_accuracy: 0.8369
#
# Epoch 00055: val_accuracy did not improve from 0.86898
# Epoch 56/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3876 - accuracy: 0.8143 - val_loss: 0.4018 - val_accuracy: 0.8449
#
# Epoch 00056: val_accuracy did not improve from 0.86898
# Epoch 57/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3918 - accuracy: 0.8130 - val_loss: 0.4348 - val_accuracy: 0.8075
#
# Epoch 00057: val_accuracy did not improve from 0.86898
# Epoch 58/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4015 - accuracy: 0.8039 - val_loss: 0.4156 - val_accuracy: 0.8262
#
# Epoch 00058: val_accuracy did not improve from 0.86898
# Epoch 59/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3892 - accuracy: 0.8065 - val_loss: 0.4490 - val_accuracy: 0.8128
#
# Epoch 00059: val_accuracy did not improve from 0.86898
# Epoch 60/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4206 - accuracy: 0.7896 - val_loss: 0.4368 - val_accuracy: 0.8209
#
# Epoch 00060: val_accuracy did not improve from 0.86898
# Epoch 61/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4250 - accuracy: 0.7974 - val_loss: 0.4178 - val_accuracy: 0.8449
#
# Epoch 00061: val_accuracy did not improve from 0.86898
# Epoch 62/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4084 - accuracy: 0.7987 - val_loss: 0.4270 - val_accuracy: 0.8316
#
# Epoch 00062: val_accuracy did not improve from 0.86898
# Epoch 63/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3932 - accuracy: 0.8013 - val_loss: 0.4449 - val_accuracy: 0.8209
#
# Epoch 00063: val_accuracy did not improve from 0.86898
# Epoch 64/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3984 - accuracy: 0.8039 - val_loss: 0.4535 - val_accuracy: 0.8102
#
# Epoch 00064: val_accuracy did not improve from 0.86898
# Epoch 65/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3989 - accuracy: 0.8117 - val_loss: 0.4434 - val_accuracy: 0.8262
#
# Epoch 00065: val_accuracy did not improve from 0.86898
# Epoch 66/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4010 - accuracy: 0.8000 - val_loss: 0.4620 - val_accuracy: 0.8128
#
# Epoch 00066: val_accuracy did not improve from 0.86898
# Epoch 67/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3915 - accuracy: 0.8143 - val_loss: 0.4485 - val_accuracy: 0.8182
#
# Epoch 00067: val_accuracy did not improve from 0.86898
# Epoch 68/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.4368 - accuracy: 0.7844 - val_loss: 0.4250 - val_accuracy: 0.8342
#
# Epoch 00068: val_accuracy did not improve from 0.86898
# Epoch 69/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3958 - accuracy: 0.8065 - val_loss: 0.4224 - val_accuracy: 0.8316
#
# Epoch 00069: val_accuracy did not improve from 0.86898
# Epoch 70/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3873 - accuracy: 0.7896 - val_loss: 0.4090 - val_accuracy: 0.8422
#
# Epoch 00070: val_accuracy did not improve from 0.86898
# Epoch 71/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.4108 - accuracy: 0.7935 - val_loss: 0.4182 - val_accuracy: 0.8289
#
# Epoch 00071: val_accuracy did not improve from 0.86898
# Epoch 72/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3941 - accuracy: 0.8052 - val_loss: 0.4347 - val_accuracy: 0.8128
#
# Epoch 00072: val_accuracy did not improve from 0.86898
# Epoch 73/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3802 - accuracy: 0.8000 - val_loss: 0.4298 - val_accuracy: 0.8209
#
# Epoch 00073: val_accuracy did not improve from 0.86898
# Epoch 74/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3950 - accuracy: 0.8104 - val_loss: 0.4066 - val_accuracy: 0.8209
#
# Epoch 00074: val_accuracy did not improve from 0.86898
# Epoch 75/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3980 - accuracy: 0.8000 - val_loss: 0.4395 - val_accuracy: 0.8102
#
# Epoch 00075: val_accuracy did not improve from 0.86898
# Epoch 76/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3945 - accuracy: 0.7935 - val_loss: 0.4327 - val_accuracy: 0.8102
#
# Epoch 00076: val_accuracy did not improve from 0.86898
# Epoch 77/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3970 - accuracy: 0.8156 - val_loss: 0.4240 - val_accuracy: 0.8369
#
# Epoch 00077: val_accuracy did not improve from 0.86898
# Epoch 78/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3899 - accuracy: 0.8026 - val_loss: 0.4312 - val_accuracy: 0.8342
#
# Epoch 00078: val_accuracy did not improve from 0.86898
# Epoch 79/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3873 - accuracy: 0.8000 - val_loss: 0.4445 - val_accuracy: 0.8396
#
# Epoch 00079: val_accuracy did not improve from 0.86898
# Epoch 80/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3822 - accuracy: 0.8013 - val_loss: 0.4480 - val_accuracy: 0.8369
#
# Epoch 00080: val_accuracy did not improve from 0.86898
# Epoch 81/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3976 - accuracy: 0.8143 - val_loss: 0.4297 - val_accuracy: 0.8396
#
# Epoch 00081: val_accuracy did not improve from 0.86898
# Epoch 82/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3795 - accuracy: 0.8013 - val_loss: 0.4116 - val_accuracy: 0.8369
#
# Epoch 00082: val_accuracy did not improve from 0.86898
# Epoch 83/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3799 - accuracy: 0.8247 - val_loss: 0.4585 - val_accuracy: 0.8021
#
# Epoch 00083: val_accuracy did not improve from 0.86898
# Epoch 84/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3870 - accuracy: 0.8065 - val_loss: 0.4323 - val_accuracy: 0.8422
#
# Epoch 00084: val_accuracy did not improve from 0.86898
# Epoch 85/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3790 - accuracy: 0.8117 - val_loss: 0.4307 - val_accuracy: 0.8342
#
# Epoch 00085: val_accuracy did not improve from 0.86898
# Epoch 86/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3849 - accuracy: 0.8195 - val_loss: 0.4499 - val_accuracy: 0.8155
#
# Epoch 00086: val_accuracy did not improve from 0.86898
# Epoch 87/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3950 - accuracy: 0.8078 - val_loss: 0.4334 - val_accuracy: 0.8155
#
# Epoch 00087: val_accuracy did not improve from 0.86898
# Epoch 88/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3770 - accuracy: 0.8195 - val_loss: 0.4423 - val_accuracy: 0.8262
#
# Epoch 00088: val_accuracy did not improve from 0.86898
# Epoch 89/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3858 - accuracy: 0.8013 - val_loss: 0.4716 - val_accuracy: 0.8048
#
# Epoch 00089: val_accuracy did not improve from 0.86898
# Epoch 90/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3755 - accuracy: 0.8169 - val_loss: 0.4413 - val_accuracy: 0.8342
#
# Epoch 00090: val_accuracy did not improve from 0.86898
# Epoch 91/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.4049 - accuracy: 0.7974 - val_loss: 0.4272 - val_accuracy: 0.8289
#
# Epoch 00091: val_accuracy did not improve from 0.86898
# Epoch 92/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3865 - accuracy: 0.8104 - val_loss: 0.3993 - val_accuracy: 0.8316
#
# Epoch 00092: val_accuracy did not improve from 0.86898
# Epoch 93/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3891 - accuracy: 0.7935 - val_loss: 0.4485 - val_accuracy: 0.8396
#
# Epoch 00093: val_accuracy did not improve from 0.86898
# Epoch 94/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3744 - accuracy: 0.8208 - val_loss: 0.4536 - val_accuracy: 0.7995
#
# Epoch 00094: val_accuracy did not improve from 0.86898
# Epoch 95/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3800 - accuracy: 0.8182 - val_loss: 0.4491 - val_accuracy: 0.8262
#
# Epoch 00095: val_accuracy did not improve from 0.86898
# Epoch 96/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3840 - accuracy: 0.7922 - val_loss: 0.4805 - val_accuracy: 0.8155
#
# Epoch 00096: val_accuracy did not improve from 0.86898
# Epoch 97/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.3655 - accuracy: 0.8130 - val_loss: 0.4606 - val_accuracy: 0.8342
#
# Epoch 00097: val_accuracy did not improve from 0.86898
# Epoch 98/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3716 - accuracy: 0.7961 - val_loss: 0.4746 - val_accuracy: 0.8289
#
# Epoch 00098: val_accuracy did not improve from 0.86898
# Epoch 99/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3724 - accuracy: 0.8286 - val_loss: 0.4770 - val_accuracy: 0.8075
#
# Epoch 00099: val_accuracy did not improve from 0.86898
# Epoch 100/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.3692 - accuracy: 0.8104 - val_loss: 0.4575 - val_accuracy: 0.8262
#
# Epoch 00100: val_accuracy did not improve from 0.86898
# MobileNet FT Train Time = 182.8962504863739s

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_ft_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
start_time = time.time()
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
duration = time.time() - start_time
print(f'MobileNet FT Test Time = {duration}s')
print(f'MobileNet FT Test Time / sample = {duration/1155}s')
# Out:
# 37/37 [==============================] - 2s 43ms/step - loss: 0.4700 - accuracy: 0.7983
# MobileNet FT Test Time = 1.6506900787353516s
# MobileNet FT Test Time / sample = 0.0014291688993379667s

# %%
start_time = time.time()
# perform cross validation
if (CROSS_VALIDATE == True):
  # import libraries
  from sklearn.model_selection import StratifiedKFold
  # using stratifiedkfold so that we have balanced classes in each split
  cvfold = StratifiedKFold(n_splits = CROSS_VALIDATION_FOLDS, shuffle = True)
  # we will use below to store all individual validation scores
  cvscores = []
  # based on the class value, get the split done and respective train and test index
  for train_index, val_index in cvfold.split(all_images, all_labels_before_categorical):
    # model definition as is from top - starts
    # mobilenet = tf.keras.applications.mobilenet.MobileNet()
    # mobilenet = tf.keras.applications.MobileNet()
    mobilenet = tf.keras.applications.MobileNetV2()
    prediction_mn = mobilenet.output
    prediction_mn = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction_mn)
    prediction_mn = Dropout(DENSE_LAYER_DROPOUT)(prediction_mn)
    prediction_mn = Dense(2, activation = 'softmax')(prediction_mn)
    model_mn = Model(inputs = mobilenet.input, outputs = prediction_mn)
    for layer in mobilenet.layers:
      layer.trainable = False
    model_mn.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])
    # note using the file from transfer and not from finetune to load the weights
    model_mn.load_weights(path_to_mobilenet_xfr_parameters_file)
    for layer in model_mn.layers[:80]:
      layer.trainable=False
    for layer in model_mn.layers[80:]:
      layer.trainable=True
    # model definition as is from top - ends
    # train based on train index elements
    model_mn.fit(all_images[train_index], all_labels[train_index], epochs = EPOCHS, batch_size = BATCH_SIZE) 
    # validate based on validation index elements
    cv_score = model_mn.evaluate(all_images[val_index], all_labels[val_index])
    print("Validation Accuracy: %0.2f%%" % (cv_score[1]*100))
    # append each iteration validation accuracy score
    cvscores.append(cv_score[1]*100)
  # print mean and std deviation of the validation accuracy for the complete cross validation i.e. for all iterations
  print("Validation Accuracy Mean (+/- Std Deviation): %0.2f%% (+/- %0.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
duration = time.time() - start_time
print(f'MobileNet FT Cross Validation Time = {duration}s')
# Out:
# Epoch 1/100
# 173/173 [==============================] - 5s 17ms/step - loss: 0.5978 - accuracy: 0.7428
# Epoch 2/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5200 - accuracy: 0.7382
# Epoch 3/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5013 - accuracy: 0.7488
# Epoch 4/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4853 - accuracy: 0.7572
# Epoch 5/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4867 - accuracy: 0.7504
# Epoch 6/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4854 - accuracy: 0.7592
# Epoch 7/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4778 - accuracy: 0.7755
# Epoch 8/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4702 - accuracy: 0.7710
# Epoch 9/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4653 - accuracy: 0.7871
# Epoch 10/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4733 - accuracy: 0.7737
# Epoch 11/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4853 - accuracy: 0.7618
# Epoch 12/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4621 - accuracy: 0.7737
# Epoch 13/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4392 - accuracy: 0.7734
# Epoch 14/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5012 - accuracy: 0.7472
# Epoch 15/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4452 - accuracy: 0.7698
# Epoch 16/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4605 - accuracy: 0.7755
# Epoch 17/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4601 - accuracy: 0.7715
# Epoch 18/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4673 - accuracy: 0.7604
# Epoch 19/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4664 - accuracy: 0.7710
# Epoch 20/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4393 - accuracy: 0.7770
# Epoch 21/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4562 - accuracy: 0.7672
# Epoch 22/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4673 - accuracy: 0.7777
# Epoch 23/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4494 - accuracy: 0.7949
# Epoch 24/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4578 - accuracy: 0.7703
# Epoch 25/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4433 - accuracy: 0.7874
# Epoch 26/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4674 - accuracy: 0.7812
# Epoch 27/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4427 - accuracy: 0.7748
# Epoch 28/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4416 - accuracy: 0.7897
# Epoch 29/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4347 - accuracy: 0.7858
# Epoch 30/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4531 - accuracy: 0.7768
# Epoch 31/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4573 - accuracy: 0.7758
# Epoch 32/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4418 - accuracy: 0.7786
# Epoch 33/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4228 - accuracy: 0.7952
# Epoch 34/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4683 - accuracy: 0.7739
# Epoch 35/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4385 - accuracy: 0.7925
# Epoch 36/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4387 - accuracy: 0.7897
# Epoch 37/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4525 - accuracy: 0.7830
# Epoch 38/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4450 - accuracy: 0.7943
# Epoch 39/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4249 - accuracy: 0.8004
# Epoch 40/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4313 - accuracy: 0.8006
# Epoch 41/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4188 - accuracy: 0.7963
# Epoch 42/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4115 - accuracy: 0.8016
# Epoch 43/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4281 - accuracy: 0.7825
# Epoch 44/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4158 - accuracy: 0.7805
# Epoch 45/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4435 - accuracy: 0.8018
# Epoch 46/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4255 - accuracy: 0.8007
# Epoch 47/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4249 - accuracy: 0.8037
# Epoch 48/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4168 - accuracy: 0.8044
# Epoch 49/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4469 - accuracy: 0.7851
# Epoch 50/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4142 - accuracy: 0.7876
# Epoch 51/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4000 - accuracy: 0.8027
# Epoch 52/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4252 - accuracy: 0.7768
# Epoch 53/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4352 - accuracy: 0.7638
# Epoch 54/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4108 - accuracy: 0.8015
# Epoch 55/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4008 - accuracy: 0.8127
# Epoch 56/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4165 - accuracy: 0.8031
# Epoch 57/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4281 - accuracy: 0.7993
# Epoch 58/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3690 - accuracy: 0.8247
# Epoch 59/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4201 - accuracy: 0.7935
# Epoch 60/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4147 - accuracy: 0.8060
# Epoch 61/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4023 - accuracy: 0.8100
# Epoch 62/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4037 - accuracy: 0.8103
# Epoch 63/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3988 - accuracy: 0.8022
# Epoch 64/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4152 - accuracy: 0.7887
# Epoch 65/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4162 - accuracy: 0.8064
# Epoch 66/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4054 - accuracy: 0.8047
# Epoch 67/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4192 - accuracy: 0.7961
# Epoch 68/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4008 - accuracy: 0.8190
# Epoch 69/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4059 - accuracy: 0.8088
# Epoch 70/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4043 - accuracy: 0.7921
# Epoch 71/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4157 - accuracy: 0.8034
# Epoch 72/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4214 - accuracy: 0.7927
# Epoch 73/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3966 - accuracy: 0.8073
# Epoch 74/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4167 - accuracy: 0.7883
# Epoch 75/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3948 - accuracy: 0.7926
# Epoch 76/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3923 - accuracy: 0.7913
# Epoch 77/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3874 - accuracy: 0.8046
# Epoch 78/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3768 - accuracy: 0.8328
# Epoch 79/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4198 - accuracy: 0.7825
# Epoch 80/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4238 - accuracy: 0.7860
# Epoch 81/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3914 - accuracy: 0.8089
# Epoch 82/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3806 - accuracy: 0.8255
# Epoch 83/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4109 - accuracy: 0.7913
# Epoch 84/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3987 - accuracy: 0.7981
# Epoch 85/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3915 - accuracy: 0.8134
# Epoch 86/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3941 - accuracy: 0.7925
# Epoch 87/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4039 - accuracy: 0.8017
# Epoch 88/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3765 - accuracy: 0.8210
# Epoch 89/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3967 - accuracy: 0.8087
# Epoch 90/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3973 - accuracy: 0.7970
# Epoch 91/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4007 - accuracy: 0.8059
# Epoch 92/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3829 - accuracy: 0.8299
# Epoch 93/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3852 - accuracy: 0.8162
# Epoch 94/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3622 - accuracy: 0.8355
# Epoch 95/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3866 - accuracy: 0.8148
# Epoch 96/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3968 - accuracy: 0.8115
# Epoch 97/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3923 - accuracy: 0.8083
# Epoch 98/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4055 - accuracy: 0.7963
# Epoch 99/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3954 - accuracy: 0.7923
# Epoch 100/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4030 - accuracy: 0.8080
# 18/18 [==============================] - 2s 43ms/step - loss: 0.5221 - accuracy: 0.7913
# Validation Accuracy: 79.13%
# Epoch 1/100
# 173/173 [==============================] - 5s 17ms/step - loss: 0.5667 - accuracy: 0.7604
# Epoch 2/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5358 - accuracy: 0.7611
# Epoch 3/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5166 - accuracy: 0.7568
# Epoch 4/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5246 - accuracy: 0.7289
# Epoch 5/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5203 - accuracy: 0.7536
# Epoch 6/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4917 - accuracy: 0.7599
# Epoch 7/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4940 - accuracy: 0.7609
# Epoch 8/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5243 - accuracy: 0.7309
# Epoch 9/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4743 - accuracy: 0.7552
# Epoch 10/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5001 - accuracy: 0.7621
# Epoch 11/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4894 - accuracy: 0.7608
# Epoch 12/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4725 - accuracy: 0.7761
# Epoch 13/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4744 - accuracy: 0.7749
# Epoch 14/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4757 - accuracy: 0.7633
# Epoch 15/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4752 - accuracy: 0.7525
# Epoch 16/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4565 - accuracy: 0.7789
# Epoch 17/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4647 - accuracy: 0.7883
# Epoch 18/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4909 - accuracy: 0.7635
# Epoch 19/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4693 - accuracy: 0.7690
# Epoch 20/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4803 - accuracy: 0.7751
# Epoch 21/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4845 - accuracy: 0.7713
# Epoch 22/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4607 - accuracy: 0.7890
# Epoch 23/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4690 - accuracy: 0.7593
# Epoch 24/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4644 - accuracy: 0.7746
# Epoch 25/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4515 - accuracy: 0.7828
# Epoch 26/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4848 - accuracy: 0.7571
# Epoch 27/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4560 - accuracy: 0.7795
# Epoch 28/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4522 - accuracy: 0.7774
# Epoch 29/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4556 - accuracy: 0.7814
# Epoch 30/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4458 - accuracy: 0.7831
# Epoch 31/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4498 - accuracy: 0.7820
# Epoch 32/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4610 - accuracy: 0.7749
# Epoch 33/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4515 - accuracy: 0.7882
# Epoch 34/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4462 - accuracy: 0.7817
# Epoch 35/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4580 - accuracy: 0.7742
# Epoch 36/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4695 - accuracy: 0.7661
# Epoch 37/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4412 - accuracy: 0.7790
# Epoch 38/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4444 - accuracy: 0.7821
# Epoch 39/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4577 - accuracy: 0.7676
# Epoch 40/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4472 - accuracy: 0.7931
# Epoch 41/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4393 - accuracy: 0.7950
# Epoch 42/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4506 - accuracy: 0.7777
# Epoch 43/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4364 - accuracy: 0.7828
# Epoch 44/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4492 - accuracy: 0.7725
# Epoch 45/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4261 - accuracy: 0.7842
# Epoch 46/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4585 - accuracy: 0.7678
# Epoch 47/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4512 - accuracy: 0.7870
# Epoch 48/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4614 - accuracy: 0.7606
# Epoch 49/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4487 - accuracy: 0.7728
# Epoch 50/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4347 - accuracy: 0.7872
# Epoch 51/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4407 - accuracy: 0.7847
# Epoch 52/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4397 - accuracy: 0.7832
# Epoch 53/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4334 - accuracy: 0.7841
# Epoch 54/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4373 - accuracy: 0.7857
# Epoch 55/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4375 - accuracy: 0.7765
# Epoch 56/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4419 - accuracy: 0.8025
# Epoch 57/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4436 - accuracy: 0.7668
# Epoch 58/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4262 - accuracy: 0.7921
# Epoch 59/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4182 - accuracy: 0.7985
# Epoch 60/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4020 - accuracy: 0.8067
# Epoch 61/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4281 - accuracy: 0.8011
# Epoch 62/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4426 - accuracy: 0.7823
# Epoch 63/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4070 - accuracy: 0.8163
# Epoch 64/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4552 - accuracy: 0.7712
# Epoch 65/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4168 - accuracy: 0.8093
# Epoch 66/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4254 - accuracy: 0.8037
# Epoch 67/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4241 - accuracy: 0.8034
# Epoch 68/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4246 - accuracy: 0.7939
# Epoch 69/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4273 - accuracy: 0.7887
# Epoch 70/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4327 - accuracy: 0.7903
# Epoch 71/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4160 - accuracy: 0.8117
# Epoch 72/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4150 - accuracy: 0.7908
# Epoch 73/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4248 - accuracy: 0.7933
# Epoch 74/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4207 - accuracy: 0.7966
# Epoch 75/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4113 - accuracy: 0.7907
# Epoch 76/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4357 - accuracy: 0.7858
# Epoch 77/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4433 - accuracy: 0.7834
# Epoch 78/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3989 - accuracy: 0.8121
# Epoch 79/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4216 - accuracy: 0.7977
# Epoch 80/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4251 - accuracy: 0.7975
# Epoch 81/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4134 - accuracy: 0.8052
# Epoch 82/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4184 - accuracy: 0.8020
# Epoch 83/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4533 - accuracy: 0.7632
# Epoch 84/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4129 - accuracy: 0.7899
# Epoch 85/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3955 - accuracy: 0.7969
# Epoch 86/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4146 - accuracy: 0.7967
# Epoch 87/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4299 - accuracy: 0.8014
# Epoch 88/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4207 - accuracy: 0.7908
# Epoch 89/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4108 - accuracy: 0.8052
# Epoch 90/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4098 - accuracy: 0.8147
# Epoch 91/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4295 - accuracy: 0.7930
# Epoch 92/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4202 - accuracy: 0.8010
# Epoch 93/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4245 - accuracy: 0.7958
# Epoch 94/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4208 - accuracy: 0.7995
# Epoch 95/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4120 - accuracy: 0.7906
# Epoch 96/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3955 - accuracy: 0.7950
# Epoch 97/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4112 - accuracy: 0.8012
# Epoch 98/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4155 - accuracy: 0.7891
# Epoch 99/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4256 - accuracy: 0.7921
# Epoch 100/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3993 - accuracy: 0.8033
# 18/18 [==============================] - 2s 44ms/step - loss: 0.4553 - accuracy: 0.8052
# Validation Accuracy: 80.52%
# Epoch 1/100
# 173/173 [==============================] - 6s 18ms/step - loss: 0.5150 - accuracy: 0.7636
# Epoch 2/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5107 - accuracy: 0.7427
# Epoch 3/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4944 - accuracy: 0.7700
# Epoch 4/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5041 - accuracy: 0.7544
# Epoch 5/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4999 - accuracy: 0.7558
# Epoch 6/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.5168 - accuracy: 0.7441
# Epoch 7/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4734 - accuracy: 0.7768
# Epoch 8/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4664 - accuracy: 0.7714
# Epoch 9/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4649 - accuracy: 0.7714
# Epoch 10/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4647 - accuracy: 0.7633
# Epoch 11/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4567 - accuracy: 0.7983
# Epoch 12/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4715 - accuracy: 0.7685
# Epoch 13/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4528 - accuracy: 0.7912
# Epoch 14/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4511 - accuracy: 0.7687
# Epoch 15/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4517 - accuracy: 0.7773
# Epoch 16/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4772 - accuracy: 0.7606
# Epoch 17/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4781 - accuracy: 0.7614
# Epoch 18/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4695 - accuracy: 0.7744
# Epoch 19/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4331 - accuracy: 0.7988
# Epoch 20/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4400 - accuracy: 0.7928
# Epoch 21/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4555 - accuracy: 0.7744
# Epoch 22/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4117 - accuracy: 0.8027
# Epoch 23/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4471 - accuracy: 0.7798
# Epoch 24/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4548 - accuracy: 0.7853
# Epoch 25/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4144 - accuracy: 0.8064
# Epoch 26/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4480 - accuracy: 0.7859
# Epoch 27/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4297 - accuracy: 0.7899
# Epoch 28/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4274 - accuracy: 0.7832
# Epoch 29/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4541 - accuracy: 0.7708
# Epoch 30/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4376 - accuracy: 0.7872
# Epoch 31/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4255 - accuracy: 0.7885
# Epoch 32/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4212 - accuracy: 0.8094
# Epoch 33/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4096 - accuracy: 0.8049
# Epoch 34/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4298 - accuracy: 0.7798
# Epoch 35/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4479 - accuracy: 0.7801
# Epoch 36/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4290 - accuracy: 0.8007
# Epoch 37/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4416 - accuracy: 0.8020
# Epoch 38/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4372 - accuracy: 0.7846
# Epoch 39/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3981 - accuracy: 0.8189
# Epoch 40/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4083 - accuracy: 0.8193
# Epoch 41/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4168 - accuracy: 0.7970
# Epoch 42/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4066 - accuracy: 0.8030
# Epoch 43/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3976 - accuracy: 0.8211
# Epoch 44/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4135 - accuracy: 0.8137
# Epoch 45/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4179 - accuracy: 0.8056
# Epoch 46/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4089 - accuracy: 0.7981
# Epoch 47/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4158 - accuracy: 0.7898
# Epoch 48/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4244 - accuracy: 0.7961
# Epoch 49/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4121 - accuracy: 0.7979
# Epoch 50/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4490 - accuracy: 0.7609
# Epoch 51/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4565 - accuracy: 0.7806
# Epoch 52/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.4090 - accuracy: 0.8035
# Epoch 53/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3977 - accuracy: 0.8048
# Epoch 54/100
# 173/173 [==============================] - 3s 17ms/step - loss: 0.3948 - accuracy: 0.8047
# Epoch 55/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3977 - accuracy: 0.8076
# Epoch 56/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3996 - accuracy: 0.8076
# Epoch 57/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3947 - accuracy: 0.8141
# Epoch 58/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3952 - accuracy: 0.7992
# Epoch 59/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3912 - accuracy: 0.8169
# Epoch 60/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4106 - accuracy: 0.8150
# Epoch 61/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4145 - accuracy: 0.7988
# Epoch 62/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3990 - accuracy: 0.8140
# Epoch 63/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3969 - accuracy: 0.8279
# Epoch 64/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4348 - accuracy: 0.7927
# Epoch 65/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4086 - accuracy: 0.8038
# Epoch 66/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3861 - accuracy: 0.8158
# Epoch 67/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4121 - accuracy: 0.7899
# Epoch 68/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3728 - accuracy: 0.8224
# Epoch 69/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4008 - accuracy: 0.7919
# Epoch 70/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3795 - accuracy: 0.8183
# Epoch 71/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4206 - accuracy: 0.7761
# Epoch 72/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3993 - accuracy: 0.8021
# Epoch 73/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3825 - accuracy: 0.8116
# Epoch 74/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4062 - accuracy: 0.7918
# Epoch 75/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3831 - accuracy: 0.8051
# Epoch 76/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3650 - accuracy: 0.8133
# Epoch 77/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3720 - accuracy: 0.8210
# Epoch 78/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3915 - accuracy: 0.8268
# Epoch 79/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3930 - accuracy: 0.8085
# Epoch 80/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3828 - accuracy: 0.8318
# Epoch 81/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4014 - accuracy: 0.8098
# Epoch 82/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3935 - accuracy: 0.8264
# Epoch 83/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3975 - accuracy: 0.8084
# Epoch 84/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4150 - accuracy: 0.7917
# Epoch 85/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3931 - accuracy: 0.8194
# Epoch 86/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3927 - accuracy: 0.7986
# Epoch 87/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4002 - accuracy: 0.8031
# Epoch 88/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3809 - accuracy: 0.8256
# Epoch 89/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3994 - accuracy: 0.7990
# Epoch 90/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3693 - accuracy: 0.8302
# Epoch 91/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3611 - accuracy: 0.8338
# Epoch 92/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3882 - accuracy: 0.8167
# Epoch 93/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3786 - accuracy: 0.8208
# Epoch 94/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3713 - accuracy: 0.8140
# Epoch 95/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3947 - accuracy: 0.8156
# Epoch 96/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3987 - accuracy: 0.8086
# Epoch 97/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3655 - accuracy: 0.8159
# Epoch 98/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3673 - accuracy: 0.8187
# Epoch 99/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3977 - accuracy: 0.8088
# Epoch 100/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3893 - accuracy: 0.8111
# 18/18 [==============================] - 2s 44ms/step - loss: 0.5041 - accuracy: 0.7757
# Validation Accuracy: 77.57%
# Epoch 1/100
# 173/173 [==============================] - 6s 18ms/step - loss: 0.5351 - accuracy: 0.7222
# Epoch 2/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.5095 - accuracy: 0.7487
# Epoch 3/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.5018 - accuracy: 0.7308
# Epoch 4/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4958 - accuracy: 0.7619
# Epoch 5/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.5187 - accuracy: 0.7364
# Epoch 6/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4841 - accuracy: 0.7550
# Epoch 7/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4734 - accuracy: 0.7807
# Epoch 8/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4653 - accuracy: 0.7783
# Epoch 9/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4813 - accuracy: 0.7598
# Epoch 10/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4584 - accuracy: 0.7861
# Epoch 11/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4574 - accuracy: 0.7804
# Epoch 12/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4532 - accuracy: 0.7816
# Epoch 13/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4650 - accuracy: 0.7751
# Epoch 14/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4532 - accuracy: 0.7809
# Epoch 15/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4631 - accuracy: 0.7892
# Epoch 16/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4936 - accuracy: 0.7614
# Epoch 17/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4828 - accuracy: 0.7559
# Epoch 18/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4716 - accuracy: 0.7688
# Epoch 19/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4682 - accuracy: 0.7818
# Epoch 20/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4221 - accuracy: 0.7919
# Epoch 21/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4647 - accuracy: 0.7681
# Epoch 22/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4418 - accuracy: 0.7855
# Epoch 23/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4407 - accuracy: 0.7885
# Epoch 24/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4614 - accuracy: 0.7754
# Epoch 25/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4468 - accuracy: 0.7869
# Epoch 26/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4324 - accuracy: 0.7946
# Epoch 27/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4556 - accuracy: 0.7662
# Epoch 28/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4584 - accuracy: 0.7744
# Epoch 29/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4427 - accuracy: 0.7899
# Epoch 30/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4403 - accuracy: 0.7926
# Epoch 31/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4393 - accuracy: 0.7919
# Epoch 32/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4399 - accuracy: 0.7853
# Epoch 33/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4420 - accuracy: 0.8004
# Epoch 34/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4305 - accuracy: 0.8014
# Epoch 35/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4409 - accuracy: 0.8018
# Epoch 36/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4336 - accuracy: 0.7981
# Epoch 37/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4230 - accuracy: 0.8100
# Epoch 38/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4475 - accuracy: 0.7816
# Epoch 39/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4317 - accuracy: 0.7938
# Epoch 40/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4351 - accuracy: 0.7838
# Epoch 41/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4215 - accuracy: 0.7961
# Epoch 42/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4159 - accuracy: 0.8064
# Epoch 43/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4156 - accuracy: 0.8003
# Epoch 44/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4243 - accuracy: 0.7903
# Epoch 45/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4444 - accuracy: 0.7940
# Epoch 46/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4220 - accuracy: 0.7982
# Epoch 47/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4259 - accuracy: 0.7999
# Epoch 48/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4055 - accuracy: 0.8215
# Epoch 49/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4278 - accuracy: 0.7950
# Epoch 50/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4011 - accuracy: 0.8037
# Epoch 51/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4217 - accuracy: 0.8068
# Epoch 52/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4056 - accuracy: 0.8037
# Epoch 53/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4323 - accuracy: 0.7909
# Epoch 54/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4189 - accuracy: 0.7849
# Epoch 55/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4073 - accuracy: 0.7985
# Epoch 56/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4044 - accuracy: 0.8110
# Epoch 57/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4101 - accuracy: 0.8125
# Epoch 58/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4151 - accuracy: 0.8081
# Epoch 59/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4098 - accuracy: 0.8158
# Epoch 60/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4587 - accuracy: 0.7763
# Epoch 61/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4062 - accuracy: 0.8137
# Epoch 62/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4152 - accuracy: 0.7891
# Epoch 63/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4507 - accuracy: 0.7796
# Epoch 64/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3879 - accuracy: 0.8165
# Epoch 65/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4153 - accuracy: 0.7929
# Epoch 66/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4129 - accuracy: 0.7937
# Epoch 67/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4233 - accuracy: 0.8083
# Epoch 68/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4391 - accuracy: 0.7847
# Epoch 69/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4261 - accuracy: 0.8025
# Epoch 70/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3897 - accuracy: 0.8180
# Epoch 71/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3885 - accuracy: 0.8133
# Epoch 72/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3946 - accuracy: 0.8219
# Epoch 73/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4075 - accuracy: 0.8075
# Epoch 74/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4443 - accuracy: 0.7783
# Epoch 75/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3846 - accuracy: 0.8079
# Epoch 76/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4006 - accuracy: 0.8017
# Epoch 77/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3911 - accuracy: 0.8223
# Epoch 78/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4036 - accuracy: 0.8011
# Epoch 79/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3959 - accuracy: 0.8016
# Epoch 80/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4010 - accuracy: 0.8203
# Epoch 81/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4047 - accuracy: 0.8183
# Epoch 82/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4285 - accuracy: 0.8040
# Epoch 83/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4321 - accuracy: 0.7876
# Epoch 84/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4075 - accuracy: 0.7967
# Epoch 85/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4040 - accuracy: 0.8036
# Epoch 86/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3889 - accuracy: 0.8292
# Epoch 87/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3984 - accuracy: 0.8080
# Epoch 88/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3720 - accuracy: 0.8143
# Epoch 89/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3917 - accuracy: 0.8149
# Epoch 90/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3795 - accuracy: 0.8220
# Epoch 91/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3989 - accuracy: 0.8054
# Epoch 92/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3983 - accuracy: 0.8026
# Epoch 93/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4030 - accuracy: 0.8040
# Epoch 94/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3910 - accuracy: 0.8033
# Epoch 95/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3910 - accuracy: 0.8146
# Epoch 96/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3833 - accuracy: 0.8087
# Epoch 97/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.3990 - accuracy: 0.8043
# Epoch 98/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4175 - accuracy: 0.8142
# Epoch 99/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4117 - accuracy: 0.8083
# Epoch 100/100
# 173/173 [==============================] - 3s 18ms/step - loss: 0.4057 - accuracy: 0.8019
# 18/18 [==============================] - 2s 45ms/step - loss: 0.4609 - accuracy: 0.7875
# Validation Accuracy: 78.75%
# Validation Accuracy Mean (+/- Std Deviation): 78.99% (+/- 1.06%)
# MobileNet FT Cross Validation Time = 1235.9836418628693s

# %%
model_mn.summary()
# Out:
# Model: "model_25"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_26 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         input_26[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise (Depthw (None, 112, 112, 32) 288         Conv1_relu[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_BN (Bat (None, 112, 112, 32) 128         expanded_conv_depthwise[0][0]
# __________________________________________________________________________________________________
# expanded_conv_depthwise_relu (R (None, 112, 112, 32) 0           expanded_conv_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# expanded_conv_project (Conv2D)  (None, 112, 112, 16) 512         expanded_conv_depthwise_relu[0][0
# __________________________________________________________________________________________________
# expanded_conv_project_BN (Batch (None, 112, 112, 16) 64          expanded_conv_project[0][0]
# __________________________________________________________________________________________________
# block_1_expand (Conv2D)         (None, 112, 112, 96) 1536        expanded_conv_project_BN[0][0]
# __________________________________________________________________________________________________
# block_1_expand_BN (BatchNormali (None, 112, 112, 96) 384         block_1_expand[0][0]
# __________________________________________________________________________________________________
# block_1_expand_relu (ReLU)      (None, 112, 112, 96) 0           block_1_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_1_pad (ZeroPadding2D)     (None, 113, 113, 96) 0           block_1_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise (DepthwiseCon (None, 56, 56, 96)   864         block_1_pad[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_BN (BatchNorm (None, 56, 56, 96)   384         block_1_depthwise[0][0]
# __________________________________________________________________________________________________
# block_1_depthwise_relu (ReLU)   (None, 56, 56, 96)   0           block_1_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_1_project (Conv2D)        (None, 56, 56, 24)   2304        block_1_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_1_project_BN (BatchNormal (None, 56, 56, 24)   96          block_1_project[0][0]
# __________________________________________________________________________________________________
# block_2_expand (Conv2D)         (None, 56, 56, 144)  3456        block_1_project_BN[0][0]
# __________________________________________________________________________________________________
# block_2_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_2_expand[0][0]
# __________________________________________________________________________________________________
# block_2_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_2_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise (DepthwiseCon (None, 56, 56, 144)  1296        block_2_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_BN (BatchNorm (None, 56, 56, 144)  576         block_2_depthwise[0][0]
# __________________________________________________________________________________________________
# block_2_depthwise_relu (ReLU)   (None, 56, 56, 144)  0           block_2_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_2_project (Conv2D)        (None, 56, 56, 24)   3456        block_2_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_2_project_BN (BatchNormal (None, 56, 56, 24)   96          block_2_project[0][0]
# __________________________________________________________________________________________________
# block_2_add (Add)               (None, 56, 56, 24)   0           block_1_project_BN[0][0]
#                                                                  block_2_project_BN[0][0]
# __________________________________________________________________________________________________
# block_3_expand (Conv2D)         (None, 56, 56, 144)  3456        block_2_add[0][0]
# __________________________________________________________________________________________________
# block_3_expand_BN (BatchNormali (None, 56, 56, 144)  576         block_3_expand[0][0]
# __________________________________________________________________________________________________
# block_3_expand_relu (ReLU)      (None, 56, 56, 144)  0           block_3_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_3_pad (ZeroPadding2D)     (None, 57, 57, 144)  0           block_3_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise (DepthwiseCon (None, 28, 28, 144)  1296        block_3_pad[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_BN (BatchNorm (None, 28, 28, 144)  576         block_3_depthwise[0][0]
# __________________________________________________________________________________________________
# block_3_depthwise_relu (ReLU)   (None, 28, 28, 144)  0           block_3_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_3_project (Conv2D)        (None, 28, 28, 32)   4608        block_3_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_3_project_BN (BatchNormal (None, 28, 28, 32)   128         block_3_project[0][0]
# __________________________________________________________________________________________________
# block_4_expand (Conv2D)         (None, 28, 28, 192)  6144        block_3_project_BN[0][0]
# __________________________________________________________________________________________________
# block_4_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_4_expand[0][0]
# __________________________________________________________________________________________________
# block_4_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_4_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_4_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_4_depthwise[0][0]
# __________________________________________________________________________________________________
# block_4_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_4_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_4_project (Conv2D)        (None, 28, 28, 32)   6144        block_4_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_4_project_BN (BatchNormal (None, 28, 28, 32)   128         block_4_project[0][0]
# __________________________________________________________________________________________________
# block_4_add (Add)               (None, 28, 28, 32)   0           block_3_project_BN[0][0]
#                                                                  block_4_project_BN[0][0]
# __________________________________________________________________________________________________
# block_5_expand (Conv2D)         (None, 28, 28, 192)  6144        block_4_add[0][0]
# __________________________________________________________________________________________________
# block_5_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_5_expand[0][0]
# __________________________________________________________________________________________________
# block_5_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_5_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise (DepthwiseCon (None, 28, 28, 192)  1728        block_5_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_BN (BatchNorm (None, 28, 28, 192)  768         block_5_depthwise[0][0]
# __________________________________________________________________________________________________
# block_5_depthwise_relu (ReLU)   (None, 28, 28, 192)  0           block_5_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_5_project (Conv2D)        (None, 28, 28, 32)   6144        block_5_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_5_project_BN (BatchNormal (None, 28, 28, 32)   128         block_5_project[0][0]
# __________________________________________________________________________________________________
# block_5_add (Add)               (None, 28, 28, 32)   0           block_4_add[0][0]
#                                                                  block_5_project_BN[0][0]
# __________________________________________________________________________________________________
# block_6_expand (Conv2D)         (None, 28, 28, 192)  6144        block_5_add[0][0]
# __________________________________________________________________________________________________
# block_6_expand_BN (BatchNormali (None, 28, 28, 192)  768         block_6_expand[0][0]
# __________________________________________________________________________________________________
# block_6_expand_relu (ReLU)      (None, 28, 28, 192)  0           block_6_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_6_pad (ZeroPadding2D)     (None, 29, 29, 192)  0           block_6_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise (DepthwiseCon (None, 14, 14, 192)  1728        block_6_pad[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_BN (BatchNorm (None, 14, 14, 192)  768         block_6_depthwise[0][0]
# __________________________________________________________________________________________________
# block_6_depthwise_relu (ReLU)   (None, 14, 14, 192)  0           block_6_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_6_project (Conv2D)        (None, 14, 14, 64)   12288       block_6_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_6_project_BN (BatchNormal (None, 14, 14, 64)   256         block_6_project[0][0]
# __________________________________________________________________________________________________
# block_7_expand (Conv2D)         (None, 14, 14, 384)  24576       block_6_project_BN[0][0]
# __________________________________________________________________________________________________
# block_7_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_7_expand[0][0]
# __________________________________________________________________________________________________
# block_7_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_7_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_7_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_7_depthwise[0][0]
# __________________________________________________________________________________________________
# block_7_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_7_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_7_project (Conv2D)        (None, 14, 14, 64)   24576       block_7_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_7_project_BN (BatchNormal (None, 14, 14, 64)   256         block_7_project[0][0]
# __________________________________________________________________________________________________
# block_7_add (Add)               (None, 14, 14, 64)   0           block_6_project_BN[0][0]
#                                                                  block_7_project_BN[0][0]
# __________________________________________________________________________________________________
# block_8_expand (Conv2D)         (None, 14, 14, 384)  24576       block_7_add[0][0]
# __________________________________________________________________________________________________
# block_8_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_8_expand[0][0]
# __________________________________________________________________________________________________
# block_8_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_8_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_8_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_8_depthwise[0][0]
# __________________________________________________________________________________________________
# block_8_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_8_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_8_project (Conv2D)        (None, 14, 14, 64)   24576       block_8_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_8_project_BN (BatchNormal (None, 14, 14, 64)   256         block_8_project[0][0]
# __________________________________________________________________________________________________
# block_8_add (Add)               (None, 14, 14, 64)   0           block_7_add[0][0]
#                                                                  block_8_project_BN[0][0]
# __________________________________________________________________________________________________
# block_9_expand (Conv2D)         (None, 14, 14, 384)  24576       block_8_add[0][0]
# __________________________________________________________________________________________________
# block_9_expand_BN (BatchNormali (None, 14, 14, 384)  1536        block_9_expand[0][0]
# __________________________________________________________________________________________________
# block_9_expand_relu (ReLU)      (None, 14, 14, 384)  0           block_9_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise (DepthwiseCon (None, 14, 14, 384)  3456        block_9_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_BN (BatchNorm (None, 14, 14, 384)  1536        block_9_depthwise[0][0]
# __________________________________________________________________________________________________
# block_9_depthwise_relu (ReLU)   (None, 14, 14, 384)  0           block_9_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_9_project (Conv2D)        (None, 14, 14, 64)   24576       block_9_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_9_project_BN (BatchNormal (None, 14, 14, 64)   256         block_9_project[0][0]
# __________________________________________________________________________________________________
# block_9_add (Add)               (None, 14, 14, 64)   0           block_8_add[0][0]
#                                                                  block_9_project_BN[0][0]
# __________________________________________________________________________________________________
# block_10_expand (Conv2D)        (None, 14, 14, 384)  24576       block_9_add[0][0]
# __________________________________________________________________________________________________
# block_10_expand_BN (BatchNormal (None, 14, 14, 384)  1536        block_10_expand[0][0]
# __________________________________________________________________________________________________
# block_10_expand_relu (ReLU)     (None, 14, 14, 384)  0           block_10_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise (DepthwiseCo (None, 14, 14, 384)  3456        block_10_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_BN (BatchNor (None, 14, 14, 384)  1536        block_10_depthwise[0][0]
# __________________________________________________________________________________________________
# block_10_depthwise_relu (ReLU)  (None, 14, 14, 384)  0           block_10_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_10_project (Conv2D)       (None, 14, 14, 96)   36864       block_10_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_10_project_BN (BatchNorma (None, 14, 14, 96)   384         block_10_project[0][0]
# __________________________________________________________________________________________________
# block_11_expand (Conv2D)        (None, 14, 14, 576)  55296       block_10_project_BN[0][0]
# __________________________________________________________________________________________________
# block_11_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_11_expand[0][0]
# __________________________________________________________________________________________________
# block_11_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_11_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_11_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_11_depthwise[0][0]
# __________________________________________________________________________________________________
# block_11_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_11_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_11_project (Conv2D)       (None, 14, 14, 96)   55296       block_11_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_11_project_BN (BatchNorma (None, 14, 14, 96)   384         block_11_project[0][0]
# __________________________________________________________________________________________________
# block_11_add (Add)              (None, 14, 14, 96)   0           block_10_project_BN[0][0]
#                                                                  block_11_project_BN[0][0]
# __________________________________________________________________________________________________
# block_12_expand (Conv2D)        (None, 14, 14, 576)  55296       block_11_add[0][0]
# __________________________________________________________________________________________________
# block_12_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_12_expand[0][0]
# __________________________________________________________________________________________________
# block_12_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_12_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise (DepthwiseCo (None, 14, 14, 576)  5184        block_12_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_BN (BatchNor (None, 14, 14, 576)  2304        block_12_depthwise[0][0]
# __________________________________________________________________________________________________
# block_12_depthwise_relu (ReLU)  (None, 14, 14, 576)  0           block_12_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_12_project (Conv2D)       (None, 14, 14, 96)   55296       block_12_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_12_project_BN (BatchNorma (None, 14, 14, 96)   384         block_12_project[0][0]
# __________________________________________________________________________________________________
# block_12_add (Add)              (None, 14, 14, 96)   0           block_11_add[0][0]
#                                                                  block_12_project_BN[0][0]
# __________________________________________________________________________________________________
# block_13_expand (Conv2D)        (None, 14, 14, 576)  55296       block_12_add[0][0]
# __________________________________________________________________________________________________
# block_13_expand_BN (BatchNormal (None, 14, 14, 576)  2304        block_13_expand[0][0]
# __________________________________________________________________________________________________
# block_13_expand_relu (ReLU)     (None, 14, 14, 576)  0           block_13_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_13_pad (ZeroPadding2D)    (None, 15, 15, 576)  0           block_13_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise (DepthwiseCo (None, 7, 7, 576)    5184        block_13_pad[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_BN (BatchNor (None, 7, 7, 576)    2304        block_13_depthwise[0][0]
# __________________________________________________________________________________________________
# block_13_depthwise_relu (ReLU)  (None, 7, 7, 576)    0           block_13_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_13_project (Conv2D)       (None, 7, 7, 160)    92160       block_13_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_13_project_BN (BatchNorma (None, 7, 7, 160)    640         block_13_project[0][0]
# __________________________________________________________________________________________________
# block_14_expand (Conv2D)        (None, 7, 7, 960)    153600      block_13_project_BN[0][0]
# __________________________________________________________________________________________________
# block_14_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_14_expand[0][0]
# __________________________________________________________________________________________________
# block_14_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_14_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_14_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_14_depthwise[0][0]
# __________________________________________________________________________________________________
# block_14_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_14_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_14_project (Conv2D)       (None, 7, 7, 160)    153600      block_14_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_14_project_BN (BatchNorma (None, 7, 7, 160)    640         block_14_project[0][0]
# __________________________________________________________________________________________________
# block_14_add (Add)              (None, 7, 7, 160)    0           block_13_project_BN[0][0]
#                                                                  block_14_project_BN[0][0]
# __________________________________________________________________________________________________
# block_15_expand (Conv2D)        (None, 7, 7, 960)    153600      block_14_add[0][0]
# __________________________________________________________________________________________________
# block_15_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_15_expand[0][0]
# __________________________________________________________________________________________________
# block_15_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_15_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_15_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_15_depthwise[0][0]
# __________________________________________________________________________________________________
# block_15_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_15_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_15_project (Conv2D)       (None, 7, 7, 160)    153600      block_15_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_15_project_BN (BatchNorma (None, 7, 7, 160)    640         block_15_project[0][0]
# __________________________________________________________________________________________________
# block_15_add (Add)              (None, 7, 7, 160)    0           block_14_add[0][0]
#                                                                  block_15_project_BN[0][0]
# __________________________________________________________________________________________________
# block_16_expand (Conv2D)        (None, 7, 7, 960)    153600      block_15_add[0][0]
# __________________________________________________________________________________________________
# block_16_expand_BN (BatchNormal (None, 7, 7, 960)    3840        block_16_expand[0][0]
# __________________________________________________________________________________________________
# block_16_expand_relu (ReLU)     (None, 7, 7, 960)    0           block_16_expand_BN[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise (DepthwiseCo (None, 7, 7, 960)    8640        block_16_expand_relu[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_BN (BatchNor (None, 7, 7, 960)    3840        block_16_depthwise[0][0]
# __________________________________________________________________________________________________
# block_16_depthwise_relu (ReLU)  (None, 7, 7, 960)    0           block_16_depthwise_BN[0][0]
# __________________________________________________________________________________________________
# block_16_project (Conv2D)       (None, 7, 7, 320)    307200      block_16_depthwise_relu[0][0]
# __________________________________________________________________________________________________
# block_16_project_BN (BatchNorma (None, 7, 7, 320)    1280        block_16_project[0][0]
# __________________________________________________________________________________________________
# Conv_1 (Conv2D)                 (None, 7, 7, 1280)   409600      block_16_project_BN[0][0]
# __________________________________________________________________________________________________
# Conv_1_bn (BatchNormalization)  (None, 7, 7, 1280)   5120        Conv_1[0][0]
# __________________________________________________________________________________________________
# out_relu (ReLU)                 (None, 7, 7, 1280)   0           Conv_1_bn[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_25 (Gl (None, 1280)         0           out_relu[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 1000)         1281000     global_average_pooling2d_25[0][0]
# __________________________________________________________________________________________________
# dense_50 (Dense)                (None, 512)          512512      predictions[0][0]
# __________________________________________________________________________________________________
# dropout_25 (Dropout)            (None, 512)          0           dense_50[0][0]
# __________________________________________________________________________________________________
# dense_51 (Dense)                (None, 2)            1026        dropout_25[0][0]
# ==================================================================================================
# Total params: 4,052,522
# Trainable params: 3,833,322
# Non-trainable params: 219,200
# __________________________________________________________________________________________________

# %% [markdown]
# ### SqueezeNet

# %% [markdown]
# will continue on SqueezeNet as future work.
