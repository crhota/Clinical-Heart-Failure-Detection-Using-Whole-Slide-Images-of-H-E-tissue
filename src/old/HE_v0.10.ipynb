# %% [markdown]
# # Clinical Heart Failure Detection Using Whole-Slide Images of H&E tissue

# %% [markdown]
# ## Version

# %% [markdown]
# ### Version 0.10

# %% [markdown]
# - **0.10**
#   - Cleaned up indenting
#   - Added hyperparameter macros that can be used for all models
#     - ResNet50 was with 1024 neurons, 40% dropout
#     - MobileNet was with 512 neurons, 60% dropout.
#     - Made EPOCHS = 100, BATCH_SIZE = 10, LEARNING_RATE = 0.01, DENSE_LAYER_NEURONS = 512, DENSE_LAYER_DROPOUT = 0.4
#   - Implemented 'checkpoint' as a function to be used a callback by any model. Enabled callback for ResNet50
#   - Accuracy
#     - ResNet50 (XFR Learning): Best_Train/Best_Val/Test = 89.4 / 88.8 / 80.7
#     - MobileNet (XFR Learning): Best_Train/Best_Val/Test = 83.6 / 85.0 / 77.6
#     - MobileNet (Fine Tuning): Best_Train/Best_Val/Test = 86.9 / 84.0 / 77.7

# %% [markdown]
# ### Version 0.09

# %% [markdown]
# - **0.09** **MobileNet**
#   - **Epoch=100**: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 87.4/80.8/78.0
#   - Epoch=100: **Best Model**: Train/Val/Test Acc = 82.1/84.0/77.8
#   - **Epoch=200**: Best Model: Train/Val/Test Acc = 79.0/84.0/78.9
#   - **Epoch=100**: Best Model: **Regularizer: Kernel/Bias L2(0.01) for Dense(1024)**: Train/Val/Test Acc = 70.6/80.0/72.5
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias L2(0.01) for Dense(1024), **Dense(2)**: Train/Val/Test Acc = 69.0/78.3/72.6
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias **L1**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/**Activity L2**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = 68.1/79.1/72.4
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(0.2)** for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(1e-4/1e-4/1e-5)** for Dense(1024), Dense(2): Train/Val/Test Acc = 77.6/84.0/77.5 ... regularizer is not helping much ... revert to No Regularizer
#   - **Best Model**: **Epoch=100**: Train/Val/Test Acc = 81.5/84.5/77.8
#   - Best Model: **Epoch=1**: **Nottrainable/trainabele layers = 0-79/80-94**:  Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: **Epoch=100**: NonTrainable(MobileNet)+ Trainable(Dense(1024), Dropout, Dense(2)): Train/Val/Test Acc = 82.3/85/79
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.8/78.7
#   - Best Model: Epoch=100: **MobileNet NT till Conv13 (0-85), T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: MobileNet NT **till Conv12 (0-79)**, T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 88.5/85.0/77.7
#   - Best Model: Epoch=100: **NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet till <86) Trainable (86 and later = GAP...)+ Trainable(Dense(**512**), Dropout, Dense(2))**: Train/Val/Test Acc = 78.7/84.8/76.8 -> ../84.8/76.8
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.2/78.2 -> ../84.2/78.2
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 80.1/84.2/78.4 -> ../84.2/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> **Trainable(MobileNet till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 81.8/84.2/78.3 -> 86.2/84.5/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Params (Total/Trainable/Non-trainable)= 4,767,402 / 2,600,426 / 2,166,976: Train/Val/Test Acc = 79.8/84.8/78.4 -> ../84.8/78.4

# %% [markdown]
# ### Version 0.08

# %% [markdown]
# - **0.08** **MobileNet**
#   - Changed model to Pre-trained MobileNet
#   - Epoch=1: **img resize**: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 68.2/76.5/73.8
#   - Epoch=10: img resize: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 80.5/82.4/78.9
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = N:Train/Val/Test Acc = 83.7/79.2/76.5 ... revert to Epoch=10
#   - **Epoch=10**: img resize: **lr=0.0001**: BN = N: Dropout = N:Train/Val/Test Acc = 71.9/78.6/73.6 ... revert to lr=0.01
#   - Epoch=10: img resize: **lr=0.01**: **BN = Y**: Dropout = N: Train/Val/Test Acc = 83.0/77.8/71.0 revert to BN = N
#   - Epoch=10: img resize: lr=0.01: **BN = N**: **Dropout = 0.2**: Train/Val/Test Acc = 77.1/80.8/76.9
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Train/Val/Test Acc = 78.8/82.6/78.0
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = 0.4: Train/Val/Test Acc = 81.6/76.6/75.4 ... revert to Epoch = 10
#   - **Epoch=10**: img resize: lr=0.01: BN = N: **Dropout = 0.5**: Train/Val/Test Acc = 78.3/84.2/77.8 ... revert to Dropout = 0.4
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 78.3/79.1/76.5

# %% [markdown]
# ### Version 0.07

# %% [markdown]
# - **0.07** **ResNet50**
#   - As is rerun: Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: batch size = 10: Train/Val/Test Acc = 86.7/86.6/81.4
#   - Change **batch size** from 10 to 20: Train/Val/Test Acc = 91.2/83.7/78.9 ... reduces accuracy, so reverted to batch size of 10
#   - Implemented **Data Augmentation** with batch size of 10: Train/Val/Test Acc = 78.1/79.7/69.0 ...reduces accuracy, should we increase batch size?
#   - Implemented **Data Augmentation** with batch size of 100: Train/Val/Test Acc = 89.3/72.2/67.9 ...reduces accuracy, should we decrease batch size?
#   - Implemented **Data Augmentation** with batch size of 5: Train/Val/Test Acc = 58.3/48.4/48.1  ... reduces accuracy, reverted to batch size of 10, and no Data Augmentation
#   - Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: **batch size = 10**: **No DataAug**: Params (Total/Trainable/Non-trainable)= 25,687,938 / 2,100,226 / 23,587,712: Train/Val/Test Acc = 91.8/90.6/81.1

# %% [markdown]
# ### Version 0.06

# %% [markdown]
# - **0.06** **ResNet50**
#   - Before any modification: full rerun took ~15mins (most of it for loading train/val/test images/labels... and very less for model training/test)
#   - Before any modification: Train/Val/Test Acc = 53/51.1/51.3
#   - Changed model = Pre-trained ResNet50 + Modified FCN Layer
#     - SGD (LR=0.0001, M=0.9), Categorical Crossentropy
#     - 1st run: Train/Val/Test Acc = 57.5/72.7/67.1
#     - Converted ones/zeroes count to function
#     - Converted images/label prep to function
#     - Epoch=1: Train/Val/Test Acc = 61/67.9/67
#     - Epoch=5: Train/Val/Test Acc = 85.6/80.8/75.9
#     - Epoch=10: Train/Val/Test Acc = 93.0/85.6/77.7
#     - Epoch=20: Train/Val/Test Acc = 94.1/89.0/80.4
#     - Epoch=20: Changed loss function to 'binary crossentropy', reduced the accuracy: Train/Val/Test Acc = 90.2/84.0/77.7 Hence, reverted to categorical crossentropy as the loss function
#     - Epoch=20: Changed optimizer to Adam(lr=0.01), increased accuracy: Train/Val/Test Acc = 99.3/86.9/83.2
#     - In above training accuracy is high, validation and test accuracy is low ... it is overfitting ... let us implement Dropout
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): Train/Val/Test Acc = 93.0/88.8/82.1
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 90.8/89.8/83.4
#     - Epoch=20: Adam(lr=0.01): Dropout(0.5): Train/Val/Test Acc = 92.2/90.6/82.3 .. reverted to Dropout(0.4)
#     - Let us try Batch Normalization. ResNet50 -> Dense (1024) -> Batch Norm -> relu -> Dropout -> Dense(2,softmax)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): BN: Train/Val/Test Acc = 90.6/81.6/79.0 ... reduced accuracy
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): BN: Train/Val/Test Acc = 95.2/86.9/81.9 ... reduced accuracy will revert to no BN, Dropout(0.4)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 88.2/89.3/81.7

# %% [markdown]
# ### Version 0.01 - 0.05

# %% [markdown]
# - **0.05**: Migrate to Google Colab/Drive, changed loss function to 'binary_crossentropy', epochs to 1 : Train/Val/Test Acc = 55.7/55.9/55.2
# - **0.04**: Class Label Info in List was not accurate - fixed it. Now, Train/Validate/Test Accuracy is more realistic = ~55%
# - **0.03**: Tweak CNN model done for MNIST to work for this dataset to have a working end to end CNN model. Train/Validate/Test Accuracy = ~100%
# - **0.02**: Prepare Train/Validate/Test Labels and Images
# - **0.01**: Prepare Train/Validate/Test Images

# %% [markdown]
# ## Improvement Opportunity

# %% [markdown]
# - **TRIED**: As this is a 2 class classification - loss function can be changed to binary_crossentropy instead of categorical_crossentropy
# - **DONE**: Change model to ResNet50
# - **DONE**: Convert code sections in data preparation for train/validation/test to functions
# - **TRIED**: Reduce parameters, epochs.
# - **TRIED**: Try changing batch size
# - **TRIED**: Use Data Augmentation
# - **DONE**: Try to train last few layers of ResNet50 with the data
# - **TRIED**: Accuracy is fluctuating... optimize hyper parameters to have a smooth increase
# - Try k-cross validation
# - **TRIED** Try Regularization
# - Our image size is 250x250. ResNet50 expects 224x224. Do we need to do anything or ResNet50 will understand ?
# - **DONE**: Change Model to MobileNet
# - **DONE**: Is image resize done correctly for MobileNet ?

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# ### Download Train, Validate and Test Images

# %% [markdown]
# - Source Link to the Dataset / Annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Follow the instructions at following link, install IBM Aspera Desktop Client to download the dataset.
# - Copy downloaded folders to '**data/images**' folder in your working directory where you have this Jupyter Notebook:
#   - 'held-out_validation'
#   - 'training'

# %% [markdown]
# ### Download Label Information for Train, Validate and Test Images

# %% [markdown]
# - Following link will point to below Github link which has the annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Source Link for the Annotation File: https://github.com/IDR/idr0042-nirschl-wsideeplearning/tree/master/experimentA
# - Download and copy file '**idr0042-experimentA-annotation.csv**' to '**data/labels/**' folder in your working directory where you have this Jupyter Notebook

# %% [markdown]
# ## References

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# - Access Google Drive files from Google Colab
#   - https://www.youtube.com/watch?reload=9&v=lHRC5gFvQnA
# - Reading an image
#   - mathplotlib: https://stackoverflow.com/questions/9298665/cannot-import-scipy-misc-imread
#   - pathlib: https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f#:~:text=To%20use%20it%2C%20you%20just,for%20the%20current%20operating%20system.
#   - OpenCV: https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/
# - Load multiple images into a numpy array
#   - glob / os.listdir: https://stackoverflow.com/questions/39195113/how-to-load-multiple-images-in-a-numpy-array
#   - glob / cv2: https://medium.com/@muskulpesent/create-numpy-array-of-images-fecb4e514c4b
# - Load a CSV file
#   - Datacamp: https://www.datacamp.com/community/tutorials/pandas-read-csv?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377095&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=9061994&gclid=EAIaIQobChMIz5TKz-v17QIV1AorCh0bfw96EAAYASAAEgKiGPD_BwE
# - Split a String
#   - Python Central: https://www.pythoncentral.io/cutting-and-slicing-strings-in-python/
# - Image Resize
#   - https://stackoverflow.com/questions/44650888/resize-an-image-without-distortion-opencv
#   - https://stackoverflow.com/questions/55571664/mobilenets-for-a-custom-image-size

# %% [markdown]
# ### Model Definition

# %% [markdown]
# - ResNet50
#   - https://cv-tricks.com/keras/understand-implement-resnets/
#   - Finetuning ResNet50
#     - https://www.pyimagesearch.com/2020/04/27/fine-tuning-resnet-with-keras-tensorflow-and-deep-learning/
# - MobileNet
#   - https://deeplizard.com/learn/video/Zrt76AIbeh4
#   - https://towardsdatascience.com/exploring-mobilenets-from-paper-to-keras-f01308ada818
#   - Fine Tuning MobileNet - Last few layers trainable
#     - https://towardsdatascience.com/transfer-learning-using-mobilenet-and-keras-c75daf7ff299
# - SqueezeNet
#   - https://codelabs.developers.google.com/codelabs/keras-flowers-squeezenet#6

# %% [markdown]
# ### Model Validation

# %% [markdown]
# - Keras Optimizer / Adam
#   - https://keras.io/api/optimizers/
# - Regularizer
#   - https://keras.io/api/layers/regularizers/
# - Save Weights for Best Model
#   - https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
#   - Monitoring Validaiton Accuracy - Skipping Error Solution
#     - https://github.com/tensorflow/tensorflow/issues/33163
#   - Predict using saved model
#     - https://stackoverflow.com/questions/44259651/how-to-use-predefined-trained-hdf5-file-with-wights-to-predict-a-class-of-new
# - K-cross validation: https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538

# %% [markdown]
# ## Understand Dataset

# %% [markdown]
# ### Understand Images Folder Structure and Number of Images Available

# %% [markdown]
# Training/Validation
# - \..\training\fold_1: has images for training = 770#
# - \..\training\test_fold_1: has images for validation = 374#
# - Total = 770 + 374 = 1144 images
#
# Test
# - \..\held-out_validation: has images for testing = 1155#

# %% [markdown]
# ### Understand Annotation File and Label Information Available

# %% [markdown]
# Relevant columns of interest:
# - Column A: Dataset Name: Classifies each row/instance as 'training' or 'test'
# - Column B: Image Name: Specifies filename of the image for the row/instance
# - Column Z: Experimental Condition [Diagnosis]: has 3 classes:
#   - 'chronic heart failure'
#   - 'heart tissue pathology' - We will treat this as 'not chronic heart failure'
#   - 'not chronic heart failure'
# - Column AA: Channels: mentions RGB => images are color images and will have 3 channels Red/Green/Blue (for CNN).
#
# Breakup of training/test instances:
# - training
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 627
# - test
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 638
#
# Total 'training' = 517 + 627 = 1144  (Note: 'validate' is a portion of this 'training' set.)
#
# Total 'test' = 517 + 638 = 1155

# %% [markdown]
# ## Access Dataset

# %% [markdown]
# ### Load Libraries

# %% [markdown]
# We need to read 'train, validate and test images' to arrays so that we can then use them to feed to our CNN model. We need to import the annotation file into a dataframe so that we can then access the labels information.

# %%
# install OpenCV package - this is required only once
# pip install opencv-python

# %%
# aids in reading image files
import cv2
import glob

# %%
# aids in working with arrays
import numpy as np

# %%
# aids in working with dataframes
import pandas as pd

# %% [markdown]
# ### Mount Google Drive

# %% [markdown]
# We need to mount the google drive so that we can then access the files from google drive.

# %%
# run this. click on the link it will ask for. get the authentication code. Copy/Paste in the cell. Hit Enter.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### Get labels info into a dataframe

# %%
# Google Drive / Colab
filepath_annotation_file = r'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/labels/idr0042-experimentA-annotation.csv'
labels = pd.read_csv(filepath_annotation_file)

# Local Drive / Jupyter
# labels = pd.read_csv('data/labels/idr0042-experimentA-annotation.csv')

# %% [markdown]
# ### Explore and Understand

# %%
# uncomment & check the contents of labels is as expected
labels
# Out:
#      Dataset Name  ... Channels
# 0        training  ...      RGB
# 1        training  ...      RGB
# 2        training  ...      RGB
# 3        training  ...      RGB
# 4        training  ...      RGB
# ...           ...  ...      ...
# 2294         test  ...      RGB
# 2295         test  ...      RGB
# 2296         test  ...      RGB
# 2297         test  ...      RGB
# 2298         test  ...      RGB
#
# [2299 rows x 27 columns]

# %%
print(labels['Dataset Name'])
# Out:
# 0       training
# 1       training
# 2       training
# 3       training
# 4       training
#           ...
# 2294        test
# 2295        test
# 2296        test
# 2297        test
# 2298        test
# Name: Dataset Name, Length: 2299, dtype: object

# %%
print(labels['Dataset Name'][0])
# Out:
# training

# %%
type(labels['Dataset Name'][0])
# Out:
# str

# %%
print(labels['Image Name'])
# Out:
# 0       33381_0_fal_10_0.png
# 1       33381_0_fal_14_0.png
# 2       33381_0_fal_16_0.png
# 3       33381_0_fal_18_0.png
# 4       33381_0_fal_25_0.png
#                 ...
# 2294    36175_1_nrm_18_0.png
# 2295     36175_1_nrm_1_0.png
# 2296    36175_1_nrm_20_0.png
# 2297    36175_1_nrm_21_0.png
# 2298     36175_1_nrm_2_0.png
# Name: Image Name, Length: 2299, dtype: object

# %%
print(labels['Image Name'][0])
# Out:
# 33381_0_fal_10_0.png

# %%
type(labels['Image Name'][0])
# Out:
# str

# %%
print(labels['Experimental Condition [Diagnosis]'])
# Out:
# 0           chronic heart failure
# 1           chronic heart failure
# 2           chronic heart failure
# 3           chronic heart failure
# 4           chronic heart failure
#                   ...
# 2294    not chronic heart failure
# 2295    not chronic heart failure
# 2296    not chronic heart failure
# 2297    not chronic heart failure
# 2298    not chronic heart failure
# Name: Experimental Condition [Diagnosis], Length: 2299, dtype: object

# %%
print(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# chronic heart failure

# %%
type(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# str

# %%
# confirm 'no info' cells have been encoded as 'nan'... check one entry
print(labels['Characteristics [Disease Subtype]'][463])
# Out:
# nan

# %% [markdown]
# ### Prepare Train Images and Train Labels

# %% [markdown]
# #### Explore and Understand

# %%
# Google Drive / Colab
filepathlist_train = glob.glob('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png')

# %%
# confirm you have got the total number of desired items in the list
len(filepathlist_train)
# Out:
# 770

# %%
# check what an element in the filelist contain.
# it has both directory information and the filename, we need to extract filename 
# the filename can then be used to check for the label info in the labels dataframe
filepathlist_train[0]
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/33392_0_fal_4_0.png'

# %% [markdown]
# #### Extract Filename and Label Info

# %% [markdown]
# All the images are of type '*.png'. We will read filepath for all "filenames with extension as 'png'" into a list. Here, filepath means 'relative directory + filename'. We will extract filename of the image from the file path. This filename can then be used to get the label information from the annotation file.

# %% [markdown]
# ##### Local Drive / Jupyter

# %%
# this scenario has '\\' between the directory and filename
# split the string
# directory, filename = filepathlist_train[0].split('\\')
# gives the directory info
# directory
# gives the filname we need
# filename

# %% [markdown]
# ##### Google Drive / Colab

# %% [markdown]
# ###### Explore and Understand

# %%
len(filepathlist_train[0])
# Out:
# 128

# %%
filepathlist_train[0][-19:]
# Out:
# '33392_0_fal_4_0.png'

# %%
filepathlist_train[0][len(filepathlist_train[0]) - 1]
# Out:
# 'g'

# %%
filepathlist_train[0][-1]
# Out:
# 'g'

# %%
# POC
idx = -1
while (filepathlist_train[0][idx] != '/'):
  idx = idx - 1 
# index currently points to '/' location, we need to start reading from next location to get file name
print(idx)
filename = filepathlist_train[0][idx + 1:]
print(filename)
# Out:
# -20
# 33392_0_fal_4_0.png

# %%
# POC
index_filepathlist = 0
for filepath in filepathlist_train:
    #print(index_filepathlist, filepath)
    index_filepathlist += 1

# %%
# read a file using the list containing the file path
img = cv2.imread(filepathlist_train[0])

# %% [markdown]
# ##### Define a Call Function to prepare images and labels

# %%
# function to prepare images & labels for the model
def prepare_images_labels (path_to_img_files, labels_dataframe, resize = 0):
  filepathlist = glob.glob(path_to_img_files)
  # define the empty list that need to populated with info
  images = []
  labels = []
  index_filepathlist = 0
  # iterate for all items in the file path list
  for filepath in filepathlist:
      # prepare image list
      img = cv2.imread(filepath)
      if (resize == 1):
        dim = (224,224)
        img = cv2.resize(img, dim)#, interpolation = inter)
      images.append(img)
      # prepare labels list
      # extract filename from the file path
      # Local Drive / Jupyter
      # directory, filename = filepath.split('\\')
      # Google Drive / Colab
      index_character = -1
      while (filepathlist[index_filepathlist][index_character] != '/'):
        index_character = index_character - 1 
      # character index currently points to '/' location, we need to start reading from next location to get file name
      filename = filepathlist[index_filepathlist][index_character + 1:]
      index_filepathlist += 1
      # iterate for all items in our labels dataframe to search for the label
      for index in range(len(labels_dataframe)):
          # we will compare the filename with all the filenames in the 'Image Name' column of the labels dataframe
          # when there is a match, we will copy the label from the 'Experimental Condition [Diagnosis]' column
          if (filename == labels_dataframe['Image Name'][index]):
              label = labels_dataframe['Experimental Condition [Diagnosis]'][index]
              # encode Class1 and Class0 as applicable
              if (label == 'chronic heart failure'):
                  label = 1
              elif (label == 'not chronic heart failure'):
                  label = 0
              elif (label == 'heart tissue pathology'):
                  label = 0
              # append the label to the list
              labels.append(label)
  return images, labels

# %% [markdown]
# ##### Prepare Train Images and Train Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png'
# for resnet50
# train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_train = glob.glob('data/images/training/fold_1/*.png')

# %%
# train_labels

# %% [markdown]
# Convert images to numpy arrays and confirm shape is as required for CNN.

# %%
# confirm you have got the total number desired images in the list
len(train_images)
# Out:
# 770

# %%
# train is a list
type(train_images)
# Out:
# list

# %%
# convert list to a numpy array and the values to float
train_images = np.array(train_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
# number of instances, width, height, number of channels
# number of instances = number of image
# number of channels = 3 ... as these are color images
train_images.shape
# Out:
# (770, 224, 224, 3)

# %% [markdown]
# Convert labels to numpy arrays and confirm shape is as required for CNN.

# %%
len(train_labels)
# Out:
# 770

# %%
type(train_labels)
# Out:
# list

# %%
train_labels[0]
# Out:
# 1

# %%
train_labels[432]
# Out:
# 0

# %%
# convert list to a numpy array and the values to int64
train_labels = np.array(train_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
train_labels.shape
# Out:
# (770,)

# %%
len(train_labels)
# Out:
# 770

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
# function to count ones and zeroes in the label array
def print_ones_zeroes (labels):
  count_ones = 0
  count_zeroes = 0
  for i in range(len(labels)):
    if (labels[i] == 1):
      count_ones += 1
    elif (labels[i] == 0):
      count_zeroes += 1
  print('Total Labels:',(count_ones + count_zeroes))
  print('# of Class 1:',count_ones)   
  print('# of Class 0:',count_zeroes)

# %%
print_ones_zeroes(train_labels)
# Out:
# Total Labels: 770
# # of Class 1: 352
# # of Class 0: 418

# %% [markdown]
# We will convert the labels to 2bit values: 01 and 10 to correspond to the 2 classes. This is required to match to the model's output layer expectation so that we can effectively train and test.

# %%
from keras.utils import to_categorical

# %%
# convert labels to categorical
train_labels = to_categorical(train_labels)

# %% [markdown]
# ### Prepare Validation Images and Validation Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/test_fold_1/*.png'
# for resnet50
# validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_validation = glob.glob('data/images/training/test_fold_1/*.png')

# %%
# convert list to a numpy array and the values to float
validation_images = np.array(validation_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
validation_images.shape
# Out:
# (374, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
validation_labels = np.array(validation_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
validation_labels.shape
# Out:
# (374,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(validation_labels)
# Out:
# Total Labels: 374
# # of Class 1: 165
# # of Class 0: 209

# %%
# convert labels to categorical
validation_labels = to_categorical(validation_labels)

# %% [markdown]
# ### Prepare Test Images and Test Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/held-out_validation/*.png'
# for resnet50
# test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_test = glob.glob('data/images/held-out_validation/*.png')

# %%
# convert list to a numpy array and the values to float
test_images = np.array(test_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
test_images.shape
# Out:
# (1155, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
test_labels = np.array(test_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
test_labels.shape
# Out:
# (1155,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(test_labels)
# Out:
# Total Labels: 1155
# # of Class 1: 517
# # of Class 0: 638

# %%
# convert labels to categorical
test_labels = to_categorical(test_labels)

# %% [markdown]
# ## Model Definition / Train / Validate / Test

# %% [markdown]
# ### MNIST CNN modified for HE

# %%
# import libraries (general)
# from keras import models
# from keras import layers
# model_cnn = models.Sequential()

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 32
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# - Input Shape = 250x250 matrix with 3 channel (as we have a color image)
# model_cnn.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(250,250,3)))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation = 'relu'))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation='relu'))

# Data at this stage is in matrix form. We will convert it to vector form to feed to a fully connected network (FCN).
# model_cnn.add(layers.Flatten())

# We will design for 64 outputs with activation function as relu (to learn non-linearity).
# model_cnn.add(layers.Dense(64, activation = 'relu'))

# This is the final layer. Hence, the outputs will be 2 corresponding to the 2 classes:
# - clinical heart failure = yes: 1
# - clinical heart failure = no: 0
# Activation Function chosen here is softmax to have a probabilistic output. 
# model_cnn.add(layers.Dense(2, activation = 'softmax'))

# model_cnn.summary()

# Define Optimizer, Loss Function and Metrics to be used for the Model
# - Going ahead with the well known functions at this point in time
# - Selected accuracy as the metrics to understand validation / test accuracy of the model
# model_cnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Train and Validate the Model
# We will now train the model using train images and train labels. 
# - We will use a batch size = 10.
# - 1 epoch = 770 / 10 = 77 batches
# - 1 epoch = 1 complete run of all train samples for training the model
# - We will go for a total of 5 epochs = 5 complete run of the all train samples
# We will validate the model using validation images and validation labels.
# model_cnn.fit(train_images, train_labels, epochs = 1, batch_size = 10, validation_data = (validation_images, validation_labels))

# Test the Model
# We will now test model's performance with the test data.
# - We predict the class for each of the 1155 test using the model.
# - We will check the test accuracy.
# test_loss, test_acc = model_cnn.evaluate(test_images, test_labels)
# print('test accuracy:', (test_acc*100))

# %% [markdown]
# ### Define Common Hyperparameters

# %%
BATCH_SIZE = 10
EPOCHS = 100
LEARNING_RATE = 0.01
DENSE_LAYER_NEURONS = 512
DENSE_LAYER_DROPOUT = 0.4

# %% [markdown]
# ### Define a checkpoint function

# %%
def checkpoint(path_to_model_parameters_file):
  # 1st argument: file to which the weights need to be saved
  # 2nd argument: defines the quantity to monitor ... we will monitor validation accuracy
  # 3rd argument: verbose yes/no
  # 4th argument: true then save weghts else save entire model
  # 5th argument: max if val_acc, min if val_loss, auto decides based on the quantity getting monitored
  # 6th argument: period:  check after every epoch therefore 1
  # 6th arguemnt: save_freq:  specify the frequency in number of batches seen
  #checkpoint = ModelCheckpoint("/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  checkpoint_value = ModelCheckpoint(path_to_model_parameters_file, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  return checkpoint_value

# %% [markdown]
# ### ResNet50 - Transfer Learning

# %%
# import libraries (resnet50)
from keras.applications.resnet50 import ResNet50
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
from keras.preprocessing.image import ImageDataGenerator

# %%
# load ResNet50 with pre-trained parameters for 'imagenet' challenge
# disable the last layer ... so that we can have our own FCN layer for our desired classes
resnet50 = ResNet50(include_top=False, weights='imagenet')

# define the last layers
# get the output of the last layer of the ResNet50
prediction = resnet50.output
# add a Global Average Pooling layer (GAP) - this helps reduce number of parameters as compared to a flatten/dense layer
prediction = GlobalAveragePooling2D()(prediction)
# add a FCN with 1024 output neurons
#prediction = Dense(1024, activation = 'relu')(prediction)
# we will split the actions to have the Batch Normalization done befor relu
prediction = Dense(DENSE_LAYER_NEURONS)(prediction)
#prediction = BatchNormalization()(prediction)
prediction = Activation('relu')(prediction)
# add a dropout of 40% to avoid overfitting
prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)
# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction = Dense(2, activation = 'softmax')(prediction)

# connect the last layer with ResNet50 layer to define the model
model = Model(inputs = resnet50.input, outputs = prediction)

# we wish use the pretrained resnet50 model as is i.e. do not want it's parameters to get updated during training
for layer in resnet50.layers:
  layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

#model.summary()

# %%
# len(resnet50.layers)
# resnet50.layers
# resnet50.summary()

# %%
# data augmentation helps change the data slightly so that the model does not overfit
# train_generator = ImageDataGenerator(rotation_range = 8, width_shift_range = 0.08, shear_range = 0.3, height_shift_range = 0.08, zoom_range = 0.08)
# validation_generator = ImageDataGenerator()
# below ensures the augmented data is provided in batches to the model
# train_augmented = train_generator.flow(train_images, train_labels, batch_size = 10)
# validation_augmented = validation_generator.flow(validation_images, validation_labels, batch_size = 10)

# %%
# train and validate model
path_to_resnet50_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5'
model.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_resnet50_parameters_file)])

# train and validate model with augmented data
# model.fit(train_augmented, epochs = 20, batch_size = 10, validation_data = validation_augmented)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 7s 62ms/step - loss: 6.1022 - accuracy: 0.6064 - val_loss: 0.5798 - val_accuracy: 0.6765
#
# Epoch 00001: val_accuracy improved from -inf to 0.67647, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 2/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3964 - accuracy: 0.8185 - val_loss: 0.5069 - val_accuracy: 0.7674
#
# Epoch 00002: val_accuracy improved from 0.67647 to 0.76738, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 3/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3860 - accuracy: 0.8329 - val_loss: 0.4351 - val_accuracy: 0.8102
#
# Epoch 00003: val_accuracy improved from 0.76738 to 0.81016, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 4/100
# 77/77 [==============================] - 4s 51ms/step - loss: 0.3207 - accuracy: 0.8622 - val_loss: 0.6724 - val_accuracy: 0.7647
#
# Epoch 00004: val_accuracy did not improve from 0.81016
# Epoch 5/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3033 - accuracy: 0.8689 - val_loss: 0.4245 - val_accuracy: 0.8369
#
# Epoch 00005: val_accuracy improved from 0.81016 to 0.83690, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 6/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2823 - accuracy: 0.8899 - val_loss: 0.3937 - val_accuracy: 0.8262
#
# Epoch 00006: val_accuracy did not improve from 0.83690
# Epoch 7/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3811 - accuracy: 0.8383 - val_loss: 0.4690 - val_accuracy: 0.8155
#
# Epoch 00007: val_accuracy did not improve from 0.83690
# Epoch 8/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3246 - accuracy: 0.8576 - val_loss: 0.4806 - val_accuracy: 0.7914
#
# Epoch 00008: val_accuracy did not improve from 0.83690
# Epoch 9/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3545 - accuracy: 0.8275 - val_loss: 0.4614 - val_accuracy: 0.8075
#
# Epoch 00009: val_accuracy did not improve from 0.83690
# Epoch 10/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2895 - accuracy: 0.8884 - val_loss: 0.3854 - val_accuracy: 0.8289
#
# Epoch 00010: val_accuracy did not improve from 0.83690
# Epoch 11/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2591 - accuracy: 0.8946 - val_loss: 0.4287 - val_accuracy: 0.8289
#
# Epoch 00011: val_accuracy did not improve from 0.83690
# Epoch 12/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2835 - accuracy: 0.8796 - val_loss: 0.4420 - val_accuracy: 0.8182
#
# Epoch 00012: val_accuracy did not improve from 0.83690
# Epoch 13/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2735 - accuracy: 0.8794 - val_loss: 0.3934 - val_accuracy: 0.8369
#
# Epoch 00013: val_accuracy did not improve from 0.83690
# Epoch 14/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2218 - accuracy: 0.9133 - val_loss: 0.4884 - val_accuracy: 0.8102
#
# Epoch 00014: val_accuracy did not improve from 0.83690
# Epoch 15/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1982 - accuracy: 0.9109 - val_loss: 0.6795 - val_accuracy: 0.8102
#
# Epoch 00015: val_accuracy did not improve from 0.83690
# Epoch 16/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3447 - accuracy: 0.8458 - val_loss: 0.3702 - val_accuracy: 0.8690
#
# Epoch 00016: val_accuracy improved from 0.83690 to 0.86898, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 17/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2480 - accuracy: 0.8967 - val_loss: 0.4488 - val_accuracy: 0.8316
#
# Epoch 00017: val_accuracy did not improve from 0.86898
# Epoch 18/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2401 - accuracy: 0.8858 - val_loss: 0.4576 - val_accuracy: 0.8449
#
# Epoch 00018: val_accuracy did not improve from 0.86898
# Epoch 19/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1949 - accuracy: 0.9083 - val_loss: 0.4375 - val_accuracy: 0.8583
#
# Epoch 00019: val_accuracy did not improve from 0.86898
# Epoch 20/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2127 - accuracy: 0.8870 - val_loss: 0.4750 - val_accuracy: 0.8503
#
# Epoch 00020: val_accuracy did not improve from 0.86898
# Epoch 21/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2452 - accuracy: 0.8959 - val_loss: 0.5455 - val_accuracy: 0.8422
#
# Epoch 00021: val_accuracy did not improve from 0.86898
# Epoch 22/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3197 - accuracy: 0.8579 - val_loss: 0.5044 - val_accuracy: 0.8262
#
# Epoch 00022: val_accuracy did not improve from 0.86898
# Epoch 23/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2791 - accuracy: 0.8733 - val_loss: 0.3606 - val_accuracy: 0.8316
#
# Epoch 00023: val_accuracy did not improve from 0.86898
# Epoch 24/100
# 77/77 [==============================] - 4s 55ms/step - loss: 0.2887 - accuracy: 0.8673 - val_loss: 0.4536 - val_accuracy: 0.8396
#
# Epoch 00024: val_accuracy did not improve from 0.86898
# Epoch 25/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2921 - accuracy: 0.8274 - val_loss: 0.4663 - val_accuracy: 0.8369
#
# Epoch 00025: val_accuracy did not improve from 0.86898
# Epoch 26/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2702 - accuracy: 0.8932 - val_loss: 0.4123 - val_accuracy: 0.8369
#
# Epoch 00026: val_accuracy did not improve from 0.86898
# Epoch 27/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2849 - accuracy: 0.8692 - val_loss: 0.6243 - val_accuracy: 0.8369
#
# Epoch 00027: val_accuracy did not improve from 0.86898
# Epoch 28/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2333 - accuracy: 0.9056 - val_loss: 0.6776 - val_accuracy: 0.8209
#
# Epoch 00028: val_accuracy did not improve from 0.86898
# Epoch 29/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2365 - accuracy: 0.9044 - val_loss: 0.5371 - val_accuracy: 0.8583
#
# Epoch 00029: val_accuracy did not improve from 0.86898
# Epoch 30/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1946 - accuracy: 0.9046 - val_loss: 0.7186 - val_accuracy: 0.8556
#
# Epoch 00030: val_accuracy did not improve from 0.86898
# Epoch 31/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1749 - accuracy: 0.9275 - val_loss: 0.4074 - val_accuracy: 0.8529
#
# Epoch 00031: val_accuracy did not improve from 0.86898
# Epoch 32/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2241 - accuracy: 0.9114 - val_loss: 0.7445 - val_accuracy: 0.8610
#
# Epoch 00032: val_accuracy did not improve from 0.86898
# Epoch 33/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2675 - accuracy: 0.8676 - val_loss: 0.5129 - val_accuracy: 0.8556
#
# Epoch 00033: val_accuracy did not improve from 0.86898
# Epoch 34/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1843 - accuracy: 0.9008 - val_loss: 0.5152 - val_accuracy: 0.8583
#
# Epoch 00034: val_accuracy did not improve from 0.86898
# Epoch 35/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2223 - accuracy: 0.8512 - val_loss: 0.4986 - val_accuracy: 0.8476
#
# Epoch 00035: val_accuracy did not improve from 0.86898
# Epoch 36/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3560 - accuracy: 0.8026 - val_loss: 0.6893 - val_accuracy: 0.8262
#
# Epoch 00036: val_accuracy did not improve from 0.86898
# Epoch 37/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2540 - accuracy: 0.9051 - val_loss: 0.5860 - val_accuracy: 0.8583
#
# Epoch 00037: val_accuracy did not improve from 0.86898
# Epoch 38/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2180 - accuracy: 0.9119 - val_loss: 0.4672 - val_accuracy: 0.8610
#
# Epoch 00038: val_accuracy did not improve from 0.86898
# Epoch 39/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1566 - accuracy: 0.9435 - val_loss: 0.7054 - val_accuracy: 0.8583
#
# Epoch 00039: val_accuracy did not improve from 0.86898
# Epoch 40/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1833 - accuracy: 0.9210 - val_loss: 0.5230 - val_accuracy: 0.8422
#
# Epoch 00040: val_accuracy did not improve from 0.86898
# Epoch 41/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2040 - accuracy: 0.8983 - val_loss: 0.6054 - val_accuracy: 0.8556
#
# Epoch 00041: val_accuracy did not improve from 0.86898
# Epoch 42/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2543 - accuracy: 0.8826 - val_loss: 0.5620 - val_accuracy: 0.8717
#
# Epoch 00042: val_accuracy improved from 0.86898 to 0.87166, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 43/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1814 - accuracy: 0.9208 - val_loss: 0.4629 - val_accuracy: 0.8610
#
# Epoch 00043: val_accuracy did not improve from 0.87166
# Epoch 44/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1650 - accuracy: 0.9379 - val_loss: 0.8546 - val_accuracy: 0.8369
#
# Epoch 00044: val_accuracy did not improve from 0.87166
# Epoch 45/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1665 - accuracy: 0.9310 - val_loss: 0.6955 - val_accuracy: 0.8529
#
# Epoch 00045: val_accuracy did not improve from 0.87166
# Epoch 46/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1239 - accuracy: 0.9423 - val_loss: 0.9825 - val_accuracy: 0.8529
#
# Epoch 00046: val_accuracy did not improve from 0.87166
# Epoch 47/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1712 - accuracy: 0.9140 - val_loss: 0.5034 - val_accuracy: 0.8663
#
# Epoch 00047: val_accuracy did not improve from 0.87166
# Epoch 48/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1397 - accuracy: 0.9266 - val_loss: 0.7980 - val_accuracy: 0.8690
#
# Epoch 00048: val_accuracy did not improve from 0.87166
# Epoch 49/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1542 - accuracy: 0.9374 - val_loss: 0.6941 - val_accuracy: 0.8503
#
# Epoch 00049: val_accuracy did not improve from 0.87166
# Epoch 50/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2308 - accuracy: 0.8786 - val_loss: 0.8781 - val_accuracy: 0.8422
#
# Epoch 00050: val_accuracy did not improve from 0.87166
# Epoch 51/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2441 - accuracy: 0.8757 - val_loss: 0.6767 - val_accuracy: 0.8610
#
# Epoch 00051: val_accuracy did not improve from 0.87166
# Epoch 52/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1935 - accuracy: 0.9118 - val_loss: 0.7771 - val_accuracy: 0.8262
#
# Epoch 00052: val_accuracy did not improve from 0.87166
# Epoch 53/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3162 - accuracy: 0.8936 - val_loss: 0.6135 - val_accuracy: 0.8877
#
# Epoch 00053: val_accuracy improved from 0.87166 to 0.88770, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 54/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.2198 - accuracy: 0.8997 - val_loss: 0.7739 - val_accuracy: 0.8636
#
# Epoch 00054: val_accuracy did not improve from 0.88770
# Epoch 55/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1759 - accuracy: 0.9254 - val_loss: 0.9646 - val_accuracy: 0.8529
#
# Epoch 00055: val_accuracy did not improve from 0.88770
# Epoch 56/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2207 - accuracy: 0.8999 - val_loss: 0.9676 - val_accuracy: 0.8476
#
# Epoch 00056: val_accuracy did not improve from 0.88770
# Epoch 57/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1453 - accuracy: 0.9393 - val_loss: 0.9304 - val_accuracy: 0.8503
#
# Epoch 00057: val_accuracy did not improve from 0.88770
# Epoch 58/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1540 - accuracy: 0.9384 - val_loss: 0.9924 - val_accuracy: 0.8610
#
# Epoch 00058: val_accuracy did not improve from 0.88770
# Epoch 59/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1705 - accuracy: 0.9275 - val_loss: 1.0687 - val_accuracy: 0.8422
#
# Epoch 00059: val_accuracy did not improve from 0.88770
# Epoch 60/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2478 - accuracy: 0.9106 - val_loss: 0.7269 - val_accuracy: 0.8610
#
# Epoch 00060: val_accuracy did not improve from 0.88770
# Epoch 61/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2135 - accuracy: 0.9279 - val_loss: 1.0120 - val_accuracy: 0.8529
#
# Epoch 00061: val_accuracy did not improve from 0.88770
# Epoch 62/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2047 - accuracy: 0.9299 - val_loss: 0.7701 - val_accuracy: 0.8663
#
# Epoch 00062: val_accuracy did not improve from 0.88770
# Epoch 63/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1493 - accuracy: 0.9567 - val_loss: 1.0303 - val_accuracy: 0.8583
#
# Epoch 00063: val_accuracy did not improve from 0.88770
# Epoch 64/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2464 - accuracy: 0.9179 - val_loss: 0.6488 - val_accuracy: 0.8529
#
# Epoch 00064: val_accuracy did not improve from 0.88770
# Epoch 65/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1947 - accuracy: 0.9318 - val_loss: 1.0147 - val_accuracy: 0.8770
#
# Epoch 00065: val_accuracy did not improve from 0.88770
# Epoch 66/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1852 - accuracy: 0.9279 - val_loss: 0.7063 - val_accuracy: 0.8717
#
# Epoch 00066: val_accuracy did not improve from 0.88770
# Epoch 67/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2073 - accuracy: 0.9221 - val_loss: 0.7881 - val_accuracy: 0.8476
#
# Epoch 00067: val_accuracy did not improve from 0.88770
# Epoch 68/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2450 - accuracy: 0.9054 - val_loss: 1.0322 - val_accuracy: 0.8369
#
# Epoch 00068: val_accuracy did not improve from 0.88770
# Epoch 69/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1961 - accuracy: 0.9345 - val_loss: 0.9389 - val_accuracy: 0.8636
#
# Epoch 00069: val_accuracy did not improve from 0.88770
# Epoch 70/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2255 - accuracy: 0.9228 - val_loss: 1.0888 - val_accuracy: 0.8583
#
# Epoch 00070: val_accuracy did not improve from 0.88770
# Epoch 71/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2079 - accuracy: 0.9410 - val_loss: 0.6627 - val_accuracy: 0.8690
#
# Epoch 00071: val_accuracy did not improve from 0.88770
# Epoch 72/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2642 - accuracy: 0.8926 - val_loss: 1.0143 - val_accuracy: 0.8556
#
# Epoch 00072: val_accuracy did not improve from 0.88770
# Epoch 73/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1860 - accuracy: 0.9406 - val_loss: 1.0131 - val_accuracy: 0.8503
#
# Epoch 00073: val_accuracy did not improve from 0.88770
# Epoch 74/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2217 - accuracy: 0.9191 - val_loss: 0.8349 - val_accuracy: 0.8610
#
# Epoch 00074: val_accuracy did not improve from 0.88770
# Epoch 75/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1803 - accuracy: 0.9415 - val_loss: 1.0614 - val_accuracy: 0.8529
#
# Epoch 00075: val_accuracy did not improve from 0.88770
# Epoch 76/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2417 - accuracy: 0.9085 - val_loss: 1.2709 - val_accuracy: 0.8503
#
# Epoch 00076: val_accuracy did not improve from 0.88770
# Epoch 77/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1984 - accuracy: 0.9393 - val_loss: 1.2369 - val_accuracy: 0.8155
#
# Epoch 00077: val_accuracy did not improve from 0.88770
# Epoch 78/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2481 - accuracy: 0.9149 - val_loss: 0.9262 - val_accuracy: 0.8663
#
# Epoch 00078: val_accuracy did not improve from 0.88770
# Epoch 79/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1852 - accuracy: 0.9378 - val_loss: 0.5278 - val_accuracy: 0.8877
#
# Epoch 00079: val_accuracy did not improve from 0.88770
# Epoch 80/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2766 - accuracy: 0.9002 - val_loss: 0.8137 - val_accuracy: 0.8690
#
# Epoch 00080: val_accuracy did not improve from 0.88770
# Epoch 81/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1793 - accuracy: 0.9448 - val_loss: 0.8094 - val_accuracy: 0.8743
#
# Epoch 00081: val_accuracy did not improve from 0.88770
# Epoch 82/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2770 - accuracy: 0.9113 - val_loss: 1.2664 - val_accuracy: 0.8610
#
# Epoch 00082: val_accuracy did not improve from 0.88770
# Epoch 83/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1776 - accuracy: 0.9432 - val_loss: 0.8126 - val_accuracy: 0.8743
#
# Epoch 00083: val_accuracy did not improve from 0.88770
# Epoch 84/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1524 - accuracy: 0.9467 - val_loss: 1.1293 - val_accuracy: 0.8663
#
# Epoch 00084: val_accuracy did not improve from 0.88770
# Epoch 85/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1499 - accuracy: 0.9567 - val_loss: 1.3692 - val_accuracy: 0.8503
#
# Epoch 00085: val_accuracy did not improve from 0.88770
# Epoch 86/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1934 - accuracy: 0.9388 - val_loss: 0.9655 - val_accuracy: 0.8476
#
# Epoch 00086: val_accuracy did not improve from 0.88770
# Epoch 87/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2223 - accuracy: 0.9260 - val_loss: 1.2267 - val_accuracy: 0.8262
#
# Epoch 00087: val_accuracy did not improve from 0.88770
# Epoch 88/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2123 - accuracy: 0.9260 - val_loss: 0.6275 - val_accuracy: 0.8743
#
# Epoch 00088: val_accuracy did not improve from 0.88770
# Epoch 89/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.3075 - accuracy: 0.8878 - val_loss: 1.0144 - val_accuracy: 0.8529
#
# Epoch 00089: val_accuracy did not improve from 0.88770
# Epoch 90/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2093 - accuracy: 0.9231 - val_loss: 1.4281 - val_accuracy: 0.8449
#
# Epoch 00090: val_accuracy did not improve from 0.88770
# Epoch 91/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1630 - accuracy: 0.9537 - val_loss: 0.9772 - val_accuracy: 0.8556
#
# Epoch 00091: val_accuracy did not improve from 0.88770
# Epoch 92/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1864 - accuracy: 0.9384 - val_loss: 1.1710 - val_accuracy: 0.8529
#
# Epoch 00092: val_accuracy did not improve from 0.88770
# Epoch 93/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1372 - accuracy: 0.9611 - val_loss: 1.0961 - val_accuracy: 0.8449
#
# Epoch 00093: val_accuracy did not improve from 0.88770
# Epoch 94/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1621 - accuracy: 0.9502 - val_loss: 0.6818 - val_accuracy: 0.8797
#
# Epoch 00094: val_accuracy did not improve from 0.88770
# Epoch 95/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.2043 - accuracy: 0.9322 - val_loss: 1.0980 - val_accuracy: 0.8529
#
# Epoch 00095: val_accuracy did not improve from 0.88770
# Epoch 96/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1703 - accuracy: 0.9414 - val_loss: 1.4529 - val_accuracy: 0.8449
#
# Epoch 00096: val_accuracy did not improve from 0.88770
# Epoch 97/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1267 - accuracy: 0.9627 - val_loss: 1.1049 - val_accuracy: 0.8636
#
# Epoch 00097: val_accuracy did not improve from 0.88770
# Epoch 98/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1633 - accuracy: 0.9457 - val_loss: 0.9263 - val_accuracy: 0.8690
#
# Epoch 00098: val_accuracy did not improve from 0.88770
# Epoch 99/100
# 77/77 [==============================] - 4s 52ms/step - loss: 0.1404 - accuracy: 0.9584 - val_loss: 0.9906 - val_accuracy: 0.8717
#
# Epoch 00099: val_accuracy did not improve from 0.88770
# Epoch 100/100
# 77/77 [==============================] - 4s 53ms/step - loss: 0.1654 - accuracy: 0.9477 - val_loss: 0.7839 - val_accuracy: 0.8663
#
# Epoch 00100: val_accuracy did not improve from 0.88770

# %%
# test model
#test_loss, test_acc = model.evaluate(test_images, test_labels)

# %%
# test with best model
model.load_weights(path_to_resnet50_parameters_file)
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 4s 94ms/step - loss: 0.8522 - accuracy: 0.8069

# %% [markdown]
# ### MobileNet

# %% [markdown]
# We will first perform transfer learning. This will help get the parameter values initialized for the last layers before we engage few convolution layers of MobileNet in learning (Fine Tuning).

# %% [markdown]
# #### Transfer Learning

# %%
# import libraries
import tensorflow as tf
from keras.models import Model
#from keras.optimizers import SGD
from keras.optimizers import Adam
#from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
#from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers

# %%
# load MobileNet with pre-trained parameters for 'imagenet' challenge
mobilenet = tf.keras.applications.mobilenet.MobileNet()
# mobilenet.summary()

# define the last layers
# get the output of the last layer of the MobileNet
prediction_mn = mobilenet.output

# mobilenet already has a GAP layer, hence we need to only add a Dense layer

# add a FCN with 512 output neurons
prediction_mn = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction_mn)
# with regularizer
# prediction_mn = Dense(1024, activation = 'relu', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# we will split the actions to have the Batch Normalization done befor relu
# prediction_mn = Dense(1024)(prediction_mn)
# prediction_mn = BatchNormalization()(prediction_mn)
# prediction_mn = Activation('relu')(prediction_mn)

# add a dropout to avoid overfitting
prediction_mn = Dropout(DENSE_LAYER_DROPOUT)(prediction_mn)

# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction_mn = Dense(2, activation = 'softmax')(prediction_mn)
# with regularizer
# prediction_mn = Dense(2, activation = 'softmax', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# connect the last layer with MobileNet layer to define the model
model_mn = Model(inputs = mobilenet.input, outputs = prediction_mn)

# we wish use the pretrained MobileNet model as is i.e. do not want it's parameters to get updated during training
for layer in mobilenet.layers:
   layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model_mn.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
#model_mn.compile(optimizer = Adam(lr=0.01), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# we want to monitor validation accuracy and save the best validation accuracy, hence changing the metrics to 'val_accuracy'
model_mn.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

# %%
# model_mn.summary()

# %%
# let us check the layers in the model 
# for i,layer in enumerate(model_mn.layers):
#  print(i,layer.name)

# %%
# train and validate model
path_to_mobilenet_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5'
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_parameters_file)])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 3s 26ms/step - loss: 0.5950 - accuracy: 0.6796 - val_loss: 0.4695 - val_accuracy: 0.7995
#
# Epoch 00001: val_accuracy improved from -inf to 0.79947, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 2/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.5448 - accuracy: 0.7347 - val_loss: 0.4695 - val_accuracy: 0.7754
#
# Epoch 00002: val_accuracy did not improve from 0.79947
# Epoch 3/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.5192 - accuracy: 0.7527 - val_loss: 0.4432 - val_accuracy: 0.8422
#
# Epoch 00003: val_accuracy improved from 0.79947 to 0.84225, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 4/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4745 - accuracy: 0.7828 - val_loss: 0.4294 - val_accuracy: 0.8209
#
# Epoch 00004: val_accuracy did not improve from 0.84225
# Epoch 5/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4715 - accuracy: 0.7802 - val_loss: 0.4750 - val_accuracy: 0.8155
#
# Epoch 00005: val_accuracy did not improve from 0.84225
# Epoch 6/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.5084 - accuracy: 0.7666 - val_loss: 0.4071 - val_accuracy: 0.8102
#
# Epoch 00006: val_accuracy did not improve from 0.84225
# Epoch 7/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.5072 - accuracy: 0.7454 - val_loss: 0.4135 - val_accuracy: 0.8155
#
# Epoch 00007: val_accuracy did not improve from 0.84225
# Epoch 8/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4379 - accuracy: 0.8012 - val_loss: 0.4414 - val_accuracy: 0.8021
#
# Epoch 00008: val_accuracy did not improve from 0.84225
# Epoch 9/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4818 - accuracy: 0.7805 - val_loss: 0.4260 - val_accuracy: 0.8075
#
# Epoch 00009: val_accuracy did not improve from 0.84225
# Epoch 10/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4567 - accuracy: 0.7918 - val_loss: 0.4280 - val_accuracy: 0.7995
#
# Epoch 00010: val_accuracy did not improve from 0.84225
# Epoch 11/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.4627 - accuracy: 0.7849 - val_loss: 0.4206 - val_accuracy: 0.8396
#
# Epoch 00011: val_accuracy did not improve from 0.84225
# Epoch 12/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4498 - accuracy: 0.8157 - val_loss: 0.4448 - val_accuracy: 0.7941
#
# Epoch 00012: val_accuracy did not improve from 0.84225
# Epoch 13/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4528 - accuracy: 0.8009 - val_loss: 0.5248 - val_accuracy: 0.7166
#
# Epoch 00013: val_accuracy did not improve from 0.84225
# Epoch 14/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.4832 - accuracy: 0.7848 - val_loss: 0.4149 - val_accuracy: 0.8102
#
# Epoch 00014: val_accuracy did not improve from 0.84225
# Epoch 15/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4416 - accuracy: 0.8047 - val_loss: 0.4005 - val_accuracy: 0.8289
#
# Epoch 00015: val_accuracy did not improve from 0.84225
# Epoch 16/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.4355 - accuracy: 0.7955 - val_loss: 0.4972 - val_accuracy: 0.7594
#
# Epoch 00016: val_accuracy did not improve from 0.84225
# Epoch 17/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4463 - accuracy: 0.7911 - val_loss: 0.4382 - val_accuracy: 0.8182
#
# Epoch 00017: val_accuracy did not improve from 0.84225
# Epoch 18/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4377 - accuracy: 0.8116 - val_loss: 0.4417 - val_accuracy: 0.7941
#
# Epoch 00018: val_accuracy did not improve from 0.84225
# Epoch 19/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4305 - accuracy: 0.8019 - val_loss: 0.3995 - val_accuracy: 0.8289
#
# Epoch 00019: val_accuracy did not improve from 0.84225
# Epoch 20/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4495 - accuracy: 0.7892 - val_loss: 0.4197 - val_accuracy: 0.8102
#
# Epoch 00020: val_accuracy did not improve from 0.84225
# Epoch 21/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4578 - accuracy: 0.7931 - val_loss: 0.4187 - val_accuracy: 0.8102
#
# Epoch 00021: val_accuracy did not improve from 0.84225
# Epoch 22/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3986 - accuracy: 0.8269 - val_loss: 0.4660 - val_accuracy: 0.7567
#
# Epoch 00022: val_accuracy did not improve from 0.84225
# Epoch 23/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4304 - accuracy: 0.8038 - val_loss: 0.4598 - val_accuracy: 0.7861
#
# Epoch 00023: val_accuracy did not improve from 0.84225
# Epoch 24/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4623 - accuracy: 0.8119 - val_loss: 0.4650 - val_accuracy: 0.7647
#
# Epoch 00024: val_accuracy did not improve from 0.84225
# Epoch 25/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3996 - accuracy: 0.8124 - val_loss: 0.4650 - val_accuracy: 0.7647
#
# Epoch 00025: val_accuracy did not improve from 0.84225
# Epoch 26/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4029 - accuracy: 0.8204 - val_loss: 0.4731 - val_accuracy: 0.7674
#
# Epoch 00026: val_accuracy did not improve from 0.84225
# Epoch 27/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4131 - accuracy: 0.8264 - val_loss: 0.3867 - val_accuracy: 0.8449
#
# Epoch 00027: val_accuracy improved from 0.84225 to 0.84492, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 28/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4124 - accuracy: 0.7913 - val_loss: 0.3979 - val_accuracy: 0.8182
#
# Epoch 00028: val_accuracy did not improve from 0.84492
# Epoch 29/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3676 - accuracy: 0.8363 - val_loss: 0.3876 - val_accuracy: 0.8503
#
# Epoch 00029: val_accuracy improved from 0.84492 to 0.85027, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 30/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4060 - accuracy: 0.8300 - val_loss: 0.4906 - val_accuracy: 0.7567
#
# Epoch 00030: val_accuracy did not improve from 0.85027
# Epoch 31/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4027 - accuracy: 0.8240 - val_loss: 0.5563 - val_accuracy: 0.7353
#
# Epoch 00031: val_accuracy did not improve from 0.85027
# Epoch 32/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4400 - accuracy: 0.8017 - val_loss: 0.4080 - val_accuracy: 0.8128
#
# Epoch 00032: val_accuracy did not improve from 0.85027
# Epoch 33/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3843 - accuracy: 0.8344 - val_loss: 0.4065 - val_accuracy: 0.8102
#
# Epoch 00033: val_accuracy did not improve from 0.85027
# Epoch 34/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4226 - accuracy: 0.8126 - val_loss: 0.3935 - val_accuracy: 0.8342
#
# Epoch 00034: val_accuracy did not improve from 0.85027
# Epoch 35/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3841 - accuracy: 0.8041 - val_loss: 0.4232 - val_accuracy: 0.8155
#
# Epoch 00035: val_accuracy did not improve from 0.85027
# Epoch 36/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3814 - accuracy: 0.8251 - val_loss: 0.4234 - val_accuracy: 0.7888
#
# Epoch 00036: val_accuracy did not improve from 0.85027
# Epoch 37/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3976 - accuracy: 0.8088 - val_loss: 0.4279 - val_accuracy: 0.8235
#
# Epoch 00037: val_accuracy did not improve from 0.85027
# Epoch 38/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3977 - accuracy: 0.8274 - val_loss: 0.4316 - val_accuracy: 0.8021
#
# Epoch 00038: val_accuracy did not improve from 0.85027
# Epoch 39/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4262 - accuracy: 0.8199 - val_loss: 0.4353 - val_accuracy: 0.7914
#
# Epoch 00039: val_accuracy did not improve from 0.85027
# Epoch 40/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3368 - accuracy: 0.8645 - val_loss: 0.4209 - val_accuracy: 0.8048
#
# Epoch 00040: val_accuracy did not improve from 0.85027
# Epoch 41/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3956 - accuracy: 0.8450 - val_loss: 0.4480 - val_accuracy: 0.7914
#
# Epoch 00041: val_accuracy did not improve from 0.85027
# Epoch 42/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3931 - accuracy: 0.8238 - val_loss: 0.4253 - val_accuracy: 0.7941
#
# Epoch 00042: val_accuracy did not improve from 0.85027
# Epoch 43/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3731 - accuracy: 0.8537 - val_loss: 0.4471 - val_accuracy: 0.8048
#
# Epoch 00043: val_accuracy did not improve from 0.85027
# Epoch 44/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3697 - accuracy: 0.8461 - val_loss: 0.4432 - val_accuracy: 0.7888
#
# Epoch 00044: val_accuracy did not improve from 0.85027
# Epoch 45/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3750 - accuracy: 0.8333 - val_loss: 0.4220 - val_accuracy: 0.8316
#
# Epoch 00045: val_accuracy did not improve from 0.85027
# Epoch 46/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3481 - accuracy: 0.8485 - val_loss: 0.4107 - val_accuracy: 0.8289
#
# Epoch 00046: val_accuracy did not improve from 0.85027
# Epoch 47/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3869 - accuracy: 0.8470 - val_loss: 0.4388 - val_accuracy: 0.8128
#
# Epoch 00047: val_accuracy did not improve from 0.85027
# Epoch 48/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3595 - accuracy: 0.8457 - val_loss: 0.4056 - val_accuracy: 0.8396
#
# Epoch 00048: val_accuracy did not improve from 0.85027
# Epoch 49/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3722 - accuracy: 0.8442 - val_loss: 0.4596 - val_accuracy: 0.7941
#
# Epoch 00049: val_accuracy did not improve from 0.85027
# Epoch 50/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3495 - accuracy: 0.8562 - val_loss: 0.4586 - val_accuracy: 0.7914
#
# Epoch 00050: val_accuracy did not improve from 0.85027
# Epoch 51/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3477 - accuracy: 0.8595 - val_loss: 0.4087 - val_accuracy: 0.8396
#
# Epoch 00051: val_accuracy did not improve from 0.85027
# Epoch 52/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3618 - accuracy: 0.8470 - val_loss: 0.4208 - val_accuracy: 0.8182
#
# Epoch 00052: val_accuracy did not improve from 0.85027
# Epoch 53/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3451 - accuracy: 0.8473 - val_loss: 0.4475 - val_accuracy: 0.8128
#
# Epoch 00053: val_accuracy did not improve from 0.85027
# Epoch 54/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3140 - accuracy: 0.8737 - val_loss: 0.6111 - val_accuracy: 0.7487
#
# Epoch 00054: val_accuracy did not improve from 0.85027
# Epoch 55/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3906 - accuracy: 0.8234 - val_loss: 0.4068 - val_accuracy: 0.8262
#
# Epoch 00055: val_accuracy did not improve from 0.85027
# Epoch 56/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3119 - accuracy: 0.8671 - val_loss: 0.4499 - val_accuracy: 0.8182
#
# Epoch 00056: val_accuracy did not improve from 0.85027
# Epoch 57/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3477 - accuracy: 0.8321 - val_loss: 0.4542 - val_accuracy: 0.8021
#
# Epoch 00057: val_accuracy did not improve from 0.85027
# Epoch 58/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3165 - accuracy: 0.8706 - val_loss: 0.3999 - val_accuracy: 0.8369
#
# Epoch 00058: val_accuracy did not improve from 0.85027
# Epoch 59/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3433 - accuracy: 0.8548 - val_loss: 0.4598 - val_accuracy: 0.8048
#
# Epoch 00059: val_accuracy did not improve from 0.85027
# Epoch 60/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3474 - accuracy: 0.8392 - val_loss: 0.4555 - val_accuracy: 0.8128
#
# Epoch 00060: val_accuracy did not improve from 0.85027
# Epoch 61/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3611 - accuracy: 0.8425 - val_loss: 0.4087 - val_accuracy: 0.8262
#
# Epoch 00061: val_accuracy did not improve from 0.85027
# Epoch 62/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3397 - accuracy: 0.8403 - val_loss: 0.4471 - val_accuracy: 0.8128
#
# Epoch 00062: val_accuracy did not improve from 0.85027
# Epoch 63/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3203 - accuracy: 0.8611 - val_loss: 0.4363 - val_accuracy: 0.8021
#
# Epoch 00063: val_accuracy did not improve from 0.85027
# Epoch 64/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3000 - accuracy: 0.9003 - val_loss: 0.5042 - val_accuracy: 0.7594
#
# Epoch 00064: val_accuracy did not improve from 0.85027
# Epoch 65/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3353 - accuracy: 0.8740 - val_loss: 0.4445 - val_accuracy: 0.8155
#
# Epoch 00065: val_accuracy did not improve from 0.85027
# Epoch 66/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3249 - accuracy: 0.8532 - val_loss: 0.4211 - val_accuracy: 0.8262
#
# Epoch 00066: val_accuracy did not improve from 0.85027
# Epoch 67/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3505 - accuracy: 0.8529 - val_loss: 0.4338 - val_accuracy: 0.8289
#
# Epoch 00067: val_accuracy did not improve from 0.85027
# Epoch 68/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3029 - accuracy: 0.8621 - val_loss: 0.4173 - val_accuracy: 0.8289
#
# Epoch 00068: val_accuracy did not improve from 0.85027
# Epoch 69/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3250 - accuracy: 0.8689 - val_loss: 0.4451 - val_accuracy: 0.8182
#
# Epoch 00069: val_accuracy did not improve from 0.85027
# Epoch 70/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2876 - accuracy: 0.8949 - val_loss: 0.4278 - val_accuracy: 0.8102
#
# Epoch 00070: val_accuracy did not improve from 0.85027
# Epoch 71/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3081 - accuracy: 0.8621 - val_loss: 0.4371 - val_accuracy: 0.8235
#
# Epoch 00071: val_accuracy did not improve from 0.85027
# Epoch 72/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3236 - accuracy: 0.8338 - val_loss: 0.3960 - val_accuracy: 0.8289
#
# Epoch 00072: val_accuracy did not improve from 0.85027
# Epoch 73/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3380 - accuracy: 0.8710 - val_loss: 0.4242 - val_accuracy: 0.8289
#
# Epoch 00073: val_accuracy did not improve from 0.85027
# Epoch 74/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3021 - accuracy: 0.8792 - val_loss: 0.4519 - val_accuracy: 0.8075
#
# Epoch 00074: val_accuracy did not improve from 0.85027
# Epoch 75/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3293 - accuracy: 0.8553 - val_loss: 0.4732 - val_accuracy: 0.7968
#
# Epoch 00075: val_accuracy did not improve from 0.85027
# Epoch 76/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3254 - accuracy: 0.8642 - val_loss: 0.4333 - val_accuracy: 0.8289
#
# Epoch 00076: val_accuracy did not improve from 0.85027
# Epoch 77/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3042 - accuracy: 0.8732 - val_loss: 0.5549 - val_accuracy: 0.7701
#
# Epoch 00077: val_accuracy did not improve from 0.85027
# Epoch 78/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3044 - accuracy: 0.8670 - val_loss: 0.4827 - val_accuracy: 0.8021
#
# Epoch 00078: val_accuracy did not improve from 0.85027
# Epoch 79/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3128 - accuracy: 0.8480 - val_loss: 0.4277 - val_accuracy: 0.8289
#
# Epoch 00079: val_accuracy did not improve from 0.85027
# Epoch 80/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2962 - accuracy: 0.8610 - val_loss: 0.4709 - val_accuracy: 0.8048
#
# Epoch 00080: val_accuracy did not improve from 0.85027
# Epoch 81/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3004 - accuracy: 0.8706 - val_loss: 0.4756 - val_accuracy: 0.8075
#
# Epoch 00081: val_accuracy did not improve from 0.85027
# Epoch 82/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2892 - accuracy: 0.8742 - val_loss: 0.5822 - val_accuracy: 0.7594
#
# Epoch 00082: val_accuracy did not improve from 0.85027
# Epoch 83/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2796 - accuracy: 0.8918 - val_loss: 0.5315 - val_accuracy: 0.7941
#
# Epoch 00083: val_accuracy did not improve from 0.85027
# Epoch 84/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3052 - accuracy: 0.8658 - val_loss: 0.5228 - val_accuracy: 0.7914
#
# Epoch 00084: val_accuracy did not improve from 0.85027
# Epoch 85/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3105 - accuracy: 0.8712 - val_loss: 0.4890 - val_accuracy: 0.7941
#
# Epoch 00085: val_accuracy did not improve from 0.85027
# Epoch 86/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3038 - accuracy: 0.8762 - val_loss: 0.4606 - val_accuracy: 0.8235
#
# Epoch 00086: val_accuracy did not improve from 0.85027
# Epoch 87/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2931 - accuracy: 0.8728 - val_loss: 0.4762 - val_accuracy: 0.8182
#
# Epoch 00087: val_accuracy did not improve from 0.85027
# Epoch 88/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2736 - accuracy: 0.8771 - val_loss: 0.5489 - val_accuracy: 0.7834
#
# Epoch 00088: val_accuracy did not improve from 0.85027
# Epoch 89/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2952 - accuracy: 0.8652 - val_loss: 0.5239 - val_accuracy: 0.8128
#
# Epoch 00089: val_accuracy did not improve from 0.85027
# Epoch 90/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2985 - accuracy: 0.8784 - val_loss: 0.5099 - val_accuracy: 0.8209
#
# Epoch 00090: val_accuracy did not improve from 0.85027
# Epoch 91/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2639 - accuracy: 0.8682 - val_loss: 0.5086 - val_accuracy: 0.8048
#
# Epoch 00091: val_accuracy did not improve from 0.85027
# Epoch 92/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.2769 - accuracy: 0.8841 - val_loss: 0.5097 - val_accuracy: 0.8128
#
# Epoch 00092: val_accuracy did not improve from 0.85027
# Epoch 93/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2913 - accuracy: 0.8631 - val_loss: 0.5156 - val_accuracy: 0.7727
#
# Epoch 00093: val_accuracy did not improve from 0.85027
# Epoch 94/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3214 - accuracy: 0.8633 - val_loss: 0.4456 - val_accuracy: 0.8182
#
# Epoch 00094: val_accuracy did not improve from 0.85027
# Epoch 95/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2727 - accuracy: 0.8830 - val_loss: 0.4955 - val_accuracy: 0.8048
#
# Epoch 00095: val_accuracy did not improve from 0.85027
# Epoch 96/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2782 - accuracy: 0.8652 - val_loss: 0.5123 - val_accuracy: 0.8128
#
# Epoch 00096: val_accuracy did not improve from 0.85027
# Epoch 97/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2744 - accuracy: 0.8801 - val_loss: 0.4917 - val_accuracy: 0.8182
#
# Epoch 00097: val_accuracy did not improve from 0.85027
# Epoch 98/100
# 77/77 [==============================] - 2s 22ms/step - loss: 0.2633 - accuracy: 0.8693 - val_loss: 0.4773 - val_accuracy: 0.8209
#
# Epoch 00098: val_accuracy did not improve from 0.85027
# Epoch 99/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.2980 - accuracy: 0.8883 - val_loss: 0.5215 - val_accuracy: 0.7861
#
# Epoch 00099: val_accuracy did not improve from 0.85027
# Epoch 100/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2985 - accuracy: 0.8538 - val_loss: 0.4671 - val_accuracy: 0.8369
#
# Epoch 00100: val_accuracy did not improve from 0.85027

# %%
# how to get the keys in your model
# for key in hist.history:
#   print(key)

# %%
# test model
#test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)

# %%
#len(test_predict)

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 38ms/step - loss: 0.5119 - accuracy: 0.7758

# %% [markdown]
# #### Fine Tuning

# %%
# 0 to 72 = Till Conv11
# 73 to 79 - Conv12
# 80 to 85 = Conv13
# 86 to 91 = Post Conv13 before Custom (GAP...)
# 92 to 94 = Custom (Dense/Dropout/Dense(2)) = Trainable 
for layer in model_mn.layers[:80]:
    layer.trainable=False
for layer in model_mn.layers[80:]:
    layer.trainable=True

# train and validate model
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_parameters_file)])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 2s 21ms/step - loss: 0.4257 - accuracy: 0.8182 - val_loss: 0.3936 - val_accuracy: 0.8316
#
# Epoch 00001: val_accuracy improved from -inf to 0.83155, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 2/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.4112 - accuracy: 0.8156 - val_loss: 0.4202 - val_accuracy: 0.8048
#
# Epoch 00002: val_accuracy did not improve from 0.83155
# Epoch 3/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3901 - accuracy: 0.8286 - val_loss: 0.4971 - val_accuracy: 0.7647
#
# Epoch 00003: val_accuracy did not improve from 0.83155
# Epoch 4/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.4070 - accuracy: 0.8247 - val_loss: 0.4248 - val_accuracy: 0.8128
#
# Epoch 00004: val_accuracy did not improve from 0.83155
# Epoch 5/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3960 - accuracy: 0.8286 - val_loss: 0.4508 - val_accuracy: 0.7914
#
# Epoch 00005: val_accuracy did not improve from 0.83155
# Epoch 6/100
# 77/77 [==============================] - 1s 20ms/step - loss: 0.3886 - accuracy: 0.8364 - val_loss: 0.4486 - val_accuracy: 0.7941
#
# Epoch 00006: val_accuracy did not improve from 0.83155
# Epoch 7/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.4096 - accuracy: 0.8260 - val_loss: 0.4590 - val_accuracy: 0.7807
#
# Epoch 00007: val_accuracy did not improve from 0.83155
# Epoch 8/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3891 - accuracy: 0.8338 - val_loss: 0.3964 - val_accuracy: 0.8235
#
# Epoch 00008: val_accuracy did not improve from 0.83155
# Epoch 9/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3723 - accuracy: 0.8403 - val_loss: 0.3954 - val_accuracy: 0.8316
#
# Epoch 00009: val_accuracy did not improve from 0.83155
# Epoch 10/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3939 - accuracy: 0.8351 - val_loss: 0.5012 - val_accuracy: 0.7701
#
# Epoch 00010: val_accuracy did not improve from 0.83155
# Epoch 11/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3961 - accuracy: 0.8273 - val_loss: 0.4454 - val_accuracy: 0.8102
#
# Epoch 00011: val_accuracy did not improve from 0.83155
# Epoch 12/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3814 - accuracy: 0.8299 - val_loss: 0.4026 - val_accuracy: 0.8289
#
# Epoch 00012: val_accuracy did not improve from 0.83155
# Epoch 13/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3727 - accuracy: 0.8377 - val_loss: 0.3911 - val_accuracy: 0.8342
#
# Epoch 00013: val_accuracy improved from 0.83155 to 0.83422, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 14/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3733 - accuracy: 0.8390 - val_loss: 0.4718 - val_accuracy: 0.7647
#
# Epoch 00014: val_accuracy did not improve from 0.83422
# Epoch 15/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3705 - accuracy: 0.8338 - val_loss: 0.3958 - val_accuracy: 0.8342
#
# Epoch 00015: val_accuracy did not improve from 0.83422
# Epoch 16/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3741 - accuracy: 0.8519 - val_loss: 0.4329 - val_accuracy: 0.8182
#
# Epoch 00016: val_accuracy did not improve from 0.83422
# Epoch 17/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3537 - accuracy: 0.8545 - val_loss: 0.4197 - val_accuracy: 0.8235
#
# Epoch 00017: val_accuracy did not improve from 0.83422
# Epoch 18/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3671 - accuracy: 0.8481 - val_loss: 0.4084 - val_accuracy: 0.8316
#
# Epoch 00018: val_accuracy did not improve from 0.83422
# Epoch 19/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3569 - accuracy: 0.8494 - val_loss: 0.4408 - val_accuracy: 0.8048
#
# Epoch 00019: val_accuracy did not improve from 0.83422
# Epoch 20/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3634 - accuracy: 0.8429 - val_loss: 0.4561 - val_accuracy: 0.7995
#
# Epoch 00020: val_accuracy did not improve from 0.83422
# Epoch 21/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3594 - accuracy: 0.8481 - val_loss: 0.4568 - val_accuracy: 0.8182
#
# Epoch 00021: val_accuracy did not improve from 0.83422
# Epoch 22/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3657 - accuracy: 0.8429 - val_loss: 0.4785 - val_accuracy: 0.7834
#
# Epoch 00022: val_accuracy did not improve from 0.83422
# Epoch 23/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3514 - accuracy: 0.8597 - val_loss: 0.4451 - val_accuracy: 0.8235
#
# Epoch 00023: val_accuracy did not improve from 0.83422
# Epoch 24/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3477 - accuracy: 0.8429 - val_loss: 0.4208 - val_accuracy: 0.8128
#
# Epoch 00024: val_accuracy did not improve from 0.83422
# Epoch 25/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3532 - accuracy: 0.8364 - val_loss: 0.4393 - val_accuracy: 0.8182
#
# Epoch 00025: val_accuracy did not improve from 0.83422
# Epoch 26/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3402 - accuracy: 0.8325 - val_loss: 0.4208 - val_accuracy: 0.8209
#
# Epoch 00026: val_accuracy did not improve from 0.83422
# Epoch 27/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3572 - accuracy: 0.8403 - val_loss: 0.4880 - val_accuracy: 0.7995
#
# Epoch 00027: val_accuracy did not improve from 0.83422
# Epoch 28/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3594 - accuracy: 0.8429 - val_loss: 0.4837 - val_accuracy: 0.7834
#
# Epoch 00028: val_accuracy did not improve from 0.83422
# Epoch 29/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3263 - accuracy: 0.8636 - val_loss: 0.4653 - val_accuracy: 0.8209
#
# Epoch 00029: val_accuracy did not improve from 0.83422
# Epoch 30/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3433 - accuracy: 0.8610 - val_loss: 0.4529 - val_accuracy: 0.7995
#
# Epoch 00030: val_accuracy did not improve from 0.83422
# Epoch 31/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3384 - accuracy: 0.8416 - val_loss: 0.4811 - val_accuracy: 0.7941
#
# Epoch 00031: val_accuracy did not improve from 0.83422
# Epoch 32/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3670 - accuracy: 0.8494 - val_loss: 0.4665 - val_accuracy: 0.7941
#
# Epoch 00032: val_accuracy did not improve from 0.83422
# Epoch 33/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3376 - accuracy: 0.8623 - val_loss: 0.5138 - val_accuracy: 0.7754
#
# Epoch 00033: val_accuracy did not improve from 0.83422
# Epoch 34/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3737 - accuracy: 0.8377 - val_loss: 0.3865 - val_accuracy: 0.8289
#
# Epoch 00034: val_accuracy did not improve from 0.83422
# Epoch 35/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3500 - accuracy: 0.8364 - val_loss: 0.4493 - val_accuracy: 0.7995
#
# Epoch 00035: val_accuracy did not improve from 0.83422
# Epoch 36/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3420 - accuracy: 0.8377 - val_loss: 0.4242 - val_accuracy: 0.8289
#
# Epoch 00036: val_accuracy did not improve from 0.83422
# Epoch 37/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3225 - accuracy: 0.8571 - val_loss: 0.4358 - val_accuracy: 0.8235
#
# Epoch 00037: val_accuracy did not improve from 0.83422
# Epoch 38/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3423 - accuracy: 0.8519 - val_loss: 0.4366 - val_accuracy: 0.8316
#
# Epoch 00038: val_accuracy did not improve from 0.83422
# Epoch 39/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3434 - accuracy: 0.8481 - val_loss: 0.4503 - val_accuracy: 0.8128
#
# Epoch 00039: val_accuracy did not improve from 0.83422
# Epoch 40/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3223 - accuracy: 0.8649 - val_loss: 0.4283 - val_accuracy: 0.8209
#
# Epoch 00040: val_accuracy did not improve from 0.83422
# Epoch 41/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3296 - accuracy: 0.8649 - val_loss: 0.4746 - val_accuracy: 0.8075
#
# Epoch 00041: val_accuracy did not improve from 0.83422
# Epoch 42/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3159 - accuracy: 0.8675 - val_loss: 0.4450 - val_accuracy: 0.8182
#
# Epoch 00042: val_accuracy did not improve from 0.83422
# Epoch 43/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3280 - accuracy: 0.8532 - val_loss: 0.4638 - val_accuracy: 0.8128
#
# Epoch 00043: val_accuracy did not improve from 0.83422
# Epoch 44/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3276 - accuracy: 0.8714 - val_loss: 0.4805 - val_accuracy: 0.8102
#
# Epoch 00044: val_accuracy did not improve from 0.83422
# Epoch 45/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3207 - accuracy: 0.8688 - val_loss: 0.4837 - val_accuracy: 0.8128
#
# Epoch 00045: val_accuracy did not improve from 0.83422
# Epoch 46/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3201 - accuracy: 0.8714 - val_loss: 0.4461 - val_accuracy: 0.8209
#
# Epoch 00046: val_accuracy did not improve from 0.83422
# Epoch 47/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3172 - accuracy: 0.8649 - val_loss: 0.4412 - val_accuracy: 0.8155
#
# Epoch 00047: val_accuracy did not improve from 0.83422
# Epoch 48/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3056 - accuracy: 0.8623 - val_loss: 0.4689 - val_accuracy: 0.8182
#
# Epoch 00048: val_accuracy did not improve from 0.83422
# Epoch 49/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3035 - accuracy: 0.8675 - val_loss: 0.4961 - val_accuracy: 0.8021
#
# Epoch 00049: val_accuracy did not improve from 0.83422
# Epoch 50/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3127 - accuracy: 0.8571 - val_loss: 0.4602 - val_accuracy: 0.8155
#
# Epoch 00050: val_accuracy did not improve from 0.83422
# Epoch 51/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3263 - accuracy: 0.8558 - val_loss: 0.4678 - val_accuracy: 0.8182
#
# Epoch 00051: val_accuracy did not improve from 0.83422
# Epoch 52/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2970 - accuracy: 0.8701 - val_loss: 0.4694 - val_accuracy: 0.8289
#
# Epoch 00052: val_accuracy did not improve from 0.83422
# Epoch 53/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3223 - accuracy: 0.8597 - val_loss: 0.4806 - val_accuracy: 0.8048
#
# Epoch 00053: val_accuracy did not improve from 0.83422
# Epoch 54/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3271 - accuracy: 0.8584 - val_loss: 0.4265 - val_accuracy: 0.8342
#
# Epoch 00054: val_accuracy did not improve from 0.83422
# Epoch 55/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2967 - accuracy: 0.8714 - val_loss: 0.4644 - val_accuracy: 0.8262
#
# Epoch 00055: val_accuracy did not improve from 0.83422
# Epoch 56/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3014 - accuracy: 0.8766 - val_loss: 0.5181 - val_accuracy: 0.8021
#
# Epoch 00056: val_accuracy did not improve from 0.83422
# Epoch 57/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2979 - accuracy: 0.8636 - val_loss: 0.4856 - val_accuracy: 0.8155
#
# Epoch 00057: val_accuracy did not improve from 0.83422
# Epoch 58/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2948 - accuracy: 0.8753 - val_loss: 0.4995 - val_accuracy: 0.8102
#
# Epoch 00058: val_accuracy did not improve from 0.83422
# Epoch 59/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2985 - accuracy: 0.8727 - val_loss: 0.5085 - val_accuracy: 0.8075
#
# Epoch 00059: val_accuracy did not improve from 0.83422
# Epoch 60/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2831 - accuracy: 0.8727 - val_loss: 0.4966 - val_accuracy: 0.8155
#
# Epoch 00060: val_accuracy did not improve from 0.83422
# Epoch 61/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2670 - accuracy: 0.8896 - val_loss: 0.5063 - val_accuracy: 0.8075
#
# Epoch 00061: val_accuracy did not improve from 0.83422
# Epoch 62/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2984 - accuracy: 0.8675 - val_loss: 0.5763 - val_accuracy: 0.7914
#
# Epoch 00062: val_accuracy did not improve from 0.83422
# Epoch 63/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3032 - accuracy: 0.8753 - val_loss: 0.5296 - val_accuracy: 0.8048
#
# Epoch 00063: val_accuracy did not improve from 0.83422
# Epoch 64/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3011 - accuracy: 0.8753 - val_loss: 0.4927 - val_accuracy: 0.8182
#
# Epoch 00064: val_accuracy did not improve from 0.83422
# Epoch 65/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3082 - accuracy: 0.8688 - val_loss: 0.4369 - val_accuracy: 0.8396
#
# Epoch 00065: val_accuracy improved from 0.83422 to 0.83957, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 66/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2990 - accuracy: 0.8649 - val_loss: 0.5080 - val_accuracy: 0.7968
#
# Epoch 00066: val_accuracy did not improve from 0.83957
# Epoch 67/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2986 - accuracy: 0.8649 - val_loss: 0.5160 - val_accuracy: 0.7995
#
# Epoch 00067: val_accuracy did not improve from 0.83957
# Epoch 68/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2928 - accuracy: 0.8740 - val_loss: 0.5153 - val_accuracy: 0.8155
#
# Epoch 00068: val_accuracy did not improve from 0.83957
# Epoch 69/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2745 - accuracy: 0.8753 - val_loss: 0.5305 - val_accuracy: 0.7968
#
# Epoch 00069: val_accuracy did not improve from 0.83957
# Epoch 70/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2738 - accuracy: 0.8870 - val_loss: 0.5324 - val_accuracy: 0.8102
#
# Epoch 00070: val_accuracy did not improve from 0.83957
# Epoch 71/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2820 - accuracy: 0.8805 - val_loss: 0.5034 - val_accuracy: 0.8102
#
# Epoch 00071: val_accuracy did not improve from 0.83957
# Epoch 72/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2790 - accuracy: 0.8922 - val_loss: 0.4960 - val_accuracy: 0.8209
#
# Epoch 00072: val_accuracy did not improve from 0.83957
# Epoch 73/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2737 - accuracy: 0.8779 - val_loss: 0.4837 - val_accuracy: 0.8369
#
# Epoch 00073: val_accuracy did not improve from 0.83957
# Epoch 74/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2886 - accuracy: 0.8896 - val_loss: 0.5008 - val_accuracy: 0.8182
#
# Epoch 00074: val_accuracy did not improve from 0.83957
# Epoch 75/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2645 - accuracy: 0.8896 - val_loss: 0.5740 - val_accuracy: 0.7968
#
# Epoch 00075: val_accuracy did not improve from 0.83957
# Epoch 76/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2776 - accuracy: 0.8818 - val_loss: 0.4956 - val_accuracy: 0.8235
#
# Epoch 00076: val_accuracy did not improve from 0.83957
# Epoch 77/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.3057 - accuracy: 0.8636 - val_loss: 0.4615 - val_accuracy: 0.8262
#
# Epoch 00077: val_accuracy did not improve from 0.83957
# Epoch 78/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2665 - accuracy: 0.8818 - val_loss: 0.5501 - val_accuracy: 0.7861
#
# Epoch 00078: val_accuracy did not improve from 0.83957
# Epoch 79/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2697 - accuracy: 0.8948 - val_loss: 0.5424 - val_accuracy: 0.7941
#
# Epoch 00079: val_accuracy did not improve from 0.83957
# Epoch 80/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2683 - accuracy: 0.8844 - val_loss: 0.5965 - val_accuracy: 0.7540
#
# Epoch 00080: val_accuracy did not improve from 0.83957
# Epoch 81/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2798 - accuracy: 0.8779 - val_loss: 0.5174 - val_accuracy: 0.8182
#
# Epoch 00081: val_accuracy did not improve from 0.83957
# Epoch 82/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2775 - accuracy: 0.8831 - val_loss: 0.5932 - val_accuracy: 0.7807
#
# Epoch 00082: val_accuracy did not improve from 0.83957
# Epoch 83/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2681 - accuracy: 0.8779 - val_loss: 0.4998 - val_accuracy: 0.8262
#
# Epoch 00083: val_accuracy did not improve from 0.83957
# Epoch 84/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2631 - accuracy: 0.8883 - val_loss: 0.5385 - val_accuracy: 0.7968
#
# Epoch 00084: val_accuracy did not improve from 0.83957
# Epoch 85/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2605 - accuracy: 0.8909 - val_loss: 0.5225 - val_accuracy: 0.8289
#
# Epoch 00085: val_accuracy did not improve from 0.83957
# Epoch 86/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2483 - accuracy: 0.8974 - val_loss: 0.6013 - val_accuracy: 0.8075
#
# Epoch 00086: val_accuracy did not improve from 0.83957
# Epoch 87/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2659 - accuracy: 0.8961 - val_loss: 0.5946 - val_accuracy: 0.7995
#
# Epoch 00087: val_accuracy did not improve from 0.83957
# Epoch 88/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2539 - accuracy: 0.8935 - val_loss: 0.5802 - val_accuracy: 0.7834
#
# Epoch 00088: val_accuracy did not improve from 0.83957
# Epoch 89/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2561 - accuracy: 0.8909 - val_loss: 0.5098 - val_accuracy: 0.8155
#
# Epoch 00089: val_accuracy did not improve from 0.83957
# Epoch 90/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2518 - accuracy: 0.8844 - val_loss: 0.5150 - val_accuracy: 0.8235
#
# Epoch 00090: val_accuracy did not improve from 0.83957
# Epoch 91/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2353 - accuracy: 0.8883 - val_loss: 0.5795 - val_accuracy: 0.7995
#
# Epoch 00091: val_accuracy did not improve from 0.83957
# Epoch 92/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2764 - accuracy: 0.8896 - val_loss: 0.5429 - val_accuracy: 0.8155
#
# Epoch 00092: val_accuracy did not improve from 0.83957
# Epoch 93/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2671 - accuracy: 0.8883 - val_loss: 0.5201 - val_accuracy: 0.8128
#
# Epoch 00093: val_accuracy did not improve from 0.83957
# Epoch 94/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2395 - accuracy: 0.9039 - val_loss: 0.5350 - val_accuracy: 0.8128
#
# Epoch 00094: val_accuracy did not improve from 0.83957
# Epoch 95/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2579 - accuracy: 0.9052 - val_loss: 0.5386 - val_accuracy: 0.8182
#
# Epoch 00095: val_accuracy did not improve from 0.83957
# Epoch 96/100
# 77/77 [==============================] - 2s 23ms/step - loss: 0.2446 - accuracy: 0.8987 - val_loss: 0.5411 - val_accuracy: 0.8021
#
# Epoch 00096: val_accuracy did not improve from 0.83957
# Epoch 97/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2473 - accuracy: 0.8870 - val_loss: 0.5905 - val_accuracy: 0.8048
#
# Epoch 00097: val_accuracy did not improve from 0.83957
# Epoch 98/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2677 - accuracy: 0.8974 - val_loss: 0.5338 - val_accuracy: 0.8048
#
# Epoch 00098: val_accuracy did not improve from 0.83957
# Epoch 99/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2337 - accuracy: 0.9026 - val_loss: 0.5492 - val_accuracy: 0.8102
#
# Epoch 00099: val_accuracy did not improve from 0.83957
# Epoch 100/100
# 77/77 [==============================] - 2s 20ms/step - loss: 0.2478 - accuracy: 0.8896 - val_loss: 0.5910 - val_accuracy: 0.7941
#
# Epoch 00100: val_accuracy did not improve from 0.83957

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 38ms/step - loss: 0.6334 - accuracy: 0.7766

# %%
model_mn.summary()

# %% [markdown]
# ### SqueezeNet

# %% [markdown]
# will continue on SqueezeNet as future work.
