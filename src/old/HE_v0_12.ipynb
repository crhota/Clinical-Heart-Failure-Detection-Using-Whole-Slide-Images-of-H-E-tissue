# %% [markdown]
# # Clinical Heart Failure Detection Using Whole-Slide Images of H&E tissue

# %% [markdown]
# ## Version

# %% [markdown]
# ### Version 0.12

# %% [markdown]
# - **0.12**: rerun to baseline

# %% [markdown]
# ### Version 0.11

# %% [markdown]
# - **0.11**
#   - As is Rerun
#     - Epoch = 100, Batchsize = 10, Learning Rate = 0.01, Neurons = 512, Dropout = 0.4. Train & Test Acc is w.r.t. Best Val Accuracy.
#     - ResNet50 (Transfer Learning) - 5 Convolution Layers
#       - Total/Trainable Params: 24.64M/1.05M
#       - Train/Val/Test Acc: 93.7 / 89.0 / 80.7
#     - MobileNet - 13 Convolution Layers
#       - Transfer Learning
#         - Total/Trainable Params: 4.77M/0.51M
#         - Train/Val/Test Acc: 79.5 / 84.2 / 78.0
#       - Finetuning
#         - Total/Trainable Params: 4.77M/2.60M
#         - Train/Val/Test Acc: 88.2 / 84.2 / 78.8

# %% [markdown]
# ### Version 0.10

# %% [markdown]
# - **0.10**
#   - Cleaned up indenting
#   - Added hyperparameter macros that can be used for all models
#     - ResNet50 was with 1024 neurons, 40% dropout
#     - MobileNet was with 512 neurons, 60% dropout.
#     - Made EPOCHS = 100, BATCH_SIZE = 10, LEARNING_RATE = 0.01, DENSE_LAYER_NEURONS = 512, DENSE_LAYER_DROPOUT = 0.4
#   - Implemented 'checkpoint' as a function to be used a callback by any model. Enabled callback for ResNet50
#   - Accuracy
#     - ResNet50 (XFR Learning): Best_Train/Best_Val/Test = 89.4 / 88.8 / 80.7
#     - MobileNet (XFR Learning): Best_Train/Best_Val/Test = 83.6 / 85.0 / 77.6
#     - MobileNet (Fine Tuning): Best_Train/Best_Val/Test = 86.9 / 84.0 / 77.7

# %% [markdown]
# ### Version 0.09

# %% [markdown]
# - **0.09** **MobileNet**
#   - **Epoch=100**: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 87.4/80.8/78.0
#   - Epoch=100: **Best Model**: Train/Val/Test Acc = 82.1/84.0/77.8
#   - **Epoch=200**: Best Model: Train/Val/Test Acc = 79.0/84.0/78.9
#   - **Epoch=100**: Best Model: **Regularizer: Kernel/Bias L2(0.01) for Dense(1024)**: Train/Val/Test Acc = 70.6/80.0/72.5
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias L2(0.01) for Dense(1024), **Dense(2)**: Train/Val/Test Acc = 69.0/78.3/72.6
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias **L1**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/**Activity L2**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = 68.1/79.1/72.4
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(0.2)** for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(1e-4/1e-4/1e-5)** for Dense(1024), Dense(2): Train/Val/Test Acc = 77.6/84.0/77.5 ... regularizer is not helping much ... revert to No Regularizer
#   - **Best Model**: **Epoch=100**: Train/Val/Test Acc = 81.5/84.5/77.8
#   - Best Model: **Epoch=1**: **Nottrainable/trainabele layers = 0-79/80-94**:  Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: **Epoch=100**: NonTrainable(MobileNet)+ Trainable(Dense(1024), Dropout, Dense(2)): Train/Val/Test Acc = 82.3/85/79
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.8/78.7
#   - Best Model: Epoch=100: **MobileNet NT till Conv13 (0-85), T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: MobileNet NT **till Conv12 (0-79)**, T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 88.5/85.0/77.7
#   - Best Model: Epoch=100: **NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet till <86) Trainable (86 and later = GAP...)+ Trainable(Dense(**512**), Dropout, Dense(2))**: Train/Val/Test Acc = 78.7/84.8/76.8 -> ../84.8/76.8
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.2/78.2 -> ../84.2/78.2
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 80.1/84.2/78.4 -> ../84.2/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> **Trainable(MobileNet till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 81.8/84.2/78.3 -> 86.2/84.5/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Params (Total/Trainable/Non-trainable)= 4,767,402 / 2,600,426 / 2,166,976: Train/Val/Test Acc = 79.8/84.8/78.4 -> ../84.8/78.4

# %% [markdown]
# ### Version 0.08

# %% [markdown]
# - **0.08** **MobileNet**
#   - Changed model to Pre-trained MobileNet
#   - Epoch=1: **img resize**: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 68.2/76.5/73.8
#   - Epoch=10: img resize: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 80.5/82.4/78.9
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = N:Train/Val/Test Acc = 83.7/79.2/76.5 ... revert to Epoch=10
#   - **Epoch=10**: img resize: **lr=0.0001**: BN = N: Dropout = N:Train/Val/Test Acc = 71.9/78.6/73.6 ... revert to lr=0.01
#   - Epoch=10: img resize: **lr=0.01**: **BN = Y**: Dropout = N: Train/Val/Test Acc = 83.0/77.8/71.0 revert to BN = N
#   - Epoch=10: img resize: lr=0.01: **BN = N**: **Dropout = 0.2**: Train/Val/Test Acc = 77.1/80.8/76.9
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Train/Val/Test Acc = 78.8/82.6/78.0
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = 0.4: Train/Val/Test Acc = 81.6/76.6/75.4 ... revert to Epoch = 10
#   - **Epoch=10**: img resize: lr=0.01: BN = N: **Dropout = 0.5**: Train/Val/Test Acc = 78.3/84.2/77.8 ... revert to Dropout = 0.4
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 78.3/79.1/76.5

# %% [markdown]
# ### Version 0.07

# %% [markdown]
# - **0.07** **ResNet50**
#   - As is rerun: Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: batch size = 10: Train/Val/Test Acc = 86.7/86.6/81.4
#   - Change **batch size** from 10 to 20: Train/Val/Test Acc = 91.2/83.7/78.9 ... reduces accuracy, so reverted to batch size of 10
#   - Implemented **Data Augmentation** with batch size of 10: Train/Val/Test Acc = 78.1/79.7/69.0 ...reduces accuracy, should we increase batch size?
#   - Implemented **Data Augmentation** with batch size of 100: Train/Val/Test Acc = 89.3/72.2/67.9 ...reduces accuracy, should we decrease batch size?
#   - Implemented **Data Augmentation** with batch size of 5: Train/Val/Test Acc = 58.3/48.4/48.1  ... reduces accuracy, reverted to batch size of 10, and no Data Augmentation
#   - Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: **batch size = 10**: **No DataAug**: Params (Total/Trainable/Non-trainable)= 25,687,938 / 2,100,226 / 23,587,712: Train/Val/Test Acc = 91.8/90.6/81.1

# %% [markdown]
# ### Version 0.06

# %% [markdown]
# - **0.06** **ResNet50**
#   - Before any modification: full rerun took ~15mins (most of it for loading train/val/test images/labels... and very less for model training/test)
#   - Before any modification: Train/Val/Test Acc = 53/51.1/51.3
#   - Changed model = Pre-trained ResNet50 + Modified FCN Layer
#     - SGD (LR=0.0001, M=0.9), Categorical Crossentropy
#     - 1st run: Train/Val/Test Acc = 57.5/72.7/67.1
#     - Converted ones/zeroes count to function
#     - Converted images/label prep to function
#     - Epoch=1: Train/Val/Test Acc = 61/67.9/67
#     - Epoch=5: Train/Val/Test Acc = 85.6/80.8/75.9
#     - Epoch=10: Train/Val/Test Acc = 93.0/85.6/77.7
#     - Epoch=20: Train/Val/Test Acc = 94.1/89.0/80.4
#     - Epoch=20: Changed loss function to 'binary crossentropy', reduced the accuracy: Train/Val/Test Acc = 90.2/84.0/77.7 Hence, reverted to categorical crossentropy as the loss function
#     - Epoch=20: Changed optimizer to Adam(lr=0.01), increased accuracy: Train/Val/Test Acc = 99.3/86.9/83.2
#     - In above training accuracy is high, validation and test accuracy is low ... it is overfitting ... let us implement Dropout
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): Train/Val/Test Acc = 93.0/88.8/82.1
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 90.8/89.8/83.4
#     - Epoch=20: Adam(lr=0.01): Dropout(0.5): Train/Val/Test Acc = 92.2/90.6/82.3 .. reverted to Dropout(0.4)
#     - Let us try Batch Normalization. ResNet50 -> Dense (1024) -> Batch Norm -> relu -> Dropout -> Dense(2,softmax)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): BN: Train/Val/Test Acc = 90.6/81.6/79.0 ... reduced accuracy
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): BN: Train/Val/Test Acc = 95.2/86.9/81.9 ... reduced accuracy will revert to no BN, Dropout(0.4)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 88.2/89.3/81.7

# %% [markdown]
# ### Version 0.01 - 0.05

# %% [markdown]
# - **0.05**: Migrate to Google Colab/Drive, changed loss function to 'binary_crossentropy', epochs to 1 : Train/Val/Test Acc = 55.7/55.9/55.2
# - **0.04**: Class Label Info in List was not accurate - fixed it. Now, Train/Validate/Test Accuracy is more realistic = ~55%
# - **0.03**: Tweak CNN model done for MNIST to work for this dataset to have a working end to end CNN model. Train/Validate/Test Accuracy = ~100%
# - **0.02**: Prepare Train/Validate/Test Labels and Images
# - **0.01**: Prepare Train/Validate/Test Images

# %% [markdown]
# ## Improvement Opportunity

# %% [markdown]
# - **TRIED**: As this is a 2 class classification - loss function can be changed to binary_crossentropy instead of categorical_crossentropy
# - **DONE**: Change model to ResNet50
# - **DONE**: Convert code sections in data preparation for train/validation/test to functions
# - **TRIED**: Reduce parameters, epochs.
# - **TRIED**: Try changing batch size
# - **TRIED**: Use Data Augmentation
# - **DONE**: Try to train last few layers of ResNet50 with the data
# - **TRIED**: Accuracy is fluctuating... optimize hyper parameters to have a smooth increase
# - **TRIED** Try Regularization
# - Our image size is 250x250. ResNet50 expects 224x224. Do we need to do anything or ResNet50 will understand ?
# - **DONE**: Change Model to MobileNet
# - **DONE**: Is image resize done correctly for MobileNet ?
# - Check version of MobileNet
# - Implement K Cross Validation
# - Check FLOPS

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# ### Download Train, Validate and Test Images

# %% [markdown]
# - Source Link to the Dataset / Annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Follow the instructions at following link, install IBM Aspera Desktop Client to download the dataset.
# - Copy downloaded folders to '**data/images**' folder in your working directory where you have this Jupyter Notebook:
#   - 'held-out_validation'
#   - 'training'

# %% [markdown]
# ### Download Label Information for Train, Validate and Test Images

# %% [markdown]
# - Following link will point to below Github link which has the annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Source Link for the Annotation File: https://github.com/IDR/idr0042-nirschl-wsideeplearning/tree/master/experimentA
# - Download and copy file '**idr0042-experimentA-annotation.csv**' to '**data/labels/**' folder in your working directory where you have this Jupyter Notebook

# %% [markdown]
# ## References

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# - Access Google Drive files from Google Colab
#   - https://www.youtube.com/watch?reload=9&v=lHRC5gFvQnA
# - Reading an image
#   - mathplotlib: https://stackoverflow.com/questions/9298665/cannot-import-scipy-misc-imread
#   - pathlib: https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f#:~:text=To%20use%20it%2C%20you%20just,for%20the%20current%20operating%20system.
#   - OpenCV: https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/
# - Load multiple images into a numpy array
#   - glob / os.listdir: https://stackoverflow.com/questions/39195113/how-to-load-multiple-images-in-a-numpy-array
#   - glob / cv2: https://medium.com/@muskulpesent/create-numpy-array-of-images-fecb4e514c4b
# - Load a CSV file
#   - Datacamp: https://www.datacamp.com/community/tutorials/pandas-read-csv?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377095&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=9061994&gclid=EAIaIQobChMIz5TKz-v17QIV1AorCh0bfw96EAAYASAAEgKiGPD_BwE
# - Split a String
#   - Python Central: https://www.pythoncentral.io/cutting-and-slicing-strings-in-python/
# - Image Resize
#   - https://stackoverflow.com/questions/44650888/resize-an-image-without-distortion-opencv
#   - https://stackoverflow.com/questions/55571664/mobilenets-for-a-custom-image-size
# - Merge Train/Val/Test data
#   - Merge Dataframes
#     - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#   - Merge and Split Dataframes
#     - https://datascience.stackexchange.com/questions/81617/how-to-combine-and-separate-test-and-train-data-for-data-cleaning
#   -

# %% [markdown]
# ### Model Definition

# %% [markdown]
# - ResNet50
#   - https://cv-tricks.com/keras/understand-implement-resnets/
#   - Finetuning ResNet50
#     - https://www.pyimagesearch.com/2020/04/27/fine-tuning-resnet-with-keras-tensorflow-and-deep-learning/
# - MobileNet
#   - https://deeplizard.com/learn/video/Zrt76AIbeh4
#   - https://towardsdatascience.com/exploring-mobilenets-from-paper-to-keras-f01308ada818
#   - Fine Tuning MobileNet - Last few layers trainable
#     - https://towardsdatascience.com/transfer-learning-using-mobilenet-and-keras-c75daf7ff299
# - SqueezeNet
#   - https://codelabs.developers.google.com/codelabs/keras-flowers-squeezenet#6

# %% [markdown]
# ### Model Validation

# %% [markdown]
# - Keras Optimizer / Adam
#   - https://keras.io/api/optimizers/
# - Regularizer
#   - https://keras.io/api/layers/regularizers/
# - Save Weights for Best Model
#   - https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
#   - Monitoring Validaiton Accuracy - Skipping Error Solution
#     - https://github.com/tensorflow/tensorflow/issues/33163
#   - Predict using saved model
#     - https://stackoverflow.com/questions/44259651/how-to-use-predefined-trained-hdf5-file-with-wights-to-predict-a-class-of-new
# - K-cross validation: https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538
#   - use non-categorical labels for k-cross validation splits: https://stackoverflow.com/questions/48508036/sklearn-stratifiedkfold-valueerror-supported-target-types-are-binary-mul

# %% [markdown]
# ## Understand Dataset

# %% [markdown]
# ### Understand Images Folder Structure and Number of Images Available

# %% [markdown]
# Training/Validation
# - \..\training\fold_1: has images for training = 770#
# - \..\training\test_fold_1: has images for validation = 374#
# - Total = 770 + 374 = 1144 images
#
# Test
# - \..\held-out_validation: has images for testing = 1155#

# %% [markdown]
# ### Understand Annotation File and Label Information Available

# %% [markdown]
# Relevant columns of interest:
# - Column A: Dataset Name: Classifies each row/instance as 'training' or 'test'
# - Column B: Image Name: Specifies filename of the image for the row/instance
# - Column Z: Experimental Condition [Diagnosis]: has 3 classes:
#   - 'chronic heart failure'
#   - 'heart tissue pathology' - We will treat this as 'not chronic heart failure'
#   - 'not chronic heart failure'
# - Column AA: Channels: mentions RGB => images are color images and will have 3 channels Red/Green/Blue (for CNN).
#
# Breakup of training/test instances:
# - training
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 627
# - test
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 638
#
# Total 'training' = 517 + 627 = 1144  (Note: 'validate' is a portion of this 'training' set.)
#
# Total 'test' = 517 + 638 = 1155

# %% [markdown]
# ## Access Dataset

# %% [markdown]
# ### Load Libraries

# %% [markdown]
# We need to read 'train, validate and test images' to arrays so that we can then use them to feed to our CNN model. We need to import the annotation file into a dataframe so that we can then access the labels information.

# %%
# install OpenCV package - this is required only once
# pip install opencv-python

# %%
# aids in reading image files
import cv2
import glob

# %%
# aids in working with arrays
import numpy as np

# %%
# aids in working with dataframes
import pandas as pd

# %% [markdown]
# ### Mount Google Drive

# %% [markdown]
# We need to mount the google drive so that we can then access the files from google drive.

# %%
# run this. click on the link it will ask for. get the authentication code. Copy/Paste in the cell. Hit Enter.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ### Get labels info into a dataframe

# %%
# Google Drive / Colab
filepath_annotation_file = r'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/labels/idr0042-experimentA-annotation.csv'
labels = pd.read_csv(filepath_annotation_file)

# Local Drive / Jupyter
# labels = pd.read_csv('data/labels/idr0042-experimentA-annotation.csv')

# %% [markdown]
# ### Explore and Understand

# %%
# uncomment & check the contents of labels is as expected
labels
# Out:
#      Dataset Name  ... Channels
# 0        training  ...      RGB
# 1        training  ...      RGB
# 2        training  ...      RGB
# 3        training  ...      RGB
# 4        training  ...      RGB
# ...           ...  ...      ...
# 2294         test  ...      RGB
# 2295         test  ...      RGB
# 2296         test  ...      RGB
# 2297         test  ...      RGB
# 2298         test  ...      RGB
#
# [2299 rows x 27 columns]

# %%
print(labels['Dataset Name'])
# Out:
# 0       training
# 1       training
# 2       training
# 3       training
# 4       training
#           ...
# 2294        test
# 2295        test
# 2296        test
# 2297        test
# 2298        test
# Name: Dataset Name, Length: 2299, dtype: object

# %%
print(labels['Dataset Name'][0])
# Out:
# training

# %%
type(labels['Dataset Name'][0])
# Out:
# str

# %%
print(labels['Image Name'])
# Out:
# 0       33381_0_fal_10_0.png
# 1       33381_0_fal_14_0.png
# 2       33381_0_fal_16_0.png
# 3       33381_0_fal_18_0.png
# 4       33381_0_fal_25_0.png
#                 ...
# 2294    36175_1_nrm_18_0.png
# 2295     36175_1_nrm_1_0.png
# 2296    36175_1_nrm_20_0.png
# 2297    36175_1_nrm_21_0.png
# 2298     36175_1_nrm_2_0.png
# Name: Image Name, Length: 2299, dtype: object

# %%
print(labels['Image Name'][0])
# Out:
# 33381_0_fal_10_0.png

# %%
type(labels['Image Name'][0])
# Out:
# str

# %%
print(labels['Experimental Condition [Diagnosis]'])
# Out:
# 0           chronic heart failure
# 1           chronic heart failure
# 2           chronic heart failure
# 3           chronic heart failure
# 4           chronic heart failure
#                   ...
# 2294    not chronic heart failure
# 2295    not chronic heart failure
# 2296    not chronic heart failure
# 2297    not chronic heart failure
# 2298    not chronic heart failure
# Name: Experimental Condition [Diagnosis], Length: 2299, dtype: object

# %%
print(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# chronic heart failure

# %%
type(labels['Experimental Condition [Diagnosis]'][0])
# Out:
# str

# %%
# confirm 'no info' cells have been encoded as 'nan'... check one entry
print(labels['Characteristics [Disease Subtype]'][463])
# Out:
# nan

# %% [markdown]
# ### Prepare Train Images and Train Labels

# %% [markdown]
# #### Explore and Understand

# %%
# Google Drive / Colab
filepathlist_train = glob.glob('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png')

# %%
# confirm you have got the total number of desired items in the list
len(filepathlist_train)
# Out:
# 770

# %%
# check what an element in the filelist contain.
# it has both directory information and the filename, we need to extract filename 
# the filename can then be used to check for the label info in the labels dataframe
filepathlist_train[0]
# Out:
# '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/33392_0_fal_4_0.png'

# %% [markdown]
# #### Extract Filename and Label Info

# %% [markdown]
# All the images are of type '*.png'. We will read filepath for all "filenames with extension as 'png'" into a list. Here, filepath means 'relative directory + filename'. We will extract filename of the image from the file path. This filename can then be used to get the label information from the annotation file.

# %% [markdown]
# ##### Local Drive / Jupyter

# %%
# this scenario has '\\' between the directory and filename
# split the string
# directory, filename = filepathlist_train[0].split('\\')
# gives the directory info
# directory
# gives the filname we need
# filename

# %% [markdown]
# ##### Google Drive / Colab

# %% [markdown]
# ###### Explore and Understand

# %%
len(filepathlist_train[0])
# Out:
# 128

# %%
filepathlist_train[0][-19:]
# Out:
# '33392_0_fal_4_0.png'

# %%
filepathlist_train[0][len(filepathlist_train[0]) - 1]
# Out:
# 'g'

# %%
filepathlist_train[0][-1]
# Out:
# 'g'

# %%
# POC
idx = -1
while (filepathlist_train[0][idx] != '/'):
  idx = idx - 1 
# index currently points to '/' location, we need to start reading from next location to get file name
print(idx)
filename = filepathlist_train[0][idx + 1:]
print(filename)
# Out:
# -20
# 33392_0_fal_4_0.png

# %%
# POC
index_filepathlist = 0
for filepath in filepathlist_train:
    #print(index_filepathlist, filepath)
    index_filepathlist += 1

# %%
# read a file using the list containing the file path
img = cv2.imread(filepathlist_train[0])

# %% [markdown]
# ##### Define a Call Function to prepare images and labels

# %%
# function to prepare images & labels for the model
def prepare_images_labels (path_to_img_files, labels_dataframe, resize = 0):
  filepathlist = glob.glob(path_to_img_files)
  # define the empty list that need to populated with info
  images = []
  labels = []
  index_filepathlist = 0
  # iterate for all items in the file path list
  for filepath in filepathlist:
      # prepare image list
      img = cv2.imread(filepath)
      if (resize == 1):
        dim = (224,224)
        img = cv2.resize(img, dim)#, interpolation = inter)
      images.append(img)
      # prepare labels list
      # extract filename from the file path
      # Local Drive / Jupyter
      # directory, filename = filepath.split('\\')
      # Google Drive / Colab
      index_character = -1
      while (filepathlist[index_filepathlist][index_character] != '/'):
        index_character = index_character - 1 
      # character index currently points to '/' location, we need to start reading from next location to get file name
      filename = filepathlist[index_filepathlist][index_character + 1:]
      index_filepathlist += 1
      # iterate for all items in our labels dataframe to search for the label
      for index in range(len(labels_dataframe)):
          # we will compare the filename with all the filenames in the 'Image Name' column of the labels dataframe
          # when there is a match, we will copy the label from the 'Experimental Condition [Diagnosis]' column
          if (filename == labels_dataframe['Image Name'][index]):
              label = labels_dataframe['Experimental Condition [Diagnosis]'][index]
              # encode Class1 and Class0 as applicable
              if (label == 'chronic heart failure'):
                  label = 1
              elif (label == 'not chronic heart failure'):
                  label = 0
              elif (label == 'heart tissue pathology'):
                  label = 0
              # append the label to the list
              labels.append(label)
  return images, labels

# %% [markdown]
# ##### Prepare Train Images and Train Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png'
# for resnet50
# train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
train_images, train_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_train = glob.glob('data/images/training/fold_1/*.png')

# %%
# train_labels

# %% [markdown]
# Convert images to numpy arrays and confirm shape is as required for CNN.

# %%
# confirm you have got the total number desired images in the list
len(train_images)
# Out:
# 770

# %%
# train is a list
type(train_images)
# Out:
# list

# %%
# convert list to a numpy array and the values to float
train_images = np.array(train_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
# number of instances, width, height, number of channels
# number of instances = number of image
# number of channels = 3 ... as these are color images
train_images.shape
# Out:
# (770, 224, 224, 3)

# %% [markdown]
# Convert labels to numpy arrays and confirm shape is as required for CNN.

# %%
len(train_labels)
# Out:
# 770

# %%
type(train_labels)
# Out:
# list

# %%
train_labels[0]
# Out:
# 1

# %%
train_labels[432]
# Out:
# 0

# %%
# convert list to a numpy array and the values to int64
train_labels = np.array(train_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
train_labels.shape
# Out:
# (770,)

# %%
len(train_labels)
# Out:
# 770

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
# function to count ones and zeroes in the label array
def print_ones_zeroes (labels):
  count_ones = 0
  count_zeroes = 0
  for i in range(len(labels)):
    if (labels[i] == 1):
      count_ones += 1
    elif (labels[i] == 0):
      count_zeroes += 1
  print('Total Labels:',(count_ones + count_zeroes))
  print('# of Class 1:',count_ones)   
  print('# of Class 0:',count_zeroes)

# %%
print_ones_zeroes(train_labels)
# Out:
# Total Labels: 770
# # of Class 1: 352
# # of Class 0: 418

# %% [markdown]
# We will convert the labels to 2bit values: 01 and 10 to correspond to the 2 classes. This is required to match to the model's output layer expectation so that we can effectively train and test.

# %%
from keras.utils import to_categorical

# %%
# convert labels to categorical
train_labels = to_categorical(train_labels)

# %% [markdown]
# ### Prepare Validation Images and Validation Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/test_fold_1/*.png'
# for resnet50
# validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_validation = glob.glob('data/images/training/test_fold_1/*.png')

# %%
# convert list to a numpy array and the values to float
validation_images = np.array(validation_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
validation_images.shape
# Out:
# (374, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
validation_labels = np.array(validation_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
validation_labels.shape
# Out:
# (374,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(validation_labels)
# Out:
# Total Labels: 374
# # of Class 1: 165
# # of Class 0: 209

# %%
# convert labels to categorical
validation_labels = to_categorical(validation_labels)

# %% [markdown]
# ### Prepare Test Images and Test Labels

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'

# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/held-out_validation/*.png'
# for resnet50
# test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 0)
# for mobilenet
test_images, test_labels = prepare_images_labels (path_to_img_files, labels, 1)

# Local Drive / Jupyter
# filepathlist_test = glob.glob('data/images/held-out_validation/*.png')

# %%
# convert list to a numpy array and the values to float
test_images = np.array(test_images, dtype = 'float32')

# %%
# check the shape to confirm it is ready for CNN
test_images.shape
# Out:
# (1155, 224, 224, 3)

# %%
# convert list to a numpy array and the values to int64
test_labels = np.array(test_labels, dtype = 'int64')

# %%
# check the shape to confirm it is ready for CNN
test_labels.shape
# Out:
# (1155,)

# %% [markdown]
# Let us check on the number of Class 0 and Class 1s that we have.

# %%
print_ones_zeroes(test_labels)
# Out:
# Total Labels: 1155
# # of Class 1: 517
# # of Class 0: 638

# %%
# convert labels to categorical
test_labels = to_categorical(test_labels)

# %% [markdown]
# ### Prepare All Images and Labels for Cross Validation

# %%
# confirm all are numpy arrays, length and shape
print(type(train_images), len(train_images), train_images.shape)
print(type(validation_images), len(validation_images), validation_images.shape)
print(type(test_images), len(test_images), test_images.shape)
print(len(train_images) + len(validation_images) + len(test_images))
print(type(train_labels), len(train_labels), train_labels.shape)
print(type(validation_labels), len(validation_labels), validation_labels.shape)
print(type(test_labels), len(test_labels), test_labels.shape)
print(len(train_labels) + len(validation_labels) + len(test_labels))
# Out:
# <class 'numpy.ndarray'> 770 (770, 224, 224, 3)
# <class 'numpy.ndarray'> 374 (374, 224, 224, 3)
# <class 'numpy.ndarray'> 1155 (1155, 224, 224, 3)
# 2299
# <class 'numpy.ndarray'> 770 (770, 2)
# <class 'numpy.ndarray'> 374 (374, 2)
# <class 'numpy.ndarray'> 1155 (1155, 2)
# 2299

# %%
# join train / validation / test arrays for images
all_images = np.concatenate((train_images, validation_images, test_images))
print(type(all_images), len(all_images), all_images.shape)
# Out:
# <class 'numpy.ndarray'> 2299 (2299, 224, 224, 3)

# %%
# join train / validation / test arrays for labels
all_labels = np.concatenate((train_labels, validation_labels, test_labels))
print(type(all_labels), len(all_labels), all_labels.shape)
# Out:
# <class 'numpy.ndarray'> 2299 (2299, 2)

# %% [markdown]
# ## Model Definition / Train / Validate / Test

# %% [markdown]
# ### MNIST CNN modified for HE

# %%
# import libraries (general)
# from keras import models
# from keras import layers
# model_cnn = models.Sequential()

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 32
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# - Input Shape = 250x250 matrix with 3 channel (as we have a color image)
# model_cnn.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(250,250,3)))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation = 'relu'))

# Layer Details:
# - Downsample the output from previous layer
# - We will take the max value for a every 2x2 window ... moved over the input
# model_cnn.add(layers.MaxPooling2D(2,2))

# Layer Details:
# - 2 dimensional Convolution Layer
# - Number of filters/kernels = 64
# - Filter/Kernel Size = 3x3
# - Activation Function = relu (for non-linearity detection)
# model_cnn.add(layers.Conv2D(64, (3,3), activation='relu'))

# Data at this stage is in matrix form. We will convert it to vector form to feed to a fully connected network (FCN).
# model_cnn.add(layers.Flatten())

# We will design for 64 outputs with activation function as relu (to learn non-linearity).
# model_cnn.add(layers.Dense(64, activation = 'relu'))

# This is the final layer. Hence, the outputs will be 2 corresponding to the 2 classes:
# - clinical heart failure = yes: 1
# - clinical heart failure = no: 0
# Activation Function chosen here is softmax to have a probabilistic output. 
# model_cnn.add(layers.Dense(2, activation = 'softmax'))

# model_cnn.summary()

# Define Optimizer, Loss Function and Metrics to be used for the Model
# - Going ahead with the well known functions at this point in time
# - Selected accuracy as the metrics to understand validation / test accuracy of the model
# model_cnn.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# Train and Validate the Model
# We will now train the model using train images and train labels. 
# - We will use a batch size = 10.
# - 1 epoch = 770 / 10 = 77 batches
# - 1 epoch = 1 complete run of all train samples for training the model
# - We will go for a total of 5 epochs = 5 complete run of the all train samples
# We will validate the model using validation images and validation labels.
# model_cnn.fit(train_images, train_labels, epochs = 1, batch_size = 10, validation_data = (validation_images, validation_labels))

# Test the Model
# We will now test model's performance with the test data.
# - We predict the class for each of the 1155 test using the model.
# - We will check the test accuracy.
# test_loss, test_acc = model_cnn.evaluate(test_images, test_labels)
# print('test accuracy:', (test_acc*100))

# %% [markdown]
# ### Define Common Hyperparameters

# %%
BATCH_SIZE = 10
EPOCHS = 100
LEARNING_RATE = 0.01
DENSE_LAYER_NEURONS = 512
DENSE_LAYER_DROPOUT = 0.4

# %% [markdown]
# ### Define a checkpoint function

# %%
from keras.callbacks import ModelCheckpoint
def checkpoint(path_to_model_parameters_file):
  # 1st argument: file to which the weights need to be saved
  # 2nd argument: defines the quantity to monitor ... we will monitor validation accuracy
  # 3rd argument: verbose yes/no
  # 4th argument: true then save weghts else save entire model
  # 5th argument: max if val_acc, min if val_loss, auto decides based on the quantity getting monitored
  # 6th argument: period:  check after every epoch therefore 1
  # 6th arguemnt: save_freq:  specify the frequency in number of batches seen
  #checkpoint = ModelCheckpoint("/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5", monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  checkpoint_value = ModelCheckpoint(path_to_model_parameters_file, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  return checkpoint_value

# %% [markdown]
# ### ResNet50 - Transfer Learning

# %%
# import libraries (resnet50)
from keras.applications.resnet50 import ResNet50
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# from keras.layers import Dropout
from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
from keras.preprocessing.image import ImageDataGenerator

# %%
# load ResNet50 with pre-trained parameters for 'imagenet' challenge
# disable the last layer ... so that we can have our own FCN layer for our desired classes
resnet50 = ResNet50(include_top=False, weights='imagenet')

# define the last layers
# get the output of the last layer of the ResNet50
prediction = resnet50.output
# add a Global Average Pooling layer (GAP) - this helps reduce number of parameters as compared to a flatten/dense layer
prediction = GlobalAveragePooling2D()(prediction)
# add a FCN with 1024 output neurons
#prediction = Dense(1024, activation = 'relu')(prediction)
# we will split the actions to have the Batch Normalization done befor relu
prediction = Dense(DENSE_LAYER_NEURONS)(prediction)
#prediction = BatchNormalization()(prediction)
prediction = Activation('relu')(prediction)
# add a dropout of 40% to avoid overfitting
prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)
# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction = Dense(2, activation = 'softmax')(prediction)

# connect the last layer with ResNet50 layer to define the model
model = Model(inputs = resnet50.input, outputs = prediction)

# we wish use the pretrained resnet50 model as is i.e. do not want it's parameters to get updated during training
for layer in resnet50.layers:
  layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, None,  0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, None, None, 3 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, None, None, 6 9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# conv1_bn (BatchNormalization)   (None, None, None, 6 256         conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv1_relu (Activation)         (None, None, None, 6 0           conv1_bn[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, None, None, 6 0           conv1_relu[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, None, None, 6 0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, None, None, 6 4160        pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, None, None, 6 256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, None, None, 6 0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, None, None, 6 256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, None, None, 6 0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, None, None, 2 16640       pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_add (Add)          (None, None, None, 2 0           conv2_block1_0_bn[0][0]
#                                                                  conv2_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Activation)   (None, None, None, 2 0           conv2_block1_add[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, None, None, 6 256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, None, None, 6 0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, None, None, 6 256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, None, None, 6 0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_add (Add)          (None, None, None, 2 0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Activation)   (None, None, None, 2 0           conv2_block2_add[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, None, None, 6 16448       conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, None, None, 6 256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, None, None, 6 0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, None, None, 6 36928       conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, None, None, 6 256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, None, None, 6 0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, None, None, 2 16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_bn (BatchNormali (None, None, None, 2 1024        conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_add (Add)          (None, None, None, 2 0           conv2_block2_out[0][0]
#                                                                  conv2_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Activation)   (None, None, None, 2 0           conv2_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, None, None, 1 32896       conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, None, None, 1 512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, None, None, 1 0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, None, None, 1 512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, None, None, 1 0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, None, None, 5 131584      conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_add (Add)          (None, None, None, 5 0           conv3_block1_0_bn[0][0]
#                                                                  conv3_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Activation)   (None, None, None, 5 0           conv3_block1_add[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, None, None, 1 512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, None, None, 1 0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, None, None, 1 512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, None, None, 1 0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_add (Add)          (None, None, None, 5 0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Activation)   (None, None, None, 5 0           conv3_block2_add[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, None, None, 1 512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, None, None, 1 0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, None, None, 1 512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, None, None, 1 0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_add (Add)          (None, None, None, 5 0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Activation)   (None, None, None, 5 0           conv3_block3_add[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, None, None, 1 65664       conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, None, None, 1 512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, None, None, 1 0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, None, None, 1 147584      conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, None, None, 1 512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, None, None, 1 0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, None, None, 5 66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_bn (BatchNormali (None, None, None, 5 2048        conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_add (Add)          (None, None, None, 5 0           conv3_block3_out[0][0]
#                                                                  conv3_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Activation)   (None, None, None, 5 0           conv3_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, None, None, 2 131328      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, None, None, 2 0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, None, None, 2 0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, None, None, 1 525312      conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_add (Add)          (None, None, None, 1 0           conv4_block1_0_bn[0][0]
#                                                                  conv4_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Activation)   (None, None, None, 1 0           conv4_block1_add[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, None, None, 2 0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, None, None, 2 0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_add (Add)          (None, None, None, 1 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Activation)   (None, None, None, 1 0           conv4_block2_add[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, None, None, 2 0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, None, None, 2 0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_add (Add)          (None, None, None, 1 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Activation)   (None, None, None, 1 0           conv4_block3_add[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, None, None, 2 0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, None, None, 2 0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_add (Add)          (None, None, None, 1 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Activation)   (None, None, None, 1 0           conv4_block4_add[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, None, None, 2 0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, None, None, 2 0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_add (Add)          (None, None, None, 1 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Activation)   (None, None, None, 1 0           conv4_block5_add[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, None, None, 2 262400      conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, None, None, 2 0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, None, None, 2 590080      conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, None, None, 2 1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, None, None, 2 0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, None, None, 1 263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_bn (BatchNormali (None, None, None, 1 4096        conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_add (Add)          (None, None, None, 1 0           conv4_block5_out[0][0]
#                                                                  conv4_block6_3_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Activation)   (None, None, None, 1 0           conv4_block6_add[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, None, None, 5 524800      conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, None, None, 5 0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, None, None, 5 0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, None, None, 2 2099200     conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_0_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_add (Add)          (None, None, None, 2 0           conv5_block1_0_bn[0][0]
#                                                                  conv5_block1_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Activation)   (None, None, None, 2 0           conv5_block1_add[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, None, None, 5 0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, None, None, 5 0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_add (Add)          (None, None, None, 2 0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Activation)   (None, None, None, 2 0           conv5_block2_add[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, None, None, 5 1049088     conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, None, None, 5 0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, None, None, 5 2359808     conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, None, None, 5 2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, None, None, 5 0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, None, None, 2 1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_bn (BatchNormali (None, None, None, 2 8192        conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_add (Add)          (None, None, None, 2 0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Activation)   (None, None, None, 2 0           conv5_block3_add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 2048)         0           conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 512)          1049088     global_average_pooling2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 512)          0           dense[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 512)          0           activation[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 2)            1026        dropout[0][0]
# ==================================================================================================
# Total params: 24,637,826
# Trainable params: 1,050,114
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
# len(resnet50.layers)
# resnet50.layers
# resnet50.summary()

# %%
# data augmentation helps change the data slightly so that the model does not overfit
# train_generator = ImageDataGenerator(rotation_range = 8, width_shift_range = 0.08, shear_range = 0.3, height_shift_range = 0.08, zoom_range = 0.08)
# validation_generator = ImageDataGenerator()
# below ensures the augmented data is provided in batches to the model
# train_augmented = train_generator.flow(train_images, train_labels, batch_size = 10)
# validation_augmented = validation_generator.flow(validation_images, validation_labels, batch_size = 10)

# %%
# train and validate model
path_to_resnet50_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5'
model.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_resnet50_parameters_file)])

# train and validate model with augmented data
# model.fit(train_augmented, epochs = 20, batch_size = 10, validation_data = validation_augmented)
# Out:
# Epoch 1/100
# 77/77 [==============================] - 14s 59ms/step - loss: 5.6826 - accuracy: 0.6484 - val_loss: 0.5617 - val_accuracy: 0.7326
#
# Epoch 00001: val_accuracy improved from -inf to 0.73262, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 2/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.4374 - accuracy: 0.7866 - val_loss: 0.4814 - val_accuracy: 0.7781
#
# Epoch 00002: val_accuracy improved from 0.73262 to 0.77807, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 3/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.4261 - accuracy: 0.8197 - val_loss: 0.6832 - val_accuracy: 0.6578
#
# Epoch 00003: val_accuracy did not improve from 0.77807
# Epoch 4/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.4212 - accuracy: 0.8163 - val_loss: 0.4205 - val_accuracy: 0.8182
#
# Epoch 00004: val_accuracy improved from 0.77807 to 0.81818, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 5/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.3682 - accuracy: 0.8264 - val_loss: 0.4179 - val_accuracy: 0.7914
#
# Epoch 00005: val_accuracy did not improve from 0.81818
# Epoch 6/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.3110 - accuracy: 0.8782 - val_loss: 0.4354 - val_accuracy: 0.8075
#
# Epoch 00006: val_accuracy did not improve from 0.81818
# Epoch 7/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2952 - accuracy: 0.8830 - val_loss: 0.4046 - val_accuracy: 0.8369
#
# Epoch 00007: val_accuracy improved from 0.81818 to 0.83690, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 8/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3137 - accuracy: 0.8706 - val_loss: 0.6083 - val_accuracy: 0.7727
#
# Epoch 00008: val_accuracy did not improve from 0.83690
# Epoch 9/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3011 - accuracy: 0.8693 - val_loss: 0.4117 - val_accuracy: 0.8396
#
# Epoch 00009: val_accuracy improved from 0.83690 to 0.83957, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 10/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3122 - accuracy: 0.8760 - val_loss: 0.4937 - val_accuracy: 0.8182
#
# Epoch 00010: val_accuracy did not improve from 0.83957
# Epoch 11/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2678 - accuracy: 0.8683 - val_loss: 0.3845 - val_accuracy: 0.8182
#
# Epoch 00011: val_accuracy did not improve from 0.83957
# Epoch 12/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3258 - accuracy: 0.8637 - val_loss: 0.5670 - val_accuracy: 0.8262
#
# Epoch 00012: val_accuracy did not improve from 0.83957
# Epoch 13/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2698 - accuracy: 0.8925 - val_loss: 0.6689 - val_accuracy: 0.7941
#
# Epoch 00013: val_accuracy did not improve from 0.83957
# Epoch 14/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3225 - accuracy: 0.8883 - val_loss: 0.3880 - val_accuracy: 0.8556
#
# Epoch 00014: val_accuracy improved from 0.83957 to 0.85561, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 15/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2511 - accuracy: 0.8919 - val_loss: 0.4441 - val_accuracy: 0.8316
#
# Epoch 00015: val_accuracy did not improve from 0.85561
# Epoch 16/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2542 - accuracy: 0.8787 - val_loss: 0.4423 - val_accuracy: 0.8262
#
# Epoch 00016: val_accuracy did not improve from 0.85561
# Epoch 17/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2247 - accuracy: 0.8797 - val_loss: 0.3254 - val_accuracy: 0.8797
#
# Epoch 00017: val_accuracy improved from 0.85561 to 0.87968, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 18/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2341 - accuracy: 0.9037 - val_loss: 0.3950 - val_accuracy: 0.8636
#
# Epoch 00018: val_accuracy did not improve from 0.87968
# Epoch 19/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2045 - accuracy: 0.9153 - val_loss: 0.4470 - val_accuracy: 0.8583
#
# Epoch 00019: val_accuracy did not improve from 0.87968
# Epoch 20/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2609 - accuracy: 0.8719 - val_loss: 0.5732 - val_accuracy: 0.8289
#
# Epoch 00020: val_accuracy did not improve from 0.87968
# Epoch 21/100
# 77/77 [==============================] - 3s 41ms/step - loss: 0.2830 - accuracy: 0.8714 - val_loss: 0.4393 - val_accuracy: 0.8690
#
# Epoch 00021: val_accuracy did not improve from 0.87968
# Epoch 22/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3567 - accuracy: 0.8297 - val_loss: 0.5664 - val_accuracy: 0.8289
#
# Epoch 00022: val_accuracy did not improve from 0.87968
# Epoch 23/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3115 - accuracy: 0.8718 - val_loss: 0.4188 - val_accuracy: 0.8583
#
# Epoch 00023: val_accuracy did not improve from 0.87968
# Epoch 24/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2570 - accuracy: 0.8915 - val_loss: 0.4320 - val_accuracy: 0.8476
#
# Epoch 00024: val_accuracy did not improve from 0.87968
# Epoch 25/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2435 - accuracy: 0.9018 - val_loss: 0.3822 - val_accuracy: 0.8877
#
# Epoch 00025: val_accuracy improved from 0.87968 to 0.88770, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 26/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1917 - accuracy: 0.9112 - val_loss: 0.5189 - val_accuracy: 0.8583
#
# Epoch 00026: val_accuracy did not improve from 0.88770
# Epoch 27/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2231 - accuracy: 0.8998 - val_loss: 0.3992 - val_accuracy: 0.8690
#
# Epoch 00027: val_accuracy did not improve from 0.88770
# Epoch 28/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2392 - accuracy: 0.8992 - val_loss: 0.5344 - val_accuracy: 0.8476
#
# Epoch 00028: val_accuracy did not improve from 0.88770
# Epoch 29/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2213 - accuracy: 0.9015 - val_loss: 0.6569 - val_accuracy: 0.8316
#
# Epoch 00029: val_accuracy did not improve from 0.88770
# Epoch 30/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2313 - accuracy: 0.9084 - val_loss: 0.5881 - val_accuracy: 0.8503
#
# Epoch 00030: val_accuracy did not improve from 0.88770
# Epoch 31/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2211 - accuracy: 0.9034 - val_loss: 0.6753 - val_accuracy: 0.8342
#
# Epoch 00031: val_accuracy did not improve from 0.88770
# Epoch 32/100
# 77/77 [==============================] - 3s 41ms/step - loss: 0.2263 - accuracy: 0.8992 - val_loss: 0.3972 - val_accuracy: 0.8316
#
# Epoch 00032: val_accuracy did not improve from 0.88770
# Epoch 33/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3018 - accuracy: 0.8371 - val_loss: 0.4610 - val_accuracy: 0.8021
#
# Epoch 00033: val_accuracy did not improve from 0.88770
# Epoch 34/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2368 - accuracy: 0.8619 - val_loss: 0.5166 - val_accuracy: 0.8824
#
# Epoch 00034: val_accuracy did not improve from 0.88770
# Epoch 35/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2251 - accuracy: 0.8782 - val_loss: 0.4670 - val_accuracy: 0.8503
#
# Epoch 00035: val_accuracy did not improve from 0.88770
# Epoch 36/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2302 - accuracy: 0.8533 - val_loss: 0.4982 - val_accuracy: 0.8476
#
# Epoch 00036: val_accuracy did not improve from 0.88770
# Epoch 37/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1791 - accuracy: 0.9116 - val_loss: 0.4252 - val_accuracy: 0.8690
#
# Epoch 00037: val_accuracy did not improve from 0.88770
# Epoch 38/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1859 - accuracy: 0.9074 - val_loss: 0.5363 - val_accuracy: 0.8797
#
# Epoch 00038: val_accuracy did not improve from 0.88770
# Epoch 39/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2529 - accuracy: 0.8690 - val_loss: 0.4741 - val_accuracy: 0.8636
#
# Epoch 00039: val_accuracy did not improve from 0.88770
# Epoch 40/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2599 - accuracy: 0.8599 - val_loss: 0.5176 - val_accuracy: 0.8209
#
# Epoch 00040: val_accuracy did not improve from 0.88770
# Epoch 41/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2450 - accuracy: 0.8554 - val_loss: 0.3908 - val_accuracy: 0.8797
#
# Epoch 00041: val_accuracy did not improve from 0.88770
# Epoch 42/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2344 - accuracy: 0.8479 - val_loss: 0.6032 - val_accuracy: 0.8342
#
# Epoch 00042: val_accuracy did not improve from 0.88770
# Epoch 43/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2768 - accuracy: 0.8278 - val_loss: 0.5460 - val_accuracy: 0.8556
#
# Epoch 00043: val_accuracy did not improve from 0.88770
# Epoch 44/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2201 - accuracy: 0.8790 - val_loss: 0.6435 - val_accuracy: 0.8369
#
# Epoch 00044: val_accuracy did not improve from 0.88770
# Epoch 45/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3019 - accuracy: 0.8421 - val_loss: 0.4440 - val_accuracy: 0.8930
#
# Epoch 00045: val_accuracy improved from 0.88770 to 0.89305, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50.hdf5
# Epoch 46/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1932 - accuracy: 0.8959 - val_loss: 0.4564 - val_accuracy: 0.8663
#
# Epoch 00046: val_accuracy did not improve from 0.89305
# Epoch 47/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2370 - accuracy: 0.8554 - val_loss: 0.6903 - val_accuracy: 0.8556
#
# Epoch 00047: val_accuracy did not improve from 0.89305
# Epoch 48/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1181 - accuracy: 0.9359 - val_loss: 0.6977 - val_accuracy: 0.8476
#
# Epoch 00048: val_accuracy did not improve from 0.89305
# Epoch 49/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2052 - accuracy: 0.9043 - val_loss: 0.5357 - val_accuracy: 0.8476
#
# Epoch 00049: val_accuracy did not improve from 0.89305
# Epoch 50/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2218 - accuracy: 0.8660 - val_loss: 0.5226 - val_accuracy: 0.8316
#
# Epoch 00050: val_accuracy did not improve from 0.89305
# Epoch 51/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2430 - accuracy: 0.8455 - val_loss: 0.7101 - val_accuracy: 0.8610
#
# Epoch 00051: val_accuracy did not improve from 0.89305
# Epoch 52/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2689 - accuracy: 0.8979 - val_loss: 0.4431 - val_accuracy: 0.8476
#
# Epoch 00052: val_accuracy did not improve from 0.89305
# Epoch 53/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2272 - accuracy: 0.8569 - val_loss: 0.4746 - val_accuracy: 0.8610
#
# Epoch 00053: val_accuracy did not improve from 0.89305
# Epoch 54/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1604 - accuracy: 0.9149 - val_loss: 0.9914 - val_accuracy: 0.8449
#
# Epoch 00054: val_accuracy did not improve from 0.89305
# Epoch 55/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2596 - accuracy: 0.8699 - val_loss: 0.3953 - val_accuracy: 0.8690
#
# Epoch 00055: val_accuracy did not improve from 0.89305
# Epoch 56/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2194 - accuracy: 0.8921 - val_loss: 0.8689 - val_accuracy: 0.8503
#
# Epoch 00056: val_accuracy did not improve from 0.89305
# Epoch 57/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2672 - accuracy: 0.8501 - val_loss: 0.4805 - val_accuracy: 0.8930
#
# Epoch 00057: val_accuracy did not improve from 0.89305
# Epoch 58/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2401 - accuracy: 0.8770 - val_loss: 0.7986 - val_accuracy: 0.8102
#
# Epoch 00058: val_accuracy did not improve from 0.89305
# Epoch 59/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2518 - accuracy: 0.8685 - val_loss: 0.5473 - val_accuracy: 0.8476
#
# Epoch 00059: val_accuracy did not improve from 0.89305
# Epoch 60/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2140 - accuracy: 0.9041 - val_loss: 0.5812 - val_accuracy: 0.8583
#
# Epoch 00060: val_accuracy did not improve from 0.89305
# Epoch 61/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2818 - accuracy: 0.8752 - val_loss: 0.5478 - val_accuracy: 0.6096
#
# Epoch 00061: val_accuracy did not improve from 0.89305
# Epoch 62/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.4187 - accuracy: 0.7295 - val_loss: 0.4504 - val_accuracy: 0.7674
#
# Epoch 00062: val_accuracy did not improve from 0.89305
# Epoch 63/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.4147 - accuracy: 0.7553 - val_loss: 0.5416 - val_accuracy: 0.8155
#
# Epoch 00063: val_accuracy did not improve from 0.89305
# Epoch 64/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.3660 - accuracy: 0.8350 - val_loss: 0.4522 - val_accuracy: 0.8476
#
# Epoch 00064: val_accuracy did not improve from 0.89305
# Epoch 65/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2355 - accuracy: 0.8971 - val_loss: 0.6581 - val_accuracy: 0.8636
#
# Epoch 00065: val_accuracy did not improve from 0.89305
# Epoch 66/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1951 - accuracy: 0.9221 - val_loss: 0.9830 - val_accuracy: 0.8289
#
# Epoch 00066: val_accuracy did not improve from 0.89305
# Epoch 67/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2353 - accuracy: 0.8993 - val_loss: 0.6063 - val_accuracy: 0.8449
#
# Epoch 00067: val_accuracy did not improve from 0.89305
# Epoch 68/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2490 - accuracy: 0.8992 - val_loss: 0.6152 - val_accuracy: 0.8610
#
# Epoch 00068: val_accuracy did not improve from 0.89305
# Epoch 69/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2394 - accuracy: 0.8900 - val_loss: 0.5965 - val_accuracy: 0.8636
#
# Epoch 00069: val_accuracy did not improve from 0.89305
# Epoch 70/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1862 - accuracy: 0.9141 - val_loss: 0.5179 - val_accuracy: 0.8717
#
# Epoch 00070: val_accuracy did not improve from 0.89305
# Epoch 71/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2120 - accuracy: 0.8933 - val_loss: 0.4432 - val_accuracy: 0.8797
#
# Epoch 00071: val_accuracy did not improve from 0.89305
# Epoch 72/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1704 - accuracy: 0.9249 - val_loss: 0.5949 - val_accuracy: 0.8770
#
# Epoch 00072: val_accuracy did not improve from 0.89305
# Epoch 73/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1906 - accuracy: 0.9006 - val_loss: 0.9684 - val_accuracy: 0.8556
#
# Epoch 00073: val_accuracy did not improve from 0.89305
# Epoch 74/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2065 - accuracy: 0.9020 - val_loss: 0.7267 - val_accuracy: 0.8717
#
# Epoch 00074: val_accuracy did not improve from 0.89305
# Epoch 75/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1520 - accuracy: 0.9438 - val_loss: 0.5587 - val_accuracy: 0.8850
#
# Epoch 00075: val_accuracy did not improve from 0.89305
# Epoch 76/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1965 - accuracy: 0.9151 - val_loss: 1.0114 - val_accuracy: 0.8422
#
# Epoch 00076: val_accuracy did not improve from 0.89305
# Epoch 77/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1959 - accuracy: 0.9047 - val_loss: 0.8537 - val_accuracy: 0.8690
#
# Epoch 00077: val_accuracy did not improve from 0.89305
# Epoch 78/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1970 - accuracy: 0.9167 - val_loss: 0.6800 - val_accuracy: 0.8690
#
# Epoch 00078: val_accuracy did not improve from 0.89305
# Epoch 79/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1850 - accuracy: 0.9199 - val_loss: 0.7499 - val_accuracy: 0.8797
#
# Epoch 00079: val_accuracy did not improve from 0.89305
# Epoch 80/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1846 - accuracy: 0.9156 - val_loss: 0.9795 - val_accuracy: 0.8583
#
# Epoch 00080: val_accuracy did not improve from 0.89305
# Epoch 81/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1689 - accuracy: 0.9317 - val_loss: 0.8453 - val_accuracy: 0.8877
#
# Epoch 00081: val_accuracy did not improve from 0.89305
# Epoch 82/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2136 - accuracy: 0.8982 - val_loss: 0.5793 - val_accuracy: 0.8797
#
# Epoch 00082: val_accuracy did not improve from 0.89305
# Epoch 83/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1889 - accuracy: 0.9148 - val_loss: 0.8876 - val_accuracy: 0.8663
#
# Epoch 00083: val_accuracy did not improve from 0.89305
# Epoch 84/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1470 - accuracy: 0.9409 - val_loss: 0.8288 - val_accuracy: 0.8690
#
# Epoch 00084: val_accuracy did not improve from 0.89305
# Epoch 85/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1646 - accuracy: 0.9389 - val_loss: 0.7958 - val_accuracy: 0.8797
#
# Epoch 00085: val_accuracy did not improve from 0.89305
# Epoch 86/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1735 - accuracy: 0.9218 - val_loss: 0.6103 - val_accuracy: 0.8717
#
# Epoch 00086: val_accuracy did not improve from 0.89305
# Epoch 87/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2154 - accuracy: 0.9044 - val_loss: 0.4634 - val_accuracy: 0.8369
#
# Epoch 00087: val_accuracy did not improve from 0.89305
# Epoch 88/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2526 - accuracy: 0.8626 - val_loss: 0.9695 - val_accuracy: 0.8262
#
# Epoch 00088: val_accuracy did not improve from 0.89305
# Epoch 89/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2300 - accuracy: 0.8516 - val_loss: 0.6968 - val_accuracy: 0.8262
#
# Epoch 00089: val_accuracy did not improve from 0.89305
# Epoch 90/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2464 - accuracy: 0.8898 - val_loss: 0.8112 - val_accuracy: 0.8636
#
# Epoch 00090: val_accuracy did not improve from 0.89305
# Epoch 91/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2939 - accuracy: 0.8637 - val_loss: 0.6738 - val_accuracy: 0.8583
#
# Epoch 00091: val_accuracy did not improve from 0.89305
# Epoch 92/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2382 - accuracy: 0.8843 - val_loss: 0.7741 - val_accuracy: 0.8717
#
# Epoch 00092: val_accuracy did not improve from 0.89305
# Epoch 93/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2297 - accuracy: 0.8777 - val_loss: 0.8642 - val_accuracy: 0.8770
#
# Epoch 00093: val_accuracy did not improve from 0.89305
# Epoch 94/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.1943 - accuracy: 0.8956 - val_loss: 0.6901 - val_accuracy: 0.8717
#
# Epoch 00094: val_accuracy did not improve from 0.89305
# Epoch 95/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2175 - accuracy: 0.8770 - val_loss: 0.5045 - val_accuracy: 0.8209
#
# Epoch 00095: val_accuracy did not improve from 0.89305
# Epoch 96/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2951 - accuracy: 0.8395 - val_loss: 0.7648 - val_accuracy: 0.8583
#
# Epoch 00096: val_accuracy did not improve from 0.89305
# Epoch 97/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.2648 - accuracy: 0.8256 - val_loss: 0.7356 - val_accuracy: 0.8449
#
# Epoch 00097: val_accuracy did not improve from 0.89305
# Epoch 98/100
# 77/77 [==============================] - 3s 39ms/step - loss: 0.1910 - accuracy: 0.8860 - val_loss: 0.9202 - val_accuracy: 0.8583
#
# Epoch 00098: val_accuracy did not improve from 0.89305
# Epoch 99/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2390 - accuracy: 0.8629 - val_loss: 0.8705 - val_accuracy: 0.8743
#
# Epoch 00099: val_accuracy did not improve from 0.89305
# Epoch 100/100
# 77/77 [==============================] - 3s 40ms/step - loss: 0.2219 - accuracy: 0.8686 - val_loss: 0.9814 - val_accuracy: 0.8556
#
# Epoch 00100: val_accuracy did not improve from 0.89305

# %%
# test model
#test_loss, test_acc = model.evaluate(test_images, test_labels)

# %%
# test with best model
model.load_weights(path_to_resnet50_parameters_file)
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 3s 63ms/step - loss: 0.6510 - accuracy: 0.8104

# %% [markdown]
# ### MobileNet

# %% [markdown]
# We will first perform transfer learning. This will help get the parameter values initialized for the last layers before we engage few convolution layers of MobileNet in learning (Fine Tuning).

# %% [markdown]
# #### Transfer Learning

# %%
# import libraries
import tensorflow as tf
from keras.models import Model
#from keras.optimizers import SGD
from keras.optimizers import Adam
#from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
#from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers

# %%
# load MobileNet with pre-trained parameters for 'imagenet' challenge
mobilenet = tf.keras.applications.mobilenet.MobileNet()
# mobilenet.summary()

# define the last layers
# get the output of the last layer of the MobileNet
prediction_mn = mobilenet.output

# mobilenet already has a GAP layer, hence we need to only add a Dense layer

# add a FCN with 512 output neurons
prediction_mn = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction_mn)
# with regularizer
# prediction_mn = Dense(1024, activation = 'relu', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# we will split the actions to have the Batch Normalization done befor relu
# prediction_mn = Dense(1024)(prediction_mn)
# prediction_mn = BatchNormalization()(prediction_mn)
# prediction_mn = Activation('relu')(prediction_mn)

# add a dropout to avoid overfitting
prediction_mn = Dropout(DENSE_LAYER_DROPOUT)(prediction_mn)

# add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
prediction_mn = Dense(2, activation = 'softmax')(prediction_mn)
# with regularizer
# prediction_mn = Dense(2, activation = 'softmax', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), activity_regularizer = regularizers.l2(1e-5))(prediction_mn)

# connect the last layer with MobileNet layer to define the model
model_mn = Model(inputs = mobilenet.input, outputs = prediction_mn)

# we wish use the pretrained MobileNet model as is i.e. do not want it's parameters to get updated during training
for layer in mobilenet.layers:
   layer.trainable = False

# define the optimizer, loss function, metrics we will use
#model_mn.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
#model_mn.compile(optimizer = Adam(lr=0.01), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# we want to monitor validation accuracy and save the best validation accuracy, hence changing the metrics to 'val_accuracy'
model_mn.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 0s 0us/step

# %%
model_mn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1000)              0
# _________________________________________________________________
# predictions (Activation)     (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 4,767,402
# Trainable params: 513,538
# Non-trainable params: 4,253,864
# _________________________________________________________________

# %%
# let us check the layers in the model 
# for i,layer in enumerate(model_mn.layers):
#  print(i,layer.name)

# %%
# train and validate model
path_to_mobilenet_parameters_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5'
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_parameters_file)])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 4s 25ms/step - loss: 0.6220 - accuracy: 0.6798 - val_loss: 0.4784 - val_accuracy: 0.7834
#
# Epoch 00001: val_accuracy improved from -inf to 0.78342, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 2/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.5544 - accuracy: 0.7234 - val_loss: 0.4549 - val_accuracy: 0.7888
#
# Epoch 00002: val_accuracy improved from 0.78342 to 0.78877, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 3/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.5044 - accuracy: 0.7706 - val_loss: 0.4510 - val_accuracy: 0.7968
#
# Epoch 00003: val_accuracy improved from 0.78877 to 0.79679, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 4/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.5260 - accuracy: 0.7453 - val_loss: 0.4315 - val_accuracy: 0.8021
#
# Epoch 00004: val_accuracy improved from 0.79679 to 0.80214, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 5/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4818 - accuracy: 0.7840 - val_loss: 0.4608 - val_accuracy: 0.8316
#
# Epoch 00005: val_accuracy improved from 0.80214 to 0.83155, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 6/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.5014 - accuracy: 0.7578 - val_loss: 0.4180 - val_accuracy: 0.8289
#
# Epoch 00006: val_accuracy did not improve from 0.83155
# Epoch 7/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4847 - accuracy: 0.7624 - val_loss: 0.3978 - val_accuracy: 0.8289
#
# Epoch 00007: val_accuracy did not improve from 0.83155
# Epoch 8/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4779 - accuracy: 0.7691 - val_loss: 0.4337 - val_accuracy: 0.8102
#
# Epoch 00008: val_accuracy did not improve from 0.83155
# Epoch 9/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4479 - accuracy: 0.7892 - val_loss: 0.4229 - val_accuracy: 0.8235
#
# Epoch 00009: val_accuracy did not improve from 0.83155
# Epoch 10/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4499 - accuracy: 0.7999 - val_loss: 0.4318 - val_accuracy: 0.8021
#
# Epoch 00010: val_accuracy did not improve from 0.83155
# Epoch 11/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4836 - accuracy: 0.7747 - val_loss: 0.4244 - val_accuracy: 0.8075
#
# Epoch 00011: val_accuracy did not improve from 0.83155
# Epoch 12/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4666 - accuracy: 0.7997 - val_loss: 0.3997 - val_accuracy: 0.8155
#
# Epoch 00012: val_accuracy did not improve from 0.83155
# Epoch 13/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4623 - accuracy: 0.8030 - val_loss: 0.4433 - val_accuracy: 0.7861
#
# Epoch 00013: val_accuracy did not improve from 0.83155
# Epoch 14/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4317 - accuracy: 0.8037 - val_loss: 0.4485 - val_accuracy: 0.7914
#
# Epoch 00014: val_accuracy did not improve from 0.83155
# Epoch 15/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4540 - accuracy: 0.7990 - val_loss: 0.4238 - val_accuracy: 0.8128
#
# Epoch 00015: val_accuracy did not improve from 0.83155
# Epoch 16/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4504 - accuracy: 0.7914 - val_loss: 0.4195 - val_accuracy: 0.8369
#
# Epoch 00016: val_accuracy improved from 0.83155 to 0.83690, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 17/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4164 - accuracy: 0.8054 - val_loss: 0.4621 - val_accuracy: 0.7781
#
# Epoch 00017: val_accuracy did not improve from 0.83690
# Epoch 18/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.4555 - accuracy: 0.8098 - val_loss: 0.4695 - val_accuracy: 0.7807
#
# Epoch 00018: val_accuracy did not improve from 0.83690
# Epoch 19/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4878 - accuracy: 0.7515 - val_loss: 0.4751 - val_accuracy: 0.7807
#
# Epoch 00019: val_accuracy did not improve from 0.83690
# Epoch 20/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4718 - accuracy: 0.8138 - val_loss: 0.4421 - val_accuracy: 0.7861
#
# Epoch 00020: val_accuracy did not improve from 0.83690
# Epoch 21/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4468 - accuracy: 0.7983 - val_loss: 0.3993 - val_accuracy: 0.8235
#
# Epoch 00021: val_accuracy did not improve from 0.83690
# Epoch 22/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4288 - accuracy: 0.8166 - val_loss: 0.4599 - val_accuracy: 0.7781
#
# Epoch 00022: val_accuracy did not improve from 0.83690
# Epoch 23/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4019 - accuracy: 0.8462 - val_loss: 0.4317 - val_accuracy: 0.7968
#
# Epoch 00023: val_accuracy did not improve from 0.83690
# Epoch 24/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4023 - accuracy: 0.8284 - val_loss: 0.4271 - val_accuracy: 0.8075
#
# Epoch 00024: val_accuracy did not improve from 0.83690
# Epoch 25/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3892 - accuracy: 0.8404 - val_loss: 0.5596 - val_accuracy: 0.7193
#
# Epoch 00025: val_accuracy did not improve from 0.83690
# Epoch 26/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4646 - accuracy: 0.7867 - val_loss: 0.3995 - val_accuracy: 0.8128
#
# Epoch 00026: val_accuracy did not improve from 0.83690
# Epoch 27/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4147 - accuracy: 0.8145 - val_loss: 0.4461 - val_accuracy: 0.7888
#
# Epoch 00027: val_accuracy did not improve from 0.83690
# Epoch 28/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3932 - accuracy: 0.8363 - val_loss: 0.4841 - val_accuracy: 0.7433
#
# Epoch 00028: val_accuracy did not improve from 0.83690
# Epoch 29/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4236 - accuracy: 0.7968 - val_loss: 0.4060 - val_accuracy: 0.8102
#
# Epoch 00029: val_accuracy did not improve from 0.83690
# Epoch 30/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3931 - accuracy: 0.8243 - val_loss: 0.4150 - val_accuracy: 0.8102
#
# Epoch 00030: val_accuracy did not improve from 0.83690
# Epoch 31/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3916 - accuracy: 0.8229 - val_loss: 0.3953 - val_accuracy: 0.8209
#
# Epoch 00031: val_accuracy did not improve from 0.83690
# Epoch 32/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3746 - accuracy: 0.8383 - val_loss: 0.3903 - val_accuracy: 0.8289
#
# Epoch 00032: val_accuracy did not improve from 0.83690
# Epoch 33/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4166 - accuracy: 0.8115 - val_loss: 0.4078 - val_accuracy: 0.8289
#
# Epoch 00033: val_accuracy did not improve from 0.83690
# Epoch 34/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4224 - accuracy: 0.7955 - val_loss: 0.4730 - val_accuracy: 0.7674
#
# Epoch 00034: val_accuracy did not improve from 0.83690
# Epoch 35/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.4104 - accuracy: 0.8217 - val_loss: 0.3871 - val_accuracy: 0.8155
#
# Epoch 00035: val_accuracy did not improve from 0.83690
# Epoch 36/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3958 - accuracy: 0.8434 - val_loss: 0.4393 - val_accuracy: 0.7888
#
# Epoch 00036: val_accuracy did not improve from 0.83690
# Epoch 37/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.4024 - accuracy: 0.8242 - val_loss: 0.4024 - val_accuracy: 0.8262
#
# Epoch 00037: val_accuracy did not improve from 0.83690
# Epoch 38/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3734 - accuracy: 0.8402 - val_loss: 0.4358 - val_accuracy: 0.7995
#
# Epoch 00038: val_accuracy did not improve from 0.83690
# Epoch 39/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3694 - accuracy: 0.8304 - val_loss: 0.4236 - val_accuracy: 0.8075
#
# Epoch 00039: val_accuracy did not improve from 0.83690
# Epoch 40/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3595 - accuracy: 0.8509 - val_loss: 0.4257 - val_accuracy: 0.8102
#
# Epoch 00040: val_accuracy did not improve from 0.83690
# Epoch 41/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3901 - accuracy: 0.8473 - val_loss: 0.3967 - val_accuracy: 0.8262
#
# Epoch 00041: val_accuracy did not improve from 0.83690
# Epoch 42/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3595 - accuracy: 0.8565 - val_loss: 0.4288 - val_accuracy: 0.8102
#
# Epoch 00042: val_accuracy did not improve from 0.83690
# Epoch 43/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3961 - accuracy: 0.8179 - val_loss: 0.4023 - val_accuracy: 0.8235
#
# Epoch 00043: val_accuracy did not improve from 0.83690
# Epoch 44/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3845 - accuracy: 0.8463 - val_loss: 0.4417 - val_accuracy: 0.8155
#
# Epoch 00044: val_accuracy did not improve from 0.83690
# Epoch 45/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3778 - accuracy: 0.8372 - val_loss: 0.4289 - val_accuracy: 0.8128
#
# Epoch 00045: val_accuracy did not improve from 0.83690
# Epoch 46/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3597 - accuracy: 0.8295 - val_loss: 0.4509 - val_accuracy: 0.8128
#
# Epoch 00046: val_accuracy did not improve from 0.83690
# Epoch 47/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3595 - accuracy: 0.8415 - val_loss: 0.3993 - val_accuracy: 0.8289
#
# Epoch 00047: val_accuracy did not improve from 0.83690
# Epoch 48/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3544 - accuracy: 0.8569 - val_loss: 0.4310 - val_accuracy: 0.8075
#
# Epoch 00048: val_accuracy did not improve from 0.83690
# Epoch 49/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3881 - accuracy: 0.8274 - val_loss: 0.4099 - val_accuracy: 0.8262
#
# Epoch 00049: val_accuracy did not improve from 0.83690
# Epoch 50/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3396 - accuracy: 0.8552 - val_loss: 0.3907 - val_accuracy: 0.8342
#
# Epoch 00050: val_accuracy did not improve from 0.83690
# Epoch 51/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3249 - accuracy: 0.8438 - val_loss: 0.4167 - val_accuracy: 0.8235
#
# Epoch 00051: val_accuracy did not improve from 0.83690
# Epoch 52/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3283 - accuracy: 0.8636 - val_loss: 0.4643 - val_accuracy: 0.7888
#
# Epoch 00052: val_accuracy did not improve from 0.83690
# Epoch 53/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3410 - accuracy: 0.8506 - val_loss: 0.4643 - val_accuracy: 0.7888
#
# Epoch 00053: val_accuracy did not improve from 0.83690
# Epoch 54/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3356 - accuracy: 0.8776 - val_loss: 0.4225 - val_accuracy: 0.8262
#
# Epoch 00054: val_accuracy did not improve from 0.83690
# Epoch 55/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3791 - accuracy: 0.8379 - val_loss: 0.4283 - val_accuracy: 0.8235
#
# Epoch 00055: val_accuracy did not improve from 0.83690
# Epoch 56/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3509 - accuracy: 0.8206 - val_loss: 0.4124 - val_accuracy: 0.8209
#
# Epoch 00056: val_accuracy did not improve from 0.83690
# Epoch 57/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3565 - accuracy: 0.8459 - val_loss: 0.4301 - val_accuracy: 0.8316
#
# Epoch 00057: val_accuracy did not improve from 0.83690
# Epoch 58/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3554 - accuracy: 0.8280 - val_loss: 0.4166 - val_accuracy: 0.8289
#
# Epoch 00058: val_accuracy did not improve from 0.83690
# Epoch 59/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3501 - accuracy: 0.8400 - val_loss: 0.4363 - val_accuracy: 0.8289
#
# Epoch 00059: val_accuracy did not improve from 0.83690
# Epoch 60/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3667 - accuracy: 0.8369 - val_loss: 0.4324 - val_accuracy: 0.8209
#
# Epoch 00060: val_accuracy did not improve from 0.83690
# Epoch 61/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3353 - accuracy: 0.8590 - val_loss: 0.4424 - val_accuracy: 0.8209
#
# Epoch 00061: val_accuracy did not improve from 0.83690
# Epoch 62/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3346 - accuracy: 0.8538 - val_loss: 0.4208 - val_accuracy: 0.8182
#
# Epoch 00062: val_accuracy did not improve from 0.83690
# Epoch 63/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3571 - accuracy: 0.8323 - val_loss: 0.4464 - val_accuracy: 0.8235
#
# Epoch 00063: val_accuracy did not improve from 0.83690
# Epoch 64/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3131 - accuracy: 0.8724 - val_loss: 0.4079 - val_accuracy: 0.8449
#
# Epoch 00064: val_accuracy improved from 0.83690 to 0.84492, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 65/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3195 - accuracy: 0.8491 - val_loss: 0.4043 - val_accuracy: 0.8449
#
# Epoch 00065: val_accuracy did not improve from 0.84492
# Epoch 66/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3320 - accuracy: 0.8550 - val_loss: 0.4578 - val_accuracy: 0.8155
#
# Epoch 00066: val_accuracy did not improve from 0.84492
# Epoch 67/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3493 - accuracy: 0.8357 - val_loss: 0.4412 - val_accuracy: 0.8209
#
# Epoch 00067: val_accuracy did not improve from 0.84492
# Epoch 68/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3363 - accuracy: 0.8452 - val_loss: 0.4538 - val_accuracy: 0.8235
#
# Epoch 00068: val_accuracy did not improve from 0.84492
# Epoch 69/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3328 - accuracy: 0.8659 - val_loss: 0.4634 - val_accuracy: 0.8102
#
# Epoch 00069: val_accuracy did not improve from 0.84492
# Epoch 70/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3378 - accuracy: 0.8546 - val_loss: 0.4371 - val_accuracy: 0.8021
#
# Epoch 00070: val_accuracy did not improve from 0.84492
# Epoch 71/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3242 - accuracy: 0.8595 - val_loss: 0.4461 - val_accuracy: 0.8155
#
# Epoch 00071: val_accuracy did not improve from 0.84492
# Epoch 72/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3330 - accuracy: 0.8717 - val_loss: 0.4240 - val_accuracy: 0.8262
#
# Epoch 00072: val_accuracy did not improve from 0.84492
# Epoch 73/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3176 - accuracy: 0.8796 - val_loss: 0.4557 - val_accuracy: 0.8075
#
# Epoch 00073: val_accuracy did not improve from 0.84492
# Epoch 74/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3547 - accuracy: 0.8379 - val_loss: 0.4396 - val_accuracy: 0.8235
#
# Epoch 00074: val_accuracy did not improve from 0.84492
# Epoch 75/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.3313 - accuracy: 0.8386 - val_loss: 0.4510 - val_accuracy: 0.8235
#
# Epoch 00075: val_accuracy did not improve from 0.84492
# Epoch 76/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2900 - accuracy: 0.8849 - val_loss: 0.4630 - val_accuracy: 0.8128
#
# Epoch 00076: val_accuracy did not improve from 0.84492
# Epoch 77/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3165 - accuracy: 0.8631 - val_loss: 0.4334 - val_accuracy: 0.8342
#
# Epoch 00077: val_accuracy did not improve from 0.84492
# Epoch 78/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2862 - accuracy: 0.8898 - val_loss: 0.4457 - val_accuracy: 0.8235
#
# Epoch 00078: val_accuracy did not improve from 0.84492
# Epoch 79/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2816 - accuracy: 0.8723 - val_loss: 0.4749 - val_accuracy: 0.8102
#
# Epoch 00079: val_accuracy did not improve from 0.84492
# Epoch 80/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2756 - accuracy: 0.8948 - val_loss: 0.4589 - val_accuracy: 0.8289
#
# Epoch 00080: val_accuracy did not improve from 0.84492
# Epoch 81/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3323 - accuracy: 0.8585 - val_loss: 0.4806 - val_accuracy: 0.8102
#
# Epoch 00081: val_accuracy did not improve from 0.84492
# Epoch 82/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2917 - accuracy: 0.8681 - val_loss: 0.4452 - val_accuracy: 0.8316
#
# Epoch 00082: val_accuracy did not improve from 0.84492
# Epoch 83/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2956 - accuracy: 0.8691 - val_loss: 0.4426 - val_accuracy: 0.8316
#
# Epoch 00083: val_accuracy did not improve from 0.84492
# Epoch 84/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2929 - accuracy: 0.8834 - val_loss: 0.4718 - val_accuracy: 0.8182
#
# Epoch 00084: val_accuracy did not improve from 0.84492
# Epoch 85/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2968 - accuracy: 0.8962 - val_loss: 0.4482 - val_accuracy: 0.8075
#
# Epoch 00085: val_accuracy did not improve from 0.84492
# Epoch 86/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2868 - accuracy: 0.8586 - val_loss: 0.4349 - val_accuracy: 0.8155
#
# Epoch 00086: val_accuracy did not improve from 0.84492
# Epoch 87/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3498 - accuracy: 0.8290 - val_loss: 0.4994 - val_accuracy: 0.7888
#
# Epoch 00087: val_accuracy did not improve from 0.84492
# Epoch 88/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3331 - accuracy: 0.8767 - val_loss: 0.4645 - val_accuracy: 0.7968
#
# Epoch 00088: val_accuracy did not improve from 0.84492
# Epoch 89/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2526 - accuracy: 0.8933 - val_loss: 0.4683 - val_accuracy: 0.8209
#
# Epoch 00089: val_accuracy did not improve from 0.84492
# Epoch 90/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2849 - accuracy: 0.8781 - val_loss: 0.4790 - val_accuracy: 0.8075
#
# Epoch 00090: val_accuracy did not improve from 0.84492
# Epoch 91/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2938 - accuracy: 0.8687 - val_loss: 0.4786 - val_accuracy: 0.8021
#
# Epoch 00091: val_accuracy did not improve from 0.84492
# Epoch 92/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3056 - accuracy: 0.8590 - val_loss: 0.4902 - val_accuracy: 0.8021
#
# Epoch 00092: val_accuracy did not improve from 0.84492
# Epoch 93/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3029 - accuracy: 0.8674 - val_loss: 0.4593 - val_accuracy: 0.8422
#
# Epoch 00093: val_accuracy did not improve from 0.84492
# Epoch 94/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2714 - accuracy: 0.8762 - val_loss: 0.4797 - val_accuracy: 0.8155
#
# Epoch 00094: val_accuracy did not improve from 0.84492
# Epoch 95/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2857 - accuracy: 0.8824 - val_loss: 0.5255 - val_accuracy: 0.7834
#
# Epoch 00095: val_accuracy did not improve from 0.84492
# Epoch 96/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3001 - accuracy: 0.8808 - val_loss: 0.5656 - val_accuracy: 0.7674
#
# Epoch 00096: val_accuracy did not improve from 0.84492
# Epoch 97/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2803 - accuracy: 0.8943 - val_loss: 0.5514 - val_accuracy: 0.7647
#
# Epoch 00097: val_accuracy did not improve from 0.84492
# Epoch 98/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2691 - accuracy: 0.8987 - val_loss: 0.4681 - val_accuracy: 0.8289
#
# Epoch 00098: val_accuracy did not improve from 0.84492
# Epoch 99/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3018 - accuracy: 0.8791 - val_loss: 0.4891 - val_accuracy: 0.8128
#
# Epoch 00099: val_accuracy did not improve from 0.84492
# Epoch 100/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3028 - accuracy: 0.8699 - val_loss: 0.4853 - val_accuracy: 0.8289
#
# Epoch 00100: val_accuracy did not improve from 0.84492

# %%
# how to get the keys in your model
# for key in hist.history:
#   print(key)

# %%
# test model
#test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)

# %%
#len(test_predict)

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 30ms/step - loss: 0.5570 - accuracy: 0.7879

# %% [markdown]
# #### Fine Tuning

# %%
# 0 to 72 = Till Conv11
# 73 to 79 - Conv12
# 80 to 85 = Conv13
# 86 to 91 = Post Conv13 before Custom (GAP...)
# 92 to 94 = Custom (Dense/Dropout/Dense(2)) = Trainable 
for layer in model_mn.layers[:80]:
    layer.trainable=False
for layer in model_mn.layers[80:]:
    layer.trainable=True

# train and validate model
hist = model_mn.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels), callbacks=[checkpoint(path_to_mobilenet_parameters_file)])
# Out:
# Epoch 1/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3297 - accuracy: 0.8545 - val_loss: 0.4513 - val_accuracy: 0.8155
#
# Epoch 00001: val_accuracy improved from -inf to 0.81551, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 2/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3242 - accuracy: 0.8558 - val_loss: 0.4819 - val_accuracy: 0.7888
#
# Epoch 00002: val_accuracy did not improve from 0.81551
# Epoch 3/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3374 - accuracy: 0.8584 - val_loss: 0.4208 - val_accuracy: 0.8182
#
# Epoch 00003: val_accuracy improved from 0.81551 to 0.81818, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 4/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3284 - accuracy: 0.8442 - val_loss: 0.4472 - val_accuracy: 0.8235
#
# Epoch 00004: val_accuracy improved from 0.81818 to 0.82353, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 5/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3216 - accuracy: 0.8494 - val_loss: 0.4179 - val_accuracy: 0.8316
#
# Epoch 00005: val_accuracy improved from 0.82353 to 0.83155, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 6/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3427 - accuracy: 0.8519 - val_loss: 0.4561 - val_accuracy: 0.7914
#
# Epoch 00006: val_accuracy did not improve from 0.83155
# Epoch 7/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3241 - accuracy: 0.8610 - val_loss: 0.4324 - val_accuracy: 0.8155
#
# Epoch 00007: val_accuracy did not improve from 0.83155
# Epoch 8/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3005 - accuracy: 0.8701 - val_loss: 0.4542 - val_accuracy: 0.8182
#
# Epoch 00008: val_accuracy did not improve from 0.83155
# Epoch 9/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3155 - accuracy: 0.8545 - val_loss: 0.4779 - val_accuracy: 0.8021
#
# Epoch 00009: val_accuracy did not improve from 0.83155
# Epoch 10/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3230 - accuracy: 0.8558 - val_loss: 0.4603 - val_accuracy: 0.7995
#
# Epoch 00010: val_accuracy did not improve from 0.83155
# Epoch 11/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3098 - accuracy: 0.8779 - val_loss: 0.4646 - val_accuracy: 0.8048
#
# Epoch 00011: val_accuracy did not improve from 0.83155
# Epoch 12/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3326 - accuracy: 0.8519 - val_loss: 0.4367 - val_accuracy: 0.8289
#
# Epoch 00012: val_accuracy did not improve from 0.83155
# Epoch 13/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3044 - accuracy: 0.8792 - val_loss: 0.4786 - val_accuracy: 0.8209
#
# Epoch 00013: val_accuracy did not improve from 0.83155
# Epoch 14/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2990 - accuracy: 0.8662 - val_loss: 0.4568 - val_accuracy: 0.8235
#
# Epoch 00014: val_accuracy did not improve from 0.83155
# Epoch 15/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2982 - accuracy: 0.8662 - val_loss: 0.4765 - val_accuracy: 0.8102
#
# Epoch 00015: val_accuracy did not improve from 0.83155
# Epoch 16/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3033 - accuracy: 0.8714 - val_loss: 0.4534 - val_accuracy: 0.8262
#
# Epoch 00016: val_accuracy did not improve from 0.83155
# Epoch 17/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3092 - accuracy: 0.8597 - val_loss: 0.4566 - val_accuracy: 0.8155
#
# Epoch 00017: val_accuracy did not improve from 0.83155
# Epoch 18/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3022 - accuracy: 0.8701 - val_loss: 0.5248 - val_accuracy: 0.7968
#
# Epoch 00018: val_accuracy did not improve from 0.83155
# Epoch 19/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3050 - accuracy: 0.8792 - val_loss: 0.5289 - val_accuracy: 0.7781
#
# Epoch 00019: val_accuracy did not improve from 0.83155
# Epoch 20/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3081 - accuracy: 0.8701 - val_loss: 0.4747 - val_accuracy: 0.8048
#
# Epoch 00020: val_accuracy did not improve from 0.83155
# Epoch 21/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3223 - accuracy: 0.8545 - val_loss: 0.4317 - val_accuracy: 0.8289
#
# Epoch 00021: val_accuracy did not improve from 0.83155
# Epoch 22/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3125 - accuracy: 0.8714 - val_loss: 0.4733 - val_accuracy: 0.8155
#
# Epoch 00022: val_accuracy did not improve from 0.83155
# Epoch 23/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2774 - accuracy: 0.8805 - val_loss: 0.4664 - val_accuracy: 0.8155
#
# Epoch 00023: val_accuracy did not improve from 0.83155
# Epoch 24/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2908 - accuracy: 0.8662 - val_loss: 0.5031 - val_accuracy: 0.7888
#
# Epoch 00024: val_accuracy did not improve from 0.83155
# Epoch 25/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2971 - accuracy: 0.8779 - val_loss: 0.5018 - val_accuracy: 0.8102
#
# Epoch 00025: val_accuracy did not improve from 0.83155
# Epoch 26/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2868 - accuracy: 0.8740 - val_loss: 0.4923 - val_accuracy: 0.8048
#
# Epoch 00026: val_accuracy did not improve from 0.83155
# Epoch 27/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.3010 - accuracy: 0.8740 - val_loss: 0.5082 - val_accuracy: 0.8021
#
# Epoch 00027: val_accuracy did not improve from 0.83155
# Epoch 28/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3037 - accuracy: 0.8610 - val_loss: 0.4695 - val_accuracy: 0.8262
#
# Epoch 00028: val_accuracy did not improve from 0.83155
# Epoch 29/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2852 - accuracy: 0.8766 - val_loss: 0.5086 - val_accuracy: 0.8021
#
# Epoch 00029: val_accuracy did not improve from 0.83155
# Epoch 30/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2788 - accuracy: 0.8831 - val_loss: 0.4892 - val_accuracy: 0.7968
#
# Epoch 00030: val_accuracy did not improve from 0.83155
# Epoch 31/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2811 - accuracy: 0.8779 - val_loss: 0.4789 - val_accuracy: 0.8102
#
# Epoch 00031: val_accuracy did not improve from 0.83155
# Epoch 32/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2722 - accuracy: 0.8805 - val_loss: 0.5223 - val_accuracy: 0.8021
#
# Epoch 00032: val_accuracy did not improve from 0.83155
# Epoch 33/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2926 - accuracy: 0.8753 - val_loss: 0.5416 - val_accuracy: 0.7754
#
# Epoch 00033: val_accuracy did not improve from 0.83155
# Epoch 34/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.3179 - accuracy: 0.8649 - val_loss: 0.4376 - val_accuracy: 0.8182
#
# Epoch 00034: val_accuracy did not improve from 0.83155
# Epoch 35/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2942 - accuracy: 0.8792 - val_loss: 0.4748 - val_accuracy: 0.8209
#
# Epoch 00035: val_accuracy did not improve from 0.83155
# Epoch 36/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2814 - accuracy: 0.8753 - val_loss: 0.5343 - val_accuracy: 0.7861
#
# Epoch 00036: val_accuracy did not improve from 0.83155
# Epoch 37/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2836 - accuracy: 0.8805 - val_loss: 0.4885 - val_accuracy: 0.8422
#
# Epoch 00037: val_accuracy improved from 0.83155 to 0.84225, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenet.hdf5
# Epoch 38/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2947 - accuracy: 0.8623 - val_loss: 0.4519 - val_accuracy: 0.8396
#
# Epoch 00038: val_accuracy did not improve from 0.84225
# Epoch 39/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2775 - accuracy: 0.8935 - val_loss: 0.4790 - val_accuracy: 0.8155
#
# Epoch 00039: val_accuracy did not improve from 0.84225
# Epoch 40/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2666 - accuracy: 0.8870 - val_loss: 0.4767 - val_accuracy: 0.8316
#
# Epoch 00040: val_accuracy did not improve from 0.84225
# Epoch 41/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2630 - accuracy: 0.9000 - val_loss: 0.5464 - val_accuracy: 0.8048
#
# Epoch 00041: val_accuracy did not improve from 0.84225
# Epoch 42/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2707 - accuracy: 0.8766 - val_loss: 0.5057 - val_accuracy: 0.8235
#
# Epoch 00042: val_accuracy did not improve from 0.84225
# Epoch 43/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2925 - accuracy: 0.8714 - val_loss: 0.5385 - val_accuracy: 0.8128
#
# Epoch 00043: val_accuracy did not improve from 0.84225
# Epoch 44/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2945 - accuracy: 0.8727 - val_loss: 0.4926 - val_accuracy: 0.8048
#
# Epoch 00044: val_accuracy did not improve from 0.84225
# Epoch 45/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2880 - accuracy: 0.8740 - val_loss: 0.5717 - val_accuracy: 0.7914
#
# Epoch 00045: val_accuracy did not improve from 0.84225
# Epoch 46/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2697 - accuracy: 0.8792 - val_loss: 0.5110 - val_accuracy: 0.8102
#
# Epoch 00046: val_accuracy did not improve from 0.84225
# Epoch 47/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2792 - accuracy: 0.8870 - val_loss: 0.5245 - val_accuracy: 0.7995
#
# Epoch 00047: val_accuracy did not improve from 0.84225
# Epoch 48/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2733 - accuracy: 0.8766 - val_loss: 0.5436 - val_accuracy: 0.7995
#
# Epoch 00048: val_accuracy did not improve from 0.84225
# Epoch 49/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2634 - accuracy: 0.8753 - val_loss: 0.5169 - val_accuracy: 0.7968
#
# Epoch 00049: val_accuracy did not improve from 0.84225
# Epoch 50/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2810 - accuracy: 0.8766 - val_loss: 0.4977 - val_accuracy: 0.8128
#
# Epoch 00050: val_accuracy did not improve from 0.84225
# Epoch 51/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2639 - accuracy: 0.8779 - val_loss: 0.5066 - val_accuracy: 0.8102
#
# Epoch 00051: val_accuracy did not improve from 0.84225
# Epoch 52/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2466 - accuracy: 0.8987 - val_loss: 0.5536 - val_accuracy: 0.8075
#
# Epoch 00052: val_accuracy did not improve from 0.84225
# Epoch 53/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2663 - accuracy: 0.9026 - val_loss: 0.5007 - val_accuracy: 0.8262
#
# Epoch 00053: val_accuracy did not improve from 0.84225
# Epoch 54/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2785 - accuracy: 0.8610 - val_loss: 0.5531 - val_accuracy: 0.8021
#
# Epoch 00054: val_accuracy did not improve from 0.84225
# Epoch 55/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2458 - accuracy: 0.8935 - val_loss: 0.5079 - val_accuracy: 0.8235
#
# Epoch 00055: val_accuracy did not improve from 0.84225
# Epoch 56/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2892 - accuracy: 0.8649 - val_loss: 0.5362 - val_accuracy: 0.8048
#
# Epoch 00056: val_accuracy did not improve from 0.84225
# Epoch 57/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2661 - accuracy: 0.8974 - val_loss: 0.5674 - val_accuracy: 0.7968
#
# Epoch 00057: val_accuracy did not improve from 0.84225
# Epoch 58/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2733 - accuracy: 0.8792 - val_loss: 0.5313 - val_accuracy: 0.8128
#
# Epoch 00058: val_accuracy did not improve from 0.84225
# Epoch 59/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2453 - accuracy: 0.8896 - val_loss: 0.5834 - val_accuracy: 0.7941
#
# Epoch 00059: val_accuracy did not improve from 0.84225
# Epoch 60/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2605 - accuracy: 0.8844 - val_loss: 0.5805 - val_accuracy: 0.8048
#
# Epoch 00060: val_accuracy did not improve from 0.84225
# Epoch 61/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2543 - accuracy: 0.9000 - val_loss: 0.5481 - val_accuracy: 0.8075
#
# Epoch 00061: val_accuracy did not improve from 0.84225
# Epoch 62/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2516 - accuracy: 0.8857 - val_loss: 0.6029 - val_accuracy: 0.7968
#
# Epoch 00062: val_accuracy did not improve from 0.84225
# Epoch 63/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2604 - accuracy: 0.8792 - val_loss: 0.5281 - val_accuracy: 0.8209
#
# Epoch 00063: val_accuracy did not improve from 0.84225
# Epoch 64/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2985 - accuracy: 0.8948 - val_loss: 0.4953 - val_accuracy: 0.8128
#
# Epoch 00064: val_accuracy did not improve from 0.84225
# Epoch 65/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2610 - accuracy: 0.8935 - val_loss: 0.6143 - val_accuracy: 0.7754
#
# Epoch 00065: val_accuracy did not improve from 0.84225
# Epoch 66/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2561 - accuracy: 0.8922 - val_loss: 0.5370 - val_accuracy: 0.8342
#
# Epoch 00066: val_accuracy did not improve from 0.84225
# Epoch 67/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2430 - accuracy: 0.8987 - val_loss: 0.5759 - val_accuracy: 0.7861
#
# Epoch 00067: val_accuracy did not improve from 0.84225
# Epoch 68/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2395 - accuracy: 0.8935 - val_loss: 0.5498 - val_accuracy: 0.8048
#
# Epoch 00068: val_accuracy did not improve from 0.84225
# Epoch 69/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2525 - accuracy: 0.8961 - val_loss: 0.8080 - val_accuracy: 0.7380
#
# Epoch 00069: val_accuracy did not improve from 0.84225
# Epoch 70/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2511 - accuracy: 0.8753 - val_loss: 0.5998 - val_accuracy: 0.7995
#
# Epoch 00070: val_accuracy did not improve from 0.84225
# Epoch 71/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2607 - accuracy: 0.8922 - val_loss: 0.5612 - val_accuracy: 0.8102
#
# Epoch 00071: val_accuracy did not improve from 0.84225
# Epoch 72/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2501 - accuracy: 0.8961 - val_loss: 0.5782 - val_accuracy: 0.7888
#
# Epoch 00072: val_accuracy did not improve from 0.84225
# Epoch 73/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2605 - accuracy: 0.8935 - val_loss: 0.5761 - val_accuracy: 0.8021
#
# Epoch 00073: val_accuracy did not improve from 0.84225
# Epoch 74/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2461 - accuracy: 0.8935 - val_loss: 0.6034 - val_accuracy: 0.7888
#
# Epoch 00074: val_accuracy did not improve from 0.84225
# Epoch 75/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2637 - accuracy: 0.8883 - val_loss: 0.5671 - val_accuracy: 0.7941
#
# Epoch 00075: val_accuracy did not improve from 0.84225
# Epoch 76/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2261 - accuracy: 0.9026 - val_loss: 0.5472 - val_accuracy: 0.8262
#
# Epoch 00076: val_accuracy did not improve from 0.84225
# Epoch 77/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2238 - accuracy: 0.9039 - val_loss: 0.5957 - val_accuracy: 0.7941
#
# Epoch 00077: val_accuracy did not improve from 0.84225
# Epoch 78/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2314 - accuracy: 0.9117 - val_loss: 0.6060 - val_accuracy: 0.7968
#
# Epoch 00078: val_accuracy did not improve from 0.84225
# Epoch 79/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2335 - accuracy: 0.8935 - val_loss: 0.6343 - val_accuracy: 0.7995
#
# Epoch 00079: val_accuracy did not improve from 0.84225
# Epoch 80/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2598 - accuracy: 0.8922 - val_loss: 0.6077 - val_accuracy: 0.8075
#
# Epoch 00080: val_accuracy did not improve from 0.84225
# Epoch 81/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2427 - accuracy: 0.8974 - val_loss: 0.5756 - val_accuracy: 0.8128
#
# Epoch 00081: val_accuracy did not improve from 0.84225
# Epoch 82/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2246 - accuracy: 0.8948 - val_loss: 0.5979 - val_accuracy: 0.7995
#
# Epoch 00082: val_accuracy did not improve from 0.84225
# Epoch 83/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2159 - accuracy: 0.9013 - val_loss: 0.5853 - val_accuracy: 0.8075
#
# Epoch 00083: val_accuracy did not improve from 0.84225
# Epoch 84/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2387 - accuracy: 0.8948 - val_loss: 0.6058 - val_accuracy: 0.7968
#
# Epoch 00084: val_accuracy did not improve from 0.84225
# Epoch 85/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2574 - accuracy: 0.8974 - val_loss: 0.5660 - val_accuracy: 0.7968
#
# Epoch 00085: val_accuracy did not improve from 0.84225
# Epoch 86/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2411 - accuracy: 0.9078 - val_loss: 0.5802 - val_accuracy: 0.8155
#
# Epoch 00086: val_accuracy did not improve from 0.84225
# Epoch 87/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2192 - accuracy: 0.9091 - val_loss: 0.5761 - val_accuracy: 0.8102
#
# Epoch 00087: val_accuracy did not improve from 0.84225
# Epoch 88/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2185 - accuracy: 0.9169 - val_loss: 0.5814 - val_accuracy: 0.8262
#
# Epoch 00088: val_accuracy did not improve from 0.84225
# Epoch 89/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2499 - accuracy: 0.8948 - val_loss: 0.6087 - val_accuracy: 0.7941
#
# Epoch 00089: val_accuracy did not improve from 0.84225
# Epoch 90/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2323 - accuracy: 0.8961 - val_loss: 0.5744 - val_accuracy: 0.8128
#
# Epoch 00090: val_accuracy did not improve from 0.84225
# Epoch 91/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2195 - accuracy: 0.8948 - val_loss: 0.6192 - val_accuracy: 0.7941
#
# Epoch 00091: val_accuracy did not improve from 0.84225
# Epoch 92/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2399 - accuracy: 0.8857 - val_loss: 0.5386 - val_accuracy: 0.8182
#
# Epoch 00092: val_accuracy did not improve from 0.84225
# Epoch 93/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2217 - accuracy: 0.8935 - val_loss: 0.5825 - val_accuracy: 0.8075
#
# Epoch 00093: val_accuracy did not improve from 0.84225
# Epoch 94/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2362 - accuracy: 0.9104 - val_loss: 0.5786 - val_accuracy: 0.7941
#
# Epoch 00094: val_accuracy did not improve from 0.84225
# Epoch 95/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2094 - accuracy: 0.9130 - val_loss: 0.5595 - val_accuracy: 0.8316
#
# Epoch 00095: val_accuracy did not improve from 0.84225
# Epoch 96/100
# 77/77 [==============================] - 1s 18ms/step - loss: 0.2292 - accuracy: 0.9130 - val_loss: 0.5387 - val_accuracy: 0.8235
#
# Epoch 00096: val_accuracy did not improve from 0.84225
# Epoch 97/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2474 - accuracy: 0.8935 - val_loss: 0.5384 - val_accuracy: 0.7995
#
# Epoch 00097: val_accuracy did not improve from 0.84225
# Epoch 98/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2051 - accuracy: 0.9117 - val_loss: 0.5929 - val_accuracy: 0.8048
#
# Epoch 00098: val_accuracy did not improve from 0.84225
# Epoch 99/100
# 77/77 [==============================] - 1s 19ms/step - loss: 0.2255 - accuracy: 0.9091 - val_loss: 0.5969 - val_accuracy: 0.7941
#
# Epoch 00099: val_accuracy did not improve from 0.84225
# Epoch 100/100
# 77/77 [==============================] - 1s 17ms/step - loss: 0.2027 - accuracy: 0.9169 - val_loss: 0.5595 - val_accuracy: 0.8182
#
# Epoch 00100: val_accuracy did not improve from 0.84225

# %%
# test with best model
#model_mn.load_weights('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_model.hdf5')
model_mn.load_weights(path_to_mobilenet_parameters_file)
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
test_loss_mn, test_acc_mn = model_mn.evaluate(test_images, test_labels)
# Out:
# 37/37 [==============================] - 1s 27ms/step - loss: 0.6874 - accuracy: 0.7775

# %%
model_mn.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1, 1, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 1, 1, 1024)        0
# _________________________________________________________________
# conv_preds (Conv2D)          (None, 1, 1, 1000)        1025000
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 1000)              0
# _________________________________________________________________
# predictions (Activation)     (None, 1000)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 4,767,402
# Trainable params: 2,600,426
# Non-trainable params: 2,166,976
# _________________________________________________________________

# %% [markdown]
# ### SqueezeNet

# %% [markdown]
# will continue on SqueezeNet as future work.
