# %% [markdown]
# **Clinical Heart Failure Detection Using Whole-Slide Images of H&E tissue**

# %% [markdown]
# **Download Train, Validate and Test Images**

# %% [markdown]
# - Source Link to the Dataset / Annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Follow the instructions at following link, install IBM Aspera Desktop Client to download the dataset.
# - Copy downloaded folders to '**data/images**' folder in your working directory where you have this Jupyter Notebook:
#   - 'held-out_validation'
#   - 'training'

# %% [markdown]
# **Download Label Information for Train, Validate and Test Images**

# %% [markdown]
# - Following link will point to below Github link which has the annotation File: https://idr.openmicroscopy.org/webclient/?show=project-402
# - Source Link for the Annotation File: https://github.com/IDR/idr0042-nirschl-wsideeplearning/tree/master/experimentA
# - Download and copy file '**idr0042-experimentA-annotation.csv**' to '**data/labels/**' folder in your working directory where you have this Jupyter Notebook

# %% [markdown]
# **Understand Images Folder Structure and Number of Images Available**

# %% [markdown]
# Training/Validation
# - \..\training\fold_1: has images for training = 770#
# - \..\training\test_fold_1: has images for validation = 374#
# - Total = 770 + 374 = 1144 images
#
# Test
# - \..\held-out_validation: has images for testing = 1155#

# %% [markdown]
# **Understand Annotation File and Label Information Available**

# %% [markdown]
# Relevant columns of interest:
# - Column A: Dataset Name: Classifies each row/instance as 'training' or 'test'
# - Column B: Image Name: Specifies filename of the image for the row/instance
# - Column Z: Experimental Condition [Diagnosis]: has 3 classes:
#   - 'chronic heart failure'
#   - 'heart tissue pathology' - We will treat this as 'not chronic heart failure'
#   - 'not chronic heart failure'
# - Column AA: Channels: mentions RGB => images are color images and will have 3 channels Red/Green/Blue (for CNN).
#
# Breakup of training/test instances:
# - training
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 627
# - test
#   - 'chronic heart failure' = 517
#   - 'not chronic heart failure' = 638
#
# Total 'training' = 517 + 627 = 1144  (Note: 'validate' is a portion of this 'training' set.)
#
# Total 'test' = 517 + 638 = 1155

# %% [markdown]
# **Load Common Libraries**

# %%
# install OpenCV package - this is required only once
# pip install opencv-python

# %%
# aids in reading image files
import cv2
import glob
# aids in working with arrays
import numpy as np
# aids in working with dataframes
import pandas as pd
# aids in calculation of time
import time
# aids in converting the labels to categorical
from keras.utils import to_categorical

# %%
pip install keras-flops
# Out:
# Collecting keras-flops
#   Downloading https://files.pythonhosted.org/packages/bc/77/e384f6e427e1920624a9229b411010eaa244134cff6a230d303d3b1ea0be/keras_flops-0.1.2-py3-none-any.whl
# Requirement already satisfied: tensorflow<3.0,>=2.2 in /usr/local/lib/python3.6/dist-packages (from keras-flops) (2.4.1)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.2.0)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.4.0)
# Requirement already satisfied: six~=1.15.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.15.0)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.36.2)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.3.3)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.12)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (0.10.0)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.19.5)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.7.4.3)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.12.4)
# Requirement already satisfied: grpcio~=1.32.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.32.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.1.2)
# Requirement already satisfied: h5py~=2.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.10.0)
# Requirement already satisfied: tensorboard~=2.4 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (2.4.1)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (1.6.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow<3.0,>=2.2->keras-flops) (3.3.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.9.2->tensorflow<3.0,>=2.2->keras-flops) (53.0.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.4.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.3.3)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.25.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.8.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (2.10)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (1.3.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.4.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (4.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (4.7)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (3.4.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow<3.0,>=2.2->keras-flops) (0.4.8)
# Installing collected packages: keras-flops
# Successfully installed keras-flops-0.1.2

# %%
# aids in calculation of flops of the model
from keras_flops import get_flops

# %% [markdown]
# **Mount Google Drive**

# %% [markdown]
# We need to mount the google drive so that we can then access the files from google drive.

# %%
# run this. click on the link it will ask for. get the authentication code. Copy/Paste in the cell. Hit Enter.
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# **Get labels info into a dataframe**

# %% [markdown]
# We need to import the annotation file into a dataframe so that we can then access the labels information.

# %%
# Google Drive / Colab
filepath_annotation_file = r'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/labels/idr0042-experimentA-annotation.csv'
labels = pd.read_csv(filepath_annotation_file)

# Local Drive / Jupyter
# labels = pd.read_csv('data/labels/idr0042-experimentA-annotation.csv')

# %%
### for understanding purposes ###
print(labels)
print(type(labels))
print(labels['Dataset Name'])
print(labels['Dataset Name'][0])
type(labels['Dataset Name'][0])
print(labels['Image Name'])
print(labels['Image Name'][0])
type(labels['Image Name'][0])
print(labels['Experimental Condition [Diagnosis]'])
print(labels['Experimental Condition [Diagnosis]'][0])
type(labels['Experimental Condition [Diagnosis]'][0])
# confirm 'no info' cells have been encoded as 'nan'... check one entry
print(labels['Characteristics [Disease Subtype]'][463])
### for understanding purposes ###
# Out:
#      Dataset Name  ... Channels
# 0        training  ...      RGB
# 1        training  ...      RGB
# 2        training  ...      RGB
# 3        training  ...      RGB
# 4        training  ...      RGB
# ...           ...  ...      ...
# 2294         test  ...      RGB
# 2295         test  ...      RGB
# 2296         test  ...      RGB
# 2297         test  ...      RGB
# 2298         test  ...      RGB
#
# [2299 rows x 27 columns]
# <class 'pandas.core.frame.DataFrame'>
# 0       training
# 1       training
# 2       training
# 3       training
# 4       training
#           ...
# 2294        test
# 2295        test
# 2296        test
# 2297        test
# 2298        test
# Name: Dataset Name, Length: 2299, dtype: object
# training
# 0       33381_0_fal_10_0.png
# 1       33381_0_fal_14_0.png
# 2       33381_0_fal_16_0.png
# 3       33381_0_fal_18_0.png
# 4       33381_0_fal_25_0.png
#                 ...
# 2294    36175_1_nrm_18_0.png
# 2295     36175_1_nrm_1_0.png
# 2296    36175_1_nrm_20_0.png
# 2297    36175_1_nrm_21_0.png
# 2298     36175_1_nrm_2_0.png
# Name: Image Name, Length: 2299, dtype: object
# 33381_0_fal_10_0.png
# 0           chronic heart failure
# 1           chronic heart failure
# 2           chronic heart failure
# 3           chronic heart failure
# 4           chronic heart failure
#                   ...
# 2294    not chronic heart failure
# 2295    not chronic heart failure
# 2296    not chronic heart failure
# 2297    not chronic heart failure
# 2298    not chronic heart failure
# Name: Experimental Condition [Diagnosis], Length: 2299, dtype: object
# chronic heart failure
# nan

# %% [markdown]
# **Function to prepare images and labels for CNN based Model**

# %% [markdown]
# We need to read 'train, validate and test images' to arrays so that we can then use them to feed to our CNN model. We need to prepare the labels to match to CNN model's expectation. All the images are of type '*.png'. We will read filepath for all "filenames with extension as 'png'" into a list. Here, filepath means 'relative directory + filename'. We will extract filename of the image from the file path. This filename can then be used to get the label information from the annotation file.

# %%
### for understanding purposes ###
# This is useful for Local Drive / Jupyter. This scenario has '\\' between the directory and filename. 
# We can split the string to get directory and filename separately
# directory, filename = filepathlist_train[0].split('\\')
# print(directory)
# print(filename)
### for understanding purposes ###

# %%
### for understanding purposes ###
# Google Drive / Colab
filepathlist_train = glob.glob('/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png')
# confirm you have got the total number of desired items in the list
print(len(filepathlist_train))
# check what an element in the filelist contain.
# it has both directory information and the filename, we need to extract filename 
# the filename can then be used to check for the label info in the labels dataframe
print(filepathlist_train[0])
print(len(filepathlist_train[0]))
print(filepathlist_train[0][-19:])
print(filepathlist_train[0][len(filepathlist_train[0]) - 1])
print(filepathlist_train[0][-1])
### for understanding purposes ###
# Out:
# 770
# /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/33392_0_fal_4_0.png
# 128
# 33392_0_fal_4_0.png
# g
# g

# %%
### for understanding purposes ###
# POC to get filename for a given filepath
idx = -1
while (filepathlist_train[0][idx] != '/'):
  idx = idx - 1 
# index currently points to '/' location, we need to start reading from next location to get file name
print(idx)
filename = filepathlist_train[0][idx + 1:]
print(filename)
### for understanding purposes ###
# Out:
# -20
# 33392_0_fal_4_0.png

# %%
### for understanding purposes ###
# POC to iterate over multiple filepaths
index_filepathlist = 0
for filepath in filepathlist_train:
    #print(index_filepathlist, filepath)
    index_filepathlist += 1
### for understanding purposes ###

# %%
### for understanding purposes ###
# read a file using the list containing the file path
img = cv2.imread(filepathlist_train[0])
### for understanding purposes ###

# %%
# function to count ones and zeroes in the label array
def print_ones_zeroes (labels):
  count_ones = 0
  count_zeroes = 0
  for i in range(len(labels)):
    if (labels[i] == 1):
      count_ones += 1
    elif (labels[i] == 0):
      count_zeroes += 1
  print('Total Labels:',(count_ones + count_zeroes))
  print('# of Class 1:',count_ones)   
  print('# of Class 0:',count_zeroes)

# %%
# function to prepare images & labels for the model
def prepare_images_labels (path_to_img_files, labels_dataframe, resize = True):
  start_time = time.time()
  filepathlist = glob.glob(path_to_img_files)
  # define the empty list that need to populated with info
  images = []
  labels = []
  index_filepathlist = 0
  # iterate for all items in the file path list
  for filepath in filepathlist:
      # prepare image list
      img = cv2.imread(filepath)
      if (resize == True):
        dim = (224,224)
        img = cv2.resize(img, dim)#, interpolation = inter)
      images.append(img)
      # prepare labels list
      # extract filename from the file path
      # Local Drive / Jupyter
      # directory, filename = filepath.split('\\')
      # Google Drive / Colab
      index_character = -1
      while (filepathlist[index_filepathlist][index_character] != '/'):
        index_character = index_character - 1 
      # character index currently points to '/' location, we need to start reading from next location to get file name
      filename = filepathlist[index_filepathlist][index_character + 1:]
      index_filepathlist += 1
      # iterate for all items in our labels dataframe to search for the label
      for index in range(len(labels_dataframe)):
          # we will compare the filename with all the filenames in the 'Image Name' column of the labels dataframe
          # when there is a match, we will copy the label from the 'Experimental Condition [Diagnosis]' column
          if (filename == labels_dataframe['Image Name'][index]):
              label = labels_dataframe['Experimental Condition [Diagnosis]'][index]
              # encode Class1 and Class0 as applicable
              if (label == 'chronic heart failure'):
                  label = 1
              elif (label == 'not chronic heart failure'):
                  label = 0
              elif (label == 'heart tissue pathology'):
                  label = 0
              # append the label to the list
              labels.append(label)
  # convert list to a numpy array and the values to float
  images = np.array(images, dtype = 'float32')
  # check the shape to confirm it is ready for CNN
  # number of instances, width, height, number of channels
  # number of instances = number of image
  # number of channels = 3 ... as these are color images
  print('Shape of Images:',images.shape)
  # convert list to a numpy array and the values to int64
  labels = np.array(labels, dtype = 'int64')
  # check the shape to confirm it is ready for CNN
  print('Shape of Labels:', labels.shape)
  print_ones_zeroes(labels)
  duration = time.time() - start_time 
  print(f'Images/Labels Prep Core Time = {duration}s')
  return images, labels

# %% [markdown]
# **Prepare Train Images and Train Labels**

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'
# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/fold_1/*.png'
# Local Drive / Jupyter
# filepathlist_train = glob.glob('data/images/training/fold_1/*.png')
train_images, train_labels = prepare_images_labels (path_to_img_files, labels, True) # resize set to True to resize images to 224 x 224
# save the labels before converting to categorical to use for cross validation splits
train_labels_before_categorical = train_labels
print('train_labels_before_categorical:', type(train_labels_before_categorical), len(train_labels_before_categorical), train_labels_before_categorical.shape)
# convert labels to categorical
train_labels = to_categorical(train_labels)
# Out:
# Shape of Images: (770, 224, 224, 3)
# Shape of Labels: (770,)
# Total Labels: 770
# # of Class 1: 352
# # of Class 0: 418
# Images/Labels Prep Core Time = 13.421767950057983s
# train_labels_before_categorical: <class 'numpy.ndarray'> 770 (770,)

# %% [markdown]
# **Prepare Validation Images and Validation Labels**

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'
# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/training/test_fold_1/*.png'
# Local Drive / Jupyter
# filepathlist_validation = glob.glob('data/images/training/test_fold_1/*.png')
validation_images, validation_labels = prepare_images_labels (path_to_img_files, labels, True) # resize set to True to resize images to 224 x 224
# save the labels before converting to categorical to use for cross validation splits
validation_labels_before_categorical = validation_labels
print('validation_labels_before_categorical:', type(validation_labels_before_categorical), len(validation_labels_before_categorical), validation_labels_before_categorical.shape)
# convert labels to categorical
validation_labels = to_categorical(validation_labels)
# Out:
# Shape of Images: (374, 224, 224, 3)
# Shape of Labels: (374,)
# Total Labels: 374
# # of Class 1: 165
# # of Class 0: 209
# Images/Labels Prep Core Time = 6.551560640335083s
# validation_labels_before_categorical: <class 'numpy.ndarray'> 374 (374,)

# %% [markdown]
# **Prepare Test Images and Test Labels**

# %%
# read filepath for all "filenames with extension as 'png'" into a list
# here filepath means 'relative directory + filename'
# Google Drive / Colab
path_to_img_files = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images /data/images/held-out_validation/*.png'
# Local Drive / Jupyter
# filepathlist_test = glob.glob('data/images/held-out_validation/*.png')
test_images, test_labels = prepare_images_labels (path_to_img_files, labels, True) # resize set to True to resize images to 224 x 224
# save the labels before converting to categorical to use for cross validation splits
test_labels_before_categorical = test_labels
print('test_labels_before_categorical:', type(test_labels_before_categorical), len(test_labels_before_categorical), test_labels_before_categorical.shape)
# convert labels to categorical
test_labels = to_categorical(test_labels)
# Out:
# Shape of Images: (1155, 224, 224, 3)
# Shape of Labels: (1155,)
# Total Labels: 1155
# # of Class 1: 517
# # of Class 0: 638
# Images/Labels Prep Core Time = 20.108590364456177s
# test_labels_before_categorical: <class 'numpy.ndarray'> 1155 (1155,)

# %% [markdown]
# **Prepare All Images and Labels for Cross Validation**

# %%
# confirm all are numpy arrays, length and shape
print('train_images:', type(train_images), len(train_images), train_images.shape)
print('validation_images:', type(validation_images), len(validation_images), validation_images.shape)
#print('test_images:', type(test_images), len(test_images), test_images.shape)
print('Total Images:', len(train_images) + len(validation_images))# + len(test_images))
print('train_labels:', type(train_labels), len(train_labels), train_labels.shape)
print('validation_labels:', type(validation_labels), len(validation_labels), validation_labels.shape)
#print('test_labels:', type(test_labels), len(test_labels), test_labels.shape)
print('Total Labels:', len(train_labels) + len(validation_labels))# + len(test_labels))
# join train / validation / test arrays for images
all_images = np.concatenate((train_images, validation_images))#, test_images))
print('all_images:', type(all_images), len(all_images), all_images.shape)
# join train / validation / test arrays for labels
all_labels = np.concatenate((train_labels, validation_labels))#, test_labels))
print('all_labels:', type(all_labels), len(all_labels), all_labels.shape)
# prepare the labels to enable split during k-cross validation
all_labels_before_categorical = np.concatenate((train_labels_before_categorical, validation_labels_before_categorical))#, test_labels_before_categorical))
print('all_labels_before_categorical;', type(all_labels_before_categorical), len(all_labels_before_categorical), all_labels_before_categorical.shape)
# Out:
# train_images: <class 'numpy.ndarray'> 770 (770, 224, 224, 3)
# validation_images: <class 'numpy.ndarray'> 374 (374, 224, 224, 3)
# Total Images: 1144
# train_labels: <class 'numpy.ndarray'> 770 (770, 2)
# validation_labels: <class 'numpy.ndarray'> 374 (374, 2)
# Total Labels: 1144
# all_images: <class 'numpy.ndarray'> 1144 (1144, 224, 224, 3)
# all_labels: <class 'numpy.ndarray'> 1144 (1144, 2)
# all_labels_before_categorical; <class 'numpy.ndarray'> 1144 (1144,)

# %% [markdown]
# **Define Common Hyperparameters**

# %%
# 1 epoch = 770 / 10 = 77 batches
BATCH_SIZE = 10  
# 1 epoch = 1 complete run of all train samples for training the model
EPOCHS = 100 
LEARNING_RATE = 0.01
DENSE_LAYER_NEURONS = 512
DENSE_LAYER_DROPOUT = 0.4
CROSS_VALIDATE = True
CROSS_VALIDATION_FOLDS = 4 
TOTAL_TEST_SAMPLES = 1155

# MobileNetV1
# set trainable layers starting from 80th layer
# 0 to 72 = Till Conv11 ; # 73 to 79 - Conv12; # 80 to 85 = Conv13 ; # 86 to 91 = Post Conv13 before Custom (GAP...) ; # 92 to 94 = Custom (Dense/Dropout/Dense(2))
MOBILENETV1_TRAINABLE_START_LAYER = 80
# MobileNetV2
MOBILENETV2_TRAINABLE_START_LAYER = 151

# %% [markdown]
# **Function to check values during training**

# %%
from keras.callbacks import ModelCheckpoint
def checkpoint(path_to_model_parameters_file):
  # path_to_model_parameters_file: file to which the weights need to be saved
  # monitor: defines the quantity to monitor ... we will monitor validation accuracy
  # verbose: verbose yes/no
  # save_best_only: true then save weghts else save entire model
  # mode: max if val_acc, min if val_loss, auto decides based on the quantity getting monitored
  # save_freq: save_freq:  specify the frequency in number of batches seen
  # period:  check after every epoch therefore 1
  checkpoint_value = ModelCheckpoint(path_to_model_parameters_file, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max', save_freq = 'epoch') #period=1
  return checkpoint_value

# %% [markdown]
# **Define function to train and validate the model**

# %%
# trains and validates model ... returns trained model, saves the best parameters file in the location provided
def train_and_validate_model(model_name, trn_imgs, trn_lbls, val_imgs, val_lbls, path_to_model_params_file):
  print('Model Train and Validation: Starting')
  start_time = time.time()
  model_name.fit(trn_imgs, trn_lbls, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (val_imgs, val_lbls), 
                 callbacks=[checkpoint(path_to_model_params_file)])
  duration = time.time() - start_time
  print(f'Train and Validation Time = {duration}s')
  print('Model Train and Validation: Completed')
  return model_name

# %% [markdown]
# **Define function to test model with best parameters**

# %%
# test with best model (params from best epoch)
def test_model_with_best_params(model_name, path_to_best_params_file, test_imgs, test_lbls):
  print('Model Test: Starting')
  model_name.load_weights(path_to_best_params_file)
  start_time = time.time()
  test_loss, test_acc = model_name.evaluate(test_imgs, test_lbls)
  duration = time.time() - start_time
  print(f'Test Time = {duration}s')
  print(f'Test Time / sample = {duration/TOTAL_TEST_SAMPLES}s')
  print('Model Test: Completed')
  return model_name

# %% [markdown]
# **Define function to set the trainable layers for the model**

# %%
def set_trainable_layers_starting_from(model_name, trainable_start_layer_number):
  ############################################################################################################################################################################
  # CONFIGURE LAYERS FOR TRAINING #
  print(f'Layers Configuration: Starting')
  for layer in model_name.layers[:trainable_start_layer_number]: 
      layer.trainable=False
  for layer in model_name.layers[trainable_start_layer_number:]: 
      layer.trainable=True
  print(f'Layers Configuration: Completed')
  return model_name
  ############################################################################################################################################################################

# %% [markdown]
# **Define function to cross validate model**

# %%
# cross validate the model and get the path to the file containing best cross validation fold's parameters
def cross_validate_model(model_name, all_imgs, all_lbls, all_lbls_before_categorical, path_to_bestxfr_params_file = 'NULL'):
  ###############################################################################################################################################################################
  # MODEL CROSS VALIDATION #
  print('Model Cross Validation: Starting')
  # perform cross validation
  start_time = time.time()
  # import libraries
  from sklearn.model_selection import StratifiedKFold
  # using stratifiedkfold so that we have balanced classes in each split
  cvfold = StratifiedKFold(n_splits = CROSS_VALIDATION_FOLDS, shuffle = True)
  # we will use below to store all individual validation scores
  cvscores = []
  # initialize variables for the accuracy analysis for various folds  
  fold = 0
  # based on the class value, get the split done and respective train and test index
  for train_index, val_index in cvfold.split(all_imgs, all_lbls_before_categorical):
    if (model_name == 'resnet50xfr'):
      model = define_model_resnet50xfr()
    elif (model_name == 'mobilenetv1xfr'):
      model = define_model_mobilenet('V1')
    elif (model_name == 'mobilenetv1ft'):
      model = define_model_mobilenet('V1')
      set_trainable_layers_starting_from(model, MOBILENETV1_TRAINABLE_START_LAYER)
      model.load_weights(path_to_bestxfr_params_file) 
    elif (model_name == 'mobilenetv2xfr'):
      model = define_model_mobilenet('V2') 
    elif (model_name == 'mobilenetv2ft'):
      model = define_model_mobilenet('V2')
      set_trainable_layers_starting_from(model, MOBILENETV2_TRAINABLE_START_LAYER)
      model.load_weights(path_to_bestxfr_params_file)    
    # train based on train index elements
    #path_to_model_cv_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_cv.hdf5'
    path_to_model_cv_params_file = f'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_{model_name}_cvfold_{fold}.hdf5'
    hist = model.fit(all_imgs[train_index], all_lbls[train_index], epochs = EPOCHS, batch_size = BATCH_SIZE, verbose = 1, 
                     validation_data = (all_imgs[val_index], all_lbls[val_index]), callbacks=[checkpoint(path_to_model_cv_params_file)])
    # get the validation accuracy
    # hist.history['val_accuracy'] is a list ... hence, get the float value using index 0 of the list
    cv_score = hist.history['val_accuracy'][0]
    print("Cross Validation Accuracy: %0.2f%%" % (cv_score*100))
    # append each iteration validation accuracy score
    cvscores.append(cv_score*100)
    # print fold number and increment
    print(f'Fold #{fold} Complete \n')
    fold += 1
  # print mean and std deviation of the validation accuracy for the complete cross validation i.e. for all iterations
  print("Cross Validation Accuracy Mean (+/- Std Deviation): %0.2f%% (+/- %0.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
  # determine best fold
  best_accuracy = 0
  best_fold = 0
  for idx in range(CROSS_VALIDATION_FOLDS):
    if (cvscores[idx] > best_accuracy):
      best_accuracy = cvscores[idx]
      best_fold = idx
  path_to_best_cv_fold_params_file = f'/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_{model_name}_cvfold_{best_fold}.hdf5'
  duration = time.time() - start_time
  print(f'Cross Validation Time = {duration}s')
  print('Model Cross Validation: Completed')
  return path_to_best_cv_fold_params_file
  ###############################################################################################################################################################################

# %% [markdown]
# **How To ...**

# %%
### for understanding purposes ###
# how to get the keys in your model
# for key in hist.history:
#   print(key)

# how to check prediction 
# test_predict = model_mn.predict(test_images, batch_size=10, verbose=0)
# len(test_predict)
### for understanding purposes ###

# %% [markdown]
# **A basic CNN - Model Definition, Train, Validate, Test**

# %% [markdown]
# Let us see the results with a basic CNN - accuracy might not be great, however, we will get an idea of a working CNN model.

# %%
# import libraries
from keras import models
from keras import layers

# %%
# define model
def define_model_basicCNN():
  model = models.Sequential()
  # 2 dimensional convolution for 2D image. relu for non-linearity detection
  model.add(layers.Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)))
  model.add(layers.MaxPooling2D(2,2))
  model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
  model.add(layers.MaxPooling2D(2,2))
  model.add(layers.Conv2D(64, (3,3), activation='relu'))
  # Data at this stage is in matrix form. We will convert it to vector form to feed to a fully connected network (FCN).
  model.add(layers.Flatten())
  # We will design for 64 outputs with activation function as relu (to learn non-linearity).
  model.add(layers.Dense(64, activation = 'relu'))
  # This is the final layer. Hence, the outputs will be 2 corresponding to the 2 classes:
  # clinical heart failure = yes: 1 ; clinical heart failure = no: 0
  # Activation Function chosen here is softmax to have a probabilistic output. 
  model.add(layers.Dense(2, activation = 'softmax'))
  return model

# %%
model_basicCNN = define_model_basicCNN()
# model_basicCNN.summary()

# Define Optimizer, Loss Function and Metrics to be used for the Model
# Going ahead with the well known functions at this point in time
# Selected accuracy as the metrics to understand validation accuracy of the model
model_basicCNN.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# train and validate the model
model_basicCNN.fit(train_images, train_labels, epochs = EPOCHS, batch_size = BATCH_SIZE, validation_data = (validation_images, validation_labels))

# test model
test_loss, test_acc = model_basicCNN.evaluate(test_images, test_labels)
print('test accuracy:', (test_acc*100))
# Out:
# Epoch 1/100
# 77/77 [==============================] - 3s 37ms/step - loss: 151.6156 - accuracy: 0.5401 - val_loss: 0.6935 - val_accuracy: 0.4412
# Epoch 2/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6931 - accuracy: 0.5045 - val_loss: 0.6924 - val_accuracy: 0.5588
# Epoch 3/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6921 - accuracy: 0.5607 - val_loss: 0.6914 - val_accuracy: 0.5588
# Epoch 4/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6914 - accuracy: 0.5562 - val_loss: 0.6907 - val_accuracy: 0.5588
# Epoch 5/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6915 - accuracy: 0.5401 - val_loss: 0.6900 - val_accuracy: 0.5588
# Epoch 6/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6919 - accuracy: 0.5279 - val_loss: 0.6896 - val_accuracy: 0.5588
# Epoch 7/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6911 - accuracy: 0.5368 - val_loss: 0.6891 - val_accuracy: 0.5588
# Epoch 8/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6911 - accuracy: 0.5350 - val_loss: 0.6888 - val_accuracy: 0.5588
# Epoch 9/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6888 - accuracy: 0.5585 - val_loss: 0.6885 - val_accuracy: 0.5588
# Epoch 10/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6892 - accuracy: 0.5515 - val_loss: 0.6882 - val_accuracy: 0.5588
# Epoch 11/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6889 - accuracy: 0.5527 - val_loss: 0.6880 - val_accuracy: 0.5588
# Epoch 12/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6904 - accuracy: 0.5382 - val_loss: 0.6879 - val_accuracy: 0.5588
# Epoch 13/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6898 - accuracy: 0.5437 - val_loss: 0.6877 - val_accuracy: 0.5588
# Epoch 14/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6912 - accuracy: 0.5314 - val_loss: 0.6876 - val_accuracy: 0.5588
# Epoch 15/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6891 - accuracy: 0.5472 - val_loss: 0.6875 - val_accuracy: 0.5588
# Epoch 16/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6920 - accuracy: 0.5255 - val_loss: 0.6874 - val_accuracy: 0.5588
# Epoch 17/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6862 - accuracy: 0.5671 - val_loss: 0.6873 - val_accuracy: 0.5588
# Epoch 18/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6891 - accuracy: 0.5467 - val_loss: 0.6873 - val_accuracy: 0.5588
# Epoch 19/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6902 - accuracy: 0.5386 - val_loss: 0.6872 - val_accuracy: 0.5588
# Epoch 20/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6936 - accuracy: 0.5155 - val_loss: 0.6872 - val_accuracy: 0.5588
# Epoch 21/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6894 - accuracy: 0.5439 - val_loss: 0.6871 - val_accuracy: 0.5588
# Epoch 22/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6899 - accuracy: 0.5409 - val_loss: 0.6871 - val_accuracy: 0.5588
# Epoch 23/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6866 - accuracy: 0.5621 - val_loss: 0.6870 - val_accuracy: 0.5588
# Epoch 24/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6928 - accuracy: 0.5218 - val_loss: 0.6869 - val_accuracy: 0.5588
# Epoch 25/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6841 - accuracy: 0.5763 - val_loss: 0.6869 - val_accuracy: 0.5588
# Epoch 26/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6902 - accuracy: 0.5390 - val_loss: 0.6869 - val_accuracy: 0.5588
# Epoch 27/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6857 - accuracy: 0.5666 - val_loss: 0.6869 - val_accuracy: 0.5588
# Epoch 28/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6934 - accuracy: 0.5189 - val_loss: 0.6869 - val_accuracy: 0.5588
# Epoch 29/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6919 - accuracy: 0.5285 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 30/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6899 - accuracy: 0.5407 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 31/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6883 - accuracy: 0.5504 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 32/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6937 - accuracy: 0.5179 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 33/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6928 - accuracy: 0.5235 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 34/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6861 - accuracy: 0.5626 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 35/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6890 - accuracy: 0.5459 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 36/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6913 - accuracy: 0.5326 - val_loss: 0.6868 - val_accuracy: 0.5588
# Epoch 37/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6899 - accuracy: 0.5403 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 38/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6923 - accuracy: 0.5266 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 39/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6897 - accuracy: 0.5421 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 40/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6869 - accuracy: 0.5583 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 41/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6943 - accuracy: 0.5146 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 42/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6940 - accuracy: 0.5169 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 43/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6916 - accuracy: 0.5311 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 44/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6884 - accuracy: 0.5495 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 45/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6847 - accuracy: 0.5704 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 46/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6839 - accuracy: 0.5749 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 47/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6914 - accuracy: 0.5321 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 48/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6899 - accuracy: 0.5406 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 49/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6898 - accuracy: 0.5410 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 50/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6844 - accuracy: 0.5722 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 51/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6886 - accuracy: 0.5482 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 52/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6870 - accuracy: 0.5571 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 53/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6870 - accuracy: 0.5577 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 54/100
# 77/77 [==============================] - 4s 46ms/step - loss: 0.6888 - accuracy: 0.5473 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 55/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6879 - accuracy: 0.5518 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 56/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6904 - accuracy: 0.5379 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 57/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6881 - accuracy: 0.5512 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 58/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6898 - accuracy: 0.5413 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 59/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6926 - accuracy: 0.5254 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 60/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6889 - accuracy: 0.5466 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 61/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6944 - accuracy: 0.5144 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 62/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6926 - accuracy: 0.5249 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 63/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6944 - accuracy: 0.5143 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 64/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6940 - accuracy: 0.5170 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 65/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6925 - accuracy: 0.5257 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 66/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6833 - accuracy: 0.5786 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 67/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6839 - accuracy: 0.5751 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 68/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6918 - accuracy: 0.5295 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 69/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6884 - accuracy: 0.5495 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 70/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6863 - accuracy: 0.5611 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 71/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6903 - accuracy: 0.5386 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 72/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6911 - accuracy: 0.5334 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 73/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6886 - accuracy: 0.5484 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 74/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6938 - accuracy: 0.5174 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 75/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6955 - accuracy: 0.5080 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 76/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6890 - accuracy: 0.5460 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 77/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6882 - accuracy: 0.5504 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 78/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6851 - accuracy: 0.5680 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 79/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6877 - accuracy: 0.5530 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 80/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6860 - accuracy: 0.5626 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 81/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6893 - accuracy: 0.5440 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 82/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6941 - accuracy: 0.5164 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 83/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6871 - accuracy: 0.5565 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 84/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6916 - accuracy: 0.5309 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 85/100
# 77/77 [==============================] - 3s 33ms/step - loss: 0.6914 - accuracy: 0.5321 - val_loss: 0.6866 - val_accuracy: 0.5588
# Epoch 86/100
# 77/77 [==============================] - 3s 33ms/step - loss: 0.6886 - accuracy: 0.5484 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 87/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6928 - accuracy: 0.5241 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 88/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6925 - accuracy: 0.5258 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 89/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6891 - accuracy: 0.5455 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 90/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6877 - accuracy: 0.5532 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 91/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6864 - accuracy: 0.5606 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 92/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6859 - accuracy: 0.5636 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 93/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6880 - accuracy: 0.5517 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 94/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6896 - accuracy: 0.5424 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 95/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6915 - accuracy: 0.5311 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 96/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6884 - accuracy: 0.5494 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 97/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6891 - accuracy: 0.5452 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 98/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6842 - accuracy: 0.5736 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 99/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6904 - accuracy: 0.5377 - val_loss: 0.6867 - val_accuracy: 0.5588
# Epoch 100/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.6907 - accuracy: 0.5361 - val_loss: 0.6867 - val_accuracy: 0.5588
# 37/37 [==============================] - 1s 22ms/step - loss: 0.6878 - accuracy: 0.5524
# test accuracy: 55.23809790611267

# %% [markdown]
# **ResNet50**

# %% [markdown]
# **ResNet50 Transfer Learning**

# %% [markdown]
# **ResNet50 XFR: Import required libraries**

# %%
###############################################################################################################################################################################
# IMPORT LIBRARIES #
print('ResNet50 XFR / Import Libraries: Starting')
from keras.applications.resnet50 import ResNet50
from keras.layers import Dense, GlobalAveragePooling2D
from keras.models import Model
# from keras.optimizers import SGD
# from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
# from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
print('ResNet50 XFR / Import Libraries: Completed')
###############################################################################################################################################################################
# Out:
# ResNet50 XFR / Import Libraries: Starting
# ResNet50 XFR / Import Libraries: Completed

# %% [markdown]
# **ResNet50 XFR: Define function to define the model**

# %%
def define_model_resnet50xfr():
  ###############################################################################################################################################################################
  # MODEL DEFINITION #
  print('ResNet50 XFR / Model Definition: Starting')
  # load ResNet50 with pre-trained parameters for 'imagenet' challenge
  # disable the last layer ... so that we can have our own FCN layer for our desired classes
  resnet50 = ResNet50(include_top=False, weights='imagenet')

  # define the last layers

  # get the output of the last layer of the ResNet50
  prediction = resnet50.output

  # add a Global Average Pooling layer (GAP) - this helps reduce number of parameters as compared to a flatten/dense layer
  prediction = GlobalAveragePooling2D()(prediction)

  # add a custom FCN  
  # prediction = Dense(1024, activation = 'relu')(prediction)
  # we will split the actions so that we can test Batch Normalization done befor relu
  prediction = Dense(DENSE_LAYER_NEURONS)(prediction)
  # BatchNormalization did not help as the binary classes are balanced, hence commented BatchNormalization 
  # prediction = BatchNormalization()(prediction)
  prediction = Activation('relu')(prediction)
  # add a dropout to avoid overfitting
  prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)

  # add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
  prediction = Dense(2, activation = 'softmax')(prediction)

  # connect the last layers with ResNet50 output layer to define the model
  model = Model(inputs = resnet50.input, outputs = prediction)

  # we wish use the pretrained ResNet50 model as is i.e. do not want it's parameters to get updated during training
  for layer in resnet50.layers:
    layer.trainable = False

  # define the optimizer, loss function, metrics we will use
  # Adam provided better results than SGD, hence commented SGD
  # model.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
  model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

  # run to see layers, number of parameters (total/trainable/non-trainable)
  # model.summary()

  # calculate FLOPS for the model
  flops_resnet50_xfr = get_flops(model, batch_size = 1)
  print(f"ResNet50 XFR FLOPS: {flops_resnet50_xfr / 10 ** 9:.03} G")
  print('ResNet50 XFR / Model Definition: Completed')
  return model
  ###############################################################################################################################################################################

# %% [markdown]
# **ResNet50 XFR: Data Augmentation**

# %% [markdown]
# Tried data augmentation - It did not help improve the accuracy as the binary classes are pretty balanced, hence, commented it off.

# %%
###############################################################################################################################################################################
# DATA AUGMENTATION #
# commented as this did not help improve accuracy
# data augmentation helps change the data slightly so that the model does not overfit
# train_generator = ImageDataGenerator(rotation_range = 8, width_shift_range = 0.08, shear_range = 0.3, height_shift_range = 0.08, zoom_range = 0.08)
# validation_generator = ImageDataGenerator()
# below ensures the augmented data is provided in batches to the model
# train_augmented = train_generator.flow(train_images, train_labels, batch_size = 10)
# validation_augmented = validation_generator.flow(validation_images, validation_labels, batch_size = 10)
# train and validate model with augmented data
# model.fit(train_augmented, epochs = 20, batch_size = 10, validation_data = validation_augmented)
###############################################################################################################################################################################

# %% [markdown]
# **ResNet50 XFR: Train/Validate/Test/Cross Validate the Model**

# %%
print('#########################################################################################################################################')
model_resnet50xfr = define_model_resnet50xfr()
#model_resnet50xfr.summary()
path_to_resnet50xfr_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5'
model_resnet50xfr = train_and_validate_model(model_resnet50xfr, train_images, train_labels, validation_images, validation_labels,path_to_resnet50xfr_params_file)
model_resnet50xfr = test_model_with_best_params(model_resnet50xfr,path_to_resnet50xfr_params_file, test_images, test_labels)
print('#########################################################################################################################################')
if (CROSS_VALIDATE == True):
  # cross validate and get the path to the file containing best cross validation fold's parameters
  path_to_resnet50xfr_best_cv_fold_params_file = cross_validate_model('resnet50xfr', all_images, all_labels, all_labels_before_categorical)
  print(f'Path to Best CV Fold Params: {path_to_resnet50xfr_best_cv_fold_params_file}')
  # define a model, load best cross validation fold params, test
  model_resnet50xfr_cv = define_model_resnet50xfr()
  model_resnet50xfr_cv = test_model_with_best_params(model_resnet50xfr_cv,path_to_resnet50xfr_best_cv_fold_params_file, test_images, test_labels)
# Out:
# #########################################################################################################################################
# ResNet50 XFR / Model Definition: Starting
# ResNet50 XFR FLOPS: 0.0021 G
# ResNet50 XFR / Model Definition: Completed
# Model Train and Validation: Starting
# Epoch 1/100
# 77/77 [==============================] - 9s 83ms/step - loss: 7.4901 - accuracy: 0.5798 - val_loss: 0.5685 - val_accuracy: 0.7086
#
# Epoch 00001: val_accuracy improved from -inf to 0.70856, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 2/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.4404 - accuracy: 0.7956 - val_loss: 0.4847 - val_accuracy: 0.7701
#
# Epoch 00002: val_accuracy improved from 0.70856 to 0.77005, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 3/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.3524 - accuracy: 0.8436 - val_loss: 0.4925 - val_accuracy: 0.7834
#
# Epoch 00003: val_accuracy improved from 0.77005 to 0.78342, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 4/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2979 - accuracy: 0.8763 - val_loss: 0.3718 - val_accuracy: 0.8449
#
# Epoch 00004: val_accuracy improved from 0.78342 to 0.84492, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 5/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2814 - accuracy: 0.8741 - val_loss: 0.4760 - val_accuracy: 0.8128
#
# Epoch 00005: val_accuracy did not improve from 0.84492
# Epoch 6/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2891 - accuracy: 0.8640 - val_loss: 0.3458 - val_accuracy: 0.8690
#
# Epoch 00006: val_accuracy improved from 0.84492 to 0.86898, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 7/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2827 - accuracy: 0.8638 - val_loss: 0.4005 - val_accuracy: 0.8529
#
# Epoch 00007: val_accuracy did not improve from 0.86898
# Epoch 8/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2789 - accuracy: 0.8907 - val_loss: 0.3942 - val_accuracy: 0.8476
#
# Epoch 00008: val_accuracy did not improve from 0.86898
# Epoch 9/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2779 - accuracy: 0.8800 - val_loss: 0.4003 - val_accuracy: 0.8476
#
# Epoch 00009: val_accuracy did not improve from 0.86898
# Epoch 10/100
# 77/77 [==============================] - 6s 78ms/step - loss: 0.2723 - accuracy: 0.8818 - val_loss: 0.4163 - val_accuracy: 0.8021
#
# Epoch 00010: val_accuracy did not improve from 0.86898
# Epoch 11/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.3533 - accuracy: 0.8343 - val_loss: 0.3925 - val_accuracy: 0.8422
#
# Epoch 00011: val_accuracy did not improve from 0.86898
# Epoch 12/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.3932 - accuracy: 0.8072 - val_loss: 0.5085 - val_accuracy: 0.8075
#
# Epoch 00012: val_accuracy did not improve from 0.86898
# Epoch 13/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.3137 - accuracy: 0.8418 - val_loss: 0.4066 - val_accuracy: 0.8396
#
# Epoch 00013: val_accuracy did not improve from 0.86898
# Epoch 14/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2517 - accuracy: 0.8860 - val_loss: 0.4429 - val_accuracy: 0.8075
#
# Epoch 00014: val_accuracy did not improve from 0.86898
# Epoch 15/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.3671 - accuracy: 0.8595 - val_loss: 0.4838 - val_accuracy: 0.8449
#
# Epoch 00015: val_accuracy did not improve from 0.86898
# Epoch 16/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.3999 - accuracy: 0.8441 - val_loss: 0.4752 - val_accuracy: 0.8262
#
# Epoch 00016: val_accuracy did not improve from 0.86898
# Epoch 17/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2663 - accuracy: 0.8901 - val_loss: 0.4195 - val_accuracy: 0.8636
#
# Epoch 00017: val_accuracy did not improve from 0.86898
# Epoch 18/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2519 - accuracy: 0.8926 - val_loss: 0.4400 - val_accuracy: 0.8529
#
# Epoch 00018: val_accuracy did not improve from 0.86898
# Epoch 19/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2368 - accuracy: 0.8943 - val_loss: 0.6126 - val_accuracy: 0.8155
#
# Epoch 00019: val_accuracy did not improve from 0.86898
# Epoch 20/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2716 - accuracy: 0.8598 - val_loss: 0.4698 - val_accuracy: 0.8235
#
# Epoch 00020: val_accuracy did not improve from 0.86898
# Epoch 21/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.3000 - accuracy: 0.8386 - val_loss: 0.4239 - val_accuracy: 0.8503
#
# Epoch 00021: val_accuracy did not improve from 0.86898
# Epoch 22/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2553 - accuracy: 0.8390 - val_loss: 0.4806 - val_accuracy: 0.8636
#
# Epoch 00022: val_accuracy did not improve from 0.86898
# Epoch 23/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2312 - accuracy: 0.8889 - val_loss: 0.5185 - val_accuracy: 0.8476
#
# Epoch 00023: val_accuracy did not improve from 0.86898
# Epoch 24/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1922 - accuracy: 0.8947 - val_loss: 0.4406 - val_accuracy: 0.8449
#
# Epoch 00024: val_accuracy did not improve from 0.86898
# Epoch 25/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2081 - accuracy: 0.8979 - val_loss: 0.4787 - val_accuracy: 0.8396
#
# Epoch 00025: val_accuracy did not improve from 0.86898
# Epoch 26/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2473 - accuracy: 0.8812 - val_loss: 0.3861 - val_accuracy: 0.8503
#
# Epoch 00026: val_accuracy did not improve from 0.86898
# Epoch 27/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2010 - accuracy: 0.9075 - val_loss: 0.4407 - val_accuracy: 0.8369
#
# Epoch 00027: val_accuracy did not improve from 0.86898
# Epoch 28/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2095 - accuracy: 0.9068 - val_loss: 0.4565 - val_accuracy: 0.8636
#
# Epoch 00028: val_accuracy did not improve from 0.86898
# Epoch 29/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2738 - accuracy: 0.8795 - val_loss: 0.5884 - val_accuracy: 0.8476
#
# Epoch 00029: val_accuracy did not improve from 0.86898
# Epoch 30/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1999 - accuracy: 0.9149 - val_loss: 0.5999 - val_accuracy: 0.8610
#
# Epoch 00030: val_accuracy did not improve from 0.86898
# Epoch 31/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1608 - accuracy: 0.9350 - val_loss: 0.8103 - val_accuracy: 0.8209
#
# Epoch 00031: val_accuracy did not improve from 0.86898
# Epoch 32/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2423 - accuracy: 0.8994 - val_loss: 0.7702 - val_accuracy: 0.8449
#
# Epoch 00032: val_accuracy did not improve from 0.86898
# Epoch 33/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1691 - accuracy: 0.9176 - val_loss: 0.4620 - val_accuracy: 0.8422
#
# Epoch 00033: val_accuracy did not improve from 0.86898
# Epoch 34/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1739 - accuracy: 0.9391 - val_loss: 0.5625 - val_accuracy: 0.8422
#
# Epoch 00034: val_accuracy did not improve from 0.86898
# Epoch 35/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1528 - accuracy: 0.9315 - val_loss: 0.6942 - val_accuracy: 0.8235
#
# Epoch 00035: val_accuracy did not improve from 0.86898
# Epoch 36/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1884 - accuracy: 0.9046 - val_loss: 0.7458 - val_accuracy: 0.8503
#
# Epoch 00036: val_accuracy did not improve from 0.86898
# Epoch 37/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1445 - accuracy: 0.9221 - val_loss: 0.6162 - val_accuracy: 0.8422
#
# Epoch 00037: val_accuracy did not improve from 0.86898
# Epoch 38/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2001 - accuracy: 0.9045 - val_loss: 0.7077 - val_accuracy: 0.8610
#
# Epoch 00038: val_accuracy did not improve from 0.86898
# Epoch 39/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2018 - accuracy: 0.9061 - val_loss: 0.7460 - val_accuracy: 0.7888
#
# Epoch 00039: val_accuracy did not improve from 0.86898
# Epoch 40/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2457 - accuracy: 0.8895 - val_loss: 0.7236 - val_accuracy: 0.8636
#
# Epoch 00040: val_accuracy did not improve from 0.86898
# Epoch 41/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1559 - accuracy: 0.9095 - val_loss: 0.6119 - val_accuracy: 0.8717
#
# Epoch 00041: val_accuracy improved from 0.86898 to 0.87166, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 42/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1351 - accuracy: 0.9152 - val_loss: 0.5494 - val_accuracy: 0.8717
#
# Epoch 00042: val_accuracy did not improve from 0.87166
# Epoch 43/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1726 - accuracy: 0.9087 - val_loss: 0.5161 - val_accuracy: 0.8743
#
# Epoch 00043: val_accuracy improved from 0.87166 to 0.87433, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 44/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2505 - accuracy: 0.8489 - val_loss: 0.5342 - val_accuracy: 0.8690
#
# Epoch 00044: val_accuracy did not improve from 0.87433
# Epoch 45/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1325 - accuracy: 0.9333 - val_loss: 0.5174 - val_accuracy: 0.8503
#
# Epoch 00045: val_accuracy did not improve from 0.87433
# Epoch 46/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1603 - accuracy: 0.9293 - val_loss: 0.5104 - val_accuracy: 0.8556
#
# Epoch 00046: val_accuracy did not improve from 0.87433
# Epoch 47/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1959 - accuracy: 0.8872 - val_loss: 0.3946 - val_accuracy: 0.8449
#
# Epoch 00047: val_accuracy did not improve from 0.87433
# Epoch 48/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2019 - accuracy: 0.9138 - val_loss: 0.4120 - val_accuracy: 0.8930
#
# Epoch 00048: val_accuracy improved from 0.87433 to 0.89305, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50_xfr.hdf5
# Epoch 49/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1457 - accuracy: 0.9319 - val_loss: 0.6331 - val_accuracy: 0.8583
#
# Epoch 00049: val_accuracy did not improve from 0.89305
# Epoch 50/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1906 - accuracy: 0.8936 - val_loss: 0.7168 - val_accuracy: 0.8449
#
# Epoch 00050: val_accuracy did not improve from 0.89305
# Epoch 51/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1914 - accuracy: 0.8895 - val_loss: 0.6230 - val_accuracy: 0.8636
#
# Epoch 00051: val_accuracy did not improve from 0.89305
# Epoch 52/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1403 - accuracy: 0.9219 - val_loss: 0.7589 - val_accuracy: 0.8663
#
# Epoch 00052: val_accuracy did not improve from 0.89305
# Epoch 53/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1626 - accuracy: 0.9424 - val_loss: 0.7732 - val_accuracy: 0.8529
#
# Epoch 00053: val_accuracy did not improve from 0.89305
# Epoch 54/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2191 - accuracy: 0.9383 - val_loss: 0.5784 - val_accuracy: 0.8663
#
# Epoch 00054: val_accuracy did not improve from 0.89305
# Epoch 55/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1187 - accuracy: 0.9521 - val_loss: 0.6611 - val_accuracy: 0.8583
#
# Epoch 00055: val_accuracy did not improve from 0.89305
# Epoch 56/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1261 - accuracy: 0.9311 - val_loss: 0.9137 - val_accuracy: 0.8610
#
# Epoch 00056: val_accuracy did not improve from 0.89305
# Epoch 57/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1197 - accuracy: 0.9396 - val_loss: 0.7610 - val_accuracy: 0.8369
#
# Epoch 00057: val_accuracy did not improve from 0.89305
# Epoch 58/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1628 - accuracy: 0.9363 - val_loss: 0.6769 - val_accuracy: 0.8610
#
# Epoch 00058: val_accuracy did not improve from 0.89305
# Epoch 59/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2253 - accuracy: 0.8526 - val_loss: 0.4337 - val_accuracy: 0.8797
#
# Epoch 00059: val_accuracy did not improve from 0.89305
# Epoch 60/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1734 - accuracy: 0.9112 - val_loss: 0.6004 - val_accuracy: 0.8529
#
# Epoch 00060: val_accuracy did not improve from 0.89305
# Epoch 61/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1731 - accuracy: 0.9063 - val_loss: 0.5197 - val_accuracy: 0.8717
#
# Epoch 00061: val_accuracy did not improve from 0.89305
# Epoch 62/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.3022 - accuracy: 0.7749 - val_loss: 0.4144 - val_accuracy: 0.7995
#
# Epoch 00062: val_accuracy did not improve from 0.89305
# Epoch 63/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2651 - accuracy: 0.8537 - val_loss: 0.6174 - val_accuracy: 0.8422
#
# Epoch 00063: val_accuracy did not improve from 0.89305
# Epoch 64/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2358 - accuracy: 0.9148 - val_loss: 0.7442 - val_accuracy: 0.8449
#
# Epoch 00064: val_accuracy did not improve from 0.89305
# Epoch 65/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1868 - accuracy: 0.8992 - val_loss: 0.5338 - val_accuracy: 0.8636
#
# Epoch 00065: val_accuracy did not improve from 0.89305
# Epoch 66/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1707 - accuracy: 0.9027 - val_loss: 0.6038 - val_accuracy: 0.8797
#
# Epoch 00066: val_accuracy did not improve from 0.89305
# Epoch 67/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1964 - accuracy: 0.8856 - val_loss: 0.6290 - val_accuracy: 0.8369
#
# Epoch 00067: val_accuracy did not improve from 0.89305
# Epoch 68/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2557 - accuracy: 0.8545 - val_loss: 0.4748 - val_accuracy: 0.8770
#
# Epoch 00068: val_accuracy did not improve from 0.89305
# Epoch 69/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1669 - accuracy: 0.9271 - val_loss: 0.7234 - val_accuracy: 0.8503
#
# Epoch 00069: val_accuracy did not improve from 0.89305
# Epoch 70/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2458 - accuracy: 0.8781 - val_loss: 0.7283 - val_accuracy: 0.8556
#
# Epoch 00070: val_accuracy did not improve from 0.89305
# Epoch 71/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1951 - accuracy: 0.8941 - val_loss: 0.5818 - val_accuracy: 0.8342
#
# Epoch 00071: val_accuracy did not improve from 0.89305
# Epoch 72/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2371 - accuracy: 0.8888 - val_loss: 0.5513 - val_accuracy: 0.8583
#
# Epoch 00072: val_accuracy did not improve from 0.89305
# Epoch 73/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1890 - accuracy: 0.9057 - val_loss: 0.6699 - val_accuracy: 0.8422
#
# Epoch 00073: val_accuracy did not improve from 0.89305
# Epoch 74/100
# 77/77 [==============================] - 6s 75ms/step - loss: 0.1586 - accuracy: 0.9198 - val_loss: 1.2929 - val_accuracy: 0.7995
#
# Epoch 00074: val_accuracy did not improve from 0.89305
# Epoch 75/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1799 - accuracy: 0.8795 - val_loss: 1.0628 - val_accuracy: 0.8717
#
# Epoch 00075: val_accuracy did not improve from 0.89305
# Epoch 76/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2061 - accuracy: 0.8765 - val_loss: 0.6332 - val_accuracy: 0.8503
#
# Epoch 00076: val_accuracy did not improve from 0.89305
# Epoch 77/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1785 - accuracy: 0.8928 - val_loss: 1.0441 - val_accuracy: 0.8529
#
# Epoch 00077: val_accuracy did not improve from 0.89305
# Epoch 78/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2000 - accuracy: 0.9017 - val_loss: 0.8940 - val_accuracy: 0.8797
#
# Epoch 00078: val_accuracy did not improve from 0.89305
# Epoch 79/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1225 - accuracy: 0.9393 - val_loss: 1.0444 - val_accuracy: 0.8316
#
# Epoch 00079: val_accuracy did not improve from 0.89305
# Epoch 80/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2407 - accuracy: 0.8590 - val_loss: 0.9293 - val_accuracy: 0.8583
#
# Epoch 00080: val_accuracy did not improve from 0.89305
# Epoch 81/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1675 - accuracy: 0.8959 - val_loss: 0.5950 - val_accuracy: 0.8690
#
# Epoch 00081: val_accuracy did not improve from 0.89305
# Epoch 82/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1586 - accuracy: 0.8956 - val_loss: 0.7546 - val_accuracy: 0.8636
#
# Epoch 00082: val_accuracy did not improve from 0.89305
# Epoch 83/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1427 - accuracy: 0.9104 - val_loss: 0.6076 - val_accuracy: 0.8743
#
# Epoch 00083: val_accuracy did not improve from 0.89305
# Epoch 84/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1690 - accuracy: 0.8640 - val_loss: 0.7004 - val_accuracy: 0.8529
#
# Epoch 00084: val_accuracy did not improve from 0.89305
# Epoch 85/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1770 - accuracy: 0.8869 - val_loss: 0.3931 - val_accuracy: 0.8663
#
# Epoch 00085: val_accuracy did not improve from 0.89305
# Epoch 86/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2473 - accuracy: 0.8385 - val_loss: 1.3873 - val_accuracy: 0.8422
#
# Epoch 00086: val_accuracy did not improve from 0.89305
# Epoch 87/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1994 - accuracy: 0.8929 - val_loss: 1.0537 - val_accuracy: 0.8342
#
# Epoch 00087: val_accuracy did not improve from 0.89305
# Epoch 88/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2291 - accuracy: 0.8592 - val_loss: 0.9195 - val_accuracy: 0.8797
#
# Epoch 00088: val_accuracy did not improve from 0.89305
# Epoch 89/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1860 - accuracy: 0.8937 - val_loss: 1.3752 - val_accuracy: 0.8636
#
# Epoch 00089: val_accuracy did not improve from 0.89305
# Epoch 90/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2144 - accuracy: 0.9041 - val_loss: 0.6320 - val_accuracy: 0.8636
#
# Epoch 00090: val_accuracy did not improve from 0.89305
# Epoch 91/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1889 - accuracy: 0.9024 - val_loss: 1.0750 - val_accuracy: 0.8476
#
# Epoch 00091: val_accuracy did not improve from 0.89305
# Epoch 92/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2066 - accuracy: 0.8972 - val_loss: 0.5087 - val_accuracy: 0.8824
#
# Epoch 00092: val_accuracy did not improve from 0.89305
# Epoch 93/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2939 - accuracy: 0.8318 - val_loss: 0.5639 - val_accuracy: 0.8663
#
# Epoch 00093: val_accuracy did not improve from 0.89305
# Epoch 94/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2478 - accuracy: 0.8744 - val_loss: 0.4682 - val_accuracy: 0.8690
#
# Epoch 00094: val_accuracy did not improve from 0.89305
# Epoch 95/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.2114 - accuracy: 0.8786 - val_loss: 0.8297 - val_accuracy: 0.8743
#
# Epoch 00095: val_accuracy did not improve from 0.89305
# Epoch 96/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1556 - accuracy: 0.9158 - val_loss: 0.5738 - val_accuracy: 0.8690
#
# Epoch 00096: val_accuracy did not improve from 0.89305
# Epoch 97/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.2044 - accuracy: 0.8760 - val_loss: 0.6724 - val_accuracy: 0.8663
#
# Epoch 00097: val_accuracy did not improve from 0.89305
# Epoch 98/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1465 - accuracy: 0.9096 - val_loss: 0.7055 - val_accuracy: 0.8583
#
# Epoch 00098: val_accuracy did not improve from 0.89305
# Epoch 99/100
# 77/77 [==============================] - 5s 70ms/step - loss: 0.1523 - accuracy: 0.9191 - val_loss: 0.6295 - val_accuracy: 0.8636
#
# Epoch 00099: val_accuracy did not improve from 0.89305
# Epoch 100/100
# 77/77 [==============================] - 5s 71ms/step - loss: 0.1724 - accuracy: 0.8848 - val_loss: 0.7608 - val_accuracy: 0.8717
#
# Epoch 00100: val_accuracy did not improve from 0.89305
# Train and Validation Time = 554.2369706630707s
# Model Train and Validation: Completed
# Model Test: Starting
# 37/37 [==============================] - 5s 125ms/step - loss: 0.8286 - accuracy: 0.8147
# Test Time = 4.689838409423828s
# Test Time / sample = 0.004060466155345306s
# Model Test: Completed
# #########################################################################################################################################
# Model Cross Validation: Starting
# ResNet50 XFR / Model Definition: Starting
# ResNet50 XFR FLOPS: 0.0021 G
# ResNet50 XFR / Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 10s 83ms/step - loss: 5.1704 - accuracy: 0.6281 - val_loss: 0.6022 - val_accuracy: 0.7343
#
# Epoch 00001: val_accuracy improved from -inf to 0.73427, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 2/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.4944 - accuracy: 0.7670 - val_loss: 0.4388 - val_accuracy: 0.8112
#
# Epoch 00002: val_accuracy improved from 0.73427 to 0.81119, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 3/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3264 - accuracy: 0.8580 - val_loss: 0.4440 - val_accuracy: 0.8147
#
# Epoch 00003: val_accuracy improved from 0.81119 to 0.81469, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 4/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.3216 - accuracy: 0.8520 - val_loss: 0.4239 - val_accuracy: 0.8392
#
# Epoch 00004: val_accuracy improved from 0.81469 to 0.83916, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 5/100
# 86/86 [==============================] - 6s 72ms/step - loss: 0.3056 - accuracy: 0.8790 - val_loss: 0.6989 - val_accuracy: 0.7133
#
# Epoch 00005: val_accuracy did not improve from 0.83916
# Epoch 6/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3562 - accuracy: 0.8515 - val_loss: 0.4599 - val_accuracy: 0.8147
#
# Epoch 00006: val_accuracy did not improve from 0.83916
# Epoch 7/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2639 - accuracy: 0.8822 - val_loss: 0.9450 - val_accuracy: 0.7378
#
# Epoch 00007: val_accuracy did not improve from 0.83916
# Epoch 8/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3204 - accuracy: 0.8561 - val_loss: 0.4020 - val_accuracy: 0.8287
#
# Epoch 00008: val_accuracy did not improve from 0.83916
# Epoch 9/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3138 - accuracy: 0.8618 - val_loss: 0.5160 - val_accuracy: 0.8112
#
# Epoch 00009: val_accuracy did not improve from 0.83916
# Epoch 10/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2718 - accuracy: 0.8912 - val_loss: 0.3890 - val_accuracy: 0.8112
#
# Epoch 00010: val_accuracy did not improve from 0.83916
# Epoch 11/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2431 - accuracy: 0.9014 - val_loss: 0.4198 - val_accuracy: 0.8601
#
# Epoch 00011: val_accuracy improved from 0.83916 to 0.86014, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 12/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3062 - accuracy: 0.8351 - val_loss: 0.4904 - val_accuracy: 0.8427
#
# Epoch 00012: val_accuracy did not improve from 0.86014
# Epoch 13/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3045 - accuracy: 0.8844 - val_loss: 0.4577 - val_accuracy: 0.8252
#
# Epoch 00013: val_accuracy did not improve from 0.86014
# Epoch 14/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3134 - accuracy: 0.8658 - val_loss: 0.4601 - val_accuracy: 0.7972
#
# Epoch 00014: val_accuracy did not improve from 0.86014
# Epoch 15/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3514 - accuracy: 0.8423 - val_loss: 0.5488 - val_accuracy: 0.8077
#
# Epoch 00015: val_accuracy did not improve from 0.86014
# Epoch 16/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3811 - accuracy: 0.8353 - val_loss: 0.3857 - val_accuracy: 0.8497
#
# Epoch 00016: val_accuracy did not improve from 0.86014
# Epoch 17/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3467 - accuracy: 0.8425 - val_loss: 0.5100 - val_accuracy: 0.8392
#
# Epoch 00017: val_accuracy did not improve from 0.86014
# Epoch 18/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2668 - accuracy: 0.8451 - val_loss: 0.4806 - val_accuracy: 0.8462
#
# Epoch 00018: val_accuracy did not improve from 0.86014
# Epoch 19/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3479 - accuracy: 0.7989 - val_loss: 0.3709 - val_accuracy: 0.8671
#
# Epoch 00019: val_accuracy improved from 0.86014 to 0.86713, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 20/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2125 - accuracy: 0.9055 - val_loss: 0.4788 - val_accuracy: 0.8566
#
# Epoch 00020: val_accuracy did not improve from 0.86713
# Epoch 21/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2458 - accuracy: 0.8939 - val_loss: 0.3867 - val_accuracy: 0.8497
#
# Epoch 00021: val_accuracy did not improve from 0.86713
# Epoch 22/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2116 - accuracy: 0.8993 - val_loss: 0.4100 - val_accuracy: 0.8357
#
# Epoch 00022: val_accuracy did not improve from 0.86713
# Epoch 23/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2087 - accuracy: 0.8954 - val_loss: 0.4240 - val_accuracy: 0.8007
#
# Epoch 00023: val_accuracy did not improve from 0.86713
# Epoch 24/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2493 - accuracy: 0.8818 - val_loss: 0.4727 - val_accuracy: 0.8531
#
# Epoch 00024: val_accuracy did not improve from 0.86713
# Epoch 25/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1977 - accuracy: 0.8875 - val_loss: 0.4881 - val_accuracy: 0.8427
#
# Epoch 00025: val_accuracy did not improve from 0.86713
# Epoch 26/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1877 - accuracy: 0.8932 - val_loss: 0.3970 - val_accuracy: 0.8392
#
# Epoch 00026: val_accuracy did not improve from 0.86713
# Epoch 27/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2065 - accuracy: 0.9024 - val_loss: 0.6474 - val_accuracy: 0.8427
#
# Epoch 00027: val_accuracy did not improve from 0.86713
# Epoch 28/100
# 86/86 [==============================] - 6s 64ms/step - loss: 0.2072 - accuracy: 0.8986 - val_loss: 0.5708 - val_accuracy: 0.8462
#
# Epoch 00028: val_accuracy did not improve from 0.86713
# Epoch 29/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2344 - accuracy: 0.8686 - val_loss: 0.3978 - val_accuracy: 0.8531
#
# Epoch 00029: val_accuracy did not improve from 0.86713
# Epoch 30/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2233 - accuracy: 0.9110 - val_loss: 0.4979 - val_accuracy: 0.8636
#
# Epoch 00030: val_accuracy did not improve from 0.86713
# Epoch 31/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2090 - accuracy: 0.8948 - val_loss: 1.0016 - val_accuracy: 0.8322
#
# Epoch 00031: val_accuracy did not improve from 0.86713
# Epoch 32/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2734 - accuracy: 0.8450 - val_loss: 0.5156 - val_accuracy: 0.8322
#
# Epoch 00032: val_accuracy did not improve from 0.86713
# Epoch 33/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2234 - accuracy: 0.8737 - val_loss: 0.4991 - val_accuracy: 0.8462
#
# Epoch 00033: val_accuracy did not improve from 0.86713
# Epoch 34/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1472 - accuracy: 0.9236 - val_loss: 0.6737 - val_accuracy: 0.8671
#
# Epoch 00034: val_accuracy did not improve from 0.86713
# Epoch 35/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2257 - accuracy: 0.9093 - val_loss: 0.5217 - val_accuracy: 0.8916
#
# Epoch 00035: val_accuracy improved from 0.86713 to 0.89161, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 36/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1625 - accuracy: 0.9377 - val_loss: 0.4339 - val_accuracy: 0.8601
#
# Epoch 00036: val_accuracy did not improve from 0.89161
# Epoch 37/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1820 - accuracy: 0.9152 - val_loss: 0.5170 - val_accuracy: 0.8741
#
# Epoch 00037: val_accuracy did not improve from 0.89161
# Epoch 38/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2058 - accuracy: 0.8985 - val_loss: 0.7279 - val_accuracy: 0.8392
#
# Epoch 00038: val_accuracy did not improve from 0.89161
# Epoch 39/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2344 - accuracy: 0.8951 - val_loss: 0.5464 - val_accuracy: 0.8287
#
# Epoch 00039: val_accuracy did not improve from 0.89161
# Epoch 40/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1655 - accuracy: 0.9147 - val_loss: 0.4472 - val_accuracy: 0.8636
#
# Epoch 00040: val_accuracy did not improve from 0.89161
# Epoch 41/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1711 - accuracy: 0.9164 - val_loss: 0.5772 - val_accuracy: 0.8566
#
# Epoch 00041: val_accuracy did not improve from 0.89161
# Epoch 42/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1584 - accuracy: 0.9340 - val_loss: 0.6901 - val_accuracy: 0.8706
#
# Epoch 00042: val_accuracy did not improve from 0.89161
# Epoch 43/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1034 - accuracy: 0.9469 - val_loss: 0.6480 - val_accuracy: 0.8462
#
# Epoch 00043: val_accuracy did not improve from 0.89161
# Epoch 44/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1737 - accuracy: 0.9208 - val_loss: 0.5319 - val_accuracy: 0.8951
#
# Epoch 00044: val_accuracy improved from 0.89161 to 0.89510, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_0.hdf5
# Epoch 45/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1479 - accuracy: 0.9307 - val_loss: 0.7735 - val_accuracy: 0.8497
#
# Epoch 00045: val_accuracy did not improve from 0.89510
# Epoch 46/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1526 - accuracy: 0.9208 - val_loss: 0.4163 - val_accuracy: 0.8706
#
# Epoch 00046: val_accuracy did not improve from 0.89510
# Epoch 47/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1314 - accuracy: 0.9586 - val_loss: 0.7092 - val_accuracy: 0.8601
#
# Epoch 00047: val_accuracy did not improve from 0.89510
# Epoch 48/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1469 - accuracy: 0.9149 - val_loss: 0.5474 - val_accuracy: 0.8497
#
# Epoch 00048: val_accuracy did not improve from 0.89510
# Epoch 49/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1938 - accuracy: 0.8943 - val_loss: 0.5808 - val_accuracy: 0.8357
#
# Epoch 00049: val_accuracy did not improve from 0.89510
# Epoch 50/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1646 - accuracy: 0.9117 - val_loss: 0.5824 - val_accuracy: 0.8427
#
# Epoch 00050: val_accuracy did not improve from 0.89510
# Epoch 51/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1667 - accuracy: 0.9120 - val_loss: 0.5516 - val_accuracy: 0.8636
#
# Epoch 00051: val_accuracy did not improve from 0.89510
# Epoch 52/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1315 - accuracy: 0.9166 - val_loss: 0.5921 - val_accuracy: 0.8811
#
# Epoch 00052: val_accuracy did not improve from 0.89510
# Epoch 53/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1080 - accuracy: 0.9424 - val_loss: 0.7233 - val_accuracy: 0.8741
#
# Epoch 00053: val_accuracy did not improve from 0.89510
# Epoch 54/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1196 - accuracy: 0.9367 - val_loss: 0.9505 - val_accuracy: 0.8636
#
# Epoch 00054: val_accuracy did not improve from 0.89510
# Epoch 55/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1268 - accuracy: 0.9575 - val_loss: 0.6432 - val_accuracy: 0.8671
#
# Epoch 00055: val_accuracy did not improve from 0.89510
# Epoch 56/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1309 - accuracy: 0.9329 - val_loss: 0.5863 - val_accuracy: 0.8881
#
# Epoch 00056: val_accuracy did not improve from 0.89510
# Epoch 57/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1197 - accuracy: 0.9402 - val_loss: 1.0497 - val_accuracy: 0.8462
#
# Epoch 00057: val_accuracy did not improve from 0.89510
# Epoch 58/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1781 - accuracy: 0.9454 - val_loss: 0.4371 - val_accuracy: 0.8951
#
# Epoch 00058: val_accuracy did not improve from 0.89510
# Epoch 59/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1610 - accuracy: 0.9261 - val_loss: 0.6951 - val_accuracy: 0.8776
#
# Epoch 00059: val_accuracy did not improve from 0.89510
# Epoch 60/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1655 - accuracy: 0.9286 - val_loss: 0.6280 - val_accuracy: 0.8287
#
# Epoch 00060: val_accuracy did not improve from 0.89510
# Epoch 61/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2070 - accuracy: 0.8939 - val_loss: 0.5917 - val_accuracy: 0.8601
#
# Epoch 00061: val_accuracy did not improve from 0.89510
# Epoch 62/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1598 - accuracy: 0.9143 - val_loss: 0.3904 - val_accuracy: 0.8846
#
# Epoch 00062: val_accuracy did not improve from 0.89510
# Epoch 63/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1564 - accuracy: 0.9058 - val_loss: 0.5328 - val_accuracy: 0.8427
#
# Epoch 00063: val_accuracy did not improve from 0.89510
# Epoch 64/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1402 - accuracy: 0.9489 - val_loss: 0.6247 - val_accuracy: 0.8846
#
# Epoch 00064: val_accuracy did not improve from 0.89510
# Epoch 65/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1221 - accuracy: 0.9386 - val_loss: 0.9526 - val_accuracy: 0.8741
#
# Epoch 00065: val_accuracy did not improve from 0.89510
# Epoch 66/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2014 - accuracy: 0.8989 - val_loss: 0.3540 - val_accuracy: 0.8636
#
# Epoch 00066: val_accuracy did not improve from 0.89510
# Epoch 67/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1706 - accuracy: 0.9071 - val_loss: 0.5658 - val_accuracy: 0.8846
#
# Epoch 00067: val_accuracy did not improve from 0.89510
# Epoch 68/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1454 - accuracy: 0.9183 - val_loss: 0.7361 - val_accuracy: 0.8776
#
# Epoch 00068: val_accuracy did not improve from 0.89510
# Epoch 69/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1567 - accuracy: 0.9243 - val_loss: 0.5601 - val_accuracy: 0.8636
#
# Epoch 00069: val_accuracy did not improve from 0.89510
# Epoch 70/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2495 - accuracy: 0.8616 - val_loss: 0.5088 - val_accuracy: 0.8776
#
# Epoch 00070: val_accuracy did not improve from 0.89510
# Epoch 71/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1515 - accuracy: 0.9181 - val_loss: 1.3447 - val_accuracy: 0.8566
#
# Epoch 00071: val_accuracy did not improve from 0.89510
# Epoch 72/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1407 - accuracy: 0.9141 - val_loss: 0.9330 - val_accuracy: 0.8671
#
# Epoch 00072: val_accuracy did not improve from 0.89510
# Epoch 73/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1256 - accuracy: 0.9369 - val_loss: 0.5918 - val_accuracy: 0.8671
#
# Epoch 00073: val_accuracy did not improve from 0.89510
# Epoch 74/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.0985 - accuracy: 0.9393 - val_loss: 0.9612 - val_accuracy: 0.8427
#
# Epoch 00074: val_accuracy did not improve from 0.89510
# Epoch 75/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1090 - accuracy: 0.9466 - val_loss: 1.1521 - val_accuracy: 0.8566
#
# Epoch 00075: val_accuracy did not improve from 0.89510
# Epoch 76/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1161 - accuracy: 0.9425 - val_loss: 1.0289 - val_accuracy: 0.8741
#
# Epoch 00076: val_accuracy did not improve from 0.89510
# Epoch 77/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1424 - accuracy: 0.9396 - val_loss: 0.9041 - val_accuracy: 0.8741
#
# Epoch 00077: val_accuracy did not improve from 0.89510
# Epoch 78/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1914 - accuracy: 0.9116 - val_loss: 0.7043 - val_accuracy: 0.8427
#
# Epoch 00078: val_accuracy did not improve from 0.89510
# Epoch 79/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1314 - accuracy: 0.9320 - val_loss: 0.8274 - val_accuracy: 0.8706
#
# Epoch 00079: val_accuracy did not improve from 0.89510
# Epoch 80/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1201 - accuracy: 0.9357 - val_loss: 0.8327 - val_accuracy: 0.8671
#
# Epoch 00080: val_accuracy did not improve from 0.89510
# Epoch 81/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1118 - accuracy: 0.9244 - val_loss: 0.7497 - val_accuracy: 0.8601
#
# Epoch 00081: val_accuracy did not improve from 0.89510
# Epoch 82/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1246 - accuracy: 0.9241 - val_loss: 0.9789 - val_accuracy: 0.8706
#
# Epoch 00082: val_accuracy did not improve from 0.89510
# Epoch 83/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.0855 - accuracy: 0.9489 - val_loss: 1.2338 - val_accuracy: 0.8566
#
# Epoch 00083: val_accuracy did not improve from 0.89510
# Epoch 84/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.0907 - accuracy: 0.9484 - val_loss: 1.1810 - val_accuracy: 0.8776
#
# Epoch 00084: val_accuracy did not improve from 0.89510
# Epoch 85/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1150 - accuracy: 0.9273 - val_loss: 1.0500 - val_accuracy: 0.8112
#
# Epoch 00085: val_accuracy did not improve from 0.89510
# Epoch 86/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1613 - accuracy: 0.9166 - val_loss: 0.6904 - val_accuracy: 0.8427
#
# Epoch 00086: val_accuracy did not improve from 0.89510
# Epoch 87/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1630 - accuracy: 0.9157 - val_loss: 0.9214 - val_accuracy: 0.8566
#
# Epoch 00087: val_accuracy did not improve from 0.89510
# Epoch 88/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1942 - accuracy: 0.9196 - val_loss: 1.3864 - val_accuracy: 0.8741
#
# Epoch 00088: val_accuracy did not improve from 0.89510
# Epoch 89/100
# 86/86 [==============================] - 6s 72ms/step - loss: 0.1957 - accuracy: 0.9078 - val_loss: 0.7135 - val_accuracy: 0.8846
#
# Epoch 00089: val_accuracy did not improve from 0.89510
# Epoch 90/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1522 - accuracy: 0.9083 - val_loss: 1.0596 - val_accuracy: 0.8741
#
# Epoch 00090: val_accuracy did not improve from 0.89510
# Epoch 91/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.0820 - accuracy: 0.9427 - val_loss: 0.7698 - val_accuracy: 0.8706
#
# Epoch 00091: val_accuracy did not improve from 0.89510
# Epoch 92/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1193 - accuracy: 0.9277 - val_loss: 1.2761 - val_accuracy: 0.8427
#
# Epoch 00092: val_accuracy did not improve from 0.89510
# Epoch 93/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1572 - accuracy: 0.9261 - val_loss: 1.0620 - val_accuracy: 0.8322
#
# Epoch 00093: val_accuracy did not improve from 0.89510
# Epoch 94/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2104 - accuracy: 0.8973 - val_loss: 0.7962 - val_accuracy: 0.8741
#
# Epoch 00094: val_accuracy did not improve from 0.89510
# Epoch 95/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1910 - accuracy: 0.9024 - val_loss: 0.8084 - val_accuracy: 0.8322
#
# Epoch 00095: val_accuracy did not improve from 0.89510
# Epoch 96/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2111 - accuracy: 0.8756 - val_loss: 0.9872 - val_accuracy: 0.8497
#
# Epoch 00096: val_accuracy did not improve from 0.89510
# Epoch 97/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1706 - accuracy: 0.9195 - val_loss: 0.8976 - val_accuracy: 0.8706
#
# Epoch 00097: val_accuracy did not improve from 0.89510
# Epoch 98/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.1244 - accuracy: 0.9091 - val_loss: 1.4409 - val_accuracy: 0.8671
#
# Epoch 00098: val_accuracy did not improve from 0.89510
# Epoch 99/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1282 - accuracy: 0.9318 - val_loss: 1.1727 - val_accuracy: 0.8776
#
# Epoch 00099: val_accuracy did not improve from 0.89510
# Epoch 100/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2505 - accuracy: 0.8922 - val_loss: 0.5108 - val_accuracy: 0.8566
#
# Epoch 00100: val_accuracy did not improve from 0.89510
# Cross Validation Accuracy: 73.43%
# Fold #0 Complete
#
# ResNet50 XFR / Model Definition: Starting
# ResNet50 XFR FLOPS: 0.0021 G
# ResNet50 XFR / Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 9s 77ms/step - loss: 5.1917 - accuracy: 0.6100 - val_loss: 0.4714 - val_accuracy: 0.8042
#
# Epoch 00001: val_accuracy improved from -inf to 0.80420, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 2/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.4277 - accuracy: 0.7843 - val_loss: 0.3897 - val_accuracy: 0.8357
#
# Epoch 00002: val_accuracy improved from 0.80420 to 0.83566, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 3/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3246 - accuracy: 0.8594 - val_loss: 0.3548 - val_accuracy: 0.8392
#
# Epoch 00003: val_accuracy improved from 0.83566 to 0.83916, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 4/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3263 - accuracy: 0.8418 - val_loss: 0.3023 - val_accuracy: 0.8601
#
# Epoch 00004: val_accuracy improved from 0.83916 to 0.86014, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 5/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2849 - accuracy: 0.8920 - val_loss: 0.3301 - val_accuracy: 0.8566
#
# Epoch 00005: val_accuracy did not improve from 0.86014
# Epoch 6/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3162 - accuracy: 0.8635 - val_loss: 0.3271 - val_accuracy: 0.8566
#
# Epoch 00006: val_accuracy did not improve from 0.86014
# Epoch 7/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3424 - accuracy: 0.8651 - val_loss: 0.2727 - val_accuracy: 0.8811
#
# Epoch 00007: val_accuracy improved from 0.86014 to 0.88112, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 8/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2539 - accuracy: 0.8931 - val_loss: 0.4203 - val_accuracy: 0.8042
#
# Epoch 00008: val_accuracy did not improve from 0.88112
# Epoch 9/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3021 - accuracy: 0.8793 - val_loss: 0.2680 - val_accuracy: 0.8671
#
# Epoch 00009: val_accuracy did not improve from 0.88112
# Epoch 10/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2513 - accuracy: 0.8921 - val_loss: 0.3442 - val_accuracy: 0.8671
#
# Epoch 00010: val_accuracy did not improve from 0.88112
# Epoch 11/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2755 - accuracy: 0.8814 - val_loss: 0.3157 - val_accuracy: 0.8636
#
# Epoch 00011: val_accuracy did not improve from 0.88112
# Epoch 12/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2981 - accuracy: 0.8536 - val_loss: 0.2510 - val_accuracy: 0.8776
#
# Epoch 00012: val_accuracy did not improve from 0.88112
# Epoch 13/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3093 - accuracy: 0.8481 - val_loss: 0.2789 - val_accuracy: 0.8881
#
# Epoch 00013: val_accuracy improved from 0.88112 to 0.88811, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 14/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2950 - accuracy: 0.8493 - val_loss: 0.3675 - val_accuracy: 0.8531
#
# Epoch 00014: val_accuracy did not improve from 0.88811
# Epoch 15/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2841 - accuracy: 0.8726 - val_loss: 0.2820 - val_accuracy: 0.8636
#
# Epoch 00015: val_accuracy did not improve from 0.88811
# Epoch 16/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2165 - accuracy: 0.9049 - val_loss: 0.3298 - val_accuracy: 0.8322
#
# Epoch 00016: val_accuracy did not improve from 0.88811
# Epoch 17/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2918 - accuracy: 0.8660 - val_loss: 0.3710 - val_accuracy: 0.8636
#
# Epoch 00017: val_accuracy did not improve from 0.88811
# Epoch 18/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3234 - accuracy: 0.8564 - val_loss: 0.3196 - val_accuracy: 0.8916
#
# Epoch 00018: val_accuracy improved from 0.88811 to 0.89161, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_1.hdf5
# Epoch 19/100
# 86/86 [==============================] - 6s 74ms/step - loss: 0.2593 - accuracy: 0.9258 - val_loss: 0.3113 - val_accuracy: 0.8706
#
# Epoch 00019: val_accuracy did not improve from 0.89161
# Epoch 20/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3103 - accuracy: 0.8626 - val_loss: 0.2487 - val_accuracy: 0.8916
#
# Epoch 00020: val_accuracy did not improve from 0.89161
# Epoch 21/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2913 - accuracy: 0.8471 - val_loss: 0.2483 - val_accuracy: 0.8986
#
# ...
# Epoch 26/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2392 - accuracy: 0.8967 - val_loss: 0.4438 - val_accuracy: 0.8566
#
# Epoch 00026: val_accuracy did not improve from 0.88811
# Epoch 27/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1946 - accuracy: 0.8893 - val_loss: 0.3706 - val_accuracy: 0.8776
#
# Epoch 00027: val_accuracy did not improve from 0.88811
# Epoch 28/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2653 - accuracy: 0.8610 - val_loss: 0.3197 - val_accuracy: 0.8846
#
# Epoch 00028: val_accuracy did not improve from 0.88811
# Epoch 29/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2630 - accuracy: 0.8597 - val_loss: 0.3682 - val_accuracy: 0.8811
#
# Epoch 00029: val_accuracy did not improve from 0.88811
# Epoch 30/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2554 - accuracy: 0.8629 - val_loss: 0.3497 - val_accuracy: 0.8881
#
# Epoch 00030: val_accuracy did not improve from 0.88811
# Epoch 31/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2639 - accuracy: 0.8539 - val_loss: 0.4877 - val_accuracy: 0.8636
#
# Epoch 00031: val_accuracy did not improve from 0.88811
# Epoch 32/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2421 - accuracy: 0.8743 - val_loss: 0.4867 - val_accuracy: 0.8776
#
# Epoch 00032: val_accuracy did not improve from 0.88811
# Epoch 33/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2060 - accuracy: 0.8686 - val_loss: 0.4065 - val_accuracy: 0.8741
#
# Epoch 00033: val_accuracy did not improve from 0.88811
# Epoch 34/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2534 - accuracy: 0.8949 - val_loss: 0.3728 - val_accuracy: 0.8287
#
# Epoch 00034: val_accuracy did not improve from 0.88811
# Epoch 35/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.3344 - accuracy: 0.8478 - val_loss: 0.5023 - val_accuracy: 0.8706
#
# Epoch 00035: val_accuracy did not improve from 0.88811
# Epoch 36/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2617 - accuracy: 0.9090 - val_loss: 0.3653 - val_accuracy: 0.8671
#
# Epoch 00036: val_accuracy did not improve from 0.88811
# Epoch 37/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2773 - accuracy: 0.8591 - val_loss: 0.5219 - val_accuracy: 0.8497
#
# Epoch 00037: val_accuracy did not improve from 0.88811
# Epoch 38/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2481 - accuracy: 0.8637 - val_loss: 0.3807 - val_accuracy: 0.8462
#
# Epoch 00038: val_accuracy did not improve from 0.88811
# Epoch 39/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3562 - accuracy: 0.8290 - val_loss: 0.7423 - val_accuracy: 0.8427
#
# Epoch 00039: val_accuracy did not improve from 0.88811
# Epoch 40/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2120 - accuracy: 0.8985 - val_loss: 0.6113 - val_accuracy: 0.8636
#
# Epoch 00040: val_accuracy did not improve from 0.88811
# Epoch 41/100
# 86/86 [==============================] - 6s 65ms/step - loss: 0.2367 - accuracy: 0.8865 - val_loss: 0.5093 - val_accuracy: 0.8601
#
# Epoch 00041: val_accuracy did not improve from 0.88811
# Epoch 42/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2408 - accuracy: 0.8698 - val_loss: 0.4421 - val_accuracy: 0.8741
#
# Epoch 00042: val_accuracy did not improve from 0.88811
# Epoch 43/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2043 - accuracy: 0.8963 - val_loss: 0.5015 - val_accuracy: 0.8916
#
# Epoch 00043: val_accuracy improved from 0.88811 to 0.89161, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_3.hdf5
# Epoch 44/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1639 - accuracy: 0.9168 - val_loss: 0.7157 - val_accuracy: 0.8741
#
# Epoch 00044: val_accuracy did not improve from 0.89161
# Epoch 45/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2310 - accuracy: 0.8885 - val_loss: 0.4590 - val_accuracy: 0.8916
#
# Epoch 00045: val_accuracy did not improve from 0.89161
# Epoch 46/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1502 - accuracy: 0.9320 - val_loss: 0.5828 - val_accuracy: 0.8601
#
# Epoch 00046: val_accuracy did not improve from 0.89161
# Epoch 47/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1883 - accuracy: 0.9372 - val_loss: 0.5814 - val_accuracy: 0.8811
#
# Epoch 00047: val_accuracy did not improve from 0.89161
# Epoch 48/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1567 - accuracy: 0.9122 - val_loss: 0.5491 - val_accuracy: 0.8706
#
# Epoch 00048: val_accuracy did not improve from 0.89161
# Epoch 49/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1274 - accuracy: 0.9308 - val_loss: 0.5965 - val_accuracy: 0.8846
#
# Epoch 00049: val_accuracy did not improve from 0.89161
# Epoch 50/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1298 - accuracy: 0.9268 - val_loss: 0.5604 - val_accuracy: 0.8846
#
# Epoch 00050: val_accuracy did not improve from 0.89161
# Epoch 51/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1953 - accuracy: 0.9055 - val_loss: 0.4174 - val_accuracy: 0.8741
#
# Epoch 00051: val_accuracy did not improve from 0.89161
# Epoch 52/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2012 - accuracy: 0.8693 - val_loss: 0.4106 - val_accuracy: 0.8776
#
# Epoch 00052: val_accuracy did not improve from 0.89161
# Epoch 53/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2154 - accuracy: 0.9002 - val_loss: 0.4689 - val_accuracy: 0.8846
#
# Epoch 00053: val_accuracy did not improve from 0.89161
# Epoch 54/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3107 - accuracy: 0.8573 - val_loss: 0.5026 - val_accuracy: 0.8846
#
# Epoch 00054: val_accuracy did not improve from 0.89161
# Epoch 55/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1988 - accuracy: 0.8797 - val_loss: 0.5734 - val_accuracy: 0.8671
#
# Epoch 00055: val_accuracy did not improve from 0.89161
# Epoch 56/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2224 - accuracy: 0.8634 - val_loss: 0.5829 - val_accuracy: 0.8951
#
# Epoch 00056: val_accuracy improved from 0.89161 to 0.89510, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_3.hdf5
# Epoch 57/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1291 - accuracy: 0.9214 - val_loss: 0.6894 - val_accuracy: 0.8846
#
# Epoch 00057: val_accuracy did not improve from 0.89510
# Epoch 58/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1170 - accuracy: 0.9365 - val_loss: 0.8760 - val_accuracy: 0.8811
#
# Epoch 00058: val_accuracy did not improve from 0.89510
# Epoch 59/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1546 - accuracy: 0.9258 - val_loss: 0.7296 - val_accuracy: 0.8846
#
# Epoch 00059: val_accuracy did not improve from 0.89510
# Epoch 60/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1271 - accuracy: 0.9348 - val_loss: 0.5803 - val_accuracy: 0.8881
#
# Epoch 00060: val_accuracy did not improve from 0.89510
# Epoch 61/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1638 - accuracy: 0.9097 - val_loss: 0.7208 - val_accuracy: 0.8881
#
# Epoch 00061: val_accuracy did not improve from 0.89510
# Epoch 62/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1443 - accuracy: 0.8983 - val_loss: 0.5193 - val_accuracy: 0.8916
#
# Epoch 00062: val_accuracy did not improve from 0.89510
# Epoch 63/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1693 - accuracy: 0.9098 - val_loss: 1.2382 - val_accuracy: 0.8811
#
# Epoch 00063: val_accuracy did not improve from 0.89510
# Epoch 64/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2028 - accuracy: 0.9076 - val_loss: 0.5662 - val_accuracy: 0.7937
#
# Epoch 00064: val_accuracy did not improve from 0.89510
# Epoch 65/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.3739 - accuracy: 0.7742 - val_loss: 0.9180 - val_accuracy: 0.8881
#
# Epoch 00065: val_accuracy did not improve from 0.89510
# Epoch 66/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1951 - accuracy: 0.8905 - val_loss: 0.5836 - val_accuracy: 0.8881
#
# Epoch 00066: val_accuracy did not improve from 0.89510
# Epoch 67/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1578 - accuracy: 0.9151 - val_loss: 0.6781 - val_accuracy: 0.8601
#
# Epoch 00067: val_accuracy did not improve from 0.89510
# Epoch 68/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2154 - accuracy: 0.9003 - val_loss: 0.6825 - val_accuracy: 0.8811
#
# Epoch 00068: val_accuracy did not improve from 0.89510
# Epoch 69/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1535 - accuracy: 0.9319 - val_loss: 0.7477 - val_accuracy: 0.8671
#
# Epoch 00069: val_accuracy did not improve from 0.89510
# Epoch 70/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1874 - accuracy: 0.9125 - val_loss: 0.6051 - val_accuracy: 0.8846
#
# Epoch 00070: val_accuracy did not improve from 0.89510
# Epoch 71/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1567 - accuracy: 0.9271 - val_loss: 0.8583 - val_accuracy: 0.8601
#
# Epoch 00071: val_accuracy did not improve from 0.89510
# Epoch 72/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2219 - accuracy: 0.9024 - val_loss: 0.7059 - val_accuracy: 0.8846
#
# Epoch 00072: val_accuracy did not improve from 0.89510
# Epoch 73/100
# 86/86 [==============================] - 6s 72ms/step - loss: 0.1433 - accuracy: 0.9253 - val_loss: 0.8279 - val_accuracy: 0.8706
#
# Epoch 00073: val_accuracy did not improve from 0.89510
# Epoch 74/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2247 - accuracy: 0.8809 - val_loss: 0.7154 - val_accuracy: 0.8916
#
# Epoch 00074: val_accuracy did not improve from 0.89510
# Epoch 75/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1348 - accuracy: 0.9413 - val_loss: 0.6528 - val_accuracy: 0.9021
#
# Epoch 00075: val_accuracy improved from 0.89510 to 0.90210, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_3.hdf5
# Epoch 76/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1436 - accuracy: 0.9386 - val_loss: 1.0152 - val_accuracy: 0.8846
#
# Epoch 00076: val_accuracy did not improve from 0.90210
# Epoch 77/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.2101 - accuracy: 0.8958 - val_loss: 1.1521 - val_accuracy: 0.8811
#
# Epoch 00077: val_accuracy did not improve from 0.90210
# Epoch 78/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1944 - accuracy: 0.9163 - val_loss: 0.9297 - val_accuracy: 0.8706
#
# Epoch 00078: val_accuracy did not improve from 0.90210
# Epoch 79/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1793 - accuracy: 0.9378 - val_loss: 1.0666 - val_accuracy: 0.8846
#
# Epoch 00079: val_accuracy did not improve from 0.90210
# Epoch 80/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1942 - accuracy: 0.9140 - val_loss: 1.2017 - val_accuracy: 0.8636
#
# Epoch 00080: val_accuracy did not improve from 0.90210
# Epoch 81/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.2132 - accuracy: 0.9234 - val_loss: 0.6880 - val_accuracy: 0.8916
#
# Epoch 00081: val_accuracy did not improve from 0.90210
# Epoch 82/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1643 - accuracy: 0.9311 - val_loss: 0.8803 - val_accuracy: 0.8951
#
# Epoch 00082: val_accuracy did not improve from 0.90210
# Epoch 83/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1525 - accuracy: 0.9352 - val_loss: 1.0485 - val_accuracy: 0.8846
#
# Epoch 00083: val_accuracy did not improve from 0.90210
# Epoch 84/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1415 - accuracy: 0.9438 - val_loss: 0.7507 - val_accuracy: 0.8706
#
# Epoch 00084: val_accuracy did not improve from 0.90210
# Epoch 85/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1103 - accuracy: 0.9489 - val_loss: 0.9700 - val_accuracy: 0.8706
#
# Epoch 00085: val_accuracy did not improve from 0.90210
# Epoch 86/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.0993 - accuracy: 0.9619 - val_loss: 0.9344 - val_accuracy: 0.8776
#
# Epoch 00086: val_accuracy did not improve from 0.90210
# Epoch 87/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1448 - accuracy: 0.9223 - val_loss: 0.8793 - val_accuracy: 0.8671
#
# Epoch 00087: val_accuracy did not improve from 0.90210
# Epoch 88/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1956 - accuracy: 0.8925 - val_loss: 0.6687 - val_accuracy: 0.8776
#
# Epoch 00088: val_accuracy did not improve from 0.90210
# Epoch 89/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1803 - accuracy: 0.9055 - val_loss: 0.8328 - val_accuracy: 0.8776
#
# Epoch 00089: val_accuracy did not improve from 0.90210
# Epoch 90/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1655 - accuracy: 0.9345 - val_loss: 1.1632 - val_accuracy: 0.8916
#
# Epoch 00090: val_accuracy did not improve from 0.90210
# Epoch 91/100
# 86/86 [==============================] - 6s 67ms/step - loss: 0.1800 - accuracy: 0.9318 - val_loss: 0.8207 - val_accuracy: 0.8986
#
# Epoch 00091: val_accuracy did not improve from 0.90210
# Epoch 92/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1273 - accuracy: 0.9536 - val_loss: 1.2074 - val_accuracy: 0.8741
#
# Epoch 00092: val_accuracy did not improve from 0.90210
# Epoch 93/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1087 - accuracy: 0.9529 - val_loss: 1.0970 - val_accuracy: 0.8881
#
# Epoch 00093: val_accuracy did not improve from 0.90210
# Epoch 94/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1349 - accuracy: 0.9374 - val_loss: 1.0280 - val_accuracy: 0.8811
#
# Epoch 00094: val_accuracy did not improve from 0.90210
# Epoch 95/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1360 - accuracy: 0.9393 - val_loss: 1.5033 - val_accuracy: 0.8566
#
# Epoch 00095: val_accuracy did not improve from 0.90210
# Epoch 96/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1388 - accuracy: 0.9390 - val_loss: 0.8379 - val_accuracy: 0.8741
#
# Epoch 00096: val_accuracy did not improve from 0.90210
# Epoch 97/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1611 - accuracy: 0.9214 - val_loss: 0.8160 - val_accuracy: 0.8811
#
# Epoch 00097: val_accuracy did not improve from 0.90210
# Epoch 98/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1543 - accuracy: 0.9132 - val_loss: 0.8316 - val_accuracy: 0.8776
#
# Epoch 00098: val_accuracy did not improve from 0.90210
# Epoch 99/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1457 - accuracy: 0.9337 - val_loss: 1.4239 - val_accuracy: 0.8776
#
# Epoch 00099: val_accuracy did not improve from 0.90210
# Epoch 100/100
# 86/86 [==============================] - 6s 66ms/step - loss: 0.1397 - accuracy: 0.9499 - val_loss: 1.3456 - val_accuracy: 0.8811
#
# Epoch 00100: val_accuracy did not improve from 0.90210
# Cross Validation Accuracy: 82.52%
# Fold #3 Complete
#
# Cross Validation Accuracy Mean (+/- Std Deviation): 79.81% (+/- 3.80%)
# Cross Validation Time = 2360.335835456848s
# Model Cross Validation: Completed
# Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_2.hdf5
# ResNet50 XFR / Model Definition: Starting
# ResNet50 XFR FLOPS: 0.0021 G
# ResNet50 XFR / Model Definition: Completed
# Model Test: Starting
# 37/37 [==============================] - 6s 130ms/step - loss: 0.9599 - accuracy: 0.8024
# Test Time = 6.264003276824951s
# Test Time / sample = 0.005423379460454503s
# Model Test: Completed

# %% [markdown]
# **MobileNet**

# %% [markdown]
# **MobileNet: Import Libraries**

# %%
############################################################################################################################################################################
# IMPORT LIBRARIES #
# import libraries
print(f'MobileNet / Import Libraries: Starting')
import tensorflow as tf
from keras.models import Model
# from keras.optimizers import SGD
from keras.optimizers import Adam
# from keras.layers.normalization import BatchNormalization
from keras.layers.core import Dense, Dropout, Activation
# from keras.preprocessing.image import ImageDataGenerator
# from tensorflow.keras import regularizers
print(f'MobileNet / Import Libraries: Completed')
############################################################################################################################################################################
# Out:
# MobileNet / Import Libraries: Starting
# MobileNet / Import Libraries: Completed

# %% [markdown]
# **MobileNet: Define function to define the model**

# %%
def define_model_mobilenet(version):
  ############################################################################################################################################################################
  # MODEL DEFINITION #
  print(f'MobileNet{version} Model Definition: Starting')
  # load MobileNet with pre-trained parameters for 'imagenet' challenge
  if (version == 'V1'):
    # mobilenet = tf.keras.applications.mobilenet.MobileNet()
    mobilenet = tf.keras.applications.MobileNet()
  elif (version == 'V2'):
    mobilenet = tf.keras.applications.MobileNetV2()

  # understand mobilenet layers   
  # mobilenet.summary()

  # define the last layers

  # get the output of the last layer of the MobileNet
  prediction = mobilenet.output

  # mobilenet already has a GAP layer, hence we need to only add a FCN

  # add a FCN w/o regularizer
  prediction = Dense(DENSE_LAYER_NEURONS, activation = 'relu')(prediction)
  # add FCN w/ regularizer
  # did not help improve accuracy, hence, commented
  # prediction = Dense(1024, activation = 'relu', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), 
  #                      activity_regularizer = regularizers.l2(1e-5))(prediction)

  # batch normalization
  # did not help improve accuracy, hence, commented
  # we will split the actions to have the Batch Normalization done befor relu
  # prediction = Dense(1024)(prediction)
  # prediction = BatchNormalization()(prediction)
  # prediction = Activation('relu')(prediction)

  # add a dropout to avoid overfitting
  prediction = Dropout(DENSE_LAYER_DROPOUT)(prediction)

  # add a FCN with 2 output neurons corresponding to the 2 classes we want to predict
  # without regularizer
  prediction = Dense(2, activation = 'softmax')(prediction)
  # with regularizer
  # prediction = Dense(2, activation = 'softmax', kernel_regularizer = regularizers.l2(1e-4), bias_regularizer = regularizers.l2(1e-4), 
  #                      activity_regularizer = regularizers.l2(1e-5))(prediction)

  # connect the last layer with MobileNet layer to define the model
  model = Model(inputs = mobilenet.input, outputs = prediction)

  # we wish use the pretrained MobileNet model as is i.e. do not want it's parameters to get updated during training
  for layer in mobilenet.layers:
    layer.trainable = False

  # define the optimizer, loss function, metrics we will use
  # model.compile(optimizer = SGD(lr=0.0001, momentum = 0.9), loss = 'categorical_crossentropy', metrics = ['accuracy'])
  model.compile(optimizer = Adam(lr=LEARNING_RATE), loss = 'categorical_crossentropy', metrics = ['accuracy'])

  # run to see layers, number of parameters (total/trainable/non-trainable)
  # model.summary()

  # calculate FLOPS for the model
  flops = get_flops(model, batch_size = 1)
  print(f"MobileNet{version} FLOPS: {flops / 10 ** 9:.03} G")

  # let us check the layers in the model 
  # for i,layer in enumerate(model.layers):
  #  print(i,layer.name)

  print(f'MobileNet{version} Model Definition: Completed')
  return model
  ############################################################################################################################################################################

# %% [markdown]
# **MobileNetV1**

# %% [markdown]
# **MobileNetV1 XFR: Train/Validate/Test/Cross Validate/Convert the Model**

# %%
print('#######################################################################################################################################')
model_mobilenetv1xfr = define_model_mobilenet('V1')
#model_mobilenetv1xfr.summary()
path_to_mobilenetv1xfr_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr.hdf5'
model_mobilenetv1xfr = train_and_validate_model(model_mobilenetv1xfr, train_images, train_labels, validation_images, validation_labels,path_to_mobilenetv1xfr_params_file)
model_mobilenetv1xfr = test_model_with_best_params(model_mobilenetv1xfr, path_to_mobilenetv1xfr_params_file, test_images, test_labels)
print('#######################################################################################################################################')
if (CROSS_VALIDATE == True):
  # cross validate and get the path to the file containing best cross validation fold's parameters
  path_to_mobilenetv1xfr_best_cv_fold_params_file = cross_validate_model('mobilenetv1xfr', all_images, all_labels, all_labels_before_categorical)
  print(f'Path to Best CV Fold Params: {path_to_mobilenetv1xfr_best_cv_fold_params_file}')
  # define a model, load best cross validation fold params, test
  model_mobilenetv1xfr_cv = define_model_mobilenet('V1')
  model_mobilenetv1xfr_cv = test_model_with_best_params(model_mobilenetv1xfr_cv, path_to_mobilenetv1xfr_best_cv_fold_params_file, test_images, test_labels)
  # convert to TensorFlowLite Model
  # specify the path to save the model
  saved_model_dir = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/TFLite/mobilenetv1xfr'
  # save the model in the path
  tf.saved_model.save(model_mobilenetv1xfr_cv, saved_model_dir)
  # convert the model to tensorflowlite model
  converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
  tflite_model = converter.convert()
  # save the tensorflowlite model
  with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# #######################################################################################################################################
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Model Train and Validation: Starting
# Epoch 1/100
# 77/77 [==============================] - 4s 37ms/step - loss: 0.5886 - accuracy: 0.7320 - val_loss: 0.4904 - val_accuracy: 0.7781
#
# Epoch 00001: val_accuracy improved from -inf to 0.77807, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr.hdf5
# Epoch 2/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.5164 - accuracy: 0.7457 - val_loss: 0.4841 - val_accuracy: 0.7701
#
# Epoch 00002: val_accuracy did not improve from 0.77807
# Epoch 3/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.5501 - accuracy: 0.7328 - val_loss: 0.4473 - val_accuracy: 0.7941
#
# Epoch 00003: val_accuracy improved from 0.77807 to 0.79412, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr.hdf5
# Epoch 4/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.5215 - accuracy: 0.7625 - val_loss: 0.4678 - val_accuracy: 0.7701
#
# Epoch 00004: val_accuracy did not improve from 0.79412
# Epoch 5/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.5043 - accuracy: 0.7727 - val_loss: 0.3982 - val_accuracy: 0.8262
#
# Epoch 00005: val_accuracy improved from 0.79412 to 0.82620, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr.hdf5
# Epoch 6/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.5494 - accuracy: 0.7583 - val_loss: 0.4077 - val_accuracy: 0.8262
#
# Epoch 00006: val_accuracy did not improve from 0.82620
# Epoch 7/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4690 - accuracy: 0.7818 - val_loss: 0.4332 - val_accuracy: 0.8449
#
# Epoch 00007: val_accuracy improved from 0.82620 to 0.84492, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr.hdf5
# Epoch 8/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4832 - accuracy: 0.7971 - val_loss: 0.3986 - val_accuracy: 0.8155
#
# Epoch 00008: val_accuracy did not improve from 0.84492
# Epoch 9/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.5036 - accuracy: 0.7820 - val_loss: 0.5248 - val_accuracy: 0.7406
#
# Epoch 00009: val_accuracy did not improve from 0.84492
# Epoch 10/100
# 77/77 [==============================] - 3s 44ms/step - loss: 0.5175 - accuracy: 0.7561 - val_loss: 0.4635 - val_accuracy: 0.7727
#
# Epoch 00010: val_accuracy did not improve from 0.84492
# Epoch 11/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4779 - accuracy: 0.7692 - val_loss: 0.3883 - val_accuracy: 0.8316
#
# Epoch 00011: val_accuracy did not improve from 0.84492
# Epoch 12/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4291 - accuracy: 0.8223 - val_loss: 0.4117 - val_accuracy: 0.8396
#
# Epoch 00012: val_accuracy did not improve from 0.84492
# Epoch 13/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4738 - accuracy: 0.7827 - val_loss: 0.4309 - val_accuracy: 0.7968
#
# Epoch 00013: val_accuracy did not improve from 0.84492
# Epoch 14/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4292 - accuracy: 0.8027 - val_loss: 0.4239 - val_accuracy: 0.7888
#
# Epoch 00014: val_accuracy did not improve from 0.84492
# Epoch 15/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4366 - accuracy: 0.8138 - val_loss: 0.4258 - val_accuracy: 0.8369
#
# Epoch 00015: val_accuracy did not improve from 0.84492
# Epoch 16/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4533 - accuracy: 0.7923 - val_loss: 0.4062 - val_accuracy: 0.8075
#
# Epoch 00016: val_accuracy did not improve from 0.84492
# Epoch 17/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4505 - accuracy: 0.7902 - val_loss: 0.4021 - val_accuracy: 0.8128
#
# Epoch 00017: val_accuracy did not improve from 0.84492
# Epoch 18/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3910 - accuracy: 0.8213 - val_loss: 0.4123 - val_accuracy: 0.8075
#
# Epoch 00018: val_accuracy did not improve from 0.84492
# Epoch 19/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4233 - accuracy: 0.8136 - val_loss: 0.4017 - val_accuracy: 0.8155
#
# Epoch 00019: val_accuracy did not improve from 0.84492
# Epoch 20/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4451 - accuracy: 0.8097 - val_loss: 0.4336 - val_accuracy: 0.7914
#
# Epoch 00020: val_accuracy did not improve from 0.84492
# Epoch 21/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3802 - accuracy: 0.8474 - val_loss: 0.4502 - val_accuracy: 0.7834
#
# Epoch 00021: val_accuracy did not improve from 0.84492
# Epoch 22/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4227 - accuracy: 0.8173 - val_loss: 0.4213 - val_accuracy: 0.8262
#
# Epoch 00022: val_accuracy did not improve from 0.84492
# Epoch 23/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4611 - accuracy: 0.7725 - val_loss: 0.4437 - val_accuracy: 0.7807
#
# Epoch 00023: val_accuracy did not improve from 0.84492
# Epoch 24/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3959 - accuracy: 0.8251 - val_loss: 0.4518 - val_accuracy: 0.7807
#
# Epoch 00024: val_accuracy did not improve from 0.84492
# Epoch 25/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4164 - accuracy: 0.8163 - val_loss: 0.4136 - val_accuracy: 0.8209
#
# Epoch 00025: val_accuracy did not improve from 0.84492
# Epoch 26/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3811 - accuracy: 0.8203 - val_loss: 0.4634 - val_accuracy: 0.7834
#
# Epoch 00026: val_accuracy did not improve from 0.84492
# Epoch 27/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4239 - accuracy: 0.7964 - val_loss: 0.4086 - val_accuracy: 0.8182
#
# Epoch 00027: val_accuracy did not improve from 0.84492
# Epoch 28/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4054 - accuracy: 0.8261 - val_loss: 0.4450 - val_accuracy: 0.7781
#
# Epoch 00028: val_accuracy did not improve from 0.84492
# Epoch 29/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3829 - accuracy: 0.8466 - val_loss: 0.4504 - val_accuracy: 0.7941
#
# Epoch 00029: val_accuracy did not improve from 0.84492
# Epoch 30/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4079 - accuracy: 0.8329 - val_loss: 0.4345 - val_accuracy: 0.7941
#
# Epoch 00030: val_accuracy did not improve from 0.84492
# Epoch 31/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3914 - accuracy: 0.8231 - val_loss: 0.4798 - val_accuracy: 0.7594
#
# Epoch 00031: val_accuracy did not improve from 0.84492
# Epoch 32/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3908 - accuracy: 0.8288 - val_loss: 0.3946 - val_accuracy: 0.8262
#
# Epoch 00032: val_accuracy did not improve from 0.84492
# Epoch 33/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3738 - accuracy: 0.8318 - val_loss: 0.4111 - val_accuracy: 0.8102
#
# Epoch 00033: val_accuracy did not improve from 0.84492
# Epoch 34/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3874 - accuracy: 0.8239 - val_loss: 0.3983 - val_accuracy: 0.8235
#
# Epoch 00034: val_accuracy did not improve from 0.84492
# Epoch 35/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3734 - accuracy: 0.8561 - val_loss: 0.4654 - val_accuracy: 0.7807
#
# Epoch 00035: val_accuracy did not improve from 0.84492
# Epoch 36/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3981 - accuracy: 0.8203 - val_loss: 0.4013 - val_accuracy: 0.8342
#
# Epoch 00036: val_accuracy did not improve from 0.84492
# Epoch 37/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3925 - accuracy: 0.8369 - val_loss: 0.3997 - val_accuracy: 0.8155
#
# Epoch 00037: val_accuracy did not improve from 0.84492
# Epoch 38/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3753 - accuracy: 0.8522 - val_loss: 0.4116 - val_accuracy: 0.8289
#
# Epoch 00038: val_accuracy did not improve from 0.84492
# Epoch 39/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3666 - accuracy: 0.8343 - val_loss: 0.4508 - val_accuracy: 0.7807
#
# Epoch 00039: val_accuracy did not improve from 0.84492
# Epoch 40/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3844 - accuracy: 0.8213 - val_loss: 0.4490 - val_accuracy: 0.7834
#
# Epoch 00040: val_accuracy did not improve from 0.84492
# Epoch 41/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3633 - accuracy: 0.8493 - val_loss: 0.4005 - val_accuracy: 0.8209
#
# Epoch 00041: val_accuracy did not improve from 0.84492
# Epoch 42/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4340 - accuracy: 0.8148 - val_loss: 0.5014 - val_accuracy: 0.7487
#
# Epoch 00042: val_accuracy did not improve from 0.84492
# Epoch 43/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4372 - accuracy: 0.7904 - val_loss: 0.4846 - val_accuracy: 0.7914
#
# Epoch 00043: val_accuracy did not improve from 0.84492
# Epoch 44/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3719 - accuracy: 0.8601 - val_loss: 0.4179 - val_accuracy: 0.8182
#
# Epoch 00044: val_accuracy did not improve from 0.84492
# Epoch 45/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3378 - accuracy: 0.8752 - val_loss: 0.4222 - val_accuracy: 0.8182
#
# Epoch 00045: val_accuracy did not improve from 0.84492
# Epoch 46/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4317 - accuracy: 0.7958 - val_loss: 0.4904 - val_accuracy: 0.7781
#
# Epoch 00046: val_accuracy did not improve from 0.84492
# Epoch 47/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3479 - accuracy: 0.8600 - val_loss: 0.5493 - val_accuracy: 0.7487
#
# Epoch 00047: val_accuracy did not improve from 0.84492
# Epoch 48/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.4046 - accuracy: 0.8017 - val_loss: 0.4328 - val_accuracy: 0.8021
#
# Epoch 00048: val_accuracy did not improve from 0.84492
# Epoch 49/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3494 - accuracy: 0.8474 - val_loss: 0.4189 - val_accuracy: 0.8289
#
# Epoch 00049: val_accuracy did not improve from 0.84492
# Epoch 50/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3795 - accuracy: 0.8319 - val_loss: 0.4074 - val_accuracy: 0.8369
#
# Epoch 00050: val_accuracy did not improve from 0.84492
# Epoch 51/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3726 - accuracy: 0.8229 - val_loss: 0.4117 - val_accuracy: 0.8289
#
# Epoch 00051: val_accuracy did not improve from 0.84492
# Epoch 52/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3937 - accuracy: 0.8463 - val_loss: 0.4217 - val_accuracy: 0.8155
#
# Epoch 00052: val_accuracy did not improve from 0.84492
# Epoch 53/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3548 - accuracy: 0.8610 - val_loss: 0.4062 - val_accuracy: 0.8369
#
# Epoch 00053: val_accuracy did not improve from 0.84492
# Epoch 54/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3612 - accuracy: 0.8524 - val_loss: 0.4625 - val_accuracy: 0.7861
#
# Epoch 00054: val_accuracy did not improve from 0.84492
# Epoch 55/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3610 - accuracy: 0.8347 - val_loss: 0.5138 - val_accuracy: 0.7727
#
# Epoch 00055: val_accuracy did not improve from 0.84492
# Epoch 56/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3936 - accuracy: 0.8355 - val_loss: 0.4788 - val_accuracy: 0.7754
#
# Epoch 00056: val_accuracy did not improve from 0.84492
# Epoch 57/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3395 - accuracy: 0.8568 - val_loss: 0.4407 - val_accuracy: 0.8262
#
# Epoch 00057: val_accuracy did not improve from 0.84492
# Epoch 58/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3377 - accuracy: 0.8540 - val_loss: 0.4519 - val_accuracy: 0.8048
#
# Epoch 00058: val_accuracy did not improve from 0.84492
# Epoch 59/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3198 - accuracy: 0.8622 - val_loss: 0.4563 - val_accuracy: 0.8102
#
# Epoch 00059: val_accuracy did not improve from 0.84492
# Epoch 60/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3199 - accuracy: 0.8685 - val_loss: 0.4105 - val_accuracy: 0.8235
#
# Epoch 00060: val_accuracy did not improve from 0.84492
# Epoch 61/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3603 - accuracy: 0.8290 - val_loss: 0.4354 - val_accuracy: 0.8235
#
# Epoch 00061: val_accuracy did not improve from 0.84492
# Epoch 62/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3312 - accuracy: 0.8628 - val_loss: 0.4244 - val_accuracy: 0.8342
#
# Epoch 00062: val_accuracy did not improve from 0.84492
# Epoch 63/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3263 - accuracy: 0.8641 - val_loss: 0.4209 - val_accuracy: 0.8262
#
# Epoch 00063: val_accuracy did not improve from 0.84492
# Epoch 64/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3223 - accuracy: 0.8598 - val_loss: 0.4376 - val_accuracy: 0.8182
#
# Epoch 00064: val_accuracy did not improve from 0.84492
# Epoch 65/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3067 - accuracy: 0.8623 - val_loss: 0.4703 - val_accuracy: 0.7968
#
# Epoch 00065: val_accuracy did not improve from 0.84492
# Epoch 66/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3041 - accuracy: 0.8675 - val_loss: 0.4452 - val_accuracy: 0.8209
#
# Epoch 00066: val_accuracy did not improve from 0.84492
# Epoch 67/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3129 - accuracy: 0.8679 - val_loss: 0.4314 - val_accuracy: 0.8102
#
# Epoch 00067: val_accuracy did not improve from 0.84492
# Epoch 68/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3493 - accuracy: 0.8444 - val_loss: 0.4437 - val_accuracy: 0.8155
#
# Epoch 00068: val_accuracy did not improve from 0.84492
# Epoch 69/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3203 - accuracy: 0.8627 - val_loss: 0.4323 - val_accuracy: 0.8316
#
# Epoch 00069: val_accuracy did not improve from 0.84492
# Epoch 70/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3463 - accuracy: 0.8426 - val_loss: 0.5081 - val_accuracy: 0.7941
#
# Epoch 00070: val_accuracy did not improve from 0.84492
# Epoch 71/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3309 - accuracy: 0.8567 - val_loss: 0.5496 - val_accuracy: 0.7513
#
# Epoch 00071: val_accuracy did not improve from 0.84492
# Epoch 72/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3479 - accuracy: 0.8457 - val_loss: 0.4436 - val_accuracy: 0.8155
#
# Epoch 00072: val_accuracy did not improve from 0.84492
# Epoch 73/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3141 - accuracy: 0.8598 - val_loss: 0.4934 - val_accuracy: 0.7995
#
# Epoch 00073: val_accuracy did not improve from 0.84492
# Epoch 74/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3308 - accuracy: 0.8459 - val_loss: 0.4760 - val_accuracy: 0.8102
#
# Epoch 00074: val_accuracy did not improve from 0.84492
# Epoch 75/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2930 - accuracy: 0.8795 - val_loss: 0.4919 - val_accuracy: 0.7888
#
# Epoch 00075: val_accuracy did not improve from 0.84492
# Epoch 76/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3344 - accuracy: 0.8406 - val_loss: 0.4787 - val_accuracy: 0.8128
#
# Epoch 00076: val_accuracy did not improve from 0.84492
# Epoch 77/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3490 - accuracy: 0.8251 - val_loss: 0.5113 - val_accuracy: 0.7941
#
# Epoch 00077: val_accuracy did not improve from 0.84492
# Epoch 78/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3079 - accuracy: 0.8746 - val_loss: 0.4477 - val_accuracy: 0.8128
#
# Epoch 00078: val_accuracy did not improve from 0.84492
# Epoch 79/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3362 - accuracy: 0.8434 - val_loss: 0.4640 - val_accuracy: 0.8128
#
# Epoch 00079: val_accuracy did not improve from 0.84492
# Epoch 80/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2655 - accuracy: 0.8970 - val_loss: 0.5005 - val_accuracy: 0.8128
#
# Epoch 00080: val_accuracy did not improve from 0.84492
# Epoch 81/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3012 - accuracy: 0.8472 - val_loss: 0.5466 - val_accuracy: 0.7701
#
# Epoch 00081: val_accuracy did not improve from 0.84492
# Epoch 82/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2983 - accuracy: 0.8753 - val_loss: 0.4551 - val_accuracy: 0.8235
#
# Epoch 00082: val_accuracy did not improve from 0.84492
# Epoch 83/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3579 - accuracy: 0.8395 - val_loss: 0.4343 - val_accuracy: 0.8316
#
# Epoch 00083: val_accuracy did not improve from 0.84492
# Epoch 84/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3054 - accuracy: 0.8547 - val_loss: 0.4298 - val_accuracy: 0.8182
#
# Epoch 00084: val_accuracy did not improve from 0.84492
# Epoch 85/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2724 - accuracy: 0.8771 - val_loss: 0.4671 - val_accuracy: 0.8048
#
# Epoch 00085: val_accuracy did not improve from 0.84492
# Epoch 86/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3105 - accuracy: 0.8858 - val_loss: 0.4563 - val_accuracy: 0.8316
#
# Epoch 00086: val_accuracy did not improve from 0.84492
# Epoch 87/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2697 - accuracy: 0.9062 - val_loss: 0.4870 - val_accuracy: 0.8048
#
# Epoch 00087: val_accuracy did not improve from 0.84492
# Epoch 88/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2958 - accuracy: 0.8801 - val_loss: 0.4748 - val_accuracy: 0.8209
#
# Epoch 00088: val_accuracy did not improve from 0.84492
# Epoch 89/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2707 - accuracy: 0.8793 - val_loss: 0.4814 - val_accuracy: 0.8182
#
# Epoch 00089: val_accuracy did not improve from 0.84492
# Epoch 90/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3041 - accuracy: 0.8661 - val_loss: 0.4563 - val_accuracy: 0.8182
#
# Epoch 00090: val_accuracy did not improve from 0.84492
# Epoch 91/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.2964 - accuracy: 0.8749 - val_loss: 0.4883 - val_accuracy: 0.7968
#
# Epoch 00091: val_accuracy did not improve from 0.84492
# Epoch 92/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2890 - accuracy: 0.8815 - val_loss: 0.4586 - val_accuracy: 0.8396
#
# Epoch 00092: val_accuracy did not improve from 0.84492
# Epoch 93/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3066 - accuracy: 0.8537 - val_loss: 0.5305 - val_accuracy: 0.8048
#
# Epoch 00093: val_accuracy did not improve from 0.84492
# Epoch 94/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2727 - accuracy: 0.8793 - val_loss: 0.4996 - val_accuracy: 0.8048
#
# Epoch 00094: val_accuracy did not improve from 0.84492
# Epoch 95/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2630 - accuracy: 0.8936 - val_loss: 0.5154 - val_accuracy: 0.8075
#
# Epoch 00095: val_accuracy did not improve from 0.84492
# Epoch 96/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3197 - accuracy: 0.8658 - val_loss: 0.4766 - val_accuracy: 0.8209
#
# Epoch 00096: val_accuracy did not improve from 0.84492
# Epoch 97/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2902 - accuracy: 0.8876 - val_loss: 0.5150 - val_accuracy: 0.8021
#
# Epoch 00097: val_accuracy did not improve from 0.84492
# Epoch 98/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2647 - accuracy: 0.8688 - val_loss: 0.5694 - val_accuracy: 0.7995
#
# Epoch 00098: val_accuracy did not improve from 0.84492
# Epoch 99/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2940 - accuracy: 0.8677 - val_loss: 0.5290 - val_accuracy: 0.7941
#
# Epoch 00099: val_accuracy did not improve from 0.84492
# Epoch 100/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2953 - accuracy: 0.8684 - val_loss: 0.4809 - val_accuracy: 0.8209
#
# Epoch 00100: val_accuracy did not improve from 0.84492
# Train and Validation Time = 239.36364245414734s
# Model Train and Validation: Completed
# Model Test: Starting
# 37/37 [==============================] - 2s 56ms/step - loss: 0.4959 - accuracy: 0.7905
# Test Time = 2.1142632961273193s
# Test Time / sample = 0.0018305309923180254s
# Model Test: Completed
# #######################################################################################################################################
# Model Cross Validation: Starting
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 5s 38ms/step - loss: 0.5793 - accuracy: 0.7049 - val_loss: 0.5304 - val_accuracy: 0.7587
#
# Epoch 00001: val_accuracy improved from -inf to 0.75874, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 2/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.5106 - accuracy: 0.7639 - val_loss: 0.5126 - val_accuracy: 0.7797
#
# Epoch 00002: val_accuracy improved from 0.75874 to 0.77972, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 3/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4715 - accuracy: 0.7946 - val_loss: 0.4987 - val_accuracy: 0.7902
#
# Epoch 00003: val_accuracy improved from 0.77972 to 0.79021, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 4/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4755 - accuracy: 0.7888 - val_loss: 0.4940 - val_accuracy: 0.7867
#
# Epoch 00004: val_accuracy did not improve from 0.79021
# Epoch 5/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4742 - accuracy: 0.7869 - val_loss: 0.4869 - val_accuracy: 0.7937
#
# Epoch 00005: val_accuracy improved from 0.79021 to 0.79371, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 6/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4324 - accuracy: 0.7943 - val_loss: 0.4743 - val_accuracy: 0.7762
#
# Epoch 00006: val_accuracy did not improve from 0.79371
# Epoch 7/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4558 - accuracy: 0.8054 - val_loss: 0.4890 - val_accuracy: 0.7797
#
# Epoch 00007: val_accuracy did not improve from 0.79371
# Epoch 8/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4670 - accuracy: 0.7748 - val_loss: 0.4557 - val_accuracy: 0.7972
#
# Epoch 00008: val_accuracy improved from 0.79371 to 0.79720, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 9/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4109 - accuracy: 0.8104 - val_loss: 0.4591 - val_accuracy: 0.7972
#
# Epoch 00009: val_accuracy did not improve from 0.79720
# Epoch 10/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4529 - accuracy: 0.7986 - val_loss: 0.4692 - val_accuracy: 0.7902
#
# Epoch 00010: val_accuracy did not improve from 0.79720
# Epoch 11/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4373 - accuracy: 0.8059 - val_loss: 0.4855 - val_accuracy: 0.7867
#
# Epoch 00011: val_accuracy did not improve from 0.79720
# Epoch 12/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4712 - accuracy: 0.7776 - val_loss: 0.5494 - val_accuracy: 0.7762
#
# Epoch 00012: val_accuracy did not improve from 0.79720
# Epoch 13/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4390 - accuracy: 0.8156 - val_loss: 0.4524 - val_accuracy: 0.7972
#
# Epoch 00013: val_accuracy did not improve from 0.79720
# Epoch 14/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4264 - accuracy: 0.8156 - val_loss: 0.4464 - val_accuracy: 0.7972
#
# Epoch 00014: val_accuracy did not improve from 0.79720
# Epoch 15/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4416 - accuracy: 0.8020 - val_loss: 0.4607 - val_accuracy: 0.7937
#
# Epoch 00015: val_accuracy did not improve from 0.79720
# Epoch 16/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4536 - accuracy: 0.7863 - val_loss: 0.4544 - val_accuracy: 0.7972
#
# Epoch 00016: val_accuracy did not improve from 0.79720
# Epoch 17/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4277 - accuracy: 0.8036 - val_loss: 0.4470 - val_accuracy: 0.8042
#
# Epoch 00017: val_accuracy improved from 0.79720 to 0.80420, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 18/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4291 - accuracy: 0.8036 - val_loss: 0.4710 - val_accuracy: 0.7867
#
# Epoch 00018: val_accuracy did not improve from 0.80420
# Epoch 19/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4123 - accuracy: 0.8331 - val_loss: 0.4956 - val_accuracy: 0.8007
#
# Epoch 00019: val_accuracy did not improve from 0.80420
# Epoch 20/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4415 - accuracy: 0.7841 - val_loss: 0.4503 - val_accuracy: 0.7937
#
# Epoch 00020: val_accuracy did not improve from 0.80420
# Epoch 21/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3988 - accuracy: 0.8256 - val_loss: 0.4630 - val_accuracy: 0.7972
#
# Epoch 00021: val_accuracy did not improve from 0.80420
# Epoch 22/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3779 - accuracy: 0.8338 - val_loss: 0.4628 - val_accuracy: 0.7937
#
# Epoch 00022: val_accuracy did not improve from 0.80420
# Epoch 23/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4089 - accuracy: 0.8243 - val_loss: 0.4555 - val_accuracy: 0.8042
#
# Epoch 00023: val_accuracy did not improve from 0.80420
# Epoch 24/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3996 - accuracy: 0.8281 - val_loss: 0.4756 - val_accuracy: 0.7867
#
# Epoch 00024: val_accuracy did not improve from 0.80420
# Epoch 25/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3571 - accuracy: 0.8449 - val_loss: 0.4571 - val_accuracy: 0.7902
#
# Epoch 00025: val_accuracy did not improve from 0.80420
# Epoch 26/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4139 - accuracy: 0.8026 - val_loss: 0.4518 - val_accuracy: 0.7937
#
# Epoch 00026: val_accuracy did not improve from 0.80420
# Epoch 27/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4053 - accuracy: 0.8239 - val_loss: 0.4719 - val_accuracy: 0.7972
#
# Epoch 00027: val_accuracy did not improve from 0.80420
# Epoch 28/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4004 - accuracy: 0.8127 - val_loss: 0.4902 - val_accuracy: 0.7902
#
# Epoch 00028: val_accuracy did not improve from 0.80420
# Epoch 29/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4400 - accuracy: 0.8273 - val_loss: 0.4656 - val_accuracy: 0.7937
#
# Epoch 00029: val_accuracy did not improve from 0.80420
# Epoch 30/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3723 - accuracy: 0.8446 - val_loss: 0.4781 - val_accuracy: 0.7937
#
# Epoch 00030: val_accuracy did not improve from 0.80420
# Epoch 31/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3549 - accuracy: 0.8599 - val_loss: 0.5000 - val_accuracy: 0.7902
#
# Epoch 00031: val_accuracy did not improve from 0.80420
# Epoch 32/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3847 - accuracy: 0.8392 - val_loss: 0.5175 - val_accuracy: 0.7902
#
# Epoch 00032: val_accuracy did not improve from 0.80420
# Epoch 33/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4062 - accuracy: 0.8501 - val_loss: 0.4533 - val_accuracy: 0.8042
#
# Epoch 00033: val_accuracy did not improve from 0.80420
# Epoch 34/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3784 - accuracy: 0.8227 - val_loss: 0.4421 - val_accuracy: 0.8077
#
# Epoch 00034: val_accuracy improved from 0.80420 to 0.80769, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 35/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3759 - accuracy: 0.8503 - val_loss: 0.4604 - val_accuracy: 0.8112
#
# Epoch 00035: val_accuracy improved from 0.80769 to 0.81119, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 36/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3851 - accuracy: 0.8260 - val_loss: 0.4870 - val_accuracy: 0.7972
#
# Epoch 00036: val_accuracy did not improve from 0.81119
# Epoch 37/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4224 - accuracy: 0.8318 - val_loss: 0.4628 - val_accuracy: 0.7937
#
# Epoch 00037: val_accuracy did not improve from 0.81119
# Epoch 38/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.3691 - accuracy: 0.8274 - val_loss: 0.4759 - val_accuracy: 0.7902
#
# Epoch 00038: val_accuracy did not improve from 0.81119
# Epoch 39/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3500 - accuracy: 0.8682 - val_loss: 0.4867 - val_accuracy: 0.7937
#
# Epoch 00039: val_accuracy did not improve from 0.81119
# Epoch 40/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3801 - accuracy: 0.8267 - val_loss: 0.4912 - val_accuracy: 0.8007
#
# Epoch 00040: val_accuracy did not improve from 0.81119
# Epoch 41/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3605 - accuracy: 0.8425 - val_loss: 0.4633 - val_accuracy: 0.8042
#
# Epoch 00041: val_accuracy did not improve from 0.81119
# Epoch 42/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3633 - accuracy: 0.8422 - val_loss: 0.4746 - val_accuracy: 0.7867
#
# Epoch 00042: val_accuracy did not improve from 0.81119
# Epoch 43/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3308 - accuracy: 0.8630 - val_loss: 0.4512 - val_accuracy: 0.7972
#
# Epoch 00043: val_accuracy did not improve from 0.81119
# Epoch 44/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3586 - accuracy: 0.8643 - val_loss: 0.5065 - val_accuracy: 0.7902
#
# Epoch 00044: val_accuracy did not improve from 0.81119
# Epoch 45/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3978 - accuracy: 0.8213 - val_loss: 0.4556 - val_accuracy: 0.7867
#
# Epoch 00045: val_accuracy did not improve from 0.81119
# Epoch 46/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3785 - accuracy: 0.8261 - val_loss: 0.5240 - val_accuracy: 0.7937
#
# Epoch 00046: val_accuracy did not improve from 0.81119
# Epoch 47/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3343 - accuracy: 0.8764 - val_loss: 0.4838 - val_accuracy: 0.8007
#
# Epoch 00047: val_accuracy did not improve from 0.81119
# Epoch 48/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3267 - accuracy: 0.8631 - val_loss: 0.4689 - val_accuracy: 0.8077
#
# Epoch 00048: val_accuracy did not improve from 0.81119
# Epoch 49/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3527 - accuracy: 0.8550 - val_loss: 0.4646 - val_accuracy: 0.7902
#
# Epoch 00049: val_accuracy did not improve from 0.81119
# Epoch 50/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3123 - accuracy: 0.8650 - val_loss: 0.4691 - val_accuracy: 0.8147
#
# Epoch 00050: val_accuracy improved from 0.81119 to 0.81469, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_0.hdf5
# Epoch 51/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3473 - accuracy: 0.8544 - val_loss: 0.4816 - val_accuracy: 0.7937
#
# Epoch 00051: val_accuracy did not improve from 0.81469
# Epoch 52/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3275 - accuracy: 0.8784 - val_loss: 0.4756 - val_accuracy: 0.7937
#
# Epoch 00052: val_accuracy did not improve from 0.81469
# Epoch 53/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3504 - accuracy: 0.8495 - val_loss: 0.5023 - val_accuracy: 0.8077
#
# Epoch 00053: val_accuracy did not improve from 0.81469
# Epoch 54/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3255 - accuracy: 0.8682 - val_loss: 0.4959 - val_accuracy: 0.7902
#
# Epoch 00054: val_accuracy did not improve from 0.81469
# Epoch 55/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3478 - accuracy: 0.8578 - val_loss: 0.4788 - val_accuracy: 0.7972
#
# Epoch 00055: val_accuracy did not improve from 0.81469
# Epoch 56/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3047 - accuracy: 0.8745 - val_loss: 0.4660 - val_accuracy: 0.7867
#
# Epoch 00056: val_accuracy did not improve from 0.81469
# Epoch 57/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3504 - accuracy: 0.8467 - val_loss: 0.4988 - val_accuracy: 0.7937
#
# Epoch 00057: val_accuracy did not improve from 0.81469
# Epoch 58/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2939 - accuracy: 0.8857 - val_loss: 0.5306 - val_accuracy: 0.7972
#
# Epoch 00058: val_accuracy did not improve from 0.81469
# Epoch 59/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3076 - accuracy: 0.8711 - val_loss: 0.4714 - val_accuracy: 0.7937
#
# Epoch 00059: val_accuracy did not improve from 0.81469
# Epoch 60/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3465 - accuracy: 0.8348 - val_loss: 0.5168 - val_accuracy: 0.7797
#
# Epoch 00060: val_accuracy did not improve from 0.81469
# Epoch 61/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3215 - accuracy: 0.8576 - val_loss: 0.5066 - val_accuracy: 0.7657
#
# Epoch 00061: val_accuracy did not improve from 0.81469
# Epoch 62/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3237 - accuracy: 0.8697 - val_loss: 0.4936 - val_accuracy: 0.8007
#
# Epoch 00062: val_accuracy did not improve from 0.81469
# Epoch 63/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3354 - accuracy: 0.8509 - val_loss: 0.4881 - val_accuracy: 0.8042
#
# Epoch 00063: val_accuracy did not improve from 0.81469
# Epoch 64/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2809 - accuracy: 0.8824 - val_loss: 0.4818 - val_accuracy: 0.7937
#
# Epoch 00064: val_accuracy did not improve from 0.81469
# Epoch 65/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2908 - accuracy: 0.8740 - val_loss: 0.5025 - val_accuracy: 0.8112
#
# Epoch 00065: val_accuracy did not improve from 0.81469
# Epoch 66/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2991 - accuracy: 0.8538 - val_loss: 0.5417 - val_accuracy: 0.7797
#
# Epoch 00066: val_accuracy did not improve from 0.81469
# Epoch 67/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3596 - accuracy: 0.8475 - val_loss: 0.5286 - val_accuracy: 0.8042
#
# Epoch 00067: val_accuracy did not improve from 0.81469
# Epoch 68/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3389 - accuracy: 0.8636 - val_loss: 0.4806 - val_accuracy: 0.7937
#
# Epoch 00068: val_accuracy did not improve from 0.81469
# Epoch 69/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3038 - accuracy: 0.8793 - val_loss: 0.5383 - val_accuracy: 0.7832
#
# Epoch 00069: val_accuracy did not improve from 0.81469
# Epoch 70/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3214 - accuracy: 0.8581 - val_loss: 0.4881 - val_accuracy: 0.8007
#
# Epoch 00070: val_accuracy did not improve from 0.81469
# Epoch 71/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3269 - accuracy: 0.8516 - val_loss: 0.5513 - val_accuracy: 0.7727
#
# Epoch 00071: val_accuracy did not improve from 0.81469
# Epoch 72/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3540 - accuracy: 0.8504 - val_loss: 0.5154 - val_accuracy: 0.7937
#
# Epoch 00072: val_accuracy did not improve from 0.81469
# Epoch 73/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2956 - accuracy: 0.8707 - val_loss: 0.4976 - val_accuracy: 0.7937
#
# Epoch 00073: val_accuracy did not improve from 0.81469
# Epoch 74/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2966 - accuracy: 0.8826 - val_loss: 0.4992 - val_accuracy: 0.7972
#
# Epoch 00074: val_accuracy did not improve from 0.81469
# Epoch 75/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2957 - accuracy: 0.8764 - val_loss: 0.5524 - val_accuracy: 0.7867
#
# Epoch 00075: val_accuracy did not improve from 0.81469
# Epoch 76/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2797 - accuracy: 0.8861 - val_loss: 0.5359 - val_accuracy: 0.7937
#
# Epoch 00076: val_accuracy did not improve from 0.81469
# Epoch 77/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2987 - accuracy: 0.8805 - val_loss: 0.5420 - val_accuracy: 0.7867
#
# Epoch 00077: val_accuracy did not improve from 0.81469
# Epoch 78/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2810 - accuracy: 0.8932 - val_loss: 0.5190 - val_accuracy: 0.7832
#
# Epoch 00078: val_accuracy did not improve from 0.81469
# Epoch 79/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3383 - accuracy: 0.8436 - val_loss: 0.5553 - val_accuracy: 0.7762
#
# Epoch 00079: val_accuracy did not improve from 0.81469
# Epoch 80/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2952 - accuracy: 0.8801 - val_loss: 0.5114 - val_accuracy: 0.7797
#
# Epoch 00080: val_accuracy did not improve from 0.81469
# Epoch 81/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2960 - accuracy: 0.8765 - val_loss: 0.5116 - val_accuracy: 0.7972
#
# Epoch 00081: val_accuracy did not improve from 0.81469
# Epoch 82/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3077 - accuracy: 0.8799 - val_loss: 0.5337 - val_accuracy: 0.7832
#
# Epoch 00082: val_accuracy did not improve from 0.81469
# Epoch 83/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2913 - accuracy: 0.8727 - val_loss: 0.5756 - val_accuracy: 0.8042
#
# Epoch 00083: val_accuracy did not improve from 0.81469
# Epoch 84/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2753 - accuracy: 0.8759 - val_loss: 0.6054 - val_accuracy: 0.7692
#
# Epoch 00084: val_accuracy did not improve from 0.81469
# Epoch 85/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3090 - accuracy: 0.8604 - val_loss: 0.5224 - val_accuracy: 0.7902
#
# Epoch 00085: val_accuracy did not improve from 0.81469
# Epoch 86/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2928 - accuracy: 0.8698 - val_loss: 0.5609 - val_accuracy: 0.7832
#
# Epoch 00086: val_accuracy did not improve from 0.81469
# Epoch 87/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2629 - accuracy: 0.8888 - val_loss: 0.5948 - val_accuracy: 0.7762
#
# Epoch 00087: val_accuracy did not improve from 0.81469
# Epoch 88/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2605 - accuracy: 0.8932 - val_loss: 0.5155 - val_accuracy: 0.7832
#
# Epoch 00088: val_accuracy did not improve from 0.81469
# Epoch 89/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2800 - accuracy: 0.8754 - val_loss: 0.5915 - val_accuracy: 0.7902
#
# Epoch 00089: val_accuracy did not improve from 0.81469
# Epoch 90/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2525 - accuracy: 0.9035 - val_loss: 0.5333 - val_accuracy: 0.7832
#
# Epoch 00090: val_accuracy did not improve from 0.81469
# Epoch 91/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2576 - accuracy: 0.8975 - val_loss: 0.5907 - val_accuracy: 0.8042
#
# Epoch 00091: val_accuracy did not improve from 0.81469
# Epoch 92/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2907 - accuracy: 0.8777 - val_loss: 0.5450 - val_accuracy: 0.7867
#
# Epoch 00092: val_accuracy did not improve from 0.81469
# Epoch 93/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2675 - accuracy: 0.8842 - val_loss: 0.5646 - val_accuracy: 0.7797
#
# Epoch 00093: val_accuracy did not improve from 0.81469
# Epoch 94/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2514 - accuracy: 0.8867 - val_loss: 0.5985 - val_accuracy: 0.7867
#
# Epoch 00094: val_accuracy did not improve from 0.81469
# Epoch 95/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3051 - accuracy: 0.8702 - val_loss: 0.5910 - val_accuracy: 0.7867
#
# Epoch 00095: val_accuracy did not improve from 0.81469
# Epoch 96/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2704 - accuracy: 0.8956 - val_loss: 0.5936 - val_accuracy: 0.7762
#
# Epoch 00096: val_accuracy did not improve from 0.81469
# Epoch 97/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2753 - accuracy: 0.8878 - val_loss: 0.6094 - val_accuracy: 0.8007
#
# Epoch 00097: val_accuracy did not improve from 0.81469
# Epoch 98/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3022 - accuracy: 0.8715 - val_loss: 0.5862 - val_accuracy: 0.7867
#
# Epoch 00098: val_accuracy did not improve from 0.81469
# Epoch 99/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3091 - accuracy: 0.8565 - val_loss: 0.5823 - val_accuracy: 0.7972
#
# Epoch 00099: val_accuracy did not improve from 0.81469
# Epoch 100/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2744 - accuracy: 0.8731 - val_loss: 0.6154 - val_accuracy: 0.7727
#
# Epoch 00100: val_accuracy did not improve from 0.81469
# Cross Validation Accuracy: 75.87%
# Fold #0 Complete
#
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 5s 36ms/step - loss: 0.5902 - accuracy: 0.6761 - val_loss: 0.5598 - val_accuracy: 0.7517
#
# Epoch 00001: val_accuracy improved from -inf to 0.75175, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 2/100
# 86/86 [==============================] - 3s 30ms/step - loss: 0.5209 - accuracy: 0.7688 - val_loss: 0.5336 - val_accuracy: 0.7727
#
# Epoch 00002: val_accuracy improved from 0.75175 to 0.77273, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 3/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4929 - accuracy: 0.7788 - val_loss: 0.5094 - val_accuracy: 0.7692
#
# Epoch 00003: val_accuracy did not improve from 0.77273
# Epoch 4/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4455 - accuracy: 0.8097 - val_loss: 0.5667 - val_accuracy: 0.7203
#
# Epoch 00004: val_accuracy did not improve from 0.77273
# Epoch 5/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4673 - accuracy: 0.7900 - val_loss: 0.5892 - val_accuracy: 0.7622
#
# Epoch 00005: val_accuracy did not improve from 0.77273
# Epoch 6/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4368 - accuracy: 0.8134 - val_loss: 0.5075 - val_accuracy: 0.7797
#
# Epoch 00006: val_accuracy improved from 0.77273 to 0.77972, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 7/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4227 - accuracy: 0.8507 - val_loss: 0.4879 - val_accuracy: 0.7867
#
# Epoch 00007: val_accuracy improved from 0.77972 to 0.78671, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 8/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4378 - accuracy: 0.7910 - val_loss: 0.4980 - val_accuracy: 0.7937
#
# Epoch 00008: val_accuracy improved from 0.78671 to 0.79371, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 9/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4238 - accuracy: 0.8214 - val_loss: 0.5008 - val_accuracy: 0.7902
#
# Epoch 00009: val_accuracy did not improve from 0.79371
# Epoch 10/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4151 - accuracy: 0.8236 - val_loss: 0.4821 - val_accuracy: 0.7867
#
# Epoch 00010: val_accuracy did not improve from 0.79371
# Epoch 11/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4208 - accuracy: 0.8089 - val_loss: 0.4913 - val_accuracy: 0.7797
#
# Epoch 00011: val_accuracy did not improve from 0.79371
# Epoch 12/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4596 - accuracy: 0.7896 - val_loss: 0.4968 - val_accuracy: 0.7902
#
# Epoch 00012: val_accuracy did not improve from 0.79371
# Epoch 13/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4312 - accuracy: 0.7976 - val_loss: 0.4804 - val_accuracy: 0.7867
#
# Epoch 00013: val_accuracy did not improve from 0.79371
# Epoch 14/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4034 - accuracy: 0.8129 - val_loss: 0.5505 - val_accuracy: 0.7692
#
# Epoch 00014: val_accuracy did not improve from 0.79371
# Epoch 15/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4109 - accuracy: 0.8194 - val_loss: 0.4841 - val_accuracy: 0.7832
#
# Epoch 00015: val_accuracy did not improve from 0.79371
# Epoch 16/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4189 - accuracy: 0.8100 - val_loss: 0.4795 - val_accuracy: 0.7972
#
# Epoch 00016: val_accuracy improved from 0.79371 to 0.79720, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_1.hdf5
# Epoch 17/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3863 - accuracy: 0.8213 - val_loss: 0.5333 - val_accuracy: 0.7902
#
# Epoch 00017: val_accuracy did not improve from 0.79720
# Epoch 18/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3999 - accuracy: 0.8167 - val_loss: 0.5703 - val_accuracy: 0.7727
#
# Epoch 00018: val_accuracy did not improve from 0.79720
# Epoch 19/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4038 - accuracy: 0.8184 - val_loss: 0.5072 - val_accuracy: 0.7657
#
# Epoch 00019: val_accuracy did not improve from 0.79720
# Epoch 20/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3772 - accuracy: 0.8381 - val_loss: 0.4921 - val_accuracy: 0.7692
#
# Epoch 00020: val_accuracy did not improve from 0.79720
# Epoch 21/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3907 - accuracy: 0.8250 - val_loss: 0.4928 - val_accuracy: 0.7972
#
# Epoch 00021: val_accuracy did not improve from 0.79720
# Epoch 22/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3727 - accuracy: 0.8393 - val_loss: 0.4841 - val_accuracy: 0.7552
#
# Epoch 00022: val_accuracy did not improve from 0.79720
# Epoch 23/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3978 - accuracy: 0.8385 - val_loss: 0.5036 - val_accuracy: 0.8042
#
# ...
#
# Epoch 00024: val_accuracy did not improve from 0.86713
# Epoch 25/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4172 - accuracy: 0.8200 - val_loss: 0.4460 - val_accuracy: 0.7972
#
# Epoch 00025: val_accuracy did not improve from 0.86713
# Epoch 26/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4205 - accuracy: 0.8081 - val_loss: 0.4319 - val_accuracy: 0.8252
#
# Epoch 00026: val_accuracy did not improve from 0.86713
# Epoch 27/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3548 - accuracy: 0.8501 - val_loss: 0.4414 - val_accuracy: 0.8322
#
# Epoch 00027: val_accuracy did not improve from 0.86713
# Epoch 28/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3887 - accuracy: 0.8392 - val_loss: 0.4340 - val_accuracy: 0.8217
#
# Epoch 00028: val_accuracy did not improve from 0.86713
# Epoch 29/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3910 - accuracy: 0.8140 - val_loss: 0.4326 - val_accuracy: 0.8287
#
# Epoch 00029: val_accuracy did not improve from 0.86713
# Epoch 30/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4034 - accuracy: 0.8025 - val_loss: 0.4452 - val_accuracy: 0.8497
#
# Epoch 00030: val_accuracy did not improve from 0.86713
# Epoch 31/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3567 - accuracy: 0.8393 - val_loss: 0.4564 - val_accuracy: 0.8287
#
# Epoch 00031: val_accuracy did not improve from 0.86713
# Epoch 32/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3591 - accuracy: 0.8302 - val_loss: 0.4401 - val_accuracy: 0.8531
#
# Epoch 00032: val_accuracy did not improve from 0.86713
# Epoch 33/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4069 - accuracy: 0.8092 - val_loss: 0.4523 - val_accuracy: 0.8531
#
# Epoch 00033: val_accuracy did not improve from 0.86713
# Epoch 34/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3832 - accuracy: 0.8275 - val_loss: 0.4548 - val_accuracy: 0.8182
#
# Epoch 00034: val_accuracy did not improve from 0.86713
# Epoch 35/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3873 - accuracy: 0.8173 - val_loss: 0.4796 - val_accuracy: 0.8147
#
# Epoch 00035: val_accuracy did not improve from 0.86713
# Epoch 36/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3766 - accuracy: 0.8302 - val_loss: 0.4692 - val_accuracy: 0.8322
#
# Epoch 00036: val_accuracy did not improve from 0.86713
# Epoch 37/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3739 - accuracy: 0.8227 - val_loss: 0.4442 - val_accuracy: 0.8531
#
# Epoch 00037: val_accuracy did not improve from 0.86713
# Epoch 38/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3662 - accuracy: 0.8303 - val_loss: 0.4575 - val_accuracy: 0.8147
#
# Epoch 00038: val_accuracy did not improve from 0.86713
# Epoch 39/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3885 - accuracy: 0.8249 - val_loss: 0.4604 - val_accuracy: 0.8112
#
# Epoch 00039: val_accuracy did not improve from 0.86713
# Epoch 40/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3176 - accuracy: 0.8674 - val_loss: 0.4820 - val_accuracy: 0.8392
#
# Epoch 00040: val_accuracy did not improve from 0.86713
# Epoch 41/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3631 - accuracy: 0.8311 - val_loss: 0.4784 - val_accuracy: 0.8182
#
# Epoch 00041: val_accuracy did not improve from 0.86713
# Epoch 42/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3171 - accuracy: 0.8589 - val_loss: 0.4632 - val_accuracy: 0.8357
#
# Epoch 00042: val_accuracy did not improve from 0.86713
# Epoch 43/100
# 86/86 [==============================] - 3s 36ms/step - loss: 0.3779 - accuracy: 0.8306 - val_loss: 0.5073 - val_accuracy: 0.7867
#
# Epoch 00043: val_accuracy did not improve from 0.86713
# Epoch 44/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3599 - accuracy: 0.8374 - val_loss: 0.4895 - val_accuracy: 0.8217
#
# Epoch 00044: val_accuracy did not improve from 0.86713
# Epoch 45/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3391 - accuracy: 0.8465 - val_loss: 0.4731 - val_accuracy: 0.8392
#
# Epoch 00045: val_accuracy did not improve from 0.86713
# Epoch 46/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3487 - accuracy: 0.8329 - val_loss: 0.4501 - val_accuracy: 0.8497
#
# Epoch 00046: val_accuracy did not improve from 0.86713
# Epoch 47/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3652 - accuracy: 0.8312 - val_loss: 0.4873 - val_accuracy: 0.8007
#
# Epoch 00047: val_accuracy did not improve from 0.86713
# Epoch 48/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3692 - accuracy: 0.8304 - val_loss: 0.5022 - val_accuracy: 0.8077
#
# Epoch 00048: val_accuracy did not improve from 0.86713
# Epoch 49/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3535 - accuracy: 0.8383 - val_loss: 0.4897 - val_accuracy: 0.8217
#
# Epoch 00049: val_accuracy did not improve from 0.86713
# Epoch 50/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3280 - accuracy: 0.8518 - val_loss: 0.4834 - val_accuracy: 0.8287
#
# Epoch 00050: val_accuracy did not improve from 0.86713
# Epoch 51/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3406 - accuracy: 0.8345 - val_loss: 0.4725 - val_accuracy: 0.8392
#
# Epoch 00051: val_accuracy did not improve from 0.86713
# Epoch 52/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3739 - accuracy: 0.8321 - val_loss: 0.5125 - val_accuracy: 0.8287
#
# Epoch 00052: val_accuracy did not improve from 0.86713
# Epoch 53/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3178 - accuracy: 0.8546 - val_loss: 0.4592 - val_accuracy: 0.8427
#
# Epoch 00053: val_accuracy did not improve from 0.86713
# Epoch 54/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3631 - accuracy: 0.8159 - val_loss: 0.4997 - val_accuracy: 0.8182
#
# Epoch 00054: val_accuracy did not improve from 0.86713
# Epoch 55/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3415 - accuracy: 0.8658 - val_loss: 0.5073 - val_accuracy: 0.8427
#
# Epoch 00055: val_accuracy did not improve from 0.86713
# Epoch 56/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3402 - accuracy: 0.8673 - val_loss: 0.5075 - val_accuracy: 0.8392
#
# Epoch 00056: val_accuracy did not improve from 0.86713
# Epoch 57/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3548 - accuracy: 0.8405 - val_loss: 0.5196 - val_accuracy: 0.8322
#
# Epoch 00057: val_accuracy did not improve from 0.86713
# Epoch 58/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3050 - accuracy: 0.8707 - val_loss: 0.5278 - val_accuracy: 0.8322
#
# Epoch 00058: val_accuracy did not improve from 0.86713
# Epoch 59/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3353 - accuracy: 0.8502 - val_loss: 0.5181 - val_accuracy: 0.8077
#
# Epoch 00059: val_accuracy did not improve from 0.86713
# Epoch 60/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3181 - accuracy: 0.8505 - val_loss: 0.5424 - val_accuracy: 0.8112
#
# Epoch 00060: val_accuracy did not improve from 0.86713
# Epoch 61/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.2967 - accuracy: 0.8599 - val_loss: 0.5290 - val_accuracy: 0.8182
#
# Epoch 00061: val_accuracy did not improve from 0.86713
# Epoch 62/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3314 - accuracy: 0.8296 - val_loss: 0.4834 - val_accuracy: 0.8287
#
# Epoch 00062: val_accuracy did not improve from 0.86713
# Epoch 63/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3792 - accuracy: 0.8218 - val_loss: 0.6516 - val_accuracy: 0.6888
#
# Epoch 00063: val_accuracy did not improve from 0.86713
# Epoch 64/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3423 - accuracy: 0.8497 - val_loss: 0.6380 - val_accuracy: 0.7692
#
# Epoch 00064: val_accuracy did not improve from 0.86713
# Epoch 65/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3438 - accuracy: 0.8445 - val_loss: 0.5252 - val_accuracy: 0.8462
#
# Epoch 00065: val_accuracy did not improve from 0.86713
# Epoch 66/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3260 - accuracy: 0.8384 - val_loss: 0.5658 - val_accuracy: 0.7972
#
# Epoch 00066: val_accuracy did not improve from 0.86713
# Epoch 67/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3152 - accuracy: 0.8499 - val_loss: 0.5418 - val_accuracy: 0.8007
#
# Epoch 00067: val_accuracy did not improve from 0.86713
# Epoch 68/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3245 - accuracy: 0.8555 - val_loss: 0.5744 - val_accuracy: 0.7972
#
# Epoch 00068: val_accuracy did not improve from 0.86713
# Epoch 69/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3260 - accuracy: 0.8585 - val_loss: 0.6047 - val_accuracy: 0.7832
#
# Epoch 00069: val_accuracy did not improve from 0.86713
# Epoch 70/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3149 - accuracy: 0.8525 - val_loss: 0.5743 - val_accuracy: 0.8042
#
# Epoch 00070: val_accuracy did not improve from 0.86713
# Epoch 71/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3201 - accuracy: 0.8677 - val_loss: 0.5938 - val_accuracy: 0.8077
#
# Epoch 00071: val_accuracy did not improve from 0.86713
# Epoch 72/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2959 - accuracy: 0.8735 - val_loss: 0.5973 - val_accuracy: 0.8042
#
# Epoch 00072: val_accuracy did not improve from 0.86713
# Epoch 73/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2647 - accuracy: 0.8733 - val_loss: 0.5693 - val_accuracy: 0.8182
#
# Epoch 00073: val_accuracy did not improve from 0.86713
# Epoch 74/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2990 - accuracy: 0.8716 - val_loss: 0.5745 - val_accuracy: 0.8252
#
# Epoch 00074: val_accuracy did not improve from 0.86713
# Epoch 75/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3534 - accuracy: 0.8506 - val_loss: 0.5421 - val_accuracy: 0.8112
#
# Epoch 00075: val_accuracy did not improve from 0.86713
# Epoch 76/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2974 - accuracy: 0.8725 - val_loss: 0.5800 - val_accuracy: 0.8112
#
# Epoch 00076: val_accuracy did not improve from 0.86713
# Epoch 77/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2956 - accuracy: 0.8451 - val_loss: 0.5743 - val_accuracy: 0.8042
#
# Epoch 00077: val_accuracy did not improve from 0.86713
# Epoch 78/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3277 - accuracy: 0.8428 - val_loss: 0.5604 - val_accuracy: 0.8322
#
# Epoch 00078: val_accuracy did not improve from 0.86713
# Epoch 79/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2603 - accuracy: 0.8973 - val_loss: 0.6515 - val_accuracy: 0.7413
#
# Epoch 00079: val_accuracy did not improve from 0.86713
# Epoch 80/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3000 - accuracy: 0.8576 - val_loss: 0.5556 - val_accuracy: 0.8147
#
# Epoch 00080: val_accuracy did not improve from 0.86713
# Epoch 81/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2707 - accuracy: 0.8903 - val_loss: 0.6012 - val_accuracy: 0.8007
#
# Epoch 00081: val_accuracy did not improve from 0.86713
# Epoch 82/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2896 - accuracy: 0.8720 - val_loss: 0.6305 - val_accuracy: 0.8217
#
# Epoch 00082: val_accuracy did not improve from 0.86713
# Epoch 83/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2619 - accuracy: 0.8976 - val_loss: 0.6067 - val_accuracy: 0.7727
#
# Epoch 00083: val_accuracy did not improve from 0.86713
# Epoch 84/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3113 - accuracy: 0.8754 - val_loss: 0.6171 - val_accuracy: 0.8007
#
# Epoch 00084: val_accuracy did not improve from 0.86713
# Epoch 85/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2878 - accuracy: 0.8772 - val_loss: 0.6130 - val_accuracy: 0.8112
#
# Epoch 00085: val_accuracy did not improve from 0.86713
# Epoch 86/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2737 - accuracy: 0.8801 - val_loss: 0.5450 - val_accuracy: 0.8112
#
# Epoch 00086: val_accuracy did not improve from 0.86713
# Epoch 87/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3033 - accuracy: 0.8588 - val_loss: 0.6582 - val_accuracy: 0.8077
#
# Epoch 00087: val_accuracy did not improve from 0.86713
# Epoch 88/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2689 - accuracy: 0.8939 - val_loss: 0.6235 - val_accuracy: 0.8217
#
# Epoch 00088: val_accuracy did not improve from 0.86713
# Epoch 89/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2574 - accuracy: 0.8816 - val_loss: 0.6329 - val_accuracy: 0.8217
#
# Epoch 00089: val_accuracy did not improve from 0.86713
# Epoch 90/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2916 - accuracy: 0.8820 - val_loss: 0.6235 - val_accuracy: 0.7727
#
# Epoch 00090: val_accuracy did not improve from 0.86713
# Epoch 91/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2678 - accuracy: 0.8874 - val_loss: 0.5568 - val_accuracy: 0.8252
#
# Epoch 00091: val_accuracy did not improve from 0.86713
# Epoch 92/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2891 - accuracy: 0.8596 - val_loss: 0.5833 - val_accuracy: 0.8112
#
# Epoch 00092: val_accuracy did not improve from 0.86713
# Epoch 93/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3137 - accuracy: 0.8748 - val_loss: 0.5818 - val_accuracy: 0.8182
#
# Epoch 00093: val_accuracy did not improve from 0.86713
# Epoch 94/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2597 - accuracy: 0.8877 - val_loss: 0.6367 - val_accuracy: 0.8147
#
# Epoch 00094: val_accuracy did not improve from 0.86713
# Epoch 95/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2538 - accuracy: 0.8816 - val_loss: 0.7098 - val_accuracy: 0.7343
#
# Epoch 00095: val_accuracy did not improve from 0.86713
# Epoch 96/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2642 - accuracy: 0.8876 - val_loss: 0.6176 - val_accuracy: 0.8042
#
# Epoch 00096: val_accuracy did not improve from 0.86713
# Epoch 97/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2960 - accuracy: 0.8819 - val_loss: 0.6195 - val_accuracy: 0.8007
#
# Epoch 00097: val_accuracy did not improve from 0.86713
# Epoch 98/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.2688 - accuracy: 0.8726 - val_loss: 0.6537 - val_accuracy: 0.8252
#
# Epoch 00098: val_accuracy did not improve from 0.86713
# Epoch 99/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2708 - accuracy: 0.8689 - val_loss: 0.6314 - val_accuracy: 0.8217
#
# Epoch 00099: val_accuracy did not improve from 0.86713
# Epoch 100/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2595 - accuracy: 0.8790 - val_loss: 0.6397 - val_accuracy: 0.7902
#
# Epoch 00100: val_accuracy did not improve from 0.86713
# Cross Validation Accuracy: 81.12%
# Fold #3 Complete
#
# Cross Validation Accuracy Mean (+/- Std Deviation): 75.44% (+/- 4.09%)
# Cross Validation Time = 1021.4970147609711s
# Model Cross Validation: Completed
# Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_3.hdf5
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Model Test: Starting
# 37/37 [==============================] - 3s 57ms/step - loss: 0.5599 - accuracy: 0.7636
# Test Time = 2.922698497772217s
# Test Time / sample = 0.0025304748898460753s
# Model Test: Completed
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/TFLite/mobilenetv1xfr/assets

# %% [markdown]
# **MobileNetV1 FT: Train/Validate/Test/Cross Validate the Model**

# %%
print('#######################################################################################################################################')
model_mobilenetv1ft = define_model_mobilenet('V1')
set_trainable_layers_starting_from(model_mobilenetv1ft, MOBILENETV1_TRAINABLE_START_LAYER)
model_mobilenetv1ft.load_weights(path_to_mobilenetv1xfr_params_file)
#model_mobilenetv1ft.summary()
path_to_mobilenetv1ft_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft.hdf5'
model_mobilenetv1ft = train_and_validate_model(model_mobilenetv1ft, train_images, train_labels, validation_images, validation_labels, path_to_mobilenetv1ft_params_file)
model_mobilenetv1ft = test_model_with_best_params(model_mobilenetv1ft, path_to_mobilenetv1ft_params_file, test_images, test_labels)
print('#######################################################################################################################################')
# we shall provide the best params from transfer learning to initialize the model at cross validation
if (CROSS_VALIDATE == True):
  # cross validate and get the path to the file containing best cross validation fold's parameters
  path_to_mobilenetv1ft_best_cv_fold_params_file = cross_validate_model('mobilenetv1ft', all_images, all_labels, all_labels_before_categorical, path_to_mobilenetv1xfr_params_file)
  print(f'Path to Best CV Fold Params: {path_to_mobilenetv1ft_best_cv_fold_params_file}')
  # define a model, load best cross validation fold params, test
  model_mobilenetv1ft_cv = define_model_mobilenet('V1')
  model_mobilenetv1ft_cv = test_model_with_best_params(model_mobilenetv1ft_cv, path_to_mobilenetv1ft_best_cv_fold_params_file, test_images, test_labels)
  # convert to TensorFlowLite Model
  # specify the path to save the model
  saved_model_dir = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/TFLite/mobilenetv1ft'
  # save the model in the path
  tf.saved_model.save(model_mobilenetv1ft_cv, saved_model_dir)
  # convert the model to tensorflowlite model
  converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir)
  tflite_model = converter.convert()
  # save the tensorflowlite model
  with open('model.tflite', 'wb') as f:
    f.write(tflite_model)
# Out:
# #######################################################################################################################################
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Model Train and Validation: Starting
# Epoch 1/100
# 77/77 [==============================] - 4s 37ms/step - loss: 0.4854 - accuracy: 0.7676 - val_loss: 0.4053 - val_accuracy: 0.8182
#
# Epoch 00001: val_accuracy improved from -inf to 0.81818, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft.hdf5
# Epoch 2/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4900 - accuracy: 0.7604 - val_loss: 0.4151 - val_accuracy: 0.8102
#
# Epoch 00002: val_accuracy did not improve from 0.81818
# Epoch 3/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4461 - accuracy: 0.7874 - val_loss: 0.4278 - val_accuracy: 0.8155
#
# Epoch 00003: val_accuracy did not improve from 0.81818
# Epoch 4/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4721 - accuracy: 0.7788 - val_loss: 0.4069 - val_accuracy: 0.8529
#
# Epoch 00004: val_accuracy improved from 0.81818 to 0.85294, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft.hdf5
# Epoch 5/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4652 - accuracy: 0.7724 - val_loss: 0.4090 - val_accuracy: 0.8235
#
# Epoch 00005: val_accuracy did not improve from 0.85294
# Epoch 6/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4530 - accuracy: 0.7825 - val_loss: 0.4040 - val_accuracy: 0.8182
#
# Epoch 00006: val_accuracy did not improve from 0.85294
# Epoch 7/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4546 - accuracy: 0.7979 - val_loss: 0.4253 - val_accuracy: 0.8262
#
# Epoch 00007: val_accuracy did not improve from 0.85294
# Epoch 8/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4562 - accuracy: 0.7963 - val_loss: 0.3820 - val_accuracy: 0.8289
#
# Epoch 00008: val_accuracy did not improve from 0.85294
# Epoch 9/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4426 - accuracy: 0.7945 - val_loss: 0.4699 - val_accuracy: 0.7754
#
# Epoch 00009: val_accuracy did not improve from 0.85294
# Epoch 10/100
# 77/77 [==============================] - 3s 42ms/step - loss: 0.4761 - accuracy: 0.7831 - val_loss: 0.4058 - val_accuracy: 0.8235
#
# Epoch 00010: val_accuracy did not improve from 0.85294
# Epoch 11/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4426 - accuracy: 0.8211 - val_loss: 0.4170 - val_accuracy: 0.8128
#
# Epoch 00011: val_accuracy did not improve from 0.85294
# Epoch 12/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4086 - accuracy: 0.8318 - val_loss: 0.4167 - val_accuracy: 0.8209
#
# Epoch 00012: val_accuracy did not improve from 0.85294
# Epoch 13/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4297 - accuracy: 0.8104 - val_loss: 0.4229 - val_accuracy: 0.7941
#
# Epoch 00013: val_accuracy did not improve from 0.85294
# Epoch 14/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4672 - accuracy: 0.7719 - val_loss: 0.3932 - val_accuracy: 0.8262
#
# Epoch 00014: val_accuracy did not improve from 0.85294
# Epoch 15/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4391 - accuracy: 0.8101 - val_loss: 0.4153 - val_accuracy: 0.8048
#
# Epoch 00015: val_accuracy did not improve from 0.85294
# Epoch 16/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4018 - accuracy: 0.8238 - val_loss: 0.4691 - val_accuracy: 0.7727
#
# Epoch 00016: val_accuracy did not improve from 0.85294
# Epoch 17/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4093 - accuracy: 0.8071 - val_loss: 0.4014 - val_accuracy: 0.8342
#
# Epoch 00017: val_accuracy did not improve from 0.85294
# Epoch 18/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4106 - accuracy: 0.8357 - val_loss: 0.4417 - val_accuracy: 0.7968
#
# Epoch 00018: val_accuracy did not improve from 0.85294
# Epoch 19/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3880 - accuracy: 0.8279 - val_loss: 0.4072 - val_accuracy: 0.8262
#
# Epoch 00019: val_accuracy did not improve from 0.85294
# Epoch 20/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4120 - accuracy: 0.8137 - val_loss: 0.4999 - val_accuracy: 0.7487
#
# Epoch 00020: val_accuracy did not improve from 0.85294
# Epoch 21/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4347 - accuracy: 0.8226 - val_loss: 0.4007 - val_accuracy: 0.8102
#
# Epoch 00021: val_accuracy did not improve from 0.85294
# Epoch 22/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4066 - accuracy: 0.8290 - val_loss: 0.3971 - val_accuracy: 0.8262
#
# Epoch 00022: val_accuracy did not improve from 0.85294
# Epoch 23/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3901 - accuracy: 0.8204 - val_loss: 0.4444 - val_accuracy: 0.7995
#
# Epoch 00023: val_accuracy did not improve from 0.85294
# Epoch 24/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4192 - accuracy: 0.8136 - val_loss: 0.4696 - val_accuracy: 0.7727
#
# Epoch 00024: val_accuracy did not improve from 0.85294
# Epoch 25/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4213 - accuracy: 0.7933 - val_loss: 0.4242 - val_accuracy: 0.8182
#
# Epoch 00025: val_accuracy did not improve from 0.85294
# Epoch 26/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3756 - accuracy: 0.8279 - val_loss: 0.4612 - val_accuracy: 0.7727
#
# Epoch 00026: val_accuracy did not improve from 0.85294
# Epoch 27/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4081 - accuracy: 0.8357 - val_loss: 0.3954 - val_accuracy: 0.8262
#
# Epoch 00027: val_accuracy did not improve from 0.85294
# Epoch 28/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3543 - accuracy: 0.8431 - val_loss: 0.4021 - val_accuracy: 0.8316
#
# Epoch 00028: val_accuracy did not improve from 0.85294
# Epoch 29/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3951 - accuracy: 0.8088 - val_loss: 0.4800 - val_accuracy: 0.7861
#
# Epoch 00029: val_accuracy did not improve from 0.85294
# Epoch 30/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3892 - accuracy: 0.8334 - val_loss: 0.4731 - val_accuracy: 0.7968
#
# Epoch 00030: val_accuracy did not improve from 0.85294
# Epoch 31/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3889 - accuracy: 0.8233 - val_loss: 0.4068 - val_accuracy: 0.8235
#
# Epoch 00031: val_accuracy did not improve from 0.85294
# Epoch 32/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.4108 - accuracy: 0.8080 - val_loss: 0.4517 - val_accuracy: 0.7941
#
# Epoch 00032: val_accuracy did not improve from 0.85294
# Epoch 33/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3984 - accuracy: 0.8237 - val_loss: 0.4610 - val_accuracy: 0.7781
#
# Epoch 00033: val_accuracy did not improve from 0.85294
# Epoch 34/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3593 - accuracy: 0.8390 - val_loss: 0.4400 - val_accuracy: 0.8128
#
# Epoch 00034: val_accuracy did not improve from 0.85294
# Epoch 35/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3581 - accuracy: 0.8343 - val_loss: 0.4222 - val_accuracy: 0.8369
#
# Epoch 00035: val_accuracy did not improve from 0.85294
# Epoch 36/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3700 - accuracy: 0.8306 - val_loss: 0.4089 - val_accuracy: 0.8235
#
# Epoch 00036: val_accuracy did not improve from 0.85294
# Epoch 37/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3951 - accuracy: 0.8335 - val_loss: 0.4087 - val_accuracy: 0.8182
#
# Epoch 00037: val_accuracy did not improve from 0.85294
# Epoch 38/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3724 - accuracy: 0.8295 - val_loss: 0.3950 - val_accuracy: 0.8369
#
# Epoch 00038: val_accuracy did not improve from 0.85294
# Epoch 39/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3661 - accuracy: 0.8554 - val_loss: 0.4877 - val_accuracy: 0.7406
#
# Epoch 00039: val_accuracy did not improve from 0.85294
# Epoch 40/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3952 - accuracy: 0.8284 - val_loss: 0.4154 - val_accuracy: 0.8262
#
# Epoch 00040: val_accuracy did not improve from 0.85294
# Epoch 41/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3616 - accuracy: 0.8358 - val_loss: 0.4215 - val_accuracy: 0.8316
#
# Epoch 00041: val_accuracy did not improve from 0.85294
# Epoch 42/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3733 - accuracy: 0.8148 - val_loss: 0.4379 - val_accuracy: 0.8155
#
# Epoch 00042: val_accuracy did not improve from 0.85294
# Epoch 43/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3535 - accuracy: 0.8612 - val_loss: 0.4381 - val_accuracy: 0.8235
#
# Epoch 00043: val_accuracy did not improve from 0.85294
# Epoch 44/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3430 - accuracy: 0.8595 - val_loss: 0.4365 - val_accuracy: 0.8128
#
# Epoch 00044: val_accuracy did not improve from 0.85294
# Epoch 45/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3465 - accuracy: 0.8590 - val_loss: 0.4388 - val_accuracy: 0.8182
#
# Epoch 00045: val_accuracy did not improve from 0.85294
# Epoch 46/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3443 - accuracy: 0.8477 - val_loss: 0.4127 - val_accuracy: 0.8342
#
# Epoch 00046: val_accuracy did not improve from 0.85294
# Epoch 47/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3286 - accuracy: 0.8528 - val_loss: 0.4437 - val_accuracy: 0.8155
#
# Epoch 00047: val_accuracy did not improve from 0.85294
# Epoch 48/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3530 - accuracy: 0.8479 - val_loss: 0.4328 - val_accuracy: 0.8316
#
# Epoch 00048: val_accuracy did not improve from 0.85294
# Epoch 49/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3510 - accuracy: 0.8531 - val_loss: 0.4746 - val_accuracy: 0.7941
#
# Epoch 00049: val_accuracy did not improve from 0.85294
# Epoch 50/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3045 - accuracy: 0.8753 - val_loss: 0.4484 - val_accuracy: 0.8075
#
# Epoch 00050: val_accuracy did not improve from 0.85294
# Epoch 51/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3659 - accuracy: 0.8378 - val_loss: 0.4349 - val_accuracy: 0.8262
#
# Epoch 00051: val_accuracy did not improve from 0.85294
# Epoch 52/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3884 - accuracy: 0.8195 - val_loss: 0.4593 - val_accuracy: 0.7995
#
# Epoch 00052: val_accuracy did not improve from 0.85294
# Epoch 53/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3510 - accuracy: 0.8602 - val_loss: 0.4499 - val_accuracy: 0.8128
#
# Epoch 00053: val_accuracy did not improve from 0.85294
# Epoch 54/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3075 - accuracy: 0.8675 - val_loss: 0.4325 - val_accuracy: 0.8262
#
# Epoch 00054: val_accuracy did not improve from 0.85294
# Epoch 55/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3746 - accuracy: 0.8175 - val_loss: 0.4620 - val_accuracy: 0.8102
#
# Epoch 00055: val_accuracy did not improve from 0.85294
# Epoch 56/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3598 - accuracy: 0.8283 - val_loss: 0.4759 - val_accuracy: 0.8021
#
# Epoch 00056: val_accuracy did not improve from 0.85294
# Epoch 57/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3917 - accuracy: 0.8289 - val_loss: 0.4566 - val_accuracy: 0.8182
#
# Epoch 00057: val_accuracy did not improve from 0.85294
# Epoch 58/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3576 - accuracy: 0.8412 - val_loss: 0.4637 - val_accuracy: 0.7968
#
# Epoch 00058: val_accuracy did not improve from 0.85294
# Epoch 59/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3584 - accuracy: 0.8298 - val_loss: 0.4881 - val_accuracy: 0.7861
#
# Epoch 00059: val_accuracy did not improve from 0.85294
# Epoch 60/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3344 - accuracy: 0.8329 - val_loss: 0.4742 - val_accuracy: 0.8048
#
# Epoch 00060: val_accuracy did not improve from 0.85294
# Epoch 61/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3516 - accuracy: 0.8477 - val_loss: 0.4271 - val_accuracy: 0.8316
#
# Epoch 00061: val_accuracy did not improve from 0.85294
# Epoch 62/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3161 - accuracy: 0.8489 - val_loss: 0.4846 - val_accuracy: 0.7995
#
# Epoch 00062: val_accuracy did not improve from 0.85294
# Epoch 63/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3453 - accuracy: 0.8285 - val_loss: 0.5193 - val_accuracy: 0.7888
#
# Epoch 00063: val_accuracy did not improve from 0.85294
# Epoch 64/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3242 - accuracy: 0.8744 - val_loss: 0.4594 - val_accuracy: 0.8209
#
# Epoch 00064: val_accuracy did not improve from 0.85294
# Epoch 65/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3194 - accuracy: 0.8757 - val_loss: 0.4781 - val_accuracy: 0.8102
#
# Epoch 00065: val_accuracy did not improve from 0.85294
# Epoch 66/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3372 - accuracy: 0.8466 - val_loss: 0.4451 - val_accuracy: 0.8342
#
# Epoch 00066: val_accuracy did not improve from 0.85294
# Epoch 67/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3319 - accuracy: 0.8625 - val_loss: 0.4845 - val_accuracy: 0.8209
#
# Epoch 00067: val_accuracy did not improve from 0.85294
# Epoch 68/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2941 - accuracy: 0.8800 - val_loss: 0.4783 - val_accuracy: 0.8182
#
# Epoch 00068: val_accuracy did not improve from 0.85294
# Epoch 69/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3108 - accuracy: 0.8776 - val_loss: 0.4850 - val_accuracy: 0.8048
#
# Epoch 00069: val_accuracy did not improve from 0.85294
# Epoch 70/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2881 - accuracy: 0.8837 - val_loss: 0.5041 - val_accuracy: 0.8021
#
# Epoch 00070: val_accuracy did not improve from 0.85294
# Epoch 71/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3326 - accuracy: 0.8434 - val_loss: 0.4664 - val_accuracy: 0.8289
#
# Epoch 00071: val_accuracy did not improve from 0.85294
# Epoch 72/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3225 - accuracy: 0.8777 - val_loss: 0.4932 - val_accuracy: 0.8235
#
# Epoch 00072: val_accuracy did not improve from 0.85294
# Epoch 73/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2982 - accuracy: 0.8638 - val_loss: 0.5099 - val_accuracy: 0.7781
#
# Epoch 00073: val_accuracy did not improve from 0.85294
# Epoch 74/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2951 - accuracy: 0.8765 - val_loss: 0.5023 - val_accuracy: 0.7861
#
# Epoch 00074: val_accuracy did not improve from 0.85294
# Epoch 75/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.3196 - accuracy: 0.8722 - val_loss: 0.4932 - val_accuracy: 0.8128
#
# Epoch 00075: val_accuracy did not improve from 0.85294
# Epoch 76/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3121 - accuracy: 0.8783 - val_loss: 0.4721 - val_accuracy: 0.8262
#
# Epoch 00076: val_accuracy did not improve from 0.85294
# Epoch 77/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2999 - accuracy: 0.8836 - val_loss: 0.5260 - val_accuracy: 0.8128
#
# Epoch 00077: val_accuracy did not improve from 0.85294
# Epoch 78/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3162 - accuracy: 0.8546 - val_loss: 0.4742 - val_accuracy: 0.8021
#
# Epoch 00078: val_accuracy did not improve from 0.85294
# Epoch 79/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3178 - accuracy: 0.8610 - val_loss: 0.4860 - val_accuracy: 0.7995
#
# Epoch 00079: val_accuracy did not improve from 0.85294
# Epoch 80/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2521 - accuracy: 0.9172 - val_loss: 0.5121 - val_accuracy: 0.8075
#
# Epoch 00080: val_accuracy did not improve from 0.85294
# Epoch 81/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2800 - accuracy: 0.8816 - val_loss: 0.5128 - val_accuracy: 0.7888
#
# Epoch 00081: val_accuracy did not improve from 0.85294
# Epoch 82/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2770 - accuracy: 0.8873 - val_loss: 0.5013 - val_accuracy: 0.7995
#
# Epoch 00082: val_accuracy did not improve from 0.85294
# Epoch 83/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2815 - accuracy: 0.8712 - val_loss: 0.4749 - val_accuracy: 0.8182
#
# Epoch 00083: val_accuracy did not improve from 0.85294
# Epoch 84/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3071 - accuracy: 0.8604 - val_loss: 0.5256 - val_accuracy: 0.7941
#
# Epoch 00084: val_accuracy did not improve from 0.85294
# Epoch 85/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2595 - accuracy: 0.8932 - val_loss: 0.4861 - val_accuracy: 0.8235
#
# Epoch 00085: val_accuracy did not improve from 0.85294
# Epoch 86/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2948 - accuracy: 0.8492 - val_loss: 0.4773 - val_accuracy: 0.8235
#
# Epoch 00086: val_accuracy did not improve from 0.85294
# Epoch 87/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.3006 - accuracy: 0.8801 - val_loss: 0.4738 - val_accuracy: 0.8209
#
# Epoch 00087: val_accuracy did not improve from 0.85294
# Epoch 88/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2511 - accuracy: 0.8959 - val_loss: 0.5048 - val_accuracy: 0.8075
#
# Epoch 00088: val_accuracy did not improve from 0.85294
# Epoch 89/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2539 - accuracy: 0.8945 - val_loss: 0.4699 - val_accuracy: 0.8102
#
# Epoch 00089: val_accuracy did not improve from 0.85294
# Epoch 90/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2812 - accuracy: 0.8717 - val_loss: 0.5348 - val_accuracy: 0.7968
#
# Epoch 00090: val_accuracy did not improve from 0.85294
# Epoch 91/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2369 - accuracy: 0.9006 - val_loss: 0.5043 - val_accuracy: 0.8128
#
# Epoch 00091: val_accuracy did not improve from 0.85294
# Epoch 92/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.3106 - accuracy: 0.8704 - val_loss: 0.4700 - val_accuracy: 0.8155
#
# Epoch 00092: val_accuracy did not improve from 0.85294
# Epoch 93/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2935 - accuracy: 0.8831 - val_loss: 0.5488 - val_accuracy: 0.8048
#
# Epoch 00093: val_accuracy did not improve from 0.85294
# Epoch 94/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2586 - accuracy: 0.8824 - val_loss: 0.5083 - val_accuracy: 0.8021
#
# Epoch 00094: val_accuracy did not improve from 0.85294
# Epoch 95/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2687 - accuracy: 0.8823 - val_loss: 0.4974 - val_accuracy: 0.8102
#
# Epoch 00095: val_accuracy did not improve from 0.85294
# Epoch 96/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2826 - accuracy: 0.8743 - val_loss: 0.5205 - val_accuracy: 0.8048
#
# Epoch 00096: val_accuracy did not improve from 0.85294
# Epoch 97/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2634 - accuracy: 0.8851 - val_loss: 0.5697 - val_accuracy: 0.7861
#
# Epoch 00097: val_accuracy did not improve from 0.85294
# Epoch 98/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2684 - accuracy: 0.8611 - val_loss: 0.4922 - val_accuracy: 0.8235
#
# Epoch 00098: val_accuracy did not improve from 0.85294
# Epoch 99/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.2883 - accuracy: 0.8667 - val_loss: 0.5604 - val_accuracy: 0.7914
#
# Epoch 00099: val_accuracy did not improve from 0.85294
# Epoch 100/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.2666 - accuracy: 0.8832 - val_loss: 0.5035 - val_accuracy: 0.8021
#
# Epoch 00100: val_accuracy did not improve from 0.85294
# Train and Validation Time = 237.16838598251343s
# Model Train and Validation: Completed
# Model Test: Starting
# 37/37 [==============================] - 2s 55ms/step - loss: 0.5361 - accuracy: 0.7827
# Test Time = 2.079399585723877s
# Test Time / sample = 0.0018003459616656944s
# Model Test: Completed
# #######################################################################################################################################
# Model Cross Validation: Starting
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Epoch 1/100
# 86/86 [==============================] - 4s 34ms/step - loss: 0.5049 - accuracy: 0.7731 - val_loss: 0.4402 - val_accuracy: 0.8182
#
# Epoch 00001: val_accuracy improved from -inf to 0.81818, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_0.hdf5
# Epoch 2/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4805 - accuracy: 0.7808 - val_loss: 0.4224 - val_accuracy: 0.8252
#
# Epoch 00002: val_accuracy improved from 0.81818 to 0.82517, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_0.hdf5
# Epoch 3/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4404 - accuracy: 0.8081 - val_loss: 0.4420 - val_accuracy: 0.8007
#
# Epoch 00003: val_accuracy did not improve from 0.82517
# Epoch 4/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4453 - accuracy: 0.8047 - val_loss: 0.4662 - val_accuracy: 0.8112
#
# Epoch 00004: val_accuracy did not improve from 0.82517
# Epoch 5/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4411 - accuracy: 0.7984 - val_loss: 0.4394 - val_accuracy: 0.8112
#
# Epoch 00005: val_accuracy did not improve from 0.82517
# Epoch 6/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4457 - accuracy: 0.8065 - val_loss: 0.4378 - val_accuracy: 0.8217
#
# Epoch 00006: val_accuracy did not improve from 0.82517
# Epoch 7/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3909 - accuracy: 0.8230 - val_loss: 0.4160 - val_accuracy: 0.8182
#
# Epoch 00007: val_accuracy did not improve from 0.82517
# Epoch 8/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4308 - accuracy: 0.7998 - val_loss: 0.4199 - val_accuracy: 0.8182
#
# Epoch 00008: val_accuracy did not improve from 0.82517
# Epoch 9/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4191 - accuracy: 0.8097 - val_loss: 0.4360 - val_accuracy: 0.8182
#
# Epoch 00009: val_accuracy did not improve from 0.82517
# Epoch 10/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3902 - accuracy: 0.8259 - val_loss: 0.4348 - val_accuracy: 0.8147
#
# Epoch 00010: val_accuracy did not improve from 0.82517
# Epoch 11/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3889 - accuracy: 0.8305 - val_loss: 0.4373 - val_accuracy: 0.8147
#
# Epoch 00011: val_accuracy did not improve from 0.82517
# Epoch 12/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4423 - accuracy: 0.8071 - val_loss: 0.4240 - val_accuracy: 0.8182
#
# Epoch 00012: val_accuracy did not improve from 0.82517
# Epoch 13/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4206 - accuracy: 0.8192 - val_loss: 0.4224 - val_accuracy: 0.8252
#
# Epoch 00013: val_accuracy did not improve from 0.82517
# Epoch 14/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4471 - accuracy: 0.7801 - val_loss: 0.4225 - val_accuracy: 0.8252
#
# Epoch 00014: val_accuracy did not improve from 0.82517
# Epoch 15/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4304 - accuracy: 0.8163 - val_loss: 0.4423 - val_accuracy: 0.7937
#
# Epoch 00015: val_accuracy did not improve from 0.82517
# Epoch 16/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4008 - accuracy: 0.8195 - val_loss: 0.4290 - val_accuracy: 0.8112
#
# Epoch 00016: val_accuracy did not improve from 0.82517
# Epoch 17/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4062 - accuracy: 0.8175 - val_loss: 0.4517 - val_accuracy: 0.8077
#
# Epoch 00017: val_accuracy did not improve from 0.82517
# Epoch 18/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4471 - accuracy: 0.8027 - val_loss: 0.4458 - val_accuracy: 0.8182
#
# Epoch 00018: val_accuracy did not improve from 0.82517
# Epoch 19/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3937 - accuracy: 0.8280 - val_loss: 0.4523 - val_accuracy: 0.8287
#
# Epoch 00019: val_accuracy improved from 0.82517 to 0.82867, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_0.hdf5
# Epoch 20/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3636 - accuracy: 0.8446 - val_loss: 0.4272 - val_accuracy: 0.8287
#
# Epoch 00020: val_accuracy did not improve from 0.82867
# Epoch 21/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4104 - accuracy: 0.8105 - val_loss: 0.4288 - val_accuracy: 0.8217
#
# Epoch 00021: val_accuracy did not improve from 0.82867
# Epoch 22/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3700 - accuracy: 0.8400 - val_loss: 0.4483 - val_accuracy: 0.8112
#
# Epoch 00022: val_accuracy did not improve from 0.82867
# Epoch 23/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3689 - accuracy: 0.8408 - val_loss: 0.4470 - val_accuracy: 0.8217
#
# Epoch 00023: val_accuracy did not improve from 0.82867
# Epoch 24/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3839 - accuracy: 0.8285 - val_loss: 0.4741 - val_accuracy: 0.7972
#
# Epoch 00024: val_accuracy did not improve from 0.82867
# Epoch 25/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4107 - accuracy: 0.8294 - val_loss: 0.4427 - val_accuracy: 0.8217
#
# Epoch 00025: val_accuracy did not improve from 0.82867
# Epoch 26/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4054 - accuracy: 0.8124 - val_loss: 0.4262 - val_accuracy: 0.8252
#
# Epoch 00026: val_accuracy did not improve from 0.82867
# Epoch 27/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3462 - accuracy: 0.8587 - val_loss: 0.4340 - val_accuracy: 0.8147
#
# Epoch 00027: val_accuracy did not improve from 0.82867
# Epoch 28/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3877 - accuracy: 0.8295 - val_loss: 0.4603 - val_accuracy: 0.8042
#
# Epoch 00028: val_accuracy did not improve from 0.82867
# Epoch 29/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3591 - accuracy: 0.8509 - val_loss: 0.4324 - val_accuracy: 0.8287
#
# Epoch 00029: val_accuracy did not improve from 0.82867
# Epoch 30/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3850 - accuracy: 0.8306 - val_loss: 0.4946 - val_accuracy: 0.7867
#
# Epoch 00030: val_accuracy did not improve from 0.82867
# Epoch 31/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3496 - accuracy: 0.8514 - val_loss: 0.4378 - val_accuracy: 0.8042
#
# Epoch 00031: val_accuracy did not improve from 0.82867
# Epoch 32/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3740 - accuracy: 0.8276 - val_loss: 0.4788 - val_accuracy: 0.8217
#
# Epoch 00032: val_accuracy did not improve from 0.82867
# Epoch 33/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3783 - accuracy: 0.8197 - val_loss: 0.4567 - val_accuracy: 0.8217
#
# Epoch 00033: val_accuracy did not improve from 0.82867
# Epoch 34/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3892 - accuracy: 0.8346 - val_loss: 0.4778 - val_accuracy: 0.8112
#
# Epoch 00034: val_accuracy did not improve from 0.82867
# Epoch 35/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4186 - accuracy: 0.8207 - val_loss: 0.4575 - val_accuracy: 0.7972
#
# Epoch 00035: val_accuracy did not improve from 0.82867
# Epoch 36/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3499 - accuracy: 0.8526 - val_loss: 0.4318 - val_accuracy: 0.8182
#
# Epoch 00036: val_accuracy did not improve from 0.82867
# Epoch 37/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3374 - accuracy: 0.8515 - val_loss: 0.4805 - val_accuracy: 0.7972
#
# Epoch 00037: val_accuracy did not improve from 0.82867
# Epoch 38/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3894 - accuracy: 0.8214 - val_loss: 0.4877 - val_accuracy: 0.8077
#
# Epoch 00038: val_accuracy did not improve from 0.82867
# Epoch 39/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3344 - accuracy: 0.8421 - val_loss: 0.4690 - val_accuracy: 0.7867
#
# Epoch 00039: val_accuracy did not improve from 0.82867
# Epoch 40/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3550 - accuracy: 0.8596 - val_loss: 0.4655 - val_accuracy: 0.8007
#
# Epoch 00040: val_accuracy did not improve from 0.82867
# Epoch 41/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3748 - accuracy: 0.8394 - val_loss: 0.4919 - val_accuracy: 0.8147
#
# Epoch 00041: val_accuracy did not improve from 0.82867
# Epoch 42/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3335 - accuracy: 0.8516 - val_loss: 0.4971 - val_accuracy: 0.8077
#
# Epoch 00042: val_accuracy did not improve from 0.82867
# Epoch 43/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3520 - accuracy: 0.8507 - val_loss: 0.4631 - val_accuracy: 0.7902
#
# Epoch 00043: val_accuracy did not improve from 0.82867
# Epoch 44/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3383 - accuracy: 0.8584 - val_loss: 0.5198 - val_accuracy: 0.8007
#
# Epoch 00044: val_accuracy did not improve from 0.82867
# Epoch 45/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3687 - accuracy: 0.8485 - val_loss: 0.4627 - val_accuracy: 0.8077
#
# Epoch 00045: val_accuracy did not improve from 0.82867
# Epoch 46/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3620 - accuracy: 0.8400 - val_loss: 0.4875 - val_accuracy: 0.8147
#
# Epoch 00046: val_accuracy did not improve from 0.82867
# Epoch 47/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3296 - accuracy: 0.8451 - val_loss: 0.4845 - val_accuracy: 0.8042
#
# Epoch 00047: val_accuracy did not improve from 0.82867
# Epoch 48/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3529 - accuracy: 0.8293 - val_loss: 0.4814 - val_accuracy: 0.8112
#
# Epoch 00048: val_accuracy did not improve from 0.82867
# Epoch 49/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3176 - accuracy: 0.8772 - val_loss: 0.4984 - val_accuracy: 0.7902
#
# Epoch 00049: val_accuracy did not improve from 0.82867
# Epoch 50/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3300 - accuracy: 0.8516 - val_loss: 0.4627 - val_accuracy: 0.8147
#
# Epoch 00050: val_accuracy did not improve from 0.82867
# Epoch 51/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3098 - accuracy: 0.8730 - val_loss: 0.4857 - val_accuracy: 0.8042
#
# Epoch 00051: val_accuracy did not improve from 0.82867
# Epoch 52/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3568 - accuracy: 0.8388 - val_loss: 0.5054 - val_accuracy: 0.8042
#
# Epoch 00052: val_accuracy did not improve from 0.82867
# Epoch 53/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3321 - accuracy: 0.8584 - val_loss: 0.4844 - val_accuracy: 0.8112
#
# Epoch 00053: val_accuracy did not improve from 0.82867
# Epoch 54/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3214 - accuracy: 0.8379 - val_loss: 0.4802 - val_accuracy: 0.8007
#
# Epoch 00054: val_accuracy did not improve from 0.82867
# Epoch 55/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3222 - accuracy: 0.8540 - val_loss: 0.5037 - val_accuracy: 0.8007
#
# Epoch 00055: val_accuracy did not improve from 0.82867
# Epoch 56/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3101 - accuracy: 0.8674 - val_loss: 0.5083 - val_accuracy: 0.8042
#
# Epoch 00056: val_accuracy did not improve from 0.82867
# Epoch 57/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3329 - accuracy: 0.8534 - val_loss: 0.4827 - val_accuracy: 0.8182
#
# Epoch 00057: val_accuracy did not improve from 0.82867
# Epoch 58/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3189 - accuracy: 0.8678 - val_loss: 0.4914 - val_accuracy: 0.8182
#
# Epoch 00058: val_accuracy did not improve from 0.82867
# Epoch 59/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2986 - accuracy: 0.8718 - val_loss: 0.5008 - val_accuracy: 0.8007
#
# Epoch 00059: val_accuracy did not improve from 0.82867
# Epoch 60/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2814 - accuracy: 0.8751 - val_loss: 0.5191 - val_accuracy: 0.7972
#
# Epoch 00060: val_accuracy did not improve from 0.82867
# Epoch 61/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2918 - accuracy: 0.8570 - val_loss: 0.5186 - val_accuracy: 0.8112
#
# Epoch 00061: val_accuracy did not improve from 0.82867
# Epoch 62/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2672 - accuracy: 0.8809 - val_loss: 0.5106 - val_accuracy: 0.8182
#
# Epoch 00062: val_accuracy did not improve from 0.82867
# Epoch 63/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3019 - accuracy: 0.8631 - val_loss: 0.5115 - val_accuracy: 0.7972
#
# Epoch 00063: val_accuracy did not improve from 0.82867
# Epoch 64/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2968 - accuracy: 0.8702 - val_loss: 0.5200 - val_accuracy: 0.8077
#
# Epoch 00064: val_accuracy did not improve from 0.82867
# Epoch 65/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3112 - accuracy: 0.8725 - val_loss: 0.5526 - val_accuracy: 0.7972
#
# Epoch 00065: val_accuracy did not improve from 0.82867
# Epoch 66/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3421 - accuracy: 0.8294 - val_loss: 0.4972 - val_accuracy: 0.8077
#
# Epoch 00066: val_accuracy did not improve from 0.82867
# Epoch 67/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2590 - accuracy: 0.8892 - val_loss: 0.5108 - val_accuracy: 0.8077
#
# Epoch 00067: val_accuracy did not improve from 0.82867
# Epoch 68/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3308 - accuracy: 0.8575 - val_loss: 0.4865 - val_accuracy: 0.8147
#
# Epoch 00068: val_accuracy did not improve from 0.82867
# Epoch 69/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2897 - accuracy: 0.8811 - val_loss: 0.5228 - val_accuracy: 0.7832
#
# Epoch 00069: val_accuracy did not improve from 0.82867
# Epoch 70/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2669 - accuracy: 0.8840 - val_loss: 0.5246 - val_accuracy: 0.7867
#
# Epoch 00070: val_accuracy did not improve from 0.82867
# Epoch 71/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2813 - accuracy: 0.8746 - val_loss: 0.5219 - val_accuracy: 0.7937
#
# Epoch 00071: val_accuracy did not improve from 0.82867
# Epoch 72/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2905 - accuracy: 0.8693 - val_loss: 0.5342 - val_accuracy: 0.8112
#
# Epoch 00072: val_accuracy did not improve from 0.82867
# Epoch 73/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3514 - accuracy: 0.8531 - val_loss: 0.5365 - val_accuracy: 0.8042
#
# Epoch 00073: val_accuracy did not improve from 0.82867
# Epoch 74/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2695 - accuracy: 0.8925 - val_loss: 0.5182 - val_accuracy: 0.8077
#
# Epoch 00074: val_accuracy did not improve from 0.82867
# Epoch 75/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2928 - accuracy: 0.8558 - val_loss: 0.5578 - val_accuracy: 0.8077
#
# Epoch 00075: val_accuracy did not improve from 0.82867
# Epoch 76/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2667 - accuracy: 0.8897 - val_loss: 0.5467 - val_accuracy: 0.8112
#
# Epoch 00076: val_accuracy did not improve from 0.82867
# Epoch 77/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2975 - accuracy: 0.8817 - val_loss: 0.5185 - val_accuracy: 0.7972
#
# Epoch 00077: val_accuracy did not improve from 0.82867
# Epoch 78/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2943 - accuracy: 0.8744 - val_loss: 0.5107 - val_accuracy: 0.8077
#
# Epoch 00078: val_accuracy did not improve from 0.82867
# Epoch 79/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2598 - accuracy: 0.8964 - val_loss: 0.5282 - val_accuracy: 0.8042
#
# Epoch 00079: val_accuracy did not improve from 0.82867
# Epoch 80/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2860 - accuracy: 0.8636 - val_loss: 0.5373 - val_accuracy: 0.7972
#
# Epoch 00080: val_accuracy did not improve from 0.82867
# Epoch 81/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3001 - accuracy: 0.8554 - val_loss: 0.5311 - val_accuracy: 0.8077
#
# Epoch 00081: val_accuracy did not improve from 0.82867
# Epoch 82/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2637 - accuracy: 0.8939 - val_loss: 0.5347 - val_accuracy: 0.7867
#
# Epoch 00082: val_accuracy did not improve from 0.82867
# Epoch 83/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2771 - accuracy: 0.8783 - val_loss: 0.5588 - val_accuracy: 0.8182
#
# Epoch 00083: val_accuracy did not improve from 0.82867
# Epoch 84/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2807 - accuracy: 0.8703 - val_loss: 0.5433 - val_accuracy: 0.7972
#
# Epoch 00084: val_accuracy did not improve from 0.82867
# Epoch 85/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2896 - accuracy: 0.8771 - val_loss: 0.5728 - val_accuracy: 0.7937
#
# Epoch 00085: val_accuracy did not improve from 0.82867
# Epoch 86/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2625 - accuracy: 0.8762 - val_loss: 0.5515 - val_accuracy: 0.7867
#
# Epoch 00086: val_accuracy did not improve from 0.82867
# Epoch 87/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2934 - accuracy: 0.8720 - val_loss: 0.5321 - val_accuracy: 0.8042
#
# Epoch 00087: val_accuracy did not improve from 0.82867
# Epoch 88/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2638 - accuracy: 0.8911 - val_loss: 0.5527 - val_accuracy: 0.7867
#
# Epoch 00088: val_accuracy did not improve from 0.82867
# Epoch 89/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2580 - accuracy: 0.8975 - val_loss: 0.5754 - val_accuracy: 0.8042
#
# Epoch 00089: val_accuracy did not improve from 0.82867
# Epoch 90/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2757 - accuracy: 0.8809 - val_loss: 0.5909 - val_accuracy: 0.8147
#
# Epoch 00090: val_accuracy did not improve from 0.82867
# Epoch 91/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2812 - accuracy: 0.8823 - val_loss: 0.5708 - val_accuracy: 0.7937
#
# Epoch 00091: val_accuracy did not improve from 0.82867
# Epoch 92/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2772 - accuracy: 0.8823 - val_loss: 0.5778 - val_accuracy: 0.8007
#
# Epoch 00092: val_accuracy did not improve from 0.82867
# Epoch 93/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2709 - accuracy: 0.8798 - val_loss: 0.5811 - val_accuracy: 0.7972
#
# Epoch 00093: val_accuracy did not improve from 0.82867
# Epoch 94/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2600 - accuracy: 0.8998 - val_loss: 0.6196 - val_accuracy: 0.7762
#
# Epoch 00094: val_accuracy did not improve from 0.82867
# Epoch 95/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2674 - accuracy: 0.8919 - val_loss: 0.6193 - val_accuracy: 0.8007
#
# Epoch 00095: val_accuracy did not improve from 0.82867
# Epoch 96/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2329 - accuracy: 0.9020 - val_loss: 0.5886 - val_accuracy: 0.7832
#
# Epoch 00096: val_accuracy did not improve from 0.82867
# Epoch 97/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2827 - accuracy: 0.8560 - val_loss: 0.6177 - val_accuracy: 0.8042
#
# Epoch 00097: val_accuracy did not improve from 0.82867
# Epoch 98/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2630 - accuracy: 0.8894 - val_loss: 0.5583 - val_accuracy: 0.7867
#
# Epoch 00098: val_accuracy did not improve from 0.82867
# Epoch 99/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2621 - accuracy: 0.8778 - val_loss: 0.5788 - val_accuracy: 0.8112
#
# Epoch 00099: val_accuracy did not improve from 0.82867
# Epoch 100/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2734 - accuracy: 0.8660 - val_loss: 0.6187 - val_accuracy: 0.7867
#
# Epoch 00100: val_accuracy did not improve from 0.82867
# Cross Validation Accuracy: 81.82%
# Fold #0 Complete
#
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Epoch 1/100
# 86/86 [==============================] - 4s 35ms/step - loss: 0.4387 - accuracy: 0.8060 - val_loss: 0.4950 - val_accuracy: 0.7867
#
# Epoch 00001: val_accuracy improved from -inf to 0.78671, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_1.hdf5
# Epoch 2/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4365 - accuracy: 0.8147 - val_loss: 0.4856 - val_accuracy: 0.7552
#
# Epoch 00002: val_accuracy did not improve from 0.78671
# Epoch 3/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4674 - accuracy: 0.7904 - val_loss: 0.4756 - val_accuracy: 0.7762
#
# Epoch 00003: val_accuracy did not improve from 0.78671
# Epoch 4/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4260 - accuracy: 0.8152 - val_loss: 0.5194 - val_accuracy: 0.7308
#
# Epoch 00004: val_accuracy did not improve from 0.78671
# Epoch 5/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.5100 - accuracy: 0.7747 - val_loss: 0.5157 - val_accuracy: 0.7448
#
# Epoch 00005: val_accuracy did not improve from 0.78671
# Epoch 6/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.4255 - accuracy: 0.8047 - val_loss: 0.4865 - val_accuracy: 0.7413
#
# Epoch 00006: val_accuracy did not improve from 0.78671
# Epoch 7/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.4002 - accuracy: 0.8280 - val_loss: 0.4770 - val_accuracy: 0.7692
#
# Epoch 00007: val_accuracy did not improve from 0.78671
# Epoch 8/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4107 - accuracy: 0.8202 - val_loss: 0.4835 - val_accuracy: 0.7552
#
# Epoch 00008: val_accuracy did not improve from 0.78671
# Epoch 9/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4368 - accuracy: 0.8214 - val_loss: 0.5001 - val_accuracy: 0.7552
#
# Epoch 00009: val_accuracy did not improve from 0.78671
# Epoch 10/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4351 - accuracy: 0.7967 - val_loss: 0.5099 - val_accuracy: 0.7413
#
# Epoch 00010: val_accuracy did not improve from 0.78671
# Epoch 11/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.4164 - accuracy: 0.8206 - val_loss: 0.4844 - val_accuracy: 0.7587
#
# Epoch 00011: val_accuracy did not improve from 0.78671
# Epoch 12/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3946 - accuracy: 0.8290 - val_loss: 0.4847 - val_accuracy: 0.7692
#
# Epoch 00012: val_accuracy did not improve from 0.78671
# Epoch 13/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3906 - accuracy: 0.8426 - val_loss: 0.4984 - val_accuracy: 0.7483
#
# Epoch 00013: val_accuracy did not improve from 0.78671
# Epoch 14/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3852 - accuracy: 0.8217 - val_loss: 0.4925 - val_accuracy: 0.7552
#
# Epoch 00014: val_accuracy did not improve from 0.78671
# Epoch 15/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3820 - accuracy: 0.8360 - val_loss: 0.5193 - val_accuracy: 0.7448
#
# Epoch 00015: val_accuracy did not improve from 0.78671
# Epoch 16/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3595 - accuracy: 0.8435 - val_loss: 0.4753 - val_accuracy: 0.7587
#
# Epoch 00016: val_accuracy did not improve from 0.78671
# Epoch 17/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3588 - accuracy: 0.8297 - val_loss: 0.4735 - val_accuracy: 0.7937
#
# Epoch 00017: val_accuracy improved from 0.78671 to 0.79371, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_1.hdf5
# Epoch 18/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3740 - accuracy: 0.8260 - val_loss: 0.4727 - val_accuracy: 0.7937
#
# Epoch 00018: val_accuracy did not improve from 0.79371
# Epoch 19/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3612 - accuracy: 0.8397 - val_loss: 0.4835 - val_accuracy: 0.7692
#
# Epoch 00019: val_accuracy did not improve from 0.79371
# Epoch 20/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3587 - accuracy: 0.8459 - val_loss: 0.5102 - val_accuracy: 0.7448
#
# Epoch 00020: val_accuracy did not improve from 0.79371
# Epoch 21/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3914 - accuracy: 0.8237 - val_loss: 0.4737 - val_accuracy: 0.7902
#
# Epoch 00021: val_accuracy did not improve from 0.79371
# Epoch 22/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3965 - accuracy: 0.8128 - val_loss: 0.4992 - val_accuracy: 0.7657
#
# Epoch 00022: val_accuracy did not improve from 0.79371
# Epoch 23/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3830 - accuracy: 0.8409 - val_loss: 0.5165 - val_accuracy: 0.7867
#
# Epoch 00023: val_accuracy did not improve from 0.79371
# Epoch 24/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3973 - accuracy: 0.8213 - val_loss: 0.4974 - val_accuracy: 0.7552
#
# Epoch 00024: val_accuracy did not improve from 0.79371
# Epoch 25/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3654 - accuracy: 0.8446 - val_loss: 0.4760 - val_accuracy: 0.7762
#
# Epoch 00025: val_accuracy did not improve from 0.79371
# Epoch 26/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3863 - accuracy: 0.8201 - val_loss: 0.4908 - val_accuracy: 0.7797
#
# Epoch 00026: val_accuracy did not improve from 0.79371
# Epoch 27/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3662 - accuracy: 0.8465 - val_loss: 0.4965 - val_accuracy: 0.7832
#
# Epoch 00027: val_accuracy did not improve from 0.79371
# Epoch 28/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3758 - accuracy: 0.8392 - val_loss: 0.4774 - val_accuracy: 0.7762
#
# Epoch 00028: val_accuracy did not improve from 0.79371
# Epoch 29/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3705 - accuracy: 0.8357 - val_loss: 0.5190 - val_accuracy: 0.8007
#
# Epoch 00029: val_accuracy improved from 0.79371 to 0.80070, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_1.hdf5
# Epoch 30/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3431 - accuracy: 0.8500 - val_loss: 0.5049 - val_accuracy: 0.7797
#
# Epoch 00030: val_accuracy did not improve from 0.80070
# Epoch 31/100
# ...
#
# Epoch 00024: val_accuracy did not improve from 0.82517
# Epoch 25/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3511 - accuracy: 0.8486 - val_loss: 0.4700 - val_accuracy: 0.8147
#
# Epoch 00025: val_accuracy did not improve from 0.82517
# Epoch 26/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3896 - accuracy: 0.8196 - val_loss: 0.4503 - val_accuracy: 0.8112
#
# Epoch 00026: val_accuracy did not improve from 0.82517
# Epoch 27/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3911 - accuracy: 0.8289 - val_loss: 0.4943 - val_accuracy: 0.8077
#
# Epoch 00027: val_accuracy did not improve from 0.82517
# Epoch 28/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3801 - accuracy: 0.8301 - val_loss: 0.4814 - val_accuracy: 0.7902
#
# Epoch 00028: val_accuracy did not improve from 0.82517
# Epoch 29/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3662 - accuracy: 0.8461 - val_loss: 0.4667 - val_accuracy: 0.7972
#
# Epoch 00029: val_accuracy did not improve from 0.82517
# Epoch 30/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3937 - accuracy: 0.8256 - val_loss: 0.4569 - val_accuracy: 0.8147
#
# Epoch 00030: val_accuracy did not improve from 0.82517
# Epoch 31/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3434 - accuracy: 0.8536 - val_loss: 0.4759 - val_accuracy: 0.8077
#
# Epoch 00031: val_accuracy did not improve from 0.82517
# Epoch 32/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3630 - accuracy: 0.8495 - val_loss: 0.4808 - val_accuracy: 0.8042
#
# Epoch 00032: val_accuracy did not improve from 0.82517
# Epoch 33/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3511 - accuracy: 0.8388 - val_loss: 0.4943 - val_accuracy: 0.8077
#
# Epoch 00033: val_accuracy did not improve from 0.82517
# Epoch 34/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3778 - accuracy: 0.8320 - val_loss: 0.4623 - val_accuracy: 0.8042
#
# Epoch 00034: val_accuracy did not improve from 0.82517
# Epoch 35/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3349 - accuracy: 0.8493 - val_loss: 0.4780 - val_accuracy: 0.7972
#
# Epoch 00035: val_accuracy did not improve from 0.82517
# Epoch 36/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3852 - accuracy: 0.8321 - val_loss: 0.4828 - val_accuracy: 0.8077
#
# Epoch 00036: val_accuracy did not improve from 0.82517
# Epoch 37/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3772 - accuracy: 0.8149 - val_loss: 0.4749 - val_accuracy: 0.8042
#
# Epoch 00037: val_accuracy did not improve from 0.82517
# Epoch 38/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3532 - accuracy: 0.8386 - val_loss: 0.4807 - val_accuracy: 0.8182
#
# Epoch 00038: val_accuracy did not improve from 0.82517
# Epoch 39/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3355 - accuracy: 0.8309 - val_loss: 0.4958 - val_accuracy: 0.8112
#
# Epoch 00039: val_accuracy did not improve from 0.82517
# Epoch 40/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3412 - accuracy: 0.8578 - val_loss: 0.4614 - val_accuracy: 0.8042
#
# Epoch 00040: val_accuracy did not improve from 0.82517
# Epoch 41/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3295 - accuracy: 0.8519 - val_loss: 0.4918 - val_accuracy: 0.8217
#
# Epoch 00041: val_accuracy did not improve from 0.82517
# Epoch 42/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3313 - accuracy: 0.8582 - val_loss: 0.4822 - val_accuracy: 0.8217
#
# Epoch 00042: val_accuracy did not improve from 0.82517
# Epoch 43/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3219 - accuracy: 0.8493 - val_loss: 0.4929 - val_accuracy: 0.8182
#
# Epoch 00043: val_accuracy did not improve from 0.82517
# Epoch 44/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3099 - accuracy: 0.8622 - val_loss: 0.4816 - val_accuracy: 0.8147
#
# Epoch 00044: val_accuracy did not improve from 0.82517
# Epoch 45/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3226 - accuracy: 0.8655 - val_loss: 0.4749 - val_accuracy: 0.8077
#
# Epoch 00045: val_accuracy did not improve from 0.82517
# Epoch 46/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3606 - accuracy: 0.8402 - val_loss: 0.5133 - val_accuracy: 0.8042
#
# Epoch 00046: val_accuracy did not improve from 0.82517
# Epoch 47/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.3051 - accuracy: 0.8823 - val_loss: 0.5192 - val_accuracy: 0.7972
#
# Epoch 00047: val_accuracy did not improve from 0.82517
# Epoch 48/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3543 - accuracy: 0.8386 - val_loss: 0.5095 - val_accuracy: 0.8007
#
# Epoch 00048: val_accuracy did not improve from 0.82517
# Epoch 49/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3166 - accuracy: 0.8491 - val_loss: 0.5325 - val_accuracy: 0.8042
#
# Epoch 00049: val_accuracy did not improve from 0.82517
# Epoch 50/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3162 - accuracy: 0.8589 - val_loss: 0.5012 - val_accuracy: 0.8182
#
# Epoch 00050: val_accuracy did not improve from 0.82517
# Epoch 51/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3532 - accuracy: 0.8388 - val_loss: 0.5149 - val_accuracy: 0.7727
#
# Epoch 00051: val_accuracy did not improve from 0.82517
# Epoch 52/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3030 - accuracy: 0.8960 - val_loss: 0.5052 - val_accuracy: 0.8007
#
# Epoch 00052: val_accuracy did not improve from 0.82517
# Epoch 53/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3184 - accuracy: 0.8598 - val_loss: 0.5205 - val_accuracy: 0.8077
#
# Epoch 00053: val_accuracy did not improve from 0.82517
# Epoch 54/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3263 - accuracy: 0.8701 - val_loss: 0.5336 - val_accuracy: 0.7902
#
# Epoch 00054: val_accuracy did not improve from 0.82517
# Epoch 55/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3157 - accuracy: 0.8582 - val_loss: 0.5538 - val_accuracy: 0.7832
#
# Epoch 00055: val_accuracy did not improve from 0.82517
# Epoch 56/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3034 - accuracy: 0.8696 - val_loss: 0.5178 - val_accuracy: 0.8112
#
# Epoch 00056: val_accuracy did not improve from 0.82517
# Epoch 57/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3090 - accuracy: 0.8501 - val_loss: 0.5527 - val_accuracy: 0.8112
#
# Epoch 00057: val_accuracy did not improve from 0.82517
# Epoch 58/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3202 - accuracy: 0.8585 - val_loss: 0.5650 - val_accuracy: 0.8112
#
# Epoch 00058: val_accuracy did not improve from 0.82517
# Epoch 59/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3204 - accuracy: 0.8609 - val_loss: 0.5378 - val_accuracy: 0.8042
#
# Epoch 00059: val_accuracy did not improve from 0.82517
# Epoch 60/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3068 - accuracy: 0.8628 - val_loss: 0.5678 - val_accuracy: 0.8112
#
# Epoch 00060: val_accuracy did not improve from 0.82517
# Epoch 61/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2950 - accuracy: 0.8601 - val_loss: 0.5657 - val_accuracy: 0.8007
#
# Epoch 00061: val_accuracy did not improve from 0.82517
# Epoch 62/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2919 - accuracy: 0.8820 - val_loss: 0.5407 - val_accuracy: 0.8147
#
# Epoch 00062: val_accuracy did not improve from 0.82517
# Epoch 63/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2990 - accuracy: 0.8601 - val_loss: 0.5485 - val_accuracy: 0.8112
#
# Epoch 00063: val_accuracy did not improve from 0.82517
# Epoch 64/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2948 - accuracy: 0.8684 - val_loss: 0.5686 - val_accuracy: 0.8182
#
# Epoch 00064: val_accuracy did not improve from 0.82517
# Epoch 65/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3048 - accuracy: 0.8462 - val_loss: 0.6001 - val_accuracy: 0.8042
#
# Epoch 00065: val_accuracy did not improve from 0.82517
# Epoch 66/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2961 - accuracy: 0.8714 - val_loss: 0.5703 - val_accuracy: 0.7902
#
# Epoch 00066: val_accuracy did not improve from 0.82517
# Epoch 67/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2939 - accuracy: 0.8805 - val_loss: 0.5650 - val_accuracy: 0.8007
#
# Epoch 00067: val_accuracy did not improve from 0.82517
# Epoch 68/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3035 - accuracy: 0.8795 - val_loss: 0.5476 - val_accuracy: 0.8007
#
# Epoch 00068: val_accuracy did not improve from 0.82517
# Epoch 69/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3228 - accuracy: 0.8646 - val_loss: 0.5749 - val_accuracy: 0.8007
#
# Epoch 00069: val_accuracy did not improve from 0.82517
# Epoch 70/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2701 - accuracy: 0.8882 - val_loss: 0.5755 - val_accuracy: 0.8007
#
# Epoch 00070: val_accuracy did not improve from 0.82517
# Epoch 71/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2942 - accuracy: 0.8741 - val_loss: 0.6084 - val_accuracy: 0.8042
#
# Epoch 00071: val_accuracy did not improve from 0.82517
# Epoch 72/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2856 - accuracy: 0.8609 - val_loss: 0.6114 - val_accuracy: 0.7937
#
# Epoch 00072: val_accuracy did not improve from 0.82517
# Epoch 73/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.3091 - accuracy: 0.8589 - val_loss: 0.6311 - val_accuracy: 0.7692
#
# Epoch 00073: val_accuracy did not improve from 0.82517
# Epoch 74/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2894 - accuracy: 0.8723 - val_loss: 0.5662 - val_accuracy: 0.8077
#
# Epoch 00074: val_accuracy did not improve from 0.82517
# Epoch 75/100
# 86/86 [==============================] - 3s 29ms/step - loss: 0.2820 - accuracy: 0.8760 - val_loss: 0.6117 - val_accuracy: 0.7937
#
# Epoch 00075: val_accuracy did not improve from 0.82517
# Epoch 76/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2887 - accuracy: 0.8665 - val_loss: 0.6667 - val_accuracy: 0.7657
#
# Epoch 00076: val_accuracy did not improve from 0.82517
# Epoch 77/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2936 - accuracy: 0.8660 - val_loss: 0.6228 - val_accuracy: 0.8042
#
# Epoch 00077: val_accuracy did not improve from 0.82517
# Epoch 78/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2775 - accuracy: 0.8884 - val_loss: 0.6023 - val_accuracy: 0.8077
#
# Epoch 00078: val_accuracy did not improve from 0.82517
# Epoch 79/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2892 - accuracy: 0.8731 - val_loss: 0.6535 - val_accuracy: 0.8042
#
# Epoch 00079: val_accuracy did not improve from 0.82517
# Epoch 80/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2815 - accuracy: 0.8866 - val_loss: 0.6608 - val_accuracy: 0.7972
#
# Epoch 00080: val_accuracy did not improve from 0.82517
# Epoch 81/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2857 - accuracy: 0.8633 - val_loss: 0.6041 - val_accuracy: 0.8112
#
# Epoch 00081: val_accuracy did not improve from 0.82517
# Epoch 82/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2804 - accuracy: 0.8665 - val_loss: 0.6339 - val_accuracy: 0.8182
#
# Epoch 00082: val_accuracy did not improve from 0.82517
# Epoch 83/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2597 - accuracy: 0.8834 - val_loss: 0.5955 - val_accuracy: 0.7937
#
# Epoch 00083: val_accuracy did not improve from 0.82517
# Epoch 84/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2815 - accuracy: 0.8751 - val_loss: 0.6368 - val_accuracy: 0.8042
#
# Epoch 00084: val_accuracy did not improve from 0.82517
# Epoch 85/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2303 - accuracy: 0.9154 - val_loss: 0.6227 - val_accuracy: 0.8077
#
# Epoch 00085: val_accuracy did not improve from 0.82517
# Epoch 86/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2794 - accuracy: 0.8714 - val_loss: 0.6407 - val_accuracy: 0.7937
#
# Epoch 00086: val_accuracy did not improve from 0.82517
# Epoch 87/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2707 - accuracy: 0.8978 - val_loss: 0.6547 - val_accuracy: 0.8147
#
# Epoch 00087: val_accuracy did not improve from 0.82517
# Epoch 88/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2759 - accuracy: 0.8785 - val_loss: 0.6664 - val_accuracy: 0.8147
#
# Epoch 00088: val_accuracy did not improve from 0.82517
# Epoch 89/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2888 - accuracy: 0.8745 - val_loss: 0.6701 - val_accuracy: 0.8077
#
# Epoch 00089: val_accuracy did not improve from 0.82517
# Epoch 90/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2665 - accuracy: 0.8728 - val_loss: 0.6239 - val_accuracy: 0.8217
#
# Epoch 00090: val_accuracy did not improve from 0.82517
# Epoch 91/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2643 - accuracy: 0.8783 - val_loss: 0.6271 - val_accuracy: 0.8182
#
# Epoch 00091: val_accuracy did not improve from 0.82517
# Epoch 92/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2587 - accuracy: 0.8907 - val_loss: 0.6204 - val_accuracy: 0.8007
#
# Epoch 00092: val_accuracy did not improve from 0.82517
# Epoch 93/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2622 - accuracy: 0.8815 - val_loss: 0.6858 - val_accuracy: 0.8077
#
# Epoch 00093: val_accuracy did not improve from 0.82517
# Epoch 94/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2697 - accuracy: 0.8763 - val_loss: 0.6487 - val_accuracy: 0.8077
#
# Epoch 00094: val_accuracy did not improve from 0.82517
# Epoch 95/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2851 - accuracy: 0.8933 - val_loss: 0.6504 - val_accuracy: 0.7867
#
# Epoch 00095: val_accuracy did not improve from 0.82517
# Epoch 96/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2671 - accuracy: 0.8977 - val_loss: 0.6658 - val_accuracy: 0.8042
#
# Epoch 00096: val_accuracy did not improve from 0.82517
# Epoch 97/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2485 - accuracy: 0.8913 - val_loss: 0.6371 - val_accuracy: 0.7972
#
# Epoch 00097: val_accuracy did not improve from 0.82517
# Epoch 98/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.2482 - accuracy: 0.8918 - val_loss: 0.6874 - val_accuracy: 0.8007
#
# Epoch 00098: val_accuracy did not improve from 0.82517
# Epoch 99/100
# 86/86 [==============================] - 2s 28ms/step - loss: 0.2649 - accuracy: 0.8948 - val_loss: 0.6898 - val_accuracy: 0.8147
#
# Epoch 00099: val_accuracy did not improve from 0.82517
# Epoch 100/100
# 86/86 [==============================] - 2s 29ms/step - loss: 0.3007 - accuracy: 0.8574 - val_loss: 0.6893 - val_accuracy: 0.8112
#
# Epoch 00100: val_accuracy did not improve from 0.82517
# Cross Validation Accuracy: 80.77%
# Fold #3 Complete
#
# Cross Validation Accuracy Mean (+/- Std Deviation): 80.86% (+/- 1.36%)
# Cross Validation Time = 1007.7840912342072s
# Model Cross Validation: Completed
# Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_2.hdf5
# MobileNetV1 Model Definition: Starting
# MobileNetV1 FLOPS: 1.15 G
# MobileNetV1 Model Definition: Completed
# Model Test: Starting
# 37/37 [==============================] - 3s 57ms/step - loss: 0.5898 - accuracy: 0.7569
# Test Time = 2.910604953765869s
# Test Time / sample = 0.0025200042889747783s
# Model Test: Completed
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/TFLite/mobilenetv1ft/assets

# %% [markdown]
# **MobileNetV2**

# %% [markdown]
# **MobileNetV2 XFR: Train/Validate/Test/Cross Validate the Model**

# %%
print('#######################################################################################################################################')
model_mobilenetv2xfr = define_model_mobilenet('V2')
#model_mobilenetv2xfr.summary()
path_to_mobilenetv2xfr_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5'
model_mobilenetv2xfr = train_and_validate_model(model_mobilenetv2xfr, train_images, train_labels, validation_images, validation_labels, path_to_mobilenetv2xfr_params_file)
model_mobilenetv2xfr = test_model_with_best_params(model_mobilenetv2xfr, path_to_mobilenetv2xfr_params_file, test_images, test_labels)
print('#######################################################################################################################################')
if (CROSS_VALIDATE == True):
  # cross validate and get the path to the file containing best cross validation fold's parameters
  path_to_mobilenetv2xfr_best_cv_fold_params_file = cross_validate_model('mobilenetv2xfr', all_images, all_labels, all_labels_before_categorical)
  print(f'Path to Best CV Fold Params: {path_to_mobilenetv2xfr_best_cv_fold_params_file}')
  # define a model, load best cross validation fold params, test
  model_mobilenetv2xfr_cv = define_model_mobilenet('V2')
  model_mobilenetv2xfr_cv = test_model_with_best_params(model_mobilenetv2xfr_cv, path_to_mobilenetv2xfr_best_cv_fold_params_file, test_images, test_labels)
# Out:
# #######################################################################################################################################
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Model Train and Validation: Starting
# Epoch 1/100
# 77/77 [==============================] - 6s 45ms/step - loss: 0.6529 - accuracy: 0.6319 - val_loss: 0.5744 - val_accuracy: 0.7032
#
# Epoch 00001: val_accuracy improved from -inf to 0.70321, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 2/100
# 77/77 [==============================] - 4s 48ms/step - loss: 0.5928 - accuracy: 0.6898 - val_loss: 0.5316 - val_accuracy: 0.7567
#
# Epoch 00002: val_accuracy improved from 0.70321 to 0.75668, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 3/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5796 - accuracy: 0.7065 - val_loss: 0.5175 - val_accuracy: 0.7781
#
# Epoch 00003: val_accuracy improved from 0.75668 to 0.77807, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 4/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.6103 - accuracy: 0.6694 - val_loss: 0.5588 - val_accuracy: 0.7005
#
# Epoch 00004: val_accuracy did not improve from 0.77807
# Epoch 5/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5743 - accuracy: 0.7100 - val_loss: 0.5251 - val_accuracy: 0.7754
#
# Epoch 00005: val_accuracy did not improve from 0.77807
# Epoch 6/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5555 - accuracy: 0.7485 - val_loss: 0.5442 - val_accuracy: 0.7326
#
# Epoch 00006: val_accuracy did not improve from 0.77807
# Epoch 7/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5859 - accuracy: 0.6771 - val_loss: 0.4884 - val_accuracy: 0.7914
#
# Epoch 00007: val_accuracy improved from 0.77807 to 0.79144, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 8/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5364 - accuracy: 0.7314 - val_loss: 0.5072 - val_accuracy: 0.7941
#
# Epoch 00008: val_accuracy improved from 0.79144 to 0.79412, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 9/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5526 - accuracy: 0.7071 - val_loss: 0.4889 - val_accuracy: 0.7834
#
# Epoch 00009: val_accuracy did not improve from 0.79412
# Epoch 10/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5474 - accuracy: 0.7112 - val_loss: 0.4957 - val_accuracy: 0.7701
#
# Epoch 00010: val_accuracy did not improve from 0.79412
# Epoch 11/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5481 - accuracy: 0.7176 - val_loss: 0.5140 - val_accuracy: 0.7513
#
# Epoch 00011: val_accuracy did not improve from 0.79412
# Epoch 12/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5571 - accuracy: 0.7348 - val_loss: 0.4865 - val_accuracy: 0.7888
#
# Epoch 00012: val_accuracy did not improve from 0.79412
# Epoch 13/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5262 - accuracy: 0.7446 - val_loss: 0.4835 - val_accuracy: 0.7701
#
# Epoch 00013: val_accuracy did not improve from 0.79412
# Epoch 14/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5454 - accuracy: 0.7133 - val_loss: 0.4794 - val_accuracy: 0.7941
#
# Epoch 00014: val_accuracy did not improve from 0.79412
# Epoch 15/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5139 - accuracy: 0.7524 - val_loss: 0.4932 - val_accuracy: 0.7674
#
# Epoch 00015: val_accuracy did not improve from 0.79412
# Epoch 16/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5435 - accuracy: 0.7114 - val_loss: 0.4600 - val_accuracy: 0.7888
#
# Epoch 00016: val_accuracy did not improve from 0.79412
# Epoch 17/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5261 - accuracy: 0.7347 - val_loss: 0.5333 - val_accuracy: 0.7246
#
# Epoch 00017: val_accuracy did not improve from 0.79412
# Epoch 18/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5310 - accuracy: 0.7280 - val_loss: 0.4820 - val_accuracy: 0.8075
#
# Epoch 00018: val_accuracy improved from 0.79412 to 0.80749, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr.hdf5
# Epoch 19/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5310 - accuracy: 0.7388 - val_loss: 0.4774 - val_accuracy: 0.8021
#
# Epoch 00019: val_accuracy did not improve from 0.80749
# Epoch 20/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5017 - accuracy: 0.7501 - val_loss: 0.5066 - val_accuracy: 0.7754
#
# Epoch 00020: val_accuracy did not improve from 0.80749
# Epoch 21/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5502 - accuracy: 0.7040 - val_loss: 0.4668 - val_accuracy: 0.8021
#
# Epoch 00021: val_accuracy did not improve from 0.80749
# Epoch 22/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.5233 - accuracy: 0.7396 - val_loss: 0.4790 - val_accuracy: 0.7594
#
# Epoch 00022: val_accuracy did not improve from 0.80749
# Epoch 23/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5586 - accuracy: 0.7200 - val_loss: 0.4859 - val_accuracy: 0.7540
#
# Epoch 00023: val_accuracy did not improve from 0.80749
# Epoch 24/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5306 - accuracy: 0.7499 - val_loss: 0.4681 - val_accuracy: 0.7834
#
# Epoch 00024: val_accuracy did not improve from 0.80749
# Epoch 25/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4837 - accuracy: 0.7485 - val_loss: 0.4560 - val_accuracy: 0.7807
#
# Epoch 00025: val_accuracy did not improve from 0.80749
# Epoch 26/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4970 - accuracy: 0.7568 - val_loss: 0.5453 - val_accuracy: 0.6818
#
# Epoch 00026: val_accuracy did not improve from 0.80749
# Epoch 27/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5099 - accuracy: 0.7343 - val_loss: 0.4671 - val_accuracy: 0.7995
#
# Epoch 00027: val_accuracy did not improve from 0.80749
# Epoch 28/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5256 - accuracy: 0.7102 - val_loss: 0.4868 - val_accuracy: 0.7834
#
# Epoch 00028: val_accuracy did not improve from 0.80749
# Epoch 29/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5118 - accuracy: 0.7313 - val_loss: 0.4830 - val_accuracy: 0.7567
#
# Epoch 00029: val_accuracy did not improve from 0.80749
# Epoch 30/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5318 - accuracy: 0.7301 - val_loss: 0.4584 - val_accuracy: 0.7834
#
# Epoch 00030: val_accuracy did not improve from 0.80749
# Epoch 31/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5117 - accuracy: 0.7548 - val_loss: 0.4669 - val_accuracy: 0.7968
#
# Epoch 00031: val_accuracy did not improve from 0.80749
# Epoch 32/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4831 - accuracy: 0.7578 - val_loss: 0.4860 - val_accuracy: 0.7888
#
# Epoch 00032: val_accuracy did not improve from 0.80749
# Epoch 33/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4775 - accuracy: 0.7485 - val_loss: 0.4685 - val_accuracy: 0.7888
#
# Epoch 00033: val_accuracy did not improve from 0.80749
# Epoch 34/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4970 - accuracy: 0.7476 - val_loss: 0.4811 - val_accuracy: 0.7888
#
# Epoch 00034: val_accuracy did not improve from 0.80749
# Epoch 35/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4734 - accuracy: 0.7663 - val_loss: 0.4959 - val_accuracy: 0.7460
#
# Epoch 00035: val_accuracy did not improve from 0.80749
# Epoch 36/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4869 - accuracy: 0.7625 - val_loss: 0.4939 - val_accuracy: 0.7674
#
# Epoch 00036: val_accuracy did not improve from 0.80749
# Epoch 37/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4988 - accuracy: 0.7491 - val_loss: 0.4706 - val_accuracy: 0.7807
#
# Epoch 00037: val_accuracy did not improve from 0.80749
# Epoch 38/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4979 - accuracy: 0.7447 - val_loss: 0.4822 - val_accuracy: 0.7674
#
# Epoch 00038: val_accuracy did not improve from 0.80749
# Epoch 39/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4823 - accuracy: 0.7434 - val_loss: 0.4756 - val_accuracy: 0.7674
#
# Epoch 00039: val_accuracy did not improve from 0.80749
# Epoch 40/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4928 - accuracy: 0.7293 - val_loss: 0.4698 - val_accuracy: 0.7674
#
# Epoch 00040: val_accuracy did not improve from 0.80749
# Epoch 41/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.5016 - accuracy: 0.7491 - val_loss: 0.4629 - val_accuracy: 0.7781
#
# Epoch 00041: val_accuracy did not improve from 0.80749
# Epoch 42/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5072 - accuracy: 0.7324 - val_loss: 0.4693 - val_accuracy: 0.7834
#
# Epoch 00042: val_accuracy did not improve from 0.80749
# Epoch 43/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5304 - accuracy: 0.7334 - val_loss: 0.4690 - val_accuracy: 0.7701
#
# Epoch 00043: val_accuracy did not improve from 0.80749
# Epoch 44/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4912 - accuracy: 0.7688 - val_loss: 0.4611 - val_accuracy: 0.7807
#
# Epoch 00044: val_accuracy did not improve from 0.80749
# Epoch 45/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4893 - accuracy: 0.7456 - val_loss: 0.4629 - val_accuracy: 0.7888
#
# Epoch 00045: val_accuracy did not improve from 0.80749
# Epoch 46/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5036 - accuracy: 0.7615 - val_loss: 0.4795 - val_accuracy: 0.7701
#
# Epoch 00046: val_accuracy did not improve from 0.80749
# Epoch 47/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4695 - accuracy: 0.7552 - val_loss: 0.4647 - val_accuracy: 0.7834
#
# Epoch 00047: val_accuracy did not improve from 0.80749
# Epoch 48/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4436 - accuracy: 0.7981 - val_loss: 0.4725 - val_accuracy: 0.7727
#
# Epoch 00048: val_accuracy did not improve from 0.80749
# Epoch 49/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4648 - accuracy: 0.7728 - val_loss: 0.4691 - val_accuracy: 0.7781
#
# Epoch 00049: val_accuracy did not improve from 0.80749
# Epoch 50/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4865 - accuracy: 0.7435 - val_loss: 0.4926 - val_accuracy: 0.7727
#
# Epoch 00050: val_accuracy did not improve from 0.80749
# Epoch 51/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.5144 - accuracy: 0.7431 - val_loss: 0.4573 - val_accuracy: 0.7968
#
# Epoch 00051: val_accuracy did not improve from 0.80749
# Epoch 52/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4528 - accuracy: 0.7963 - val_loss: 0.4928 - val_accuracy: 0.7727
#
# Epoch 00052: val_accuracy did not improve from 0.80749
# Epoch 53/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4484 - accuracy: 0.7676 - val_loss: 0.4525 - val_accuracy: 0.7941
#
# Epoch 00053: val_accuracy did not improve from 0.80749
# Epoch 54/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5016 - accuracy: 0.7517 - val_loss: 0.4674 - val_accuracy: 0.7727
#
# Epoch 00054: val_accuracy did not improve from 0.80749
# Epoch 55/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4635 - accuracy: 0.7672 - val_loss: 0.5155 - val_accuracy: 0.7540
#
# Epoch 00055: val_accuracy did not improve from 0.80749
# Epoch 56/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4779 - accuracy: 0.7703 - val_loss: 0.4700 - val_accuracy: 0.7807
#
# Epoch 00056: val_accuracy did not improve from 0.80749
# Epoch 57/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4511 - accuracy: 0.7738 - val_loss: 0.4715 - val_accuracy: 0.7807
#
# Epoch 00057: val_accuracy did not improve from 0.80749
# Epoch 58/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4812 - accuracy: 0.7480 - val_loss: 0.4809 - val_accuracy: 0.7727
#
# Epoch 00058: val_accuracy did not improve from 0.80749
# Epoch 59/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4617 - accuracy: 0.7593 - val_loss: 0.4842 - val_accuracy: 0.7594
#
# Epoch 00059: val_accuracy did not improve from 0.80749
# Epoch 60/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4794 - accuracy: 0.7090 - val_loss: 0.4670 - val_accuracy: 0.7968
#
# Epoch 00060: val_accuracy did not improve from 0.80749
# Epoch 61/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4588 - accuracy: 0.7673 - val_loss: 0.4676 - val_accuracy: 0.7861
#
# Epoch 00061: val_accuracy did not improve from 0.80749
# Epoch 62/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4483 - accuracy: 0.7774 - val_loss: 0.4847 - val_accuracy: 0.7914
#
# Epoch 00062: val_accuracy did not improve from 0.80749
# Epoch 63/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5008 - accuracy: 0.7340 - val_loss: 0.4902 - val_accuracy: 0.7620
#
# Epoch 00063: val_accuracy did not improve from 0.80749
# Epoch 64/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4500 - accuracy: 0.7698 - val_loss: 0.4840 - val_accuracy: 0.8021
#
# Epoch 00064: val_accuracy did not improve from 0.80749
# Epoch 65/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4893 - accuracy: 0.7393 - val_loss: 0.4754 - val_accuracy: 0.8075
#
# Epoch 00065: val_accuracy did not improve from 0.80749
# Epoch 66/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4316 - accuracy: 0.7850 - val_loss: 0.4775 - val_accuracy: 0.7701
#
# Epoch 00066: val_accuracy did not improve from 0.80749
# Epoch 67/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4658 - accuracy: 0.7500 - val_loss: 0.4778 - val_accuracy: 0.7914
#
# Epoch 00067: val_accuracy did not improve from 0.80749
# Epoch 68/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4573 - accuracy: 0.7716 - val_loss: 0.5093 - val_accuracy: 0.7540
#
# Epoch 00068: val_accuracy did not improve from 0.80749
# Epoch 69/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4722 - accuracy: 0.7573 - val_loss: 0.4749 - val_accuracy: 0.7968
#
# Epoch 00069: val_accuracy did not improve from 0.80749
# Epoch 70/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4587 - accuracy: 0.7713 - val_loss: 0.4837 - val_accuracy: 0.7914
#
# Epoch 00070: val_accuracy did not improve from 0.80749
# Epoch 71/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4382 - accuracy: 0.7856 - val_loss: 0.5227 - val_accuracy: 0.7406
#
# Epoch 00071: val_accuracy did not improve from 0.80749
# Epoch 72/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4505 - accuracy: 0.7822 - val_loss: 0.4807 - val_accuracy: 0.8075
#
# Epoch 00072: val_accuracy did not improve from 0.80749
# Epoch 73/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4542 - accuracy: 0.7800 - val_loss: 0.4853 - val_accuracy: 0.7807
#
# Epoch 00073: val_accuracy did not improve from 0.80749
# Epoch 74/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4491 - accuracy: 0.7678 - val_loss: 0.5076 - val_accuracy: 0.7727
#
# Epoch 00074: val_accuracy did not improve from 0.80749
# Epoch 75/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4333 - accuracy: 0.7863 - val_loss: 0.5398 - val_accuracy: 0.7193
#
# Epoch 00075: val_accuracy did not improve from 0.80749
# Epoch 76/100
# 77/77 [==============================] - 3s 41ms/step - loss: 0.4588 - accuracy: 0.7734 - val_loss: 0.5178 - val_accuracy: 0.7487
#
# Epoch 00076: val_accuracy did not improve from 0.80749
# Epoch 77/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4509 - accuracy: 0.7552 - val_loss: 0.5103 - val_accuracy: 0.7834
#
# Epoch 00077: val_accuracy did not improve from 0.80749
# Epoch 78/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4987 - accuracy: 0.7332 - val_loss: 0.4963 - val_accuracy: 0.7754
#
# Epoch 00078: val_accuracy did not improve from 0.80749
# Epoch 79/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4405 - accuracy: 0.7501 - val_loss: 0.5005 - val_accuracy: 0.7727
#
# Epoch 00079: val_accuracy did not improve from 0.80749
# Epoch 80/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4312 - accuracy: 0.7646 - val_loss: 0.5043 - val_accuracy: 0.7834
#
# Epoch 00080: val_accuracy did not improve from 0.80749
# Epoch 81/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4421 - accuracy: 0.7794 - val_loss: 0.5247 - val_accuracy: 0.7567
#
# Epoch 00081: val_accuracy did not improve from 0.80749
# Epoch 82/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4484 - accuracy: 0.7844 - val_loss: 0.5331 - val_accuracy: 0.7647
#
# Epoch 00082: val_accuracy did not improve from 0.80749
# Epoch 83/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4609 - accuracy: 0.7817 - val_loss: 0.5159 - val_accuracy: 0.7914
#
# Epoch 00083: val_accuracy did not improve from 0.80749
# Epoch 84/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4212 - accuracy: 0.7943 - val_loss: 0.5183 - val_accuracy: 0.7941
#
# Epoch 00084: val_accuracy did not improve from 0.80749
# Epoch 85/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4453 - accuracy: 0.7680 - val_loss: 0.5170 - val_accuracy: 0.7727
#
# Epoch 00085: val_accuracy did not improve from 0.80749
# Epoch 86/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4530 - accuracy: 0.7577 - val_loss: 0.5027 - val_accuracy: 0.7914
#
# Epoch 00086: val_accuracy did not improve from 0.80749
# Epoch 87/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4387 - accuracy: 0.7699 - val_loss: 0.5727 - val_accuracy: 0.7193
#
# Epoch 00087: val_accuracy did not improve from 0.80749
# Epoch 88/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4428 - accuracy: 0.7702 - val_loss: 0.5571 - val_accuracy: 0.7807
#
# Epoch 00088: val_accuracy did not improve from 0.80749
# Epoch 89/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4765 - accuracy: 0.7409 - val_loss: 0.4950 - val_accuracy: 0.7807
#
# Epoch 00089: val_accuracy did not improve from 0.80749
# Epoch 90/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4326 - accuracy: 0.7838 - val_loss: 0.5043 - val_accuracy: 0.7914
#
# Epoch 00090: val_accuracy did not improve from 0.80749
# Epoch 91/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4239 - accuracy: 0.7932 - val_loss: 0.5143 - val_accuracy: 0.7888
#
# Epoch 00091: val_accuracy did not improve from 0.80749
# Epoch 92/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4171 - accuracy: 0.7874 - val_loss: 0.5024 - val_accuracy: 0.7861
#
# Epoch 00092: val_accuracy did not improve from 0.80749
# Epoch 93/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4793 - accuracy: 0.7592 - val_loss: 0.5105 - val_accuracy: 0.7674
#
# Epoch 00093: val_accuracy did not improve from 0.80749
# Epoch 94/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4337 - accuracy: 0.7739 - val_loss: 0.5185 - val_accuracy: 0.7781
#
# Epoch 00094: val_accuracy did not improve from 0.80749
# Epoch 95/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4349 - accuracy: 0.7683 - val_loss: 0.5103 - val_accuracy: 0.7914
#
# Epoch 00095: val_accuracy did not improve from 0.80749
# Epoch 96/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.3935 - accuracy: 0.7984 - val_loss: 0.5314 - val_accuracy: 0.7754
#
# Epoch 00096: val_accuracy did not improve from 0.80749
# Epoch 97/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4220 - accuracy: 0.7885 - val_loss: 0.5313 - val_accuracy: 0.7861
#
# Epoch 00097: val_accuracy did not improve from 0.80749
# Epoch 98/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4466 - accuracy: 0.7860 - val_loss: 0.5178 - val_accuracy: 0.7861
#
# Epoch 00098: val_accuracy did not improve from 0.80749
# Epoch 99/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4118 - accuracy: 0.7842 - val_loss: 0.5206 - val_accuracy: 0.7727
#
# Epoch 00099: val_accuracy did not improve from 0.80749
# Epoch 100/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4285 - accuracy: 0.7920 - val_loss: 0.5286 - val_accuracy: 0.7754
#
# Epoch 00100: val_accuracy did not improve from 0.80749
# Train and Validation Time = 279.14059805870056s
# Model Train and Validation: Completed
# Model Test: Starting
# 37/37 [==============================] - 2s 64ms/step - loss: 1.7336 - accuracy: 0.5532
# Test Time = 2.407776117324829s
# Test Time / sample = 0.002084654647034484s
# Model Test: Completed
# #######################################################################################################################################
# Model Cross Validation: Starting
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 6s 47ms/step - loss: 0.6072 - accuracy: 0.6892 - val_loss: 0.5847 - val_accuracy: 0.6818
#
# Epoch 00001: val_accuracy improved from -inf to 0.68182, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 2/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5768 - accuracy: 0.7001 - val_loss: 0.5482 - val_accuracy: 0.7203
#
# Epoch 00002: val_accuracy improved from 0.68182 to 0.72028, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 3/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5508 - accuracy: 0.7034 - val_loss: 0.5708 - val_accuracy: 0.7168
#
# Epoch 00003: val_accuracy did not improve from 0.72028
# Epoch 4/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5213 - accuracy: 0.7559 - val_loss: 0.5358 - val_accuracy: 0.7483
#
# Epoch 00004: val_accuracy improved from 0.72028 to 0.74825, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 5/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5656 - accuracy: 0.7162 - val_loss: 0.5487 - val_accuracy: 0.7133
#
# Epoch 00005: val_accuracy did not improve from 0.74825
# Epoch 6/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5372 - accuracy: 0.7405 - val_loss: 0.5333 - val_accuracy: 0.7448
#
# Epoch 00006: val_accuracy did not improve from 0.74825
# Epoch 7/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5359 - accuracy: 0.7452 - val_loss: 0.5231 - val_accuracy: 0.7587
#
# Epoch 00007: val_accuracy improved from 0.74825 to 0.75874, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 8/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5317 - accuracy: 0.7265 - val_loss: 0.5273 - val_accuracy: 0.7587
#
# Epoch 00008: val_accuracy did not improve from 0.75874
# Epoch 9/100
# 86/86 [==============================] - 3s 39ms/step - loss: 0.5404 - accuracy: 0.7324 - val_loss: 0.5204 - val_accuracy: 0.7517
#
# Epoch 00009: val_accuracy did not improve from 0.75874
# Epoch 10/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5154 - accuracy: 0.7626 - val_loss: 0.5122 - val_accuracy: 0.7692
#
# Epoch 00010: val_accuracy improved from 0.75874 to 0.76923, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 11/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5331 - accuracy: 0.7328 - val_loss: 0.5174 - val_accuracy: 0.7483
#
# Epoch 00011: val_accuracy did not improve from 0.76923
# Epoch 12/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5192 - accuracy: 0.7585 - val_loss: 0.5683 - val_accuracy: 0.6888
#
# Epoch 00012: val_accuracy did not improve from 0.76923
# Epoch 13/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5239 - accuracy: 0.7163 - val_loss: 0.5073 - val_accuracy: 0.7727
#
# Epoch 00013: val_accuracy improved from 0.76923 to 0.77273, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 14/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5027 - accuracy: 0.7515 - val_loss: 0.5103 - val_accuracy: 0.7552
#
# Epoch 00014: val_accuracy did not improve from 0.77273
# Epoch 15/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5203 - accuracy: 0.7473 - val_loss: 0.5110 - val_accuracy: 0.7727
#
# Epoch 00015: val_accuracy did not improve from 0.77273
# Epoch 16/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4923 - accuracy: 0.7647 - val_loss: 0.5048 - val_accuracy: 0.7762
#
# Epoch 00016: val_accuracy improved from 0.77273 to 0.77622, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 17/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4980 - accuracy: 0.7587 - val_loss: 0.5252 - val_accuracy: 0.7273
#
# Epoch 00017: val_accuracy did not improve from 0.77622
# Epoch 18/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5179 - accuracy: 0.7422 - val_loss: 0.5966 - val_accuracy: 0.7133
#
# Epoch 00018: val_accuracy did not improve from 0.77622
# Epoch 19/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4846 - accuracy: 0.7882 - val_loss: 0.5375 - val_accuracy: 0.6923
#
# Epoch 00019: val_accuracy did not improve from 0.77622
# Epoch 20/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4954 - accuracy: 0.7753 - val_loss: 0.5128 - val_accuracy: 0.7622
#
# Epoch 00020: val_accuracy did not improve from 0.77622
# Epoch 21/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4908 - accuracy: 0.7549 - val_loss: 0.5236 - val_accuracy: 0.7168
#
# Epoch 00021: val_accuracy did not improve from 0.77622
# Epoch 22/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4975 - accuracy: 0.7557 - val_loss: 0.5328 - val_accuracy: 0.7378
#
# Epoch 00022: val_accuracy did not improve from 0.77622
# Epoch 23/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4783 - accuracy: 0.7736 - val_loss: 0.5148 - val_accuracy: 0.7343
#
# Epoch 00023: val_accuracy did not improve from 0.77622
# Epoch 24/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4753 - accuracy: 0.7785 - val_loss: 0.5260 - val_accuracy: 0.7517
#
# Epoch 00024: val_accuracy did not improve from 0.77622
# Epoch 25/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5637 - accuracy: 0.7412 - val_loss: 0.5242 - val_accuracy: 0.7378
#
# Epoch 00025: val_accuracy did not improve from 0.77622
# Epoch 26/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4676 - accuracy: 0.7688 - val_loss: 0.5186 - val_accuracy: 0.7448
#
# Epoch 00026: val_accuracy did not improve from 0.77622
# Epoch 27/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4678 - accuracy: 0.7593 - val_loss: 0.5160 - val_accuracy: 0.7762
#
# Epoch 00027: val_accuracy did not improve from 0.77622
# Epoch 28/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4581 - accuracy: 0.7777 - val_loss: 0.5344 - val_accuracy: 0.7308
#
# Epoch 00028: val_accuracy did not improve from 0.77622
# Epoch 29/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4668 - accuracy: 0.7916 - val_loss: 0.5167 - val_accuracy: 0.7343
#
# Epoch 00029: val_accuracy did not improve from 0.77622
# Epoch 30/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4803 - accuracy: 0.7745 - val_loss: 0.5128 - val_accuracy: 0.7517
#
# Epoch 00030: val_accuracy did not improve from 0.77622
# Epoch 31/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4611 - accuracy: 0.7816 - val_loss: 0.5313 - val_accuracy: 0.7448
#
# Epoch 00031: val_accuracy did not improve from 0.77622
# Epoch 32/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4915 - accuracy: 0.7508 - val_loss: 0.5200 - val_accuracy: 0.7797
#
# Epoch 00032: val_accuracy improved from 0.77622 to 0.77972, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 33/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4962 - accuracy: 0.7510 - val_loss: 0.5284 - val_accuracy: 0.7587
#
# Epoch 00033: val_accuracy did not improve from 0.77972
# Epoch 34/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4702 - accuracy: 0.7594 - val_loss: 0.5008 - val_accuracy: 0.7727
#
# Epoch 00034: val_accuracy did not improve from 0.77972
# Epoch 35/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4892 - accuracy: 0.7442 - val_loss: 0.5204 - val_accuracy: 0.7552
#
# Epoch 00035: val_accuracy did not improve from 0.77972
# Epoch 36/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4849 - accuracy: 0.7624 - val_loss: 0.5275 - val_accuracy: 0.7692
#
# Epoch 00036: val_accuracy did not improve from 0.77972
# Epoch 37/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4533 - accuracy: 0.7754 - val_loss: 0.5019 - val_accuracy: 0.7587
#
# Epoch 00037: val_accuracy did not improve from 0.77972
# Epoch 38/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4736 - accuracy: 0.7822 - val_loss: 0.4957 - val_accuracy: 0.7622
#
# Epoch 00038: val_accuracy did not improve from 0.77972
# Epoch 39/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4267 - accuracy: 0.8040 - val_loss: 0.5097 - val_accuracy: 0.7587
#
# Epoch 00039: val_accuracy did not improve from 0.77972
# Epoch 40/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4669 - accuracy: 0.7716 - val_loss: 0.5067 - val_accuracy: 0.7657
#
# Epoch 00040: val_accuracy did not improve from 0.77972
# Epoch 41/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4522 - accuracy: 0.7896 - val_loss: 0.5216 - val_accuracy: 0.7448
#
# Epoch 00041: val_accuracy did not improve from 0.77972
# Epoch 42/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4845 - accuracy: 0.7545 - val_loss: 0.5179 - val_accuracy: 0.7587
#
# Epoch 00042: val_accuracy did not improve from 0.77972
# Epoch 43/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4564 - accuracy: 0.7822 - val_loss: 0.5107 - val_accuracy: 0.7517
#
# Epoch 00043: val_accuracy did not improve from 0.77972
# Epoch 44/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4112 - accuracy: 0.8203 - val_loss: 0.5065 - val_accuracy: 0.7517
#
# Epoch 00044: val_accuracy did not improve from 0.77972
# Epoch 45/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4652 - accuracy: 0.7731 - val_loss: 0.5164 - val_accuracy: 0.7657
#
# Epoch 00045: val_accuracy did not improve from 0.77972
# Epoch 46/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4459 - accuracy: 0.7643 - val_loss: 0.5045 - val_accuracy: 0.7552
#
# Epoch 00046: val_accuracy did not improve from 0.77972
# Epoch 47/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4185 - accuracy: 0.8117 - val_loss: 0.4961 - val_accuracy: 0.7587
#
# Epoch 00047: val_accuracy did not improve from 0.77972
# Epoch 48/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4245 - accuracy: 0.7930 - val_loss: 0.5132 - val_accuracy: 0.7413
#
# Epoch 00048: val_accuracy did not improve from 0.77972
# Epoch 49/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4219 - accuracy: 0.8128 - val_loss: 0.5005 - val_accuracy: 0.7517
#
# Epoch 00049: val_accuracy did not improve from 0.77972
# Epoch 50/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4352 - accuracy: 0.7937 - val_loss: 0.4987 - val_accuracy: 0.7483
#
# Epoch 00050: val_accuracy did not improve from 0.77972
# Epoch 51/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4593 - accuracy: 0.7889 - val_loss: 0.4986 - val_accuracy: 0.7483
#
# Epoch 00051: val_accuracy did not improve from 0.77972
# Epoch 52/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4488 - accuracy: 0.7824 - val_loss: 0.4982 - val_accuracy: 0.7622
#
# Epoch 00052: val_accuracy did not improve from 0.77972
# Epoch 53/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4387 - accuracy: 0.7954 - val_loss: 0.4921 - val_accuracy: 0.7622
#
# Epoch 00053: val_accuracy did not improve from 0.77972
# Epoch 54/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4289 - accuracy: 0.8062 - val_loss: 0.4971 - val_accuracy: 0.7517
#
# Epoch 00054: val_accuracy did not improve from 0.77972
# Epoch 55/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4488 - accuracy: 0.7830 - val_loss: 0.5021 - val_accuracy: 0.7413
#
# Epoch 00055: val_accuracy did not improve from 0.77972
# Epoch 56/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4604 - accuracy: 0.7721 - val_loss: 0.5021 - val_accuracy: 0.7832
#
# Epoch 00056: val_accuracy improved from 0.77972 to 0.78322, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_0.hdf5
# Epoch 57/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4347 - accuracy: 0.8071 - val_loss: 0.5114 - val_accuracy: 0.7483
#
# Epoch 00057: val_accuracy did not improve from 0.78322
# Epoch 58/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4326 - accuracy: 0.7918 - val_loss: 0.5008 - val_accuracy: 0.7622
#
# Epoch 00058: val_accuracy did not improve from 0.78322
# Epoch 59/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.4242 - accuracy: 0.8131 - val_loss: 0.5365 - val_accuracy: 0.7483
#
# Epoch 00059: val_accuracy did not improve from 0.78322
# Epoch 60/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4226 - accuracy: 0.8048 - val_loss: 0.5273 - val_accuracy: 0.7413
#
# Epoch 00060: val_accuracy did not improve from 0.78322
# Epoch 61/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4220 - accuracy: 0.8046 - val_loss: 0.4964 - val_accuracy: 0.7587
#
# Epoch 00061: val_accuracy did not improve from 0.78322
# Epoch 62/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4228 - accuracy: 0.8163 - val_loss: 0.5022 - val_accuracy: 0.7483
#
# Epoch 00062: val_accuracy did not improve from 0.78322
# Epoch 63/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4250 - accuracy: 0.7958 - val_loss: 0.5254 - val_accuracy: 0.7797
#
# Epoch 00063: val_accuracy did not improve from 0.78322
# Epoch 64/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4366 - accuracy: 0.7886 - val_loss: 0.5012 - val_accuracy: 0.7483
#
# Epoch 00064: val_accuracy did not improve from 0.78322
# Epoch 65/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4087 - accuracy: 0.7970 - val_loss: 0.5103 - val_accuracy: 0.7308
#
# Epoch 00065: val_accuracy did not improve from 0.78322
# Epoch 66/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4215 - accuracy: 0.8006 - val_loss: 0.5107 - val_accuracy: 0.7378
#
# Epoch 00066: val_accuracy did not improve from 0.78322
# Epoch 67/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4167 - accuracy: 0.8211 - val_loss: 0.4936 - val_accuracy: 0.7657
#
# Epoch 00067: val_accuracy did not improve from 0.78322
# Epoch 68/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4360 - accuracy: 0.7918 - val_loss: 0.5181 - val_accuracy: 0.7552
#
# Epoch 00068: val_accuracy did not improve from 0.78322
# Epoch 69/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4224 - accuracy: 0.8191 - val_loss: 0.5106 - val_accuracy: 0.7517
#
# Epoch 00069: val_accuracy did not improve from 0.78322
# Epoch 70/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4218 - accuracy: 0.7913 - val_loss: 0.5044 - val_accuracy: 0.7727
#
# Epoch 00070: val_accuracy did not improve from 0.78322
# Epoch 71/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4029 - accuracy: 0.8262 - val_loss: 0.5119 - val_accuracy: 0.7483
#
# Epoch 00071: val_accuracy did not improve from 0.78322
# Epoch 72/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4002 - accuracy: 0.8122 - val_loss: 0.5211 - val_accuracy: 0.7448
#
# Epoch 00072: val_accuracy did not improve from 0.78322
# Epoch 73/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4082 - accuracy: 0.8151 - val_loss: 0.5135 - val_accuracy: 0.7517
#
# Epoch 00073: val_accuracy did not improve from 0.78322
# Epoch 74/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4528 - accuracy: 0.7670 - val_loss: 0.5160 - val_accuracy: 0.7413
#
# Epoch 00074: val_accuracy did not improve from 0.78322
# Epoch 75/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4107 - accuracy: 0.7967 - val_loss: 0.5029 - val_accuracy: 0.7483
#
# Epoch 00075: val_accuracy did not improve from 0.78322
# Epoch 76/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4200 - accuracy: 0.8041 - val_loss: 0.5055 - val_accuracy: 0.7622
#
# Epoch 00076: val_accuracy did not improve from 0.78322
# Epoch 77/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4054 - accuracy: 0.8104 - val_loss: 0.5141 - val_accuracy: 0.7483
#
# Epoch 00077: val_accuracy did not improve from 0.78322
# Epoch 78/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3931 - accuracy: 0.8082 - val_loss: 0.5221 - val_accuracy: 0.7517
#
# Epoch 00078: val_accuracy did not improve from 0.78322
# Epoch 79/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3898 - accuracy: 0.8236 - val_loss: 0.5669 - val_accuracy: 0.7238
#
# Epoch 00079: val_accuracy did not improve from 0.78322
# Epoch 80/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4177 - accuracy: 0.7939 - val_loss: 0.5032 - val_accuracy: 0.7587
#
# Epoch 00080: val_accuracy did not improve from 0.78322
# Epoch 81/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3990 - accuracy: 0.8086 - val_loss: 0.5053 - val_accuracy: 0.7797
#
# Epoch 00081: val_accuracy did not improve from 0.78322
# Epoch 82/100
# 86/86 [==============================] - 3s 39ms/step - loss: 0.4102 - accuracy: 0.7930 - val_loss: 0.5248 - val_accuracy: 0.7448
#
# Epoch 00082: val_accuracy did not improve from 0.78322
# Epoch 83/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4104 - accuracy: 0.8099 - val_loss: 0.5481 - val_accuracy: 0.7832
#
# Epoch 00083: val_accuracy did not improve from 0.78322
# Epoch 84/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4418 - accuracy: 0.7836 - val_loss: 0.5525 - val_accuracy: 0.7727
#
# Epoch 00084: val_accuracy did not improve from 0.78322
# Epoch 85/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4106 - accuracy: 0.8048 - val_loss: 0.5241 - val_accuracy: 0.7517
#
# Epoch 00085: val_accuracy did not improve from 0.78322
# Epoch 86/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4106 - accuracy: 0.8161 - val_loss: 0.5491 - val_accuracy: 0.7483
#
# Epoch 00086: val_accuracy did not improve from 0.78322
# Epoch 87/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4158 - accuracy: 0.7909 - val_loss: 0.5273 - val_accuracy: 0.7517
#
# Epoch 00087: val_accuracy did not improve from 0.78322
# Epoch 88/100
# 86/86 [==============================] - 3s 35ms/step - loss: 0.3907 - accuracy: 0.8128 - val_loss: 0.5329 - val_accuracy: 0.7657
#
# Epoch 00088: val_accuracy did not improve from 0.78322
# Epoch 89/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3772 - accuracy: 0.8096 - val_loss: 0.5125 - val_accuracy: 0.7343
#
# Epoch 00089: val_accuracy did not improve from 0.78322
# Epoch 90/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3949 - accuracy: 0.8165 - val_loss: 0.5257 - val_accuracy: 0.7413
#
# Epoch 00090: val_accuracy did not improve from 0.78322
# Epoch 91/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4079 - accuracy: 0.8108 - val_loss: 0.5168 - val_accuracy: 0.7587
#
# Epoch 00091: val_accuracy did not improve from 0.78322
# Epoch 92/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4328 - accuracy: 0.7832 - val_loss: 0.5293 - val_accuracy: 0.7273
#
# Epoch 00092: val_accuracy did not improve from 0.78322
# Epoch 93/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4214 - accuracy: 0.7860 - val_loss: 0.5373 - val_accuracy: 0.7692
#
# Epoch 00093: val_accuracy did not improve from 0.78322
# Epoch 94/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3971 - accuracy: 0.8032 - val_loss: 0.5140 - val_accuracy: 0.7343
#
# Epoch 00094: val_accuracy did not improve from 0.78322
# Epoch 95/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4265 - accuracy: 0.7729 - val_loss: 0.5199 - val_accuracy: 0.7343
#
# Epoch 00095: val_accuracy did not improve from 0.78322
# Epoch 96/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4024 - accuracy: 0.7963 - val_loss: 0.5166 - val_accuracy: 0.7378
#
# Epoch 00096: val_accuracy did not improve from 0.78322
# Epoch 97/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3956 - accuracy: 0.8061 - val_loss: 0.5199 - val_accuracy: 0.7552
#
# Epoch 00097: val_accuracy did not improve from 0.78322
# Epoch 98/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3950 - accuracy: 0.7959 - val_loss: 0.5216 - val_accuracy: 0.7448
#
# Epoch 00098: val_accuracy did not improve from 0.78322
# Epoch 99/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3870 - accuracy: 0.8114 - val_loss: 0.5728 - val_accuracy: 0.7552
#
# Epoch 00099: val_accuracy did not improve from 0.78322
# Epoch 100/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4223 - accuracy: 0.7976 - val_loss: 0.5364 - val_accuracy: 0.7378
#
# Epoch 00100: val_accuracy did not improve from 0.78322
# Cross Validation Accuracy: 68.18%
# Fold #0 Complete
#
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Epoch 1/100
# 86/86 [==============================] - 6s 44ms/step - loss: 0.6429 - accuracy: 0.6066 - val_loss: 0.5184 - val_accuracy: 0.7622
#
# Epoch 00001: val_accuracy improved from -inf to 0.76224, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_1.hdf5
# Epoch 2/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5901 - accuracy: 0.7054 - val_loss: 0.5091 - val_accuracy: 0.7517
#
# Epoch 00002: val_accuracy did not improve from 0.76224
# Epoch 3/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5698 - accuracy: 0.7172 - val_loss: 0.4910 - val_accuracy: 0.7832
#
# Epoch 00003: val_accuracy improved from 0.76224 to 0.78322, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_1.hdf5
# Epoch 4/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5481 - accuracy: 0.7139 - val_loss: 0.5002 - val_accuracy: 0.7622
#
# Epoch 00004: val_accuracy did not improve from 0.78322
# Epoch 5/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5575 - accuracy: 0.7096 - val_loss: 0.4835 - val_accuracy: 0.7762
#
# Epoch 00005: val_accuracy did not improve from 0.78322
# Epoch 6/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5450 - accuracy: 0.7393 - val_loss: 0.5004 - val_accuracy: 0.7762
#
# Epoch 00006: val_accuracy did not improve from 0.78322
# Epoch 7/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5660 - accuracy: 0.7208 - val_loss: 0.5157 - val_accuracy: 0.7448
#
# Epoch 00007: val_accuracy did not improve from 0.78322
# Epoch 8/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5651 - accuracy: 0.7121 - val_loss: 0.4792 - val_accuracy: 0.7622
#
# Epoch 00008: val_accuracy did not improve from 0.78322
# Epoch 9/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5465 - accuracy: 0.7182 - val_loss: 0.4829 - val_accuracy: 0.7762
#
# Epoch 00009: val_accuracy did not improve from 0.78322
# Epoch 10/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5213 - accuracy: 0.7408 - val_loss: 0.4757 - val_accuracy: 0.7762
#
# Epoch 00010: val_accuracy did not improve from 0.78322
# Epoch 11/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5369 - accuracy: 0.7438 - val_loss: 0.4828 - val_accuracy: 0.8042
#
# Epoch 00011: val_accuracy improved from 0.78322 to 0.80420, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_1.hdf5
# Epoch 12/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5271 - accuracy: 0.7305 - val_loss: 0.4791 - val_accuracy: 0.7762
#
# Epoch 00012: val_accuracy did not improve from 0.80420
# Epoch 13/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4821 - accuracy: 0.7667 - val_loss: 0.5146 - val_accuracy: 0.7622
#
# Epoch 00013: val_accuracy did not improve from 0.80420
# Epoch 14/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5325 - accuracy: 0.7105 - val_loss: 0.4706 - val_accuracy: 0.7902
#
# Epoch 00014: val_accuracy did not improve from 0.80420
# Epoch 15/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5195 - accuracy: 0.7518 - val_loss: 0.4996 - val_accuracy: 0.7448
#
# Epoch 00015: val_accuracy did not improve from 0.80420
# Epoch 16/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5472 - accuracy: 0.7202 - val_loss: 0.4699 - val_accuracy: 0.7867
#
# Epoch 00016: val_accuracy did not improve from 0.80420
# Epoch 17/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5187 - accuracy: 0.7351 - val_loss: 0.5196 - val_accuracy: 0.7483
#
# Epoch 00017: val_accuracy did not improve from 0.80420
# Epoch 18/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5218 - accuracy: 0.7224 - val_loss: 0.4746 - val_accuracy: 0.7727
#
# Epoch 00018: val_accuracy did not improve from 0.80420
# Epoch 19/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5101 - accuracy: 0.7697 - val_loss: 0.4798 - val_accuracy: 0.7622
#
# Epoch 00019: val_accuracy did not improve from 0.80420
# Epoch 20/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5083 - accuracy: 0.7584 - val_loss: 0.4817 - val_accuracy: 0.7692
#
# Epoch 00020: val_accuracy did not improve from 0.80420
# Epoch 21/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4897 - accuracy: 0.7472 - val_loss: 0.4640 - val_accuracy: 0.7867
#
# Epoch 00021: val_accuracy did not improve from 0.80420
# Epoch 22/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5032 - accuracy: 0.7403 - val_loss: 0.4561 - val_accuracy: 0.7937
#
# Epoch 00022: val_accuracy did not improve from 0.80420
# Epoch 23/100
# 86/86 [==============================] - 3s 40ms/step - loss: 0.5289 - accuracy: 0.7251 - val_loss: 0.4485 - val_accuracy: 0.7797
#
# Epoch 00023: val_accuracy did not improve from 0.80420
# Epoch 24/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4980 - accuracy: 0.7807 - val_loss: 0.4848 - val_accuracy: 0.7692
#
# Epoch 00024: val_accuracy did not improve from 0.80420
# Epoch 25/100
# ...
#
# Epoch 00025: val_accuracy did not improve from 0.75524
# Epoch 26/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4915 - accuracy: 0.7461 - val_loss: 0.6459 - val_accuracy: 0.7098
#
# Epoch 00026: val_accuracy did not improve from 0.75524
# Epoch 27/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4487 - accuracy: 0.7883 - val_loss: 0.5985 - val_accuracy: 0.7517
#
# Epoch 00027: val_accuracy did not improve from 0.75524
# Epoch 28/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4559 - accuracy: 0.7602 - val_loss: 0.6430 - val_accuracy: 0.7133
#
# Epoch 00028: val_accuracy did not improve from 0.75524
# Epoch 29/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4574 - accuracy: 0.7872 - val_loss: 0.5962 - val_accuracy: 0.7483
#
# Epoch 00029: val_accuracy did not improve from 0.75524
# Epoch 30/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4475 - accuracy: 0.7869 - val_loss: 0.5942 - val_accuracy: 0.7483
#
# Epoch 00030: val_accuracy did not improve from 0.75524
# Epoch 31/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4672 - accuracy: 0.7837 - val_loss: 0.6147 - val_accuracy: 0.7448
#
# Epoch 00031: val_accuracy did not improve from 0.75524
# Epoch 32/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4478 - accuracy: 0.7809 - val_loss: 0.6106 - val_accuracy: 0.7378
#
# Epoch 00032: val_accuracy did not improve from 0.75524
# Epoch 33/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4493 - accuracy: 0.7897 - val_loss: 0.6207 - val_accuracy: 0.7483
#
# Epoch 00033: val_accuracy did not improve from 0.75524
# Epoch 34/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4821 - accuracy: 0.7659 - val_loss: 0.6115 - val_accuracy: 0.7692
#
# Epoch 00034: val_accuracy improved from 0.75524 to 0.76923, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_3.hdf5
# Epoch 35/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4816 - accuracy: 0.7647 - val_loss: 0.7303 - val_accuracy: 0.6818
#
# Epoch 00035: val_accuracy did not improve from 0.76923
# Epoch 36/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4812 - accuracy: 0.7723 - val_loss: 0.6258 - val_accuracy: 0.7413
#
# Epoch 00036: val_accuracy did not improve from 0.76923
# Epoch 37/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4391 - accuracy: 0.7790 - val_loss: 0.6361 - val_accuracy: 0.7552
#
# Epoch 00037: val_accuracy did not improve from 0.76923
# Epoch 38/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4542 - accuracy: 0.7731 - val_loss: 0.6240 - val_accuracy: 0.7692
#
# Epoch 00038: val_accuracy did not improve from 0.76923
# Epoch 39/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4522 - accuracy: 0.7795 - val_loss: 0.6158 - val_accuracy: 0.7622
#
# Epoch 00039: val_accuracy did not improve from 0.76923
# Epoch 40/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4849 - accuracy: 0.7706 - val_loss: 0.6373 - val_accuracy: 0.7692
#
# Epoch 00040: val_accuracy did not improve from 0.76923
# Epoch 41/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4423 - accuracy: 0.8021 - val_loss: 0.6161 - val_accuracy: 0.7622
#
# Epoch 00041: val_accuracy did not improve from 0.76923
# Epoch 42/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4409 - accuracy: 0.7930 - val_loss: 0.6312 - val_accuracy: 0.7517
#
# Epoch 00042: val_accuracy did not improve from 0.76923
# Epoch 43/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4546 - accuracy: 0.7785 - val_loss: 0.6397 - val_accuracy: 0.7622
#
# Epoch 00043: val_accuracy did not improve from 0.76923
# Epoch 44/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4427 - accuracy: 0.7742 - val_loss: 0.6328 - val_accuracy: 0.7657
#
# Epoch 00044: val_accuracy did not improve from 0.76923
# Epoch 45/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4748 - accuracy: 0.7679 - val_loss: 0.6233 - val_accuracy: 0.7587
#
# Epoch 00045: val_accuracy did not improve from 0.76923
# Epoch 46/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4519 - accuracy: 0.7853 - val_loss: 0.6584 - val_accuracy: 0.7483
#
# Epoch 00046: val_accuracy did not improve from 0.76923
# Epoch 47/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4232 - accuracy: 0.7965 - val_loss: 0.6324 - val_accuracy: 0.7483
#
# Epoch 00047: val_accuracy did not improve from 0.76923
# Epoch 48/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4413 - accuracy: 0.7983 - val_loss: 0.6490 - val_accuracy: 0.7587
#
# Epoch 00048: val_accuracy did not improve from 0.76923
# Epoch 49/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4269 - accuracy: 0.8103 - val_loss: 0.6815 - val_accuracy: 0.7657
#
# Epoch 00049: val_accuracy did not improve from 0.76923
# Epoch 50/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4222 - accuracy: 0.7977 - val_loss: 0.6502 - val_accuracy: 0.7657
#
# Epoch 00050: val_accuracy did not improve from 0.76923
# Epoch 51/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4326 - accuracy: 0.8095 - val_loss: 0.6828 - val_accuracy: 0.7657
#
# Epoch 00051: val_accuracy did not improve from 0.76923
# Epoch 52/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4601 - accuracy: 0.7672 - val_loss: 0.7184 - val_accuracy: 0.7308
#
# Epoch 00052: val_accuracy did not improve from 0.76923
# Epoch 53/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4325 - accuracy: 0.7976 - val_loss: 0.6771 - val_accuracy: 0.7238
#
# Epoch 00053: val_accuracy did not improve from 0.76923
# Epoch 54/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4248 - accuracy: 0.7958 - val_loss: 0.6981 - val_accuracy: 0.7552
#
# Epoch 00054: val_accuracy did not improve from 0.76923
# Epoch 55/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4600 - accuracy: 0.7522 - val_loss: 0.6680 - val_accuracy: 0.7587
#
# Epoch 00055: val_accuracy did not improve from 0.76923
# Epoch 56/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4515 - accuracy: 0.7759 - val_loss: 0.6750 - val_accuracy: 0.7448
#
# Epoch 00056: val_accuracy did not improve from 0.76923
# Epoch 57/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4672 - accuracy: 0.7629 - val_loss: 0.7001 - val_accuracy: 0.7657
#
# Epoch 00057: val_accuracy did not improve from 0.76923
# Epoch 58/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4129 - accuracy: 0.7966 - val_loss: 0.6833 - val_accuracy: 0.7483
#
# Epoch 00058: val_accuracy did not improve from 0.76923
# Epoch 59/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4129 - accuracy: 0.8106 - val_loss: 0.6844 - val_accuracy: 0.7448
#
# Epoch 00059: val_accuracy did not improve from 0.76923
# Epoch 60/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4296 - accuracy: 0.7998 - val_loss: 0.6821 - val_accuracy: 0.7413
#
# Epoch 00060: val_accuracy did not improve from 0.76923
# Epoch 61/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4288 - accuracy: 0.7818 - val_loss: 0.6892 - val_accuracy: 0.7483
#
# Epoch 00061: val_accuracy did not improve from 0.76923
# Epoch 62/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4111 - accuracy: 0.8057 - val_loss: 0.6909 - val_accuracy: 0.7657
#
# Epoch 00062: val_accuracy did not improve from 0.76923
# Epoch 63/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4447 - accuracy: 0.8031 - val_loss: 0.7296 - val_accuracy: 0.7343
#
# Epoch 00063: val_accuracy did not improve from 0.76923
# Epoch 64/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4549 - accuracy: 0.7752 - val_loss: 0.6868 - val_accuracy: 0.7448
#
# Epoch 00064: val_accuracy did not improve from 0.76923
# Epoch 65/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4122 - accuracy: 0.7971 - val_loss: 0.7103 - val_accuracy: 0.7413
#
# Epoch 00065: val_accuracy did not improve from 0.76923
# Epoch 66/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3999 - accuracy: 0.7952 - val_loss: 0.6949 - val_accuracy: 0.7552
#
# Epoch 00066: val_accuracy did not improve from 0.76923
# Epoch 67/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4429 - accuracy: 0.7711 - val_loss: 0.7134 - val_accuracy: 0.7552
#
# Epoch 00067: val_accuracy did not improve from 0.76923
# Epoch 68/100
# 86/86 [==============================] - 3s 39ms/step - loss: 0.4217 - accuracy: 0.7962 - val_loss: 0.7131 - val_accuracy: 0.7657
#
# Epoch 00068: val_accuracy did not improve from 0.76923
# Epoch 69/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4064 - accuracy: 0.7905 - val_loss: 0.7090 - val_accuracy: 0.7448
#
# Epoch 00069: val_accuracy did not improve from 0.76923
# Epoch 70/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4245 - accuracy: 0.8009 - val_loss: 0.7103 - val_accuracy: 0.7448
#
# Epoch 00070: val_accuracy did not improve from 0.76923
# Epoch 71/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4317 - accuracy: 0.7886 - val_loss: 0.7206 - val_accuracy: 0.7483
#
# Epoch 00071: val_accuracy did not improve from 0.76923
# Epoch 72/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4062 - accuracy: 0.7947 - val_loss: 0.7003 - val_accuracy: 0.7552
#
# Epoch 00072: val_accuracy did not improve from 0.76923
# Epoch 73/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4190 - accuracy: 0.7953 - val_loss: 0.7060 - val_accuracy: 0.7692
#
# Epoch 00073: val_accuracy did not improve from 0.76923
# Epoch 74/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3919 - accuracy: 0.7997 - val_loss: 0.7115 - val_accuracy: 0.7483
#
# Epoch 00074: val_accuracy did not improve from 0.76923
# Epoch 75/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4222 - accuracy: 0.7859 - val_loss: 0.7580 - val_accuracy: 0.7413
#
# Epoch 00075: val_accuracy did not improve from 0.76923
# Epoch 76/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3929 - accuracy: 0.8186 - val_loss: 0.7281 - val_accuracy: 0.7657
#
# Epoch 00076: val_accuracy did not improve from 0.76923
# Epoch 77/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4169 - accuracy: 0.8014 - val_loss: 0.7379 - val_accuracy: 0.7692
#
# Epoch 00077: val_accuracy did not improve from 0.76923
# Epoch 78/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4389 - accuracy: 0.7894 - val_loss: 0.7095 - val_accuracy: 0.7622
#
# Epoch 00078: val_accuracy did not improve from 0.76923
# Epoch 79/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4076 - accuracy: 0.8215 - val_loss: 0.7122 - val_accuracy: 0.7797
#
# Epoch 00079: val_accuracy improved from 0.76923 to 0.77972, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_3.hdf5
# Epoch 80/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3921 - accuracy: 0.8057 - val_loss: 0.7458 - val_accuracy: 0.7622
#
# Epoch 00080: val_accuracy did not improve from 0.77972
# Epoch 81/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3977 - accuracy: 0.8131 - val_loss: 0.7256 - val_accuracy: 0.7762
#
# Epoch 00081: val_accuracy did not improve from 0.77972
# Epoch 82/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4286 - accuracy: 0.7757 - val_loss: 0.7337 - val_accuracy: 0.7587
#
# Epoch 00082: val_accuracy did not improve from 0.77972
# Epoch 83/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3856 - accuracy: 0.8226 - val_loss: 0.7270 - val_accuracy: 0.7657
#
# Epoch 00083: val_accuracy did not improve from 0.77972
# Epoch 84/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4190 - accuracy: 0.8053 - val_loss: 0.7677 - val_accuracy: 0.7517
#
# Epoch 00084: val_accuracy did not improve from 0.77972
# Epoch 85/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4177 - accuracy: 0.7866 - val_loss: 0.7233 - val_accuracy: 0.7587
#
# Epoch 00085: val_accuracy did not improve from 0.77972
# Epoch 86/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3964 - accuracy: 0.8134 - val_loss: 0.7842 - val_accuracy: 0.7517
#
# Epoch 00086: val_accuracy did not improve from 0.77972
# Epoch 87/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4491 - accuracy: 0.7704 - val_loss: 0.7238 - val_accuracy: 0.7483
#
# Epoch 00087: val_accuracy did not improve from 0.77972
# Epoch 88/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4057 - accuracy: 0.8048 - val_loss: 0.7276 - val_accuracy: 0.7343
#
# Epoch 00088: val_accuracy did not improve from 0.77972
# Epoch 89/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4006 - accuracy: 0.8052 - val_loss: 0.7605 - val_accuracy: 0.7692
#
# Epoch 00089: val_accuracy did not improve from 0.77972
# Epoch 90/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3971 - accuracy: 0.8136 - val_loss: 0.7550 - val_accuracy: 0.7622
#
# Epoch 00090: val_accuracy did not improve from 0.77972
# Epoch 91/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4100 - accuracy: 0.8020 - val_loss: 0.8112 - val_accuracy: 0.7622
#
# Epoch 00091: val_accuracy did not improve from 0.77972
# Epoch 92/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3985 - accuracy: 0.8122 - val_loss: 0.7709 - val_accuracy: 0.7622
#
# Epoch 00092: val_accuracy did not improve from 0.77972
# Epoch 93/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3965 - accuracy: 0.8067 - val_loss: 0.7879 - val_accuracy: 0.7517
#
# Epoch 00093: val_accuracy did not improve from 0.77972
# Epoch 94/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3994 - accuracy: 0.8009 - val_loss: 0.7970 - val_accuracy: 0.7448
#
# Epoch 00094: val_accuracy did not improve from 0.77972
# Epoch 95/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3848 - accuracy: 0.8258 - val_loss: 0.8998 - val_accuracy: 0.7517
#
# Epoch 00095: val_accuracy did not improve from 0.77972
# Epoch 96/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4023 - accuracy: 0.8141 - val_loss: 0.7924 - val_accuracy: 0.7517
#
# Epoch 00096: val_accuracy did not improve from 0.77972
# Epoch 97/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3928 - accuracy: 0.8171 - val_loss: 0.7798 - val_accuracy: 0.7517
#
# Epoch 00097: val_accuracy did not improve from 0.77972
# Epoch 98/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3692 - accuracy: 0.8347 - val_loss: 0.8580 - val_accuracy: 0.7587
#
# Epoch 00098: val_accuracy did not improve from 0.77972
# Epoch 99/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4320 - accuracy: 0.7913 - val_loss: 0.8265 - val_accuracy: 0.7587
#
# Epoch 00099: val_accuracy did not improve from 0.77972
# Epoch 100/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3834 - accuracy: 0.8219 - val_loss: 0.8318 - val_accuracy: 0.7552
#
# Epoch 00100: val_accuracy did not improve from 0.77972
# Cross Validation Accuracy: 69.93%
# Fold #3 Complete
#
# Cross Validation Accuracy Mean (+/- Std Deviation): 71.68% (+/- 3.02%)
# Cross Validation Time = 1208.8567435741425s
# Model Cross Validation: Completed
# Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_1.hdf5
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Model Test: Starting
# 37/37 [==============================] - 4s 65ms/step - loss: 0.6237 - accuracy: 0.6560
# Test Time = 3.658114194869995s
# Test Time / sample = 0.0031671984371168787s
# Model Test: Completed

# %% [markdown]
# **MobileNetV2 FT: Train/Validate/Test/Cross Validate the Model**

# %%
print('#######################################################################################################################################')
model_mobilenetv2ft = define_model_mobilenet('V2')
set_trainable_layers_starting_from(model_mobilenetv2ft, MOBILENETV2_TRAINABLE_START_LAYER)
model_mobilenetv2ft.load_weights(path_to_mobilenetv2xfr_params_file)
#model_mobilenetv2ft.summary()
path_to_mobilenetv2ft_params_file = '/content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5'
model_mobilenetv2ft = train_and_validate_model(model_mobilenetv2ft, train_images, train_labels, validation_images, validation_labels, path_to_mobilenetv2ft_params_file)
model_mobilenetv2ft = test_model_with_best_params(model_mobilenetv2ft, path_to_mobilenetv2ft_params_file, test_images, test_labels)
print('#######################################################################################################################################')
# we shall provide the best params from transfer learning to initialize the model at cross validation
if (CROSS_VALIDATE == True):
  # cross validate and get the path to the file containing best cross validation fold's parameters
  path_to_mobilenetv2ft_best_cv_fold_params_file = cross_validate_model('mobilenetv2ft', all_images, all_labels, all_labels_before_categorical, path_to_mobilenetv2xfr_params_file)
  print(f'Path to Best CV Fold Params: {path_to_mobilenetv2ft_best_cv_fold_params_file}')
  # define a model, load best cross validation fold params, test
  model_mobilenetv2ft_cv = define_model_mobilenet('V2')
  model_mobilenetv2ft_cv = test_model_with_best_params(model_mobilenetv2ft_cv, path_to_mobilenetv2ft_best_cv_fold_params_file, test_images, test_labels)
# Out:
# #######################################################################################################################################
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Model Train and Validation: Starting
# Epoch 1/100
# 77/77 [==============================] - 6s 47ms/step - loss: 0.5197 - accuracy: 0.7315 - val_loss: 0.4848 - val_accuracy: 0.7540
#
# Epoch 00001: val_accuracy improved from -inf to 0.75401, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 2/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5032 - accuracy: 0.7577 - val_loss: 0.4852 - val_accuracy: 0.7647
#
# Epoch 00002: val_accuracy improved from 0.75401 to 0.76471, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 3/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5170 - accuracy: 0.7257 - val_loss: 0.5899 - val_accuracy: 0.7086
#
# Epoch 00003: val_accuracy did not improve from 0.76471
# Epoch 4/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5796 - accuracy: 0.7178 - val_loss: 0.4770 - val_accuracy: 0.7701
#
# Epoch 00004: val_accuracy improved from 0.76471 to 0.77005, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 5/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4940 - accuracy: 0.7542 - val_loss: 0.4632 - val_accuracy: 0.7834
#
# Epoch 00005: val_accuracy improved from 0.77005 to 0.78342, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 6/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5761 - accuracy: 0.6923 - val_loss: 0.4560 - val_accuracy: 0.7861
#
# Epoch 00006: val_accuracy improved from 0.78342 to 0.78610, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 7/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5482 - accuracy: 0.7072 - val_loss: 0.4887 - val_accuracy: 0.7594
#
# Epoch 00007: val_accuracy did not improve from 0.78610
# Epoch 8/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5047 - accuracy: 0.7579 - val_loss: 0.4627 - val_accuracy: 0.7995
#
# Epoch 00008: val_accuracy improved from 0.78610 to 0.79947, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 9/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5184 - accuracy: 0.7452 - val_loss: 0.4655 - val_accuracy: 0.7888
#
# Epoch 00009: val_accuracy did not improve from 0.79947
# Epoch 10/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5253 - accuracy: 0.7340 - val_loss: 0.4861 - val_accuracy: 0.7754
#
# Epoch 00010: val_accuracy did not improve from 0.79947
# Epoch 11/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5185 - accuracy: 0.7316 - val_loss: 0.4611 - val_accuracy: 0.7941
#
# Epoch 00011: val_accuracy did not improve from 0.79947
# Epoch 12/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5198 - accuracy: 0.7298 - val_loss: 0.4610 - val_accuracy: 0.7807
#
# Epoch 00012: val_accuracy did not improve from 0.79947
# Epoch 13/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5080 - accuracy: 0.7363 - val_loss: 0.4646 - val_accuracy: 0.7941
#
# Epoch 00013: val_accuracy did not improve from 0.79947
# Epoch 14/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4719 - accuracy: 0.7667 - val_loss: 0.4770 - val_accuracy: 0.8021
#
# Epoch 00014: val_accuracy improved from 0.79947 to 0.80214, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 15/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4997 - accuracy: 0.7366 - val_loss: 0.5018 - val_accuracy: 0.7406
#
# Epoch 00015: val_accuracy did not improve from 0.80214
# Epoch 16/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4989 - accuracy: 0.7561 - val_loss: 0.4614 - val_accuracy: 0.7888
#
# Epoch 00016: val_accuracy did not improve from 0.80214
# Epoch 17/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5200 - accuracy: 0.7445 - val_loss: 0.4593 - val_accuracy: 0.7888
#
# Epoch 00017: val_accuracy did not improve from 0.80214
# Epoch 18/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5197 - accuracy: 0.7095 - val_loss: 0.4725 - val_accuracy: 0.7861
#
# Epoch 00018: val_accuracy did not improve from 0.80214
# Epoch 19/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4968 - accuracy: 0.7570 - val_loss: 0.4683 - val_accuracy: 0.7727
#
# Epoch 00019: val_accuracy did not improve from 0.80214
# Epoch 20/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5120 - accuracy: 0.7436 - val_loss: 0.4649 - val_accuracy: 0.7807
#
# Epoch 00020: val_accuracy did not improve from 0.80214
# Epoch 21/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4949 - accuracy: 0.7500 - val_loss: 0.4699 - val_accuracy: 0.7701
#
# Epoch 00021: val_accuracy did not improve from 0.80214
# Epoch 22/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4855 - accuracy: 0.7408 - val_loss: 0.4679 - val_accuracy: 0.7620
#
# Epoch 00022: val_accuracy did not improve from 0.80214
# Epoch 23/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4655 - accuracy: 0.7624 - val_loss: 0.4963 - val_accuracy: 0.7620
#
# Epoch 00023: val_accuracy did not improve from 0.80214
# Epoch 24/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5080 - accuracy: 0.7372 - val_loss: 0.4942 - val_accuracy: 0.7807
#
# Epoch 00024: val_accuracy did not improve from 0.80214
# Epoch 25/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5045 - accuracy: 0.7607 - val_loss: 0.4939 - val_accuracy: 0.7674
#
# Epoch 00025: val_accuracy did not improve from 0.80214
# Epoch 26/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4461 - accuracy: 0.7890 - val_loss: 0.4851 - val_accuracy: 0.7834
#
# Epoch 00026: val_accuracy did not improve from 0.80214
# Epoch 27/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4578 - accuracy: 0.7845 - val_loss: 0.4882 - val_accuracy: 0.7888
#
# Epoch 00027: val_accuracy did not improve from 0.80214
# Epoch 28/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4762 - accuracy: 0.7651 - val_loss: 0.5128 - val_accuracy: 0.7594
#
# Epoch 00028: val_accuracy did not improve from 0.80214
# Epoch 29/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4924 - accuracy: 0.7696 - val_loss: 0.4759 - val_accuracy: 0.7834
#
# Epoch 00029: val_accuracy did not improve from 0.80214
# Epoch 30/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4640 - accuracy: 0.7686 - val_loss: 0.4652 - val_accuracy: 0.7754
#
# Epoch 00030: val_accuracy did not improve from 0.80214
# Epoch 31/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4736 - accuracy: 0.7771 - val_loss: 0.4718 - val_accuracy: 0.8021
#
# Epoch 00031: val_accuracy did not improve from 0.80214
# Epoch 32/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4458 - accuracy: 0.8046 - val_loss: 0.5068 - val_accuracy: 0.7460
#
# Epoch 00032: val_accuracy did not improve from 0.80214
# Epoch 33/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4845 - accuracy: 0.7535 - val_loss: 0.4765 - val_accuracy: 0.8048
#
# Epoch 00033: val_accuracy improved from 0.80214 to 0.80481, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 34/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4989 - accuracy: 0.7836 - val_loss: 0.4769 - val_accuracy: 0.7807
#
# Epoch 00034: val_accuracy did not improve from 0.80481
# Epoch 35/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5307 - accuracy: 0.7133 - val_loss: 0.4721 - val_accuracy: 0.7701
#
# Epoch 00035: val_accuracy did not improve from 0.80481
# Epoch 36/100
# 77/77 [==============================] - 3s 45ms/step - loss: 0.4652 - accuracy: 0.7937 - val_loss: 0.4728 - val_accuracy: 0.7995
#
# Epoch 00036: val_accuracy did not improve from 0.80481
# Epoch 37/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4667 - accuracy: 0.7507 - val_loss: 0.4595 - val_accuracy: 0.7807
#
# Epoch 00037: val_accuracy did not improve from 0.80481
# Epoch 38/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4521 - accuracy: 0.7706 - val_loss: 0.4786 - val_accuracy: 0.7781
#
# Epoch 00038: val_accuracy did not improve from 0.80481
# Epoch 39/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4605 - accuracy: 0.7301 - val_loss: 0.4700 - val_accuracy: 0.7781
#
# Epoch 00039: val_accuracy did not improve from 0.80481
# Epoch 40/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4463 - accuracy: 0.7774 - val_loss: 0.5133 - val_accuracy: 0.7594
#
# Epoch 00040: val_accuracy did not improve from 0.80481
# Epoch 41/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4665 - accuracy: 0.7687 - val_loss: 0.4735 - val_accuracy: 0.7727
#
# Epoch 00041: val_accuracy did not improve from 0.80481
# Epoch 42/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4715 - accuracy: 0.7495 - val_loss: 0.4893 - val_accuracy: 0.7861
#
# Epoch 00042: val_accuracy did not improve from 0.80481
# Epoch 43/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4586 - accuracy: 0.7556 - val_loss: 0.4848 - val_accuracy: 0.7727
#
# Epoch 00043: val_accuracy did not improve from 0.80481
# Epoch 44/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4446 - accuracy: 0.7766 - val_loss: 0.5069 - val_accuracy: 0.7620
#
# Epoch 00044: val_accuracy did not improve from 0.80481
# Epoch 45/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4558 - accuracy: 0.7706 - val_loss: 0.4748 - val_accuracy: 0.8128
#
# Epoch 00045: val_accuracy improved from 0.80481 to 0.81283, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft.hdf5
# Epoch 46/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4459 - accuracy: 0.7800 - val_loss: 0.4688 - val_accuracy: 0.7914
#
# Epoch 00046: val_accuracy did not improve from 0.81283
# Epoch 47/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4671 - accuracy: 0.7601 - val_loss: 0.4885 - val_accuracy: 0.7941
#
# Epoch 00047: val_accuracy did not improve from 0.81283
# Epoch 48/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4399 - accuracy: 0.7931 - val_loss: 0.4878 - val_accuracy: 0.7834
#
# Epoch 00048: val_accuracy did not improve from 0.81283
# Epoch 49/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4455 - accuracy: 0.7586 - val_loss: 0.5124 - val_accuracy: 0.7941
#
# Epoch 00049: val_accuracy did not improve from 0.81283
# Epoch 50/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4369 - accuracy: 0.7790 - val_loss: 0.5079 - val_accuracy: 0.7995
#
# Epoch 00050: val_accuracy did not improve from 0.81283
# Epoch 51/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4376 - accuracy: 0.7847 - val_loss: 0.5121 - val_accuracy: 0.7754
#
# Epoch 00051: val_accuracy did not improve from 0.81283
# Epoch 52/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4677 - accuracy: 0.7713 - val_loss: 0.5197 - val_accuracy: 0.7914
#
# Epoch 00052: val_accuracy did not improve from 0.81283
# Epoch 53/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4429 - accuracy: 0.7633 - val_loss: 0.5079 - val_accuracy: 0.7701
#
# Epoch 00053: val_accuracy did not improve from 0.81283
# Epoch 54/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4749 - accuracy: 0.7607 - val_loss: 0.5485 - val_accuracy: 0.7273
#
# Epoch 00054: val_accuracy did not improve from 0.81283
# Epoch 55/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.5041 - accuracy: 0.7356 - val_loss: 0.4891 - val_accuracy: 0.8075
#
# Epoch 00055: val_accuracy did not improve from 0.81283
# Epoch 56/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4614 - accuracy: 0.7812 - val_loss: 0.4761 - val_accuracy: 0.7941
#
# Epoch 00056: val_accuracy did not improve from 0.81283
# Epoch 57/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4680 - accuracy: 0.7658 - val_loss: 0.5259 - val_accuracy: 0.7353
#
# Epoch 00057: val_accuracy did not improve from 0.81283
# Epoch 58/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4454 - accuracy: 0.7910 - val_loss: 0.5020 - val_accuracy: 0.7620
#
# Epoch 00058: val_accuracy did not improve from 0.81283
# Epoch 59/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4493 - accuracy: 0.7866 - val_loss: 0.5103 - val_accuracy: 0.7941
#
# Epoch 00059: val_accuracy did not improve from 0.81283
# Epoch 60/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4542 - accuracy: 0.7696 - val_loss: 0.4954 - val_accuracy: 0.7754
#
# Epoch 00060: val_accuracy did not improve from 0.81283
# Epoch 61/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4181 - accuracy: 0.8018 - val_loss: 0.5053 - val_accuracy: 0.7888
#
# Epoch 00061: val_accuracy did not improve from 0.81283
# Epoch 62/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4719 - accuracy: 0.7589 - val_loss: 0.5164 - val_accuracy: 0.7540
#
# Epoch 00062: val_accuracy did not improve from 0.81283
# Epoch 63/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4552 - accuracy: 0.7833 - val_loss: 0.5108 - val_accuracy: 0.7914
#
# Epoch 00063: val_accuracy did not improve from 0.81283
# Epoch 64/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4428 - accuracy: 0.7676 - val_loss: 0.5207 - val_accuracy: 0.7567
#
# Epoch 00064: val_accuracy did not improve from 0.81283
# Epoch 65/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4402 - accuracy: 0.7502 - val_loss: 0.5138 - val_accuracy: 0.7807
#
# Epoch 00065: val_accuracy did not improve from 0.81283
# Epoch 66/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4286 - accuracy: 0.7807 - val_loss: 0.4914 - val_accuracy: 0.7914
#
# Epoch 00066: val_accuracy did not improve from 0.81283
# Epoch 67/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4127 - accuracy: 0.8061 - val_loss: 0.4974 - val_accuracy: 0.7647
#
# Epoch 00067: val_accuracy did not improve from 0.81283
# Epoch 68/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4374 - accuracy: 0.7788 - val_loss: 0.5054 - val_accuracy: 0.7941
#
# Epoch 00068: val_accuracy did not improve from 0.81283
# Epoch 69/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4411 - accuracy: 0.7736 - val_loss: 0.4969 - val_accuracy: 0.7941
#
# Epoch 00069: val_accuracy did not improve from 0.81283
# Epoch 70/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4263 - accuracy: 0.7891 - val_loss: 0.5346 - val_accuracy: 0.7861
#
# Epoch 00070: val_accuracy did not improve from 0.81283
# Epoch 71/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4457 - accuracy: 0.7695 - val_loss: 0.5559 - val_accuracy: 0.7353
#
# Epoch 00071: val_accuracy did not improve from 0.81283
# Epoch 72/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4563 - accuracy: 0.7469 - val_loss: 0.5056 - val_accuracy: 0.7941
#
# Epoch 00072: val_accuracy did not improve from 0.81283
# Epoch 73/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4243 - accuracy: 0.7917 - val_loss: 0.5284 - val_accuracy: 0.8048
#
# Epoch 00073: val_accuracy did not improve from 0.81283
# Epoch 74/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4083 - accuracy: 0.7838 - val_loss: 0.5183 - val_accuracy: 0.7834
#
# Epoch 00074: val_accuracy did not improve from 0.81283
# Epoch 75/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.3943 - accuracy: 0.8098 - val_loss: 0.5319 - val_accuracy: 0.7701
#
# Epoch 00075: val_accuracy did not improve from 0.81283
# Epoch 76/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4007 - accuracy: 0.8264 - val_loss: 0.5302 - val_accuracy: 0.7861
#
# Epoch 00076: val_accuracy did not improve from 0.81283
# Epoch 77/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4321 - accuracy: 0.7788 - val_loss: 0.5012 - val_accuracy: 0.8075
#
# Epoch 00077: val_accuracy did not improve from 0.81283
# Epoch 78/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4522 - accuracy: 0.7690 - val_loss: 0.5214 - val_accuracy: 0.7861
#
# Epoch 00078: val_accuracy did not improve from 0.81283
# Epoch 79/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4104 - accuracy: 0.8100 - val_loss: 0.5268 - val_accuracy: 0.7941
#
# Epoch 00079: val_accuracy did not improve from 0.81283
# Epoch 80/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4263 - accuracy: 0.7791 - val_loss: 0.5322 - val_accuracy: 0.7460
#
# Epoch 00080: val_accuracy did not improve from 0.81283
# Epoch 81/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4221 - accuracy: 0.7891 - val_loss: 0.5460 - val_accuracy: 0.7727
#
# Epoch 00081: val_accuracy did not improve from 0.81283
# Epoch 82/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4378 - accuracy: 0.7729 - val_loss: 0.5509 - val_accuracy: 0.7620
#
# Epoch 00082: val_accuracy did not improve from 0.81283
# Epoch 83/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4506 - accuracy: 0.7772 - val_loss: 0.5359 - val_accuracy: 0.7727
#
# Epoch 00083: val_accuracy did not improve from 0.81283
# Epoch 84/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4239 - accuracy: 0.8109 - val_loss: 0.5304 - val_accuracy: 0.7807
#
# Epoch 00084: val_accuracy did not improve from 0.81283
# Epoch 85/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4127 - accuracy: 0.8064 - val_loss: 0.5117 - val_accuracy: 0.8048
#
# Epoch 00085: val_accuracy did not improve from 0.81283
# Epoch 86/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4012 - accuracy: 0.8041 - val_loss: 0.5404 - val_accuracy: 0.7807
#
# Epoch 00086: val_accuracy did not improve from 0.81283
# Epoch 87/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4110 - accuracy: 0.8031 - val_loss: 0.5558 - val_accuracy: 0.7781
#
# Epoch 00087: val_accuracy did not improve from 0.81283
# Epoch 88/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4181 - accuracy: 0.7839 - val_loss: 0.5416 - val_accuracy: 0.7941
#
# Epoch 00088: val_accuracy did not improve from 0.81283
# Epoch 89/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4124 - accuracy: 0.7884 - val_loss: 0.5213 - val_accuracy: 0.7888
#
# Epoch 00089: val_accuracy did not improve from 0.81283
# Epoch 90/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4449 - accuracy: 0.7703 - val_loss: 0.5301 - val_accuracy: 0.7834
#
# Epoch 00090: val_accuracy did not improve from 0.81283
# Epoch 91/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4249 - accuracy: 0.7961 - val_loss: 0.5210 - val_accuracy: 0.7807
#
# Epoch 00091: val_accuracy did not improve from 0.81283
# Epoch 92/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4098 - accuracy: 0.8067 - val_loss: 0.5516 - val_accuracy: 0.7594
#
# Epoch 00092: val_accuracy did not improve from 0.81283
# Epoch 93/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4450 - accuracy: 0.7845 - val_loss: 0.5270 - val_accuracy: 0.7941
#
# Epoch 00093: val_accuracy did not improve from 0.81283
# Epoch 94/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4300 - accuracy: 0.7856 - val_loss: 0.5458 - val_accuracy: 0.7888
#
# Epoch 00094: val_accuracy did not improve from 0.81283
# Epoch 95/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.4139 - accuracy: 0.7915 - val_loss: 0.5344 - val_accuracy: 0.7807
#
# Epoch 00095: val_accuracy did not improve from 0.81283
# Epoch 96/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4779 - accuracy: 0.7734 - val_loss: 0.5553 - val_accuracy: 0.7807
#
# Epoch 00096: val_accuracy did not improve from 0.81283
# Epoch 97/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4379 - accuracy: 0.7688 - val_loss: 0.5609 - val_accuracy: 0.7594
#
# Epoch 00097: val_accuracy did not improve from 0.81283
# Epoch 98/100
# 77/77 [==============================] - 3s 41ms/step - loss: 0.4436 - accuracy: 0.7815 - val_loss: 0.5416 - val_accuracy: 0.7674
#
# Epoch 00098: val_accuracy did not improve from 0.81283
# Epoch 99/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.4242 - accuracy: 0.7934 - val_loss: 0.5261 - val_accuracy: 0.7941
#
# Epoch 00099: val_accuracy did not improve from 0.81283
# Epoch 100/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.3920 - accuracy: 0.8131 - val_loss: 0.5612 - val_accuracy: 0.7647
#
# Epoch 00100: val_accuracy did not improve from 0.81283
# Train and Validation Time = 281.10192251205444s
# Model Train and Validation: Completed
# Model Test: Starting
# 37/37 [==============================] - 2s 65ms/step - loss: 0.5766 - accuracy: 0.7299
# Test Time = 2.438354969024658s
# Test Time / sample = 0.0021111298433113923s
# Model Test: Completed
# #######################################################################################################################################
# Model Cross Validation: Starting
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Epoch 1/100
# 86/86 [==============================] - 6s 43ms/step - loss: 0.5139 - accuracy: 0.7459 - val_loss: 0.4850 - val_accuracy: 0.7483
#
# Epoch 00001: val_accuracy improved from -inf to 0.74825, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 2/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4909 - accuracy: 0.7755 - val_loss: 0.5023 - val_accuracy: 0.7727
#
# Epoch 00002: val_accuracy improved from 0.74825 to 0.77273, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 3/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5816 - accuracy: 0.7118 - val_loss: 0.4869 - val_accuracy: 0.7762
#
# Epoch 00003: val_accuracy improved from 0.77273 to 0.77622, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 4/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4825 - accuracy: 0.7541 - val_loss: 0.4782 - val_accuracy: 0.7657
#
# Epoch 00004: val_accuracy did not improve from 0.77622
# Epoch 5/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5070 - accuracy: 0.7518 - val_loss: 0.5008 - val_accuracy: 0.7448
#
# Epoch 00005: val_accuracy did not improve from 0.77622
# Epoch 6/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5370 - accuracy: 0.7015 - val_loss: 0.4830 - val_accuracy: 0.7867
#
# Epoch 00006: val_accuracy improved from 0.77622 to 0.78671, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 7/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4821 - accuracy: 0.7549 - val_loss: 0.4845 - val_accuracy: 0.7692
#
# Epoch 00007: val_accuracy did not improve from 0.78671
# Epoch 8/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4996 - accuracy: 0.7684 - val_loss: 0.5289 - val_accuracy: 0.7238
#
# Epoch 00008: val_accuracy did not improve from 0.78671
# Epoch 9/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4818 - accuracy: 0.7803 - val_loss: 0.5086 - val_accuracy: 0.7517
#
# Epoch 00009: val_accuracy did not improve from 0.78671
# Epoch 10/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4774 - accuracy: 0.7516 - val_loss: 0.4860 - val_accuracy: 0.7692
#
# Epoch 00010: val_accuracy did not improve from 0.78671
# Epoch 11/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4882 - accuracy: 0.7563 - val_loss: 0.4926 - val_accuracy: 0.7902
#
# Epoch 00011: val_accuracy improved from 0.78671 to 0.79021, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 12/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4945 - accuracy: 0.7532 - val_loss: 0.4915 - val_accuracy: 0.7587
#
# Epoch 00012: val_accuracy did not improve from 0.79021
# Epoch 13/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4793 - accuracy: 0.7578 - val_loss: 0.4738 - val_accuracy: 0.7692
#
# Epoch 00013: val_accuracy did not improve from 0.79021
# Epoch 14/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4604 - accuracy: 0.7791 - val_loss: 0.4738 - val_accuracy: 0.7832
#
# Epoch 00014: val_accuracy did not improve from 0.79021
# Epoch 15/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4824 - accuracy: 0.7608 - val_loss: 0.4915 - val_accuracy: 0.7937
#
# Epoch 00015: val_accuracy improved from 0.79021 to 0.79371, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 16/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4648 - accuracy: 0.7924 - val_loss: 0.4797 - val_accuracy: 0.7867
#
# Epoch 00016: val_accuracy did not improve from 0.79371
# Epoch 17/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4721 - accuracy: 0.7937 - val_loss: 0.4890 - val_accuracy: 0.7867
#
# Epoch 00017: val_accuracy did not improve from 0.79371
# Epoch 18/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4618 - accuracy: 0.7688 - val_loss: 0.5162 - val_accuracy: 0.7692
#
# Epoch 00018: val_accuracy did not improve from 0.79371
# Epoch 19/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4830 - accuracy: 0.7538 - val_loss: 0.4713 - val_accuracy: 0.7657
#
# Epoch 00019: val_accuracy did not improve from 0.79371
# Epoch 20/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4802 - accuracy: 0.7675 - val_loss: 0.4766 - val_accuracy: 0.7832
#
# Epoch 00020: val_accuracy did not improve from 0.79371
# Epoch 21/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4660 - accuracy: 0.7882 - val_loss: 0.4800 - val_accuracy: 0.7657
#
# Epoch 00021: val_accuracy did not improve from 0.79371
# Epoch 22/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4877 - accuracy: 0.7553 - val_loss: 0.5053 - val_accuracy: 0.7692
#
# Epoch 00022: val_accuracy did not improve from 0.79371
# Epoch 23/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4775 - accuracy: 0.7661 - val_loss: 0.4836 - val_accuracy: 0.7657
#
# Epoch 00023: val_accuracy did not improve from 0.79371
# Epoch 24/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4589 - accuracy: 0.7816 - val_loss: 0.5013 - val_accuracy: 0.7762
#
# Epoch 00024: val_accuracy did not improve from 0.79371
# Epoch 25/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4812 - accuracy: 0.7574 - val_loss: 0.4872 - val_accuracy: 0.7727
#
# Epoch 00025: val_accuracy did not improve from 0.79371
# Epoch 26/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4938 - accuracy: 0.7397 - val_loss: 0.4939 - val_accuracy: 0.7867
#
# Epoch 00026: val_accuracy did not improve from 0.79371
# Epoch 27/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4786 - accuracy: 0.7723 - val_loss: 0.4692 - val_accuracy: 0.7727
#
# Epoch 00027: val_accuracy did not improve from 0.79371
# Epoch 28/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4763 - accuracy: 0.7606 - val_loss: 0.4907 - val_accuracy: 0.7832
#
# Epoch 00028: val_accuracy did not improve from 0.79371
# Epoch 29/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4739 - accuracy: 0.7910 - val_loss: 0.4884 - val_accuracy: 0.7692
#
# Epoch 00029: val_accuracy did not improve from 0.79371
# Epoch 30/100
# 86/86 [==============================] - 3s 39ms/step - loss: 0.4530 - accuracy: 0.7839 - val_loss: 0.4763 - val_accuracy: 0.7972
#
# Epoch 00030: val_accuracy improved from 0.79371 to 0.79720, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 31/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4514 - accuracy: 0.8103 - val_loss: 0.4895 - val_accuracy: 0.7797
#
# Epoch 00031: val_accuracy did not improve from 0.79720
# Epoch 32/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4685 - accuracy: 0.7889 - val_loss: 0.4818 - val_accuracy: 0.7867
#
# Epoch 00032: val_accuracy did not improve from 0.79720
# Epoch 33/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4809 - accuracy: 0.7470 - val_loss: 0.4805 - val_accuracy: 0.7727
#
# Epoch 00033: val_accuracy did not improve from 0.79720
# Epoch 34/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4244 - accuracy: 0.7988 - val_loss: 0.4847 - val_accuracy: 0.7797
#
# Epoch 00034: val_accuracy did not improve from 0.79720
# Epoch 35/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4591 - accuracy: 0.7717 - val_loss: 0.4859 - val_accuracy: 0.7972
#
# Epoch 00035: val_accuracy did not improve from 0.79720
# Epoch 36/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4282 - accuracy: 0.8077 - val_loss: 0.5127 - val_accuracy: 0.7657
#
# Epoch 00036: val_accuracy did not improve from 0.79720
# Epoch 37/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4624 - accuracy: 0.7542 - val_loss: 0.4821 - val_accuracy: 0.7902
#
# Epoch 00037: val_accuracy did not improve from 0.79720
# Epoch 38/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4305 - accuracy: 0.7976 - val_loss: 0.4923 - val_accuracy: 0.7797
#
# Epoch 00038: val_accuracy did not improve from 0.79720
# Epoch 39/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4410 - accuracy: 0.7936 - val_loss: 0.4834 - val_accuracy: 0.7797
#
# Epoch 00039: val_accuracy did not improve from 0.79720
# Epoch 40/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4552 - accuracy: 0.7660 - val_loss: 0.5355 - val_accuracy: 0.7692
#
# Epoch 00040: val_accuracy did not improve from 0.79720
# Epoch 41/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4909 - accuracy: 0.7652 - val_loss: 0.4872 - val_accuracy: 0.7762
#
# Epoch 00041: val_accuracy did not improve from 0.79720
# Epoch 42/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4497 - accuracy: 0.7861 - val_loss: 0.5257 - val_accuracy: 0.7727
#
# Epoch 00042: val_accuracy did not improve from 0.79720
# Epoch 43/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4472 - accuracy: 0.7804 - val_loss: 0.4997 - val_accuracy: 0.7902
#
# Epoch 00043: val_accuracy did not improve from 0.79720
# Epoch 44/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4662 - accuracy: 0.7852 - val_loss: 0.4959 - val_accuracy: 0.7727
#
# Epoch 00044: val_accuracy did not improve from 0.79720
# Epoch 45/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4335 - accuracy: 0.7935 - val_loss: 0.4769 - val_accuracy: 0.7832
#
# Epoch 00045: val_accuracy did not improve from 0.79720
# Epoch 46/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4582 - accuracy: 0.7696 - val_loss: 0.4989 - val_accuracy: 0.7762
#
# Epoch 00046: val_accuracy did not improve from 0.79720
# Epoch 47/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4420 - accuracy: 0.7775 - val_loss: 0.4932 - val_accuracy: 0.7902
#
# Epoch 00047: val_accuracy did not improve from 0.79720
# Epoch 48/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4736 - accuracy: 0.7821 - val_loss: 0.4941 - val_accuracy: 0.7657
#
# Epoch 00048: val_accuracy did not improve from 0.79720
# Epoch 49/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4388 - accuracy: 0.7892 - val_loss: 0.4832 - val_accuracy: 0.7972
#
# Epoch 00049: val_accuracy did not improve from 0.79720
# Epoch 50/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4315 - accuracy: 0.7872 - val_loss: 0.4823 - val_accuracy: 0.7727
#
# Epoch 00050: val_accuracy did not improve from 0.79720
# Epoch 51/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4564 - accuracy: 0.7752 - val_loss: 0.4864 - val_accuracy: 0.7832
#
# Epoch 00051: val_accuracy did not improve from 0.79720
# Epoch 52/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4320 - accuracy: 0.7861 - val_loss: 0.4853 - val_accuracy: 0.7972
#
# Epoch 00052: val_accuracy did not improve from 0.79720
# Epoch 53/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4447 - accuracy: 0.7784 - val_loss: 0.4987 - val_accuracy: 0.7902
#
# Epoch 00053: val_accuracy did not improve from 0.79720
# Epoch 54/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4682 - accuracy: 0.7646 - val_loss: 0.4992 - val_accuracy: 0.7902
#
# Epoch 00054: val_accuracy did not improve from 0.79720
# Epoch 55/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4455 - accuracy: 0.7883 - val_loss: 0.4966 - val_accuracy: 0.7867
#
# Epoch 00055: val_accuracy did not improve from 0.79720
# Epoch 56/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4642 - accuracy: 0.7705 - val_loss: 0.4914 - val_accuracy: 0.7832
#
# Epoch 00056: val_accuracy did not improve from 0.79720
# Epoch 57/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4458 - accuracy: 0.7791 - val_loss: 0.5039 - val_accuracy: 0.7972
#
# Epoch 00057: val_accuracy did not improve from 0.79720
# Epoch 58/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4438 - accuracy: 0.8106 - val_loss: 0.5443 - val_accuracy: 0.7517
#
# Epoch 00058: val_accuracy did not improve from 0.79720
# Epoch 59/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4455 - accuracy: 0.7761 - val_loss: 0.4794 - val_accuracy: 0.7937
#
# Epoch 00059: val_accuracy did not improve from 0.79720
# Epoch 60/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3997 - accuracy: 0.8076 - val_loss: 0.4931 - val_accuracy: 0.7902
#
# Epoch 00060: val_accuracy did not improve from 0.79720
# Epoch 61/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4644 - accuracy: 0.7713 - val_loss: 0.5068 - val_accuracy: 0.7622
#
# Epoch 00061: val_accuracy did not improve from 0.79720
# Epoch 62/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4153 - accuracy: 0.7921 - val_loss: 0.4949 - val_accuracy: 0.8077
#
# Epoch 00062: val_accuracy improved from 0.79720 to 0.80769, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_0.hdf5
# Epoch 63/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4264 - accuracy: 0.7875 - val_loss: 0.5143 - val_accuracy: 0.7762
#
# Epoch 00063: val_accuracy did not improve from 0.80769
# Epoch 64/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4343 - accuracy: 0.7950 - val_loss: 0.5072 - val_accuracy: 0.7937
#
# Epoch 00064: val_accuracy did not improve from 0.80769
# Epoch 65/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4377 - accuracy: 0.7768 - val_loss: 0.4866 - val_accuracy: 0.8007
#
# Epoch 00065: val_accuracy did not improve from 0.80769
# Epoch 66/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4332 - accuracy: 0.7855 - val_loss: 0.4874 - val_accuracy: 0.8007
#
# Epoch 00066: val_accuracy did not improve from 0.80769
# Epoch 67/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4350 - accuracy: 0.7981 - val_loss: 0.4971 - val_accuracy: 0.7937
#
# Epoch 00067: val_accuracy did not improve from 0.80769
# Epoch 68/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4161 - accuracy: 0.8118 - val_loss: 0.4850 - val_accuracy: 0.7937
#
# Epoch 00068: val_accuracy did not improve from 0.80769
# Epoch 69/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4307 - accuracy: 0.7831 - val_loss: 0.4872 - val_accuracy: 0.7902
#
# Epoch 00069: val_accuracy did not improve from 0.80769
# Epoch 70/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4130 - accuracy: 0.7991 - val_loss: 0.5414 - val_accuracy: 0.7692
#
# Epoch 00070: val_accuracy did not improve from 0.80769
# Epoch 71/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4148 - accuracy: 0.8091 - val_loss: 0.5464 - val_accuracy: 0.7657
#
# Epoch 00071: val_accuracy did not improve from 0.80769
# Epoch 72/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4275 - accuracy: 0.7978 - val_loss: 0.5302 - val_accuracy: 0.7832
#
# Epoch 00072: val_accuracy did not improve from 0.80769
# Epoch 73/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4067 - accuracy: 0.8050 - val_loss: 0.5107 - val_accuracy: 0.7832
#
# Epoch 00073: val_accuracy did not improve from 0.80769
# Epoch 74/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4128 - accuracy: 0.8047 - val_loss: 0.5772 - val_accuracy: 0.7657
#
# Epoch 00074: val_accuracy did not improve from 0.80769
# Epoch 75/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4448 - accuracy: 0.7687 - val_loss: 0.5228 - val_accuracy: 0.7867
#
# Epoch 00075: val_accuracy did not improve from 0.80769
# Epoch 76/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4557 - accuracy: 0.7737 - val_loss: 0.5186 - val_accuracy: 0.7832
#
# Epoch 00076: val_accuracy did not improve from 0.80769
# Epoch 77/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4076 - accuracy: 0.8029 - val_loss: 0.5072 - val_accuracy: 0.7832
#
# Epoch 00077: val_accuracy did not improve from 0.80769
# Epoch 78/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4202 - accuracy: 0.7984 - val_loss: 0.5171 - val_accuracy: 0.7867
#
# Epoch 00078: val_accuracy did not improve from 0.80769
# Epoch 79/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4132 - accuracy: 0.8014 - val_loss: 0.5491 - val_accuracy: 0.7587
#
# Epoch 00079: val_accuracy did not improve from 0.80769
# Epoch 80/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4458 - accuracy: 0.7731 - val_loss: 0.5306 - val_accuracy: 0.7972
#
# Epoch 00080: val_accuracy did not improve from 0.80769
# Epoch 81/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4175 - accuracy: 0.8015 - val_loss: 0.5197 - val_accuracy: 0.7832
#
# Epoch 00081: val_accuracy did not improve from 0.80769
# Epoch 82/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4127 - accuracy: 0.7853 - val_loss: 0.4990 - val_accuracy: 0.8007
#
# Epoch 00082: val_accuracy did not improve from 0.80769
# Epoch 83/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4054 - accuracy: 0.7749 - val_loss: 0.5419 - val_accuracy: 0.7692
#
# Epoch 00083: val_accuracy did not improve from 0.80769
# Epoch 84/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4318 - accuracy: 0.7869 - val_loss: 0.5091 - val_accuracy: 0.7797
#
# Epoch 00084: val_accuracy did not improve from 0.80769
# Epoch 85/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4450 - accuracy: 0.7784 - val_loss: 0.4894 - val_accuracy: 0.7902
#
# Epoch 00085: val_accuracy did not improve from 0.80769
# Epoch 86/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4123 - accuracy: 0.8036 - val_loss: 0.5192 - val_accuracy: 0.7727
#
# Epoch 00086: val_accuracy did not improve from 0.80769
# Epoch 87/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4379 - accuracy: 0.7794 - val_loss: 0.5123 - val_accuracy: 0.7902
#
# Epoch 00087: val_accuracy did not improve from 0.80769
# Epoch 88/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4118 - accuracy: 0.7914 - val_loss: 0.4959 - val_accuracy: 0.7972
#
# Epoch 00088: val_accuracy did not improve from 0.80769
# Epoch 89/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4170 - accuracy: 0.7994 - val_loss: 0.5232 - val_accuracy: 0.7902
#
# Epoch 00089: val_accuracy did not improve from 0.80769
# Epoch 90/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3963 - accuracy: 0.8165 - val_loss: 0.5556 - val_accuracy: 0.7902
#
# Epoch 00090: val_accuracy did not improve from 0.80769
# Epoch 91/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4214 - accuracy: 0.7868 - val_loss: 0.5125 - val_accuracy: 0.7972
#
# Epoch 00091: val_accuracy did not improve from 0.80769
# Epoch 92/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3980 - accuracy: 0.7974 - val_loss: 0.5504 - val_accuracy: 0.8042
#
# Epoch 00092: val_accuracy did not improve from 0.80769
# Epoch 93/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4213 - accuracy: 0.7911 - val_loss: 0.5360 - val_accuracy: 0.8077
#
# Epoch 00093: val_accuracy did not improve from 0.80769
# Epoch 94/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4103 - accuracy: 0.7945 - val_loss: 0.5168 - val_accuracy: 0.7727
#
# Epoch 00094: val_accuracy did not improve from 0.80769
# Epoch 95/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4035 - accuracy: 0.7844 - val_loss: 0.5501 - val_accuracy: 0.7552
#
# Epoch 00095: val_accuracy did not improve from 0.80769
# Epoch 96/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3749 - accuracy: 0.8160 - val_loss: 0.5413 - val_accuracy: 0.8042
#
# Epoch 00096: val_accuracy did not improve from 0.80769
# Epoch 97/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4083 - accuracy: 0.8174 - val_loss: 0.5454 - val_accuracy: 0.7762
#
# Epoch 00097: val_accuracy did not improve from 0.80769
# Epoch 98/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4394 - accuracy: 0.7702 - val_loss: 0.5412 - val_accuracy: 0.7902
#
# Epoch 00098: val_accuracy did not improve from 0.80769
# Epoch 99/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3818 - accuracy: 0.8148 - val_loss: 0.5396 - val_accuracy: 0.7972
#
# Epoch 00099: val_accuracy did not improve from 0.80769
# Epoch 100/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3944 - accuracy: 0.8059 - val_loss: 0.5326 - val_accuracy: 0.8007
#
# Epoch 00100: val_accuracy did not improve from 0.80769
# Cross Validation Accuracy: 74.83%
# Fold #0 Complete
#
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Layers Configuration: Starting
# Layers Configuration: Completed
# Epoch 1/100
# 86/86 [==============================] - 6s 44ms/step - loss: 0.5273 - accuracy: 0.7343 - val_loss: 0.5141 - val_accuracy: 0.7413
#
# Epoch 00001: val_accuracy improved from -inf to 0.74126, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_1.hdf5
# Epoch 2/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5215 - accuracy: 0.7319 - val_loss: 0.5249 - val_accuracy: 0.7517
#
# Epoch 00002: val_accuracy improved from 0.74126 to 0.75175, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_1.hdf5
# Epoch 3/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5244 - accuracy: 0.7567 - val_loss: 0.5439 - val_accuracy: 0.7517
#
# Epoch 00003: val_accuracy did not improve from 0.75175
# Epoch 4/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4989 - accuracy: 0.7638 - val_loss: 0.5039 - val_accuracy: 0.7622
#
# Epoch 00004: val_accuracy improved from 0.75175 to 0.76224, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_1.hdf5
# Epoch 5/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.5146 - accuracy: 0.7473 - val_loss: 0.5026 - val_accuracy: 0.7587
#
# Epoch 00005: val_accuracy did not improve from 0.76224
# Epoch 6/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5145 - accuracy: 0.7625 - val_loss: 0.4857 - val_accuracy: 0.7727
#
# Epoch 00006: val_accuracy improved from 0.76224 to 0.77273, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_1.hdf5
# Epoch 7/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4844 - accuracy: 0.7605 - val_loss: 0.4968 - val_accuracy: 0.7587
#
# Epoch 00007: val_accuracy did not improve from 0.77273
# Epoch 8/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5099 - accuracy: 0.7297 - val_loss: 0.4896 - val_accuracy: 0.7587
#
# Epoch 00008: val_accuracy did not improve from 0.77273
# Epoch 9/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5077 - accuracy: 0.7536 - val_loss: 0.4899 - val_accuracy: 0.7832
#
# Epoch 00009: val_accuracy improved from 0.77273 to 0.78322, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_1.hdf5
# Epoch 10/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4679 - accuracy: 0.7690 - val_loss: 0.4901 - val_accuracy: 0.7657
#
# Epoch 00010: val_accuracy did not improve from 0.78322
# Epoch 11/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5216 - accuracy: 0.7503 - val_loss: 0.5294 - val_accuracy: 0.7413
#
# Epoch 00011: val_accuracy did not improve from 0.78322
# Epoch 12/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.5035 - accuracy: 0.7432 - val_loss: 0.4918 - val_accuracy: 0.7657
#
# Epoch 00012: val_accuracy did not improve from 0.78322
# Epoch 13/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4753 - accuracy: 0.7523 - val_loss: 0.4988 - val_accuracy: 0.7797
#
# Epoch 00013: val_accuracy did not improve from 0.78322
# Epoch 14/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4606 - accuracy: 0.7690 - val_loss: 0.4983 - val_accuracy: 0.7692
#
# Epoch 00014: val_accuracy did not improve from 0.78322
# Epoch 15/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4492 - accuracy: 0.7821 - val_loss: 0.5477 - val_accuracy: 0.7378
#
# Epoch 00015: val_accuracy did not improve from 0.78322
# Epoch 16/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4670 - accuracy: 0.7682 - val_loss: 0.5065 - val_accuracy: 0.7587
#
# Epoch 00016: val_accuracy did not improve from 0.78322
# Epoch 17/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4739 - accuracy: 0.7694 - val_loss: 0.5292 - val_accuracy: 0.7727
#
# Epoch 00017: val_accuracy did not improve from 0.78322
# Epoch 18/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4906 - accuracy: 0.7704 - val_loss: 0.5154 - val_accuracy: 0.7622
#
# Epoch 00018: val_accuracy did not improve from 0.78322
# Epoch 19/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4807 - accuracy: 0.7478 - val_loss: 0.5150 - val_accuracy: 0.7692
#
# Epoch 00019: val_accuracy did not improve from 0.78322
# Epoch 20/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4428 - accuracy: 0.7814 - val_loss: 0.5936 - val_accuracy: 0.7273
#
# Epoch 00020: val_accuracy did not improve from 0.78322
# Epoch 21/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4817 - accuracy: 0.7731 - val_loss: 0.5242 - val_accuracy: 0.7692
#
# ...
# Epoch 26/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4328 - accuracy: 0.7802 - val_loss: 0.5100 - val_accuracy: 0.7483
#
# Epoch 00026: val_accuracy did not improve from 0.76224
# Epoch 27/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4473 - accuracy: 0.7823 - val_loss: 0.5323 - val_accuracy: 0.7587
#
# Epoch 00027: val_accuracy did not improve from 0.76224
# Epoch 28/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4399 - accuracy: 0.7803 - val_loss: 0.5196 - val_accuracy: 0.7483
#
# Epoch 00028: val_accuracy did not improve from 0.76224
# Epoch 29/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4434 - accuracy: 0.7897 - val_loss: 0.5235 - val_accuracy: 0.7483
#
# Epoch 00029: val_accuracy did not improve from 0.76224
# Epoch 30/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4628 - accuracy: 0.7902 - val_loss: 0.5272 - val_accuracy: 0.7587
#
# Epoch 00030: val_accuracy did not improve from 0.76224
# Epoch 31/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4319 - accuracy: 0.8019 - val_loss: 0.5310 - val_accuracy: 0.7587
#
# Epoch 00031: val_accuracy did not improve from 0.76224
# Epoch 32/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4649 - accuracy: 0.7747 - val_loss: 0.5368 - val_accuracy: 0.7587
#
# Epoch 00032: val_accuracy did not improve from 0.76224
# Epoch 33/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4333 - accuracy: 0.8085 - val_loss: 0.5210 - val_accuracy: 0.7552
#
# Epoch 00033: val_accuracy did not improve from 0.76224
# Epoch 34/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4396 - accuracy: 0.8047 - val_loss: 0.5163 - val_accuracy: 0.7552
#
# Epoch 00034: val_accuracy did not improve from 0.76224
# Epoch 35/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4365 - accuracy: 0.7879 - val_loss: 0.5583 - val_accuracy: 0.7517
#
# Epoch 00035: val_accuracy did not improve from 0.76224
# Epoch 36/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4512 - accuracy: 0.7745 - val_loss: 0.5275 - val_accuracy: 0.7587
#
# Epoch 00036: val_accuracy did not improve from 0.76224
# Epoch 37/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4316 - accuracy: 0.7914 - val_loss: 0.5547 - val_accuracy: 0.7483
#
# Epoch 00037: val_accuracy did not improve from 0.76224
# Epoch 38/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4269 - accuracy: 0.8084 - val_loss: 0.5155 - val_accuracy: 0.7378
#
# Epoch 00038: val_accuracy did not improve from 0.76224
# Epoch 39/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4149 - accuracy: 0.7883 - val_loss: 0.5345 - val_accuracy: 0.7483
#
# Epoch 00039: val_accuracy did not improve from 0.76224
# Epoch 40/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4486 - accuracy: 0.7880 - val_loss: 0.5514 - val_accuracy: 0.7552
#
# Epoch 00040: val_accuracy did not improve from 0.76224
# Epoch 41/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4302 - accuracy: 0.7995 - val_loss: 0.5207 - val_accuracy: 0.7483
#
# Epoch 00041: val_accuracy did not improve from 0.76224
# Epoch 42/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4107 - accuracy: 0.8200 - val_loss: 0.5159 - val_accuracy: 0.7308
#
# Epoch 00042: val_accuracy did not improve from 0.76224
# Epoch 43/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4280 - accuracy: 0.7920 - val_loss: 0.5292 - val_accuracy: 0.7343
#
# Epoch 00043: val_accuracy did not improve from 0.76224
# Epoch 44/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4398 - accuracy: 0.7790 - val_loss: 0.5264 - val_accuracy: 0.7552
#
# Epoch 00044: val_accuracy did not improve from 0.76224
# Epoch 45/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4072 - accuracy: 0.8214 - val_loss: 0.5096 - val_accuracy: 0.7657
#
# Epoch 00045: val_accuracy improved from 0.76224 to 0.76573, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_3.hdf5
# Epoch 46/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4089 - accuracy: 0.8105 - val_loss: 0.5313 - val_accuracy: 0.7448
#
# Epoch 00046: val_accuracy did not improve from 0.76573
# Epoch 47/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3987 - accuracy: 0.8308 - val_loss: 0.5164 - val_accuracy: 0.7448
#
# Epoch 00047: val_accuracy did not improve from 0.76573
# Epoch 48/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4166 - accuracy: 0.8064 - val_loss: 0.5170 - val_accuracy: 0.7448
#
# Epoch 00048: val_accuracy did not improve from 0.76573
# Epoch 49/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4276 - accuracy: 0.8045 - val_loss: 0.5920 - val_accuracy: 0.7168
#
# Epoch 00049: val_accuracy did not improve from 0.76573
# Epoch 50/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4415 - accuracy: 0.7938 - val_loss: 0.5475 - val_accuracy: 0.7517
#
# Epoch 00050: val_accuracy did not improve from 0.76573
# Epoch 51/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4151 - accuracy: 0.8128 - val_loss: 0.5137 - val_accuracy: 0.7552
#
# Epoch 00051: val_accuracy did not improve from 0.76573
# Epoch 52/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3978 - accuracy: 0.8122 - val_loss: 0.5374 - val_accuracy: 0.7552
#
# Epoch 00052: val_accuracy did not improve from 0.76573
# Epoch 53/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3979 - accuracy: 0.8358 - val_loss: 0.5243 - val_accuracy: 0.7657
#
# Epoch 00053: val_accuracy did not improve from 0.76573
# Epoch 54/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4260 - accuracy: 0.7918 - val_loss: 0.5185 - val_accuracy: 0.7308
#
# Epoch 00054: val_accuracy did not improve from 0.76573
# Epoch 55/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3893 - accuracy: 0.8191 - val_loss: 0.5350 - val_accuracy: 0.7448
#
# Epoch 00055: val_accuracy did not improve from 0.76573
# Epoch 56/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4087 - accuracy: 0.7927 - val_loss: 0.5206 - val_accuracy: 0.7517
#
# Epoch 00056: val_accuracy did not improve from 0.76573
# Epoch 57/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4103 - accuracy: 0.7970 - val_loss: 0.5367 - val_accuracy: 0.7378
#
# Epoch 00057: val_accuracy did not improve from 0.76573
# Epoch 58/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4292 - accuracy: 0.7773 - val_loss: 0.5208 - val_accuracy: 0.7552
#
# Epoch 00058: val_accuracy did not improve from 0.76573
# Epoch 59/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4249 - accuracy: 0.7969 - val_loss: 0.5271 - val_accuracy: 0.7622
#
# Epoch 00059: val_accuracy did not improve from 0.76573
# Epoch 60/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4147 - accuracy: 0.7929 - val_loss: 0.5668 - val_accuracy: 0.7483
#
# Epoch 00060: val_accuracy did not improve from 0.76573
# Epoch 61/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4152 - accuracy: 0.8157 - val_loss: 0.5441 - val_accuracy: 0.7587
#
# Epoch 00061: val_accuracy did not improve from 0.76573
# Epoch 62/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3830 - accuracy: 0.8234 - val_loss: 0.5393 - val_accuracy: 0.7657
#
# Epoch 00062: val_accuracy did not improve from 0.76573
# Epoch 63/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3916 - accuracy: 0.8208 - val_loss: 0.5336 - val_accuracy: 0.7517
#
# Epoch 00063: val_accuracy did not improve from 0.76573
# Epoch 64/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4068 - accuracy: 0.7991 - val_loss: 0.5614 - val_accuracy: 0.7552
#
# Epoch 00064: val_accuracy did not improve from 0.76573
# Epoch 65/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3964 - accuracy: 0.8088 - val_loss: 0.5449 - val_accuracy: 0.7692
#
# Epoch 00065: val_accuracy improved from 0.76573 to 0.76923, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_3.hdf5
# Epoch 66/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4091 - accuracy: 0.8121 - val_loss: 0.5317 - val_accuracy: 0.7308
#
# Epoch 00066: val_accuracy did not improve from 0.76923
# Epoch 67/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3945 - accuracy: 0.8131 - val_loss: 0.5431 - val_accuracy: 0.7587
#
# Epoch 00067: val_accuracy did not improve from 0.76923
# Epoch 68/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3844 - accuracy: 0.8276 - val_loss: 0.5293 - val_accuracy: 0.7308
#
# Epoch 00068: val_accuracy did not improve from 0.76923
# Epoch 69/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4094 - accuracy: 0.8138 - val_loss: 0.5422 - val_accuracy: 0.7378
#
# Epoch 00069: val_accuracy did not improve from 0.76923
# Epoch 70/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4067 - accuracy: 0.8185 - val_loss: 0.5515 - val_accuracy: 0.7622
#
# Epoch 00070: val_accuracy did not improve from 0.76923
# Epoch 71/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3817 - accuracy: 0.8432 - val_loss: 0.5323 - val_accuracy: 0.7343
#
# Epoch 00071: val_accuracy did not improve from 0.76923
# Epoch 72/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4136 - accuracy: 0.7877 - val_loss: 0.5359 - val_accuracy: 0.7517
#
# Epoch 00072: val_accuracy did not improve from 0.76923
# Epoch 73/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4228 - accuracy: 0.7964 - val_loss: 0.5540 - val_accuracy: 0.7273
#
# Epoch 00073: val_accuracy did not improve from 0.76923
# Epoch 74/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4091 - accuracy: 0.7995 - val_loss: 0.5701 - val_accuracy: 0.7517
#
# Epoch 00074: val_accuracy did not improve from 0.76923
# Epoch 75/100
# 86/86 [==============================] - 3s 39ms/step - loss: 0.3768 - accuracy: 0.8076 - val_loss: 0.5241 - val_accuracy: 0.7517
#
# Epoch 00075: val_accuracy did not improve from 0.76923
# Epoch 76/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3895 - accuracy: 0.8239 - val_loss: 0.5585 - val_accuracy: 0.7587
#
# Epoch 00076: val_accuracy did not improve from 0.76923
# Epoch 77/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3739 - accuracy: 0.8203 - val_loss: 0.5379 - val_accuracy: 0.7587
#
# Epoch 00077: val_accuracy did not improve from 0.76923
# Epoch 78/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4340 - accuracy: 0.7853 - val_loss: 0.5785 - val_accuracy: 0.7273
#
# Epoch 00078: val_accuracy did not improve from 0.76923
# Epoch 79/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4004 - accuracy: 0.8218 - val_loss: 0.5451 - val_accuracy: 0.7622
#
# Epoch 00079: val_accuracy did not improve from 0.76923
# Epoch 80/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4059 - accuracy: 0.8182 - val_loss: 0.5742 - val_accuracy: 0.7343
#
# Epoch 00080: val_accuracy did not improve from 0.76923
# Epoch 81/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3893 - accuracy: 0.8009 - val_loss: 0.5479 - val_accuracy: 0.7378
#
# Epoch 00081: val_accuracy did not improve from 0.76923
# Epoch 82/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.4186 - accuracy: 0.7899 - val_loss: 0.5531 - val_accuracy: 0.7727
#
# Epoch 00082: val_accuracy improved from 0.76923 to 0.77273, saving model to /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_3.hdf5
# Epoch 83/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3784 - accuracy: 0.8039 - val_loss: 0.5637 - val_accuracy: 0.7238
#
# Epoch 00083: val_accuracy did not improve from 0.77273
# Epoch 84/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3919 - accuracy: 0.8156 - val_loss: 0.5789 - val_accuracy: 0.7448
#
# Epoch 00084: val_accuracy did not improve from 0.77273
# Epoch 85/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3805 - accuracy: 0.8257 - val_loss: 0.5809 - val_accuracy: 0.7273
#
# Epoch 00085: val_accuracy did not improve from 0.77273
# Epoch 86/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3715 - accuracy: 0.8154 - val_loss: 0.5626 - val_accuracy: 0.7552
#
# Epoch 00086: val_accuracy did not improve from 0.77273
# Epoch 87/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4132 - accuracy: 0.7889 - val_loss: 0.5437 - val_accuracy: 0.7552
#
# Epoch 00087: val_accuracy did not improve from 0.77273
# Epoch 88/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3705 - accuracy: 0.8216 - val_loss: 0.5605 - val_accuracy: 0.7413
#
# Epoch 00088: val_accuracy did not improve from 0.77273
# Epoch 89/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3872 - accuracy: 0.8067 - val_loss: 0.5476 - val_accuracy: 0.7552
#
# Epoch 00089: val_accuracy did not improve from 0.77273
# Epoch 90/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3899 - accuracy: 0.8225 - val_loss: 0.5389 - val_accuracy: 0.7483
#
# Epoch 00090: val_accuracy did not improve from 0.77273
# Epoch 91/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3613 - accuracy: 0.8160 - val_loss: 0.5410 - val_accuracy: 0.7587
#
# Epoch 00091: val_accuracy did not improve from 0.77273
# Epoch 92/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4134 - accuracy: 0.8113 - val_loss: 0.5749 - val_accuracy: 0.7133
#
# Epoch 00092: val_accuracy did not improve from 0.77273
# Epoch 93/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.4144 - accuracy: 0.7800 - val_loss: 0.5793 - val_accuracy: 0.7483
#
# Epoch 00093: val_accuracy did not improve from 0.77273
# Epoch 94/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3581 - accuracy: 0.8232 - val_loss: 0.5383 - val_accuracy: 0.7448
#
# Epoch 00094: val_accuracy did not improve from 0.77273
# Epoch 95/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3945 - accuracy: 0.8245 - val_loss: 0.6059 - val_accuracy: 0.7692
#
# Epoch 00095: val_accuracy did not improve from 0.77273
# Epoch 96/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3690 - accuracy: 0.8148 - val_loss: 0.5546 - val_accuracy: 0.7587
#
# Epoch 00096: val_accuracy did not improve from 0.77273
# Epoch 97/100
# 86/86 [==============================] - 3s 33ms/step - loss: 0.3535 - accuracy: 0.8299 - val_loss: 0.6105 - val_accuracy: 0.7133
#
# Epoch 00097: val_accuracy did not improve from 0.77273
# Epoch 98/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3771 - accuracy: 0.8214 - val_loss: 0.5433 - val_accuracy: 0.7343
#
# Epoch 00098: val_accuracy did not improve from 0.77273
# Epoch 99/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3594 - accuracy: 0.8270 - val_loss: 0.5918 - val_accuracy: 0.7517
#
# Epoch 00099: val_accuracy did not improve from 0.77273
# Epoch 100/100
# 86/86 [==============================] - 3s 34ms/step - loss: 0.3453 - accuracy: 0.8324 - val_loss: 0.6233 - val_accuracy: 0.7063
#
# Epoch 00100: val_accuracy did not improve from 0.77273
# Cross Validation Accuracy: 73.78%
# Fold #3 Complete
#
# Cross Validation Accuracy Mean (+/- Std Deviation): 74.83% (+/- 1.08%)
# Cross Validation Time = 1198.4848034381866s
# Model Cross Validation: Completed
# Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_2.hdf5
# MobileNetV2 Model Definition: Starting
# MobileNetV2 FLOPS: 0.616 G
# MobileNetV2 Model Definition: Completed
# Model Test: Starting
# 37/37 [==============================] - 4s 65ms/step - loss: 0.5839 - accuracy: 0.7312
# Test Time = 3.6701042652130127s
# Test Time / sample = 0.003177579450400877s
# Model Test: Completed

# %% [markdown]
# ### TODO / Improvement Opportunity

# %% [markdown]
# - **TRIED**: As this is a 2 class classification - loss function can be changed to binary_crossentropy instead of categorical_crossentropy
# - **DONE**: Change model to ResNet50
# - **DONE**: Convert code sections in data preparation for train/validation/test to functions
# - **TRIED**: Reduce parameters, epochs.
# - **TRIED**: Try changing batch size
# - **TRIED**: Use Data Augmentation
# - **DONE**: Try to train last few layers of ResNet50 with the data
# - **TRIED**: Accuracy is fluctuating... optimize hyper parameters to have a smooth increase
# - **TRIED**: Try Regularization
# - **DONE**:Our image size is 250x250. ResNet50 expects 224x224. Do we need to do anything or ResNet50 will understand ? Resizing for all models
# - **DONE**: Change Model to MobileNet
# - **DONE**: Is image resize done correctly for MobileNet ?
# - **DONE**: Implement K Cross Validation for Epoch = 1, Fold = 4
# - **DONE**: Implement FLOPS
# - **DONE**: Check version of MobileNet ... try using tf.keras.applications.MobileNet() instead of tf.keras.applications.mobilenet.MobileNet()
# - Query: Should the batch_size be 1 or 10 for FLOPS calculation
# - Query: There should not be any difference in FLOPS for Transfer/FineTune Model, correct ?
# - **DONE**: Run K Cross Validation for Epoch = 100, Fold = 4
# - **DONE**: IO: Convert K-cross validation sections into functions
# - IO: Save best k fold of MobileNet Transfer and use for FineTune
# - Use only the train and validation for cross validation ... so that you can use the test for test.

# %% [markdown]
# ### Version 0.25: Make code ready for Android App

# %% [markdown]
# - **0.25-0.26**
#   - We will make the Cross Validation to also store the best parameters so that we can then use them for test. For this, we will use only the train and validation images/labels for Cross Validation... so that post Cross Validation, we can use the test images/labels for Testing
#   - We will try converting the models to TensorFlowLite Models so that it can then be ported to Android App - implemented only for MobileNetV1 Transfer Learning
#   - Will make the epoch = 1, cross validation folds = 2 for now.
#   - worked
# - **0.27**
#   - run for epoch = 100, folds - 4
#   - converted MobileNetV1 Fine Tuning Model also to TensorFlowLite.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / ~24.6M / ~1.1M / 0.0021G
#     - Regular Run:
#       - Total params: 24,637,826, Trainable params: 1,050,114, Non-trainable params: 23,587,712
#       - Train and Validation Time (time) = 554.2369706630707s
#       - Train / Val / Test Acc % = 91.4 / 89.3 / 81.5
#       - Test Time (time) = 4.689838409423828s
#       - Test Time / sample (time) = 0.004060466155345306s
#     - CV:
#       - Cross Validation Time (time) = 2360.335835456848s
#       - Cross Validation Accuracy Mean (+/- Std Deviation): **79.81% (+/- 3.80%)**
#       - Test Acc = **80.2%**
#       - Test Time (time) = 6.264003276824951s
#       - Test Time / sample (time) = 0.005423379460454503s
#       - Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_resnet50xfr_cvfold_2.hdf5
#   - **MobileNetV1**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = ~4.8M / ~0.5M
#         - Total params: 4,767,402 , Trainable params: 513,538 , Non-trainable params: 4,253,864
#       - Regular Run:
#         - Train and Validation Time (time) = 239.36364245414734s
#         - Train / Val / Test Acc % = 78.2 / 84.5 / 79.1
#         - Test Time (time) = 2.1142632961273193s
#         - Test Time / sample (time) = 0.0018305309923180254s
#       - CV:
#         - Cross Validation Time (time) = 1021.4970147609711s
#         - Cross Validation Accuracy Mean (+/- Std Deviation): **75.44% (+/- 4.09%)**
#         - Test Acc = **76.4%**
#         - Test Time (time) = 2.922698497772217s
#         - Test Time / sample (time) = 0.0025304748898460753s
#         - Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1xfr_cvfold_3.hdf5
#     - **FT**
#       - Total Params / Trainable Params = ~4.8M / ~2.6M
#         - Total params: 4,767,402 , Trainable params: 2,600,426 , Non-trainable params: 2,166,976
#       - Regular Run:
#         - Train and Validation Time (time) = 237.16838598251343s
#         - Train / Val / Test Acc % = 77.9 / 85.3 / 78.3
#         - Test Time (time) = 2.079399585723877s
#         - Test Time / sample (time) = 0.0018003459616656944s
#       - CV:
#         - Cross Validation Time (time) = 1007.7840912342072s
#         - Cross Validation Accuracy Mean (+/- Std Deviation): **80.86% (+/- 1.36%)**
#         - Test Acc = **75.7%**
#         - Test Time (time) = 2.910604953765869s
#         - Test Time / sample (time) = 0.0025200042889747783s
#         - Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv1ft_cvfold_2.hdf5
#
#   - **MobileNetV2**
#   - Conv Layer / FLOPS = TBD / 0.616G
#   - **XFR**
#     - Total Params / Trainable Params = ~4.1M / ~0.5M
#       - Total params: 4,052,522 , Trainable params: 513,538 , Non-trainable params: 3,538,984
#     - Regular Run:
#       - Train and Validation Time (time) = 279.14059805870056s
#       - Train / Val / Test Acc % = 72.8 / 80.8 / 55.3
#       - Test Time (time) = 2.407776117324829s
#       - Test Time / sample (time) = 0.002084654647034484s
#     - CV:
#       - Cross Validation Time (time) = 1208.8567435741425s
#       - Cross Validation Accuracy Mean (+/- Std Deviation): **71.68% (+/- 3.02%)**
#       - Test Acc = **65.6%**
#       - Test Time (time) = 3.658114194869995s
#       - Test Time / sample (time) = 0.0031671984371168787s
#       - Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2xfr_cvfold_1.hdf5
#   - **FT**
#     - Total Params / Trainable Params = ~4.1M / ~2.2M
#       - Total params: 4,052,522 , Trainable params: 2,206,698 , Non-trainable params: 1,845,824
#     - Regular Run:
#       - Train and Validation Time (time) = 281.10192251205444s
#       - Train / Val / Test Acc % = 77.1 / 81.3 / 73.0
#       - Test Time (time) = 2.438354969024658s
#       - Test Time / sample (time) = 0.0021111298433113923s
#     - CV:
#       - Cross Validation Time (time) = 1198.4848034381866s
#       - Cross Validation Accuracy Mean (+/- Std Deviation): **74.83% (+/- 1.08%)**
#       - Test Acc = **73.1%**
#       - Test Time (time) = 3.6701042652130127s
#       - Test Time / sample (time) = 0.003177579450400877s
#       - Path to Best CV Fold Params: /content/gdrive/MyDrive/Colab Notebooks/Clinical Heart Failure using H&E Images/best_mobilenetv2ft_cvfold_2.hdf5

# %% [markdown]
# ### Version 0.24: Will do full run 100 epoch, CV with the cleaned code

# %% [markdown]
# - **0.24**
#   - added model.summary() for each model
#   - deleted monolithic commented code for resnet50, mobilenet
#   - XFR = Transfer Learning, FT = Fine tuning
#   - For Regular Run: Train & Test Acc is w.r.t. Best Val Accuracy.
#   - Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / ~24.6M / ~1.1M / 0.0021G
#       - Total params: 24,637,826, Trainable params: 1,050,114, Non-trainable params: 23,587,712
#     - Regular Run:
#       - Train and Validation Time (time) = 441.68549942970276s
#       - Test Time (time) = 3.7353672981262207s
#       - Test Time (time) / sample = 0.0032340842408019226s
#       - Train / Val / Test Acc % = 90.6 / 89.6 / 81.6
#     - CV:
#       - Cross Validation Time (time) = 2435.15261554718s
#       - **Cross Validation Accuracy Mean (+/- Std Deviation): 85.52% (+/- 4.31%)**
#   - **MobileNetV1**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = ~4.8M / ~0.5M
#         - Total params: 4,767,402 , Trainable params: 513,538 , Non-trainable params: 4,253,864
#       - Regular Run:
#         - Train and Validation Time (time) = 160.18587827682495s
#         - Test Time (time) = 1.4887826442718506s
#         - Test Time (time) / sample = 0.0012889893023998707s
#         - Train / Val / Test Acc % = 76.8 / 84.0 / 78.0
#       - CV:
#         - Cross Validation Time (time) = 900.9457154273987s
#         - **Cross Validation Accuracy Mean (+/- Std Deviation): 79.12% (+/- 2.54%)**
#     - **FT**
#       - Total Params / Trainable Params = ~4.8M / ~2.6M
#         - Total params: 4,767,402 , Trainable params: 2,600,426 , Non-trainable params: 2,166,976
#       - Regular Run:
#         - Train and Validation Time (time) = 161.2263162136078s
#         - Test Time (time) = 1.5055246353149414s
#         - Test Time (time) / sample = 0.001303484532740209s
#         - Train / Val / Test Acc % = 82.4 / 84.2 / 78.9
#       - CV:
#         - Cross Validation Time (time) = 899.4915227890015s
#         - **Cross Validation Accuracy Mean (+/- Std Deviation): 78.77% (+/- 0.45%)**
#   - **MobileNetV2**
#     - Conv Layer / FLOPS = TBD / 0.616G
#     - **XFR**
#       - Total Params / Trainable Params = ~4.1M / ~0.5M
#         - Total params: 4,052,522 , Trainable params: 513,538 , Non-trainable params: 3,538,984
#       - Regular Run:
#         - Train and Validation Time (time) = 190.26020073890686s
#         - Test Time (time) = 1.8131637573242188s
#         - Test Time (time) / sample = 0.0015698387509300595s
#         - Train / Val / Test Acc % = 75.0 / 81.0 / 71.9
#       - CV:
#         - Cross Validation Time (time) = 1015.8775858879089s
#         - **Cross Validation Accuracy Mean (+/- Std Deviation): 75.99% (+/- 0.77%)**
#     - **FT**
#       - Total Params / Trainable Params = ~4.1M / ~2.2M
#         - Total params: 4,052,522 , Trainable params: 2,206,698 , Non-trainable params: 1,845,824
#       - Regular Run:
#         - Train and Validation Time (time) = 185.37927341461182s
#         - Test Time (time) = 1.6549708843231201s
#         - Test Time (time) / sample = 0.001432875224522182s
#         - Train / Val / Test Acc % = 76.7 / 80.2 / 73.1
#       - CV:
#         - Cross Validation Time (time) = 1015.6089019775391s
#         - **Cross Validation Accuracy Mean (+/- Std Deviation): 76.77% (+/- 1.76%)**

# %% [markdown]
# ### Version 0.21-0.23: Cleaning Code and Converting to Functions

# %% [markdown]
# - **0.21**
#   - formatted the version sections
#   - changed epochs = 1, cross validation = false for now.
#   - converted whole of resnet50 into a function
#   - converted whole of mobilenet into a function with attribute to specify version (V1, V2)
# - **0.22**
#   - moved version and reference to bottom of notebook
#   - made pending independent cells in  train/val/test prep areas as part of the prep function.
# - **0.23**
#   - converted code sections of basic CNN into functions
#   - converted code sections of resnet50 into functions
#   - converted code sections of mobilenet into functions
#   - made cross validation folds = 2

# %% [markdown]
# ### Version 0.20: Tried MobileNetV2 in place of MobileNet

# %% [markdown]
# - Commented MobileNet and called MobileNetV2 in model definition for Regular Run XFR/FT, CV Run  for XFR and CV Run for FT sections
# - Epochs = 1, CV = False, Dropout = 0.4
#   - XFR: Train / Val / Test Acc % = 59 / 75 / 67
#   - FT @ 80th Layer : Train / Val / Test Acc % = 69 / 69 / 65
# - Epochs = 100, CV = False, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 76.0 / 80.5 / 72.9
#   - FT @ 80th Layer
#     - Total/Trainable Params = ~4M / ~3.8M
#     - Train / Val / Test Acc % = 76.6 / 80.2 / 72.8
# - Epochs = 100, CV = False, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 72.4 / 80.0 / 71.6
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Train / Val / Test Acc % =  73.9 / 80.8 / 73.2
# - Epochs = 100, CV = False, Dropout = 0.6
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Train / Val / Test Acc % = 76.3 / 80.5 / 70.3
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Train / Val / Test Acc % = 76.4 / 81.0 / 72.6
# - Epochs = 100, CV = True, Dropout = 0.4
#   - Flops = 0.616G
#   - XFR
#     - Total/Trainable Params = ~4M / ~0.5M
#     - Validation Accuracy Mean (+/- Std Deviation): 77.03% (+/- 0.79%)
#   - FT @ 151th Layer
#     - Total/Trainable Params = ~4M / ~2.2M
#     - Validation Accuracy Mean (+/- Std Deviation): 78.99% (+/- 1.06%)

# %% [markdown]
# ### Version 0.18-0.19: Rerun of v0.17 with time() to get time values

# %% [markdown]
# - **0.18-0.19**:
#   - Implemented time function to calculate the desired time more precisely as the time from colab and verbose are not matching.
#   - XFR = Transfer Learning, FT = Fine tuning
#   - For Regular Run: Train & Test Acc is w.r.t. Best Val Accuracy.
#   - Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / 25M / 1M / 0.0021G
#       - Total params: 24,637,826, Trainable params: 1,050,114, Non-trainable params: 23,587,712
#     - Regular Run:
#       - Train Time (time / verbose) = 446.35871052742004s / 411s
#       - Test Time (time / verbose) = 4.191006660461426s / 4s
#       - Test Time / sample (time / verbose) = 0.0036285771952046975s / 0.00346s
#       - Train / Val / Test Acc % = 92.2 / 90.4 / 82.6
#     - CV:
#       - Validation Time (time) = 2644.3752892017365s
#       - Validation Accuracy Mean (+/- Std Deviation): 88.30% (+/- 0.80%)
#   - **MobileNet**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = 4.8M / 0.5M
#         - Total params: 4,767,402 , Trainable params: 513,538 , Non-trainable params: 4,253,864
#       - Regular Run:
#         - Train Time (time / verbose) = 162.90089511871338s / 202s
#         - Test Time (time / verbose) = 1.819808006286621s / 2s
#         - Test Time / sample (time / verbose) = 0.001575591347434304s / 0.00173s
#         - Train / Val / Test Acc % = 83.2 / 85.0 / 78.4
#       - CV:
#         - Validation Time (time) = 988.1067225933075s
#         - Validation Accuracy Mean (+/- Std Deviation): 78.03% (+/- 0.78%)
#     - **FT**
#       - Total Params / Trainable Params = 4.8M / 2.6M
#         - Total params: 4,767,402 , Trainable params: 2,600,426 , Non-trainable params: 2,166,976
#       - Regular Run:
#         - Train Time (time / verbose) = 160.71819162368774s / 200s
#         - Test Time (time / verbose) = 1.453615665435791s / 1s
#         - Test Time / sample (time / verbose) = 0.0012585417016760096s / 0.00087s
#         - Train / Val / Test Acc % = 84.8 / 89.6 / 83.6
#       - CV:
#         - Validation Time (time) = 992.2293410301208s
#         - Validation Accuracy Mean (+/- Std Deviation): 78.29% (+/- 1.35%)

# %% [markdown]
# ### Version 0.17: ResNet50 XFR, MobileNet XFR, MobileNet FT Baseline Values

# %% [markdown]
# - **0.17**: run for Epoch = 100
#   - XFR = Transfer Learning, FT = Fine tuning
#   - For Regular Run: Train & Test Acc is w.r.t. Best Val Accuracy.
#   - Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - **Resnet50 XFR**
#     - Conv Layer / Total Params / Trainable Params / FLOPS = 5 / 25M / 1M / 0.0021G
#     - Regular Run:
#       - Train Time Verbose / Colab = 404s / 474.015s
#       - Test Time Verbose / Colab (1155 samples) = 4s / 490.921s ?
#       - Test Time per sample = 3.5ms / 425ms ?
#       - Train / Val / Test Acc % = 86.7 / 90.1 / 81.8
#     - CV:
#       - Validation Time (Colab) = 3030.406s
#       - Val Acc Mean (+/- Std Deviation): 87.86% (+/- 1.24%)
#   - **MobileNet**
#     - Conv Layer / FLOPS = 13 / 1.15G
#     - **XFR**
#       - Total Params / Trainable Params = 5M / 0.5M
#       - Regular Run:
#         - Train Time Verbose / Colab =  202s / 3192.38s ?
#         - Test Time Verbose / Colab (1155 samples) = 1s / 3198.253s ?
#         - Test Time per sample = 0.87ms / 2.77s ?
#         - Train / Val / Test Acc % = 82.1 / 84.2 / 77.8
#       - CV:
#         - Validation Time (Colab) = 4169.914s
#         - Val Acc Mean (+/- Std Deviation): 78.34% (+/- 1.30%)
#     - **FT**
#       - Total Params / Trainable Params = 5M / 2.6M
#       - Regular Run:
#         - Train Time Verbose / Colab = 200s / 4328.194s ?
#         - Test Time Verbose / Colab (1155 samples) = 1s / 4333.798s ?
#         - Test Time per sample = 0.87ms / 3.75s ?
#         - Train / Val / Test Acc % = 82.6 / 89.3 / 84.9
#       - CV:
#         - Validation Time (Colab) = 5311.684s
#         - Val Acc Mean (+/- Std Deviation): 79.16% (+/- 1.23%)

# %% [markdown]
# ### Version 0.16

# %% [markdown]
# - **0.16**
#   - Changed 'tf.keras.applications.mobilenet.MobileNet()' to 'mobilenet = tf.keras.applications.MobileNet()' to reconfirm using MobilenetV1
#   - mobilenet = tf.keras.applications.mobilenet.MobileNet()
#     - Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
#   - mobilenet = tf.keras.applications.MobileNet()
#     - Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf.h5
#   - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 61.2 / 74.3 / 73.3
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 77.90% (+/- 1.05%)
#   - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc = 70.1 / 76.5 / 74.0
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 76.69% (+/- 1.32%)
#   - MobileNet FineTune
#       - Regular Run: Train/Val/Test Acc = 76.4 / 80.5 / 76.5
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 77.77% (+/- 2.34%)

# %% [markdown]
# ### Version 0.15

# %% [markdown]
# - **0.15**: implemented flops
#     - ResNet50 Transfer - 0.0021G
#       - Regular Run: Train/Val/Test Acc = 59.5 / 73.5 / 71.0
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 79.34% (+/- 1.76%)
#     - MobileNet Transfer - 1.15G
#       - Regular Run: Train/Val/Test Acc =  71.0 / 82.4 / 75.6
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.03% (+/- 1.57%)
#     - MobileNet FineTune - 1.15G
#       - Regular Run: Train/Val/Test Acc =  76.9 / 83.2 / 77.1
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.16% (+/- 0.93%)
#
# - Note: XFR = Transfer Learning, FT = Fine tuning, Train & Test Acc is w.r.t. Best Val Accuracy. Common Hyper parameters: Batchsize = 10, Learning Rate = 0.01, Neurons after Conv = 512, Dropout = 0.4.
#   - Without cross-validation, with same hyper parameters, Test Accuracy/Total Params/Trainable Params/No. of Convolution Layers/FLOPS/Train Time/Test Time/Test Time per Sample
#     - Below is for Epoch = 100
#     - Resnet50 XFR (~81%/~25M/~1M/5 Conv/0.0021G/~300s/3s/~2.6ms)
#     - MobileNet XFR (~78%/~5M/~0.5M/13 Conv/1.15G/~200s/1s/~0.87ms)
#     - MobileNet FT (~79%/~5M/~2.6M/13 Conv/1.15G/~200s/1s/~0.87ms)
#   - With cross-validation, with same hyper parameters, Test Accuracy Mean +/- Std Dev/Total Params/Trainable Params/No. of Convolution Layers/FLOPS
#     - Below is for Epoch = 1, Cross Validation Folds = 4
#     - Resnet50 XFR (79.34% (+/- 1.76%)/~25M/~1M/5 Conv/0.0021G)
#     - MobileNet XFR (76.03% (+/- 1.57%)/~5M/~0.5M/13 Conv/1.15G)
#     - MobileNet FT (75.16% (+/- 0.93%)/~5M/~2.6M/13 Conv/1.15G)

# %% [markdown]
# ### Version 0.12-0.14 (Implemented Cross Validation for 1 Epoch, 4 Folds: Other hyperparameters same as in v0.11)

# %% [markdown]
# - **0.12**: rerun to baseline
# - **0.13**
#   - **epoch = 1, fold = 2**
#   - saved labels before conversion to categorical
#   - added code macros for cross validation = true, fold = 2
#   - added code for cross-validation for resnet50 transfer learning
#   - added code for cross-validation for mobilenet transfer learning
#   - ResNet50 Transfer
#     - Regular Run: Train/Val/Test Acc = 57.0 / 73.5 / 70.7
#     - CV Run: Validation Accuracy Mean (+/- Std Deviation): 74.64% (+/- 1.51%)
#   - MobileNet Transfer
#     - Regular Run: Train/Val/Test Acc = 69.1 / 77.3 / 74.5
#     - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.82% (+/- 0.27%)
# - **0.14**
#   - **epoch = 100, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 88.1 / 88.8 / 79
#       - CV Run: only for 1 fold ... 88.4 .. later I interrupted
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc .. later I interrupted
#       - CV Run: .. later I interrupted
#   - **epoch = 1, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc =  60.0 / 72.7 / 69.7
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 79.16% (+/- 2.54%)
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc =  71.6 / 80.5 / 74.8
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 75.64% (+/- 1.61%)
#     - MobileNet FineTune
#       - CV done before the regular run of train/val/test to ensure we use the weights from transfer and not from regular run of finetune.
#       - CV Run:  Validation Accuracy Mean (+/- Std Deviation): 77.82% (+/- 2.03%)
#       - Regular Run: Train/Val/Test Acc =  75.3 / 81.8 / 76.6
#   - Updated code to have separate checkpoint files for each model. Cross-validation of MobileNet FineTune Model uses MobileNet Transfer file for initialization.
#     - **epoch = 1, fold = 4**
#     - ResNet50 Transfer
#       - Regular Run: Train/Val/Test Acc = 61.5 / 71.9 / 72.1
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 78.78% (+/- 3.65%)
#     - MobileNet Transfer
#       - Regular Run: Train/Val/Test Acc = 68.0 / 81.3 / 75.6
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.64% (+/- 0.98%)
#     - MobileNet FineTune
#       - Regular Run: Train/Val/Test Acc = 74.6 / 81.8 / 76.9
#       - CV Run: Validation Accuracy Mean (+/- Std Deviation): 76.03% (+/- 1.67%)

# %% [markdown]
# ### Version 0.11

# %% [markdown]
# - **0.11**
#   - As is Rerun
#     - Epoch = 100, Batchsize = 10, Learning Rate = 0.01, Neurons = 512, Dropout = 0.4. Train & Test Acc is w.r.t. Best Val Accuracy.
#     - ResNet50 (Transfer Learning) - 5 Convolution Layers
#       - Total/Trainable Params: 24.64M/1.05M
#       - Train + Validation Time: (8s x 1) + (3s x 99) = 305s
#       - Test Time: 3s, Test/sample = (3/1155)s = 0.0026s = 2.6ms
#       - Train/Val/Test Acc: 93.7 / 89.0 / 80.7
#     - MobileNet - 13 Convolution Layers
#       - Transfer Learning
#         - Total/Trainable Params: 4.77M/0.51M
#         - Train + Validation Time: (4s x 1) + (max 2s x 99) = 202s
#         - Test Time: 1s, Test/sample = (1/1155)s = 0.87ms
#         - Train/Val/Test Acc: 79.5 / 84.2 / 78.0
#       - Finetuning
#         - Total/Trainable Params: 4.77M/2.60M
#         - Train + Validation Time: (max 2s x 100) = 200s
#         - Test Time: 1s, Test/sample = (1/1155)s = 0.87ms
#         - Train/Val/Test Acc: 88.2 / 84.2 / 78.8

# %% [markdown]
# ### Version 0.10

# %% [markdown]
# - **0.10**
#   - Cleaned up indenting
#   - Added hyperparameter macros that can be used for all models
#     - ResNet50 was with 1024 neurons, 40% dropout
#     - MobileNet was with 512 neurons, 60% dropout.
#     - Made EPOCHS = 100, BATCH_SIZE = 10, LEARNING_RATE = 0.01, DENSE_LAYER_NEURONS = 512, DENSE_LAYER_DROPOUT = 0.4
#   - Implemented 'checkpoint' as a function to be used a callback by any model. Enabled callback for ResNet50
#   - Accuracy
#     - ResNet50 (XFR Learning): Best_Train/Best_Val/Test = 89.4 / 88.8 / 80.7
#     - MobileNet (XFR Learning): Best_Train/Best_Val/Test = 83.6 / 85.0 / 77.6
#     - MobileNet (Fine Tuning): Best_Train/Best_Val/Test = 86.9 / 84.0 / 77.7

# %% [markdown]
# ### Version 0.09

# %% [markdown]
# - **0.09** **MobileNet**
#   - **Epoch=100**: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 87.4/80.8/78.0
#   - Epoch=100: **Best Model**: Train/Val/Test Acc = 82.1/84.0/77.8
#   - **Epoch=200**: Best Model: Train/Val/Test Acc = 79.0/84.0/78.9
#   - **Epoch=100**: Best Model: **Regularizer: Kernel/Bias L2(0.01) for Dense(1024)**: Train/Val/Test Acc = 70.6/80.0/72.5
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias L2(0.01) for Dense(1024), **Dense(2)**: Train/Val/Test Acc = 69.0/78.3/72.6
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias **L1**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/**Activity L2**(0.01) for Dense(1024), Dense(2): Train/Val/Test Acc = 68.1/79.1/72.4
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(0.2)** for Dense(1024), Dense(2): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Epoch=100: Best Model: Regularizer: Kernel/Bias/Activity L2**(1e-4/1e-4/1e-5)** for Dense(1024), Dense(2): Train/Val/Test Acc = 77.6/84.0/77.5 ... regularizer is not helping much ... revert to No Regularizer
#   - **Best Model**: **Epoch=100**: Train/Val/Test Acc = 81.5/84.5/77.8
#   - Best Model: **Epoch=1**: **Nottrainable/trainabele layers = 0-79/80-94**:  Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: **Epoch=100**: NonTrainable(MobileNet)+ Trainable(Dense(1024), Dropout, Dense(2)): Train/Val/Test Acc = 82.3/85/79
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.8/78.7
#   - Best Model: Epoch=100: **MobileNet NT till Conv13 (0-85), T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: MobileNet NT **till Conv12 (0-79)**, T for Rest** + Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = val acc was ~55% for 20 epochs so interrupted it
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)): Train/Val/Test Acc = 88.5/85.0/77.7
#   - Best Model: Epoch=100: **NonTrainable(MobileNet)+ Trainable(Dense(**512**), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet till <86) Trainable (86 and later = GAP...)+ Trainable(Dense(**512**), Dropout, Dense(2))**: Train/Val/Test Acc = 78.7/84.8/76.8 -> ../84.8/76.8
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 82.1/84.2/78.2 -> ../84.2/78.2
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 80.1/84.2/78.4 -> ../84.2/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> **Trainable(MobileNet till <73**) Trainable (73 and later = **Conv12,Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Train/Val/Test Acc = 81.8/84.2/78.3 -> 86.2/84.5/78.4
#   - Best Model: Epoch=100: NonTrainable(MobileNet)+ Trainable(Dense(512), Dropout, Dense(2)) -> save and load weights -> NonTrainable(MobileNet **till <80**) Trainable (80 and later = **Conv13,GAP...**)+ Trainable(Dense(512), Dropout, Dense(2)): Params (Total/Trainable/Non-trainable)= 4,767,402 / 2,600,426 / 2,166,976: Train/Val/Test Acc = 79.8/84.8/78.4 -> ../84.8/78.4

# %% [markdown]
# ### Version 0.08

# %% [markdown]
# - **0.08** **MobileNet**
#   - Changed model to Pre-trained MobileNet
#   - Epoch=1: **img resize**: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 68.2/76.5/73.8
#   - Epoch=10: img resize: lr=0.01: BN = N: Dropout = N: Train/Val/Test Acc = 80.5/82.4/78.9
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = N:Train/Val/Test Acc = 83.7/79.2/76.5 ... revert to Epoch=10
#   - **Epoch=10**: img resize: **lr=0.0001**: BN = N: Dropout = N:Train/Val/Test Acc = 71.9/78.6/73.6 ... revert to lr=0.01
#   - Epoch=10: img resize: **lr=0.01**: **BN = Y**: Dropout = N: Train/Val/Test Acc = 83.0/77.8/71.0 revert to BN = N
#   - Epoch=10: img resize: lr=0.01: **BN = N**: **Dropout = 0.2**: Train/Val/Test Acc = 77.1/80.8/76.9
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Train/Val/Test Acc = 78.8/82.6/78.0
#   - **Epoch=20**: img resize: lr=0.01: BN = N: Dropout = 0.4: Train/Val/Test Acc = 81.6/76.6/75.4 ... revert to Epoch = 10
#   - **Epoch=10**: img resize: lr=0.01: BN = N: **Dropout = 0.5**: Train/Val/Test Acc = 78.3/84.2/77.8 ... revert to Dropout = 0.4
#   - Epoch=10: img resize: lr=0.01: BN = N: **Dropout = 0.4**: Params (Total/Trainable/Non-trainable)= 5,280,938 / 1,027,074 / 4,253,864: Train/Val/Test Acc = 78.3/79.1/76.5

# %% [markdown]
# ### Version 0.07

# %% [markdown]
# - **0.07** **ResNet50**
#   - As is rerun: Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: batch size = 10: Train/Val/Test Acc = 86.7/86.6/81.4
#   - Change **batch size** from 10 to 20: Train/Val/Test Acc = 91.2/83.7/78.9 ... reduces accuracy, so reverted to batch size of 10
#   - Implemented **Data Augmentation** with batch size of 10: Train/Val/Test Acc = 78.1/79.7/69.0 ...reduces accuracy, should we increase batch size?
#   - Implemented **Data Augmentation** with batch size of 100: Train/Val/Test Acc = 89.3/72.2/67.9 ...reduces accuracy, should we decrease batch size?
#   - Implemented **Data Augmentation** with batch size of 5: Train/Val/Test Acc = 58.3/48.4/48.1  ... reduces accuracy, reverted to batch size of 10, and no Data Augmentation
#   - Epoch=20: Adam(lr=0.01): Dropout(0.4): No BN: **batch size = 10**: **No DataAug**: Params (Total/Trainable/Non-trainable)= 25,687,938 / 2,100,226 / 23,587,712: Train/Val/Test Acc = 91.8/90.6/81.1

# %% [markdown]
# ### Version 0.06

# %% [markdown]
# - **0.06** **ResNet50**
#   - Before any modification: full rerun took ~15mins (most of it for loading train/val/test images/labels... and very less for model training/test)
#   - Before any modification: Train/Val/Test Acc = 53/51.1/51.3
#   - Changed model = Pre-trained ResNet50 + Modified FCN Layer
#     - SGD (LR=0.0001, M=0.9), Categorical Crossentropy
#     - 1st run: Train/Val/Test Acc = 57.5/72.7/67.1
#     - Converted ones/zeroes count to function
#     - Converted images/label prep to function
#     - Epoch=1: Train/Val/Test Acc = 61/67.9/67
#     - Epoch=5: Train/Val/Test Acc = 85.6/80.8/75.9
#     - Epoch=10: Train/Val/Test Acc = 93.0/85.6/77.7
#     - Epoch=20: Train/Val/Test Acc = 94.1/89.0/80.4
#     - Epoch=20: Changed loss function to 'binary crossentropy', reduced the accuracy: Train/Val/Test Acc = 90.2/84.0/77.7 Hence, reverted to categorical crossentropy as the loss function
#     - Epoch=20: Changed optimizer to Adam(lr=0.01), increased accuracy: Train/Val/Test Acc = 99.3/86.9/83.2
#     - In above training accuracy is high, validation and test accuracy is low ... it is overfitting ... let us implement Dropout
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): Train/Val/Test Acc = 93.0/88.8/82.1
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 90.8/89.8/83.4
#     - Epoch=20: Adam(lr=0.01): Dropout(0.5): Train/Val/Test Acc = 92.2/90.6/82.3 .. reverted to Dropout(0.4)
#     - Let us try Batch Normalization. ResNet50 -> Dense (1024) -> Batch Norm -> relu -> Dropout -> Dense(2,softmax)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): BN: Train/Val/Test Acc = 90.6/81.6/79.0 ... reduced accuracy
#     - Epoch=20: Adam(lr=0.01): Dropout(0.2): BN: Train/Val/Test Acc = 95.2/86.9/81.9 ... reduced accuracy will revert to no BN, Dropout(0.4)
#     - Epoch=20: Adam(lr=0.01): Dropout(0.4): Train/Val/Test Acc = 88.2/89.3/81.7

# %% [markdown]
# ### Version 0.01 - 0.05

# %% [markdown]
# - **0.05**: Migrate to Google Colab/Drive, changed loss function to 'binary_crossentropy', epochs to 1 : Train/Val/Test Acc = 55.7/55.9/55.2
# - **0.04**: Class Label Info in List was not accurate - fixed it. Now, Train/Validate/Test Accuracy is more realistic = ~55%
# - **0.03**: Tweak CNN model done for MNIST to work for this dataset to have a working end to end CNN model. Train/Validate/Test Accuracy = ~100%
# - **0.02**: Prepare Train/Validate/Test Labels and Images
# - **0.01**: Prepare Train/Validate/Test Images

# %% [markdown]
# ### References - Data Preparation

# %% [markdown]
# - Access Google Drive files from Google Colab
#   - https://www.youtube.com/watch?reload=9&v=lHRC5gFvQnA
# - Reading an image
#   - mathplotlib: https://stackoverflow.com/questions/9298665/cannot-import-scipy-misc-imread
#   - pathlib: https://medium.com/@ageitgey/python-3-quick-tip-the-easy-way-to-deal-with-file-paths-on-windows-mac-and-linux-11a072b58d5f#:~:text=To%20use%20it%2C%20you%20just,for%20the%20current%20operating%20system.
#   - OpenCV: https://www.geeksforgeeks.org/python-opencv-cv2-imread-method/
# - Load multiple images into a numpy array
#   - glob / os.listdir: https://stackoverflow.com/questions/39195113/how-to-load-multiple-images-in-a-numpy-array
#   - glob / cv2: https://medium.com/@muskulpesent/create-numpy-array-of-images-fecb4e514c4b
# - Load a CSV file
#   - Datacamp: https://www.datacamp.com/community/tutorials/pandas-read-csv?utm_source=adwords_ppc&utm_campaignid=1455363063&utm_adgroupid=65083631748&utm_device=c&utm_keyword=&utm_matchtype=b&utm_network=g&utm_adpostion=&utm_creative=278443377095&utm_targetid=dsa-429603003980&utm_loc_interest_ms=&utm_loc_physical_ms=9061994&gclid=EAIaIQobChMIz5TKz-v17QIV1AorCh0bfw96EAAYASAAEgKiGPD_BwE
# - Split a String
#   - Python Central: https://www.pythoncentral.io/cutting-and-slicing-strings-in-python/
# - Image Resize
#   - https://stackoverflow.com/questions/44650888/resize-an-image-without-distortion-opencv
#   - https://stackoverflow.com/questions/55571664/mobilenets-for-a-custom-image-size
# - Merge Train/Val/Test data
#   - Merge Dataframes
#     - https://pandas.pydata.org/pandas-docs/stable/user_guide/merging.html
#   - Merge and Split Dataframes
#     - https://datascience.stackexchange.com/questions/81617/how-to-combine-and-separate-test-and-train-data-for-data-cleaning
#   -

# %% [markdown]
# ### References - Model Definition

# %% [markdown]
# - ResNet50
#   - https://cv-tricks.com/keras/understand-implement-resnets/
#   - Finetuning ResNet50
#     - https://www.pyimagesearch.com/2020/04/27/fine-tuning-resnet-with-keras-tensorflow-and-deep-learning/
# - MobileNet
#   - https://deeplizard.com/learn/video/Zrt76AIbeh4
#   - https://towardsdatascience.com/exploring-mobilenets-from-paper-to-keras-f01308ada818
#   - Fine Tuning MobileNet - Last few layers trainable
#     - https://towardsdatascience.com/transfer-learning-using-mobilenet-and-keras-c75daf7ff299
#   - MobileNet Version:
#     - https://keras.io/api/applications/mobilenet/
# - SqueezeNet
#   - https://codelabs.developers.google.com/codelabs/keras-flowers-squeezenet#6

# %% [markdown]
# ### References - Model Validation

# %% [markdown]
# - Keras Optimizer / Adam
#   - https://keras.io/api/optimizers/
# - Regularizer
#   - https://keras.io/api/layers/regularizers/
# - Save Weights for Best Model
#   - https://medium.com/@italojs/saving-your-weights-for-each-epoch-keras-callbacks-b494d9648202
#   - Monitoring Validaiton Accuracy - Skipping Error Solution
#     - https://github.com/tensorflow/tensorflow/issues/33163
#   - Predict using saved model
#     - https://stackoverflow.com/questions/44259651/how-to-use-predefined-trained-hdf5-file-with-wights-to-predict-a-class-of-new
# - K-cross validation: https://medium.com/the-owl/k-fold-cross-validation-in-keras-3ec4a3a00538
#   - use non-categorical labels for k-cross validation splits: https://stackoverflow.com/questions/48508036/sklearn-stratifiedkfold-valueerror-supported-target-types-are-binary-mul
#   - https://machinelearningmastery.com/ : Deep Learning with Python Book
# - FLOPS calculation
#   - https://pypi.org/project/keras-flops/
#   - https://www.manongdao.com/article-1967231.html
# - Time calculation
#   - https://www.tutorialspoint.com/How-to-get-current-time-in-milliseconds-in-Python#:~:text=You%20can%20get%20the%20current,1000%20and%20round%20it%20off.

# %% [markdown]
# ### References - Model Conversion

# %% [markdown]
# - Convert to TensorFlowLite Model
#   - https://heartbeat.fritz.ai/image-recognition-for-android-with-a-custom-tensorflow-lite-model-6418186ecc0e
